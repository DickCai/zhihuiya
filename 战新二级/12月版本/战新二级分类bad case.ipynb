# %%
import pandas as pd
import os
os.chdir(r'D:\数据\全国数据\战兴分类\战新二级分类\11月版本')

# %% [markdown]
# # bad case

# %%
bad_case=pd.read_excel("战新二级分类bad_case.xlsx")
bad_case
# Out:
#                            company_id     company_name          SEIC2  \
# 0    5D05A2C5AF45E397CFF0FF451700A22D   平安医疗健康管理股份有限公司  互联网与云计算、大数据服务
# 1    009838EB734D51C01ABCF001483BCD0C   深圳市拥鲜园生鲜实业有限公司  互联网与云计算、大数据服务
# 2    38C6BAA4B15BF5C6B1A792F97514BC01  厦门斯坦道科学仪器股份有限公司         先进环保产业
# 3    015B867C22249E3A869BAE4F408B54A9       深圳触阁科技有限公司       生物医学工程产业
# 4    AF50A86C3B7F6A6530EC78E5F7731B0D    煤炭科学技术研究院有限公司       资源循环利用产业
# ..                                ...              ...            ...
# 186  012D0D709837F8334532357F5ED0F9F8     吉林华碳科技发展有限公司             其它
# 187  000FF2B5BB49D292FEEF0ADA09FB291F    固泰鑫科技（深圳）有限公司       资源循环利用产业
# 188  002CF09801B500EA4714D11F74528AB4     企服（北京）科技有限公司     新技术与创新创业服务
# 189  00079C0A250BF2AD57F70E632592ECEC       浙江美蜜科技有限公司             其它
# 190  0022A94ECE6848CDC69B30724572E933     江苏君晟家居科技有限公司             其它
#
#     tier2_validated seic_accuracy  \
# 0            生物医药产业             低
# 1         生物农业及相关产业             低
# ...

# %%
bad_case.drop_duplicates(subset=['tier2_validated'],inplace=True)

# %%
bad_case.to_excel('bad_case.xlsx',encoding='utf-8',index=False)
