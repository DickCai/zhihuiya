# %%
import pandas as pd
import os
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company',echo=False)
pd.set_option('max_rows',200)
pd.set_option('max_columns',200)
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
from data_nlp_nameclean.clean.cleaning import cleanup_entity
from sklearn.metrics import classification_report
import numpy as np

# %% [markdown]
# # china_company_seic_lv2_0210

# %%
china_company_seic_lv2_0210=pd.read_sql('select * from china_company_seic_lv2_0210',con=engine)

# %%
china_company_seic_lv2_0210
# Out:
#                              company_id         company_name       seic_lv2  \
# 0      03C365C65866DF757831F8BAC96013CB           嘉兴地星科技有限公司  互联网与云计算、大数据服务
# 1      0590AD64B241548B2CF3C9370178B3F1           杭州潮源机械有限公司       智能制造装备产业
# 2      05CB3FE1A4615DBED7BD0C466E8E128D          深圳卓熠科电子有限公司     数字创意技术设备制造
# 3      076438882F3B27C9B98CCE2D827ED92B           浙江小芃科技有限公司           人工智能
# 4      0994B3D9F4299185231C96BBD39FDA74        上海东富龙生物试剂有限公司         生物医药产业
# ...                                 ...                  ...            ...
# 31181  A8398B6E5E359379A3F3AA58E9CF7305    内蒙古自治区烟草公司呼伦贝尔市公司             其它
# 31182  5A55F3D9587E11E419A01C47C0AE21A1      内蒙古自治区烟草公司乌海市公司             其它
# 31183  24E6963EAD9619EC8AA68934967A1CBC         陕西省烟草公司渭南市公司             其它
# 31184  0FE8B560B158ADCA9EBC9B403DCDC164       杭州康诺柏奥生物科技有限公司         生物医药产业
# 31185  0F41FA18792B3FA49BF19944F3A7EF0C  成都海光集成电路设计有限公司苏州分公司         电子核心产业
#
#         seic_lv1 seic_accuracy
# ...

# %%
china_company_seic_lv2_0210['seic_accuracy'].value_counts()
# Out:
# 低     20509
# 中     10387
# 高       282
# 人工        8
# Name: seic_accuracy, dtype: int64

# %%
china_company_seic_lv2_0210[china_company_seic_lv2_0210['company_id']=='21CCBD1F7874ABC1FF39C185595E4D12']
# Out:
#                              company_id  company_name       seic_lv2  \
# 24147  21CCBD1F7874ABC1FF39C185595E4D12  武汉大根科技发展有限公司  互联网与云计算、大数据服务
#
#         seic_lv1 seic_accuracy
# 24147  新一代信息技术产业             中

# %% [markdown]
# # china_company_seic_lv2_1207_detail

# %%
china_company_seic_lv2_1207_detail=pd.read_csv('/Users/caicaiqijun/Downloads/战新分类.csv')

# %%
china_company_seic_lv2_1207_detail
# Out:
#                                company_id   company_name   seic_lv1  \
# 0        00105EE4AE3AEC6078368949244C28C8   烟台东德氢能技术有限公司      新能源产业
# 1        0042FB989592C5CFC972EB4B94327F85  广州艾士杰塑料制品有限公司      新材料产业
# 2        0048C0C9B8940FD61E7256932D2C723E    四川龙瑞微电子有限公司  新一代信息技术产业
# 3        0063A7B9544EDA361BB836EED4608E50  福建省金淮建筑设备有限公司     节能环保产业
# 4        00B19156605EDB043663EE99D3896179   深圳力合节能技术有限公司     节能环保产业
# ...                                   ...            ...        ...
# 1008336  8BD8BF75EE8ACDFE9549407977553427   广州洪辉五金弹簧有限公司   高端装备制造产业
# 1008337  8BE53C2A250153AEB3CA8A4185CFE2EB       绍兴市灵耐挂具厂         其它
# 1008338  8BEFD9E75004091B0CF38AAEB4A54B58   青岛派瑞精密工业有限公司   高端装备制造产业
# 1008339  8BF90480194839D35E3D3D9B1085AC3B   郑州创岛智能科技有限公司  新一代信息技术产业
# 1008340  8BFACEB4C54E804FCD7373299196D31D   深圳市朗科特电子有限公司     数字创意产业
#
#              seic_lv2 seic_accuracy
# 0        生物质能及其他新能源产业             中
# 1           先进石化化工新材料             高
# 2              电子核心产业             高
# ...

# %%
china_company_seic_lv2_1207_detail[china_company_seic_lv2_1207_detail['company_id']=='21CCBD1F7874ABC1FF39C185595E4D12']
# Out:
#                               company_id  company_name tier2_validated  \
# 838528  21CCBD1F7874ABC1FF39C185595E4D12  武汉大根科技发展有限公司   互联网与云计算、大数据服务
#
#        tier1_validated tier2_source           tier2_prob   patent_tier2  \
# 838528       新一代信息技术产业         bert  0.05515114963054657  互联网与云计算、大数据服务
#
#        patent_tier1 seic_accuracy description  \
# 838528    新一代信息技术产业             中        None
#
#                                            business_scope
# 838528  互联网接入及相关服务、物联网、网络设备及电子领域内的技术开发、技术咨询、技术转让；计算机网络...

# %% [markdown]
# # Compare

# %%
Compare=pd.merge(china_company_seic_lv2_0210,china_company_seic_lv2_1207_detail,on='company_id',how='left')

# %%
Compare['seic_accuracy']=np.where(Compare['seic_accuracy_x']==Compare['seic_accuracy_y'],1,0)

# %%
Compare['seic_accuracy'].value_counts()
# Out:
# 0    30547
# 1      639
# Name: seic_accuracy, dtype: int64

# %%
a=Compare[Compare['seic_accuracy']==0]

# %%
b=a[a['company_name_y'].notnull()]

# %%
b
# Out:
#                              company_id       company_name_x     seic_lv2_x  \
# 653    94F07EA3A9BA5BC6D39296CFFAB1452F       宁夏科锐达自动化设备有限公司         先进环保产业
# 1757   E5E23257E4F9FEFA1CBA5FE287EB19B5        江苏埃文斯智能科技有限公司       数字文化创意活动
# 2570   E185784DB8F09B181CFA3C5A0AA7D3A9        重庆华捷地热能开发有限公司         高效节能产业
# 3038   4D6844558540639B83CBD475FED09C3C         北京大成永盛科技有限公司      下一代信息网络产业
# 3381   9EB6A0891DA5E5288B813961408BB41B         南京天科仪器科技有限公司             其它
# 5291   8CC3EDBF63B71338ABDA011FA1872C51       北京世纪环宇安防装备有限公司  新兴软件和新型信息技术服务
# 5795   E7350F29C3CAD353FE1477CD37E6AF38         北京清鹏智能科技有限公司           人工智能
# 6824   3EA943B1EBB1E459DF74280CE6CE6F9C        山东蓝景膜技术工程有限公司      先进石化化工新材料
# 7892   161C2CB2E5B83E999B552AAC3B868601         成都泰和万钟科技有限公司     数字创意技术设备制造
# 8536   E9B6EF079F1AA8D69F9E7E9CF05CC315        常州唯精医疗机器人有限公司       生物医学工程产业
# 9468   DC932E5EE8C6C3F329478C2A1278846B         湖北建烯光暖科技有限公司         高效节能产业
# ...

# %%
b[b['seic_accuracy_x']=='低']
# Out:
#                              company_id    company_name_x     seic_lv2_x  \
# 2570   E185784DB8F09B181CFA3C5A0AA7D3A9     重庆华捷地热能开发有限公司         高效节能产业
# 5291   8CC3EDBF63B71338ABDA011FA1872C51    北京世纪环宇安防装备有限公司  新兴软件和新型信息技术服务
# 9468   DC932E5EE8C6C3F329478C2A1278846B      湖北建烯光暖科技有限公司         高效节能产业
# 11131  93AC2BDF9E523D92E1269241870025AC     杭州新期待电力科技有限公司         智能电网产业
# 11138  AACF4F538B24C557274CFFE1ABE8AFCE        招远中环科技有限公司         先进环保产业
# 12323  C5A06A220FEA4E48EEA75C1C5AB3AD9D      东莞宇隆电工材料有限公司         智能电网产业
# 12330  ED0BE17F94D2E7E234DF8C8B3578E8ED  苏州思萃同位素技术研究所有限公司         生物医药产业
# 12535  4F33AF28A0408670240D9A3679957733     广西鑫锋新能源科技有限公司       资源循环利用产业
# 14828  E0B21CA563A7CCCAAE0CC81E045A5E0E   东莞市巨人机械设备制造有限公司       智能制造装备产业
# 15709  A73ADD52ADE40C54AB9810EE0635769D       成都劢可为科技有限公司          前沿新材料
# 19412  8A525FF92C5DF8CD84CF863EEE74F134        山东中鲁水务有限公司             其它
# 19661  C9CA3577D716220FE7600A9A1F235429        南宁普传科技有限公司         高效节能产业
# ...

# %%
Compare[Compare['company_name_y'].notnull()]
# Out:
#                              company_id       company_name_x       seic_lv2  \
# 72     1CF51C0419814FC9FEAD3B788E91A9FD       国房宿（上海）新能源有限公司           风能产业
# 85     5877288F9AF7B59FFA42C2BA2AF2BA1E           十堰良凯工贸有限公司             其它
# 113    EA04C575E5DCF8F36416710FBE674E14          河南省荣全实业有限公司  新兴软件和新型信息技术服务
# 131    37434A17D55099A6B1C4007ACB6FDF74       桓德信息科技（上海）有限公司     新技术与创新创业服务
# 188    392815867246872DE86C5C34DEB8CEB2      内蒙古金鄂博氟化工有限责任公司      先进石化化工新材料
# ...                                 ...                  ...            ...
# 31066  0F3D517F8F30B804990A57891C8215EE       河北昕宇泽自动化设备有限公司             其它
# 31088  EE420CA797C6A7DADCE21FAD06F3923E         云南齐力建设集团有限公司             其它
# 31116  29F0C9BE160703FA7B739CC530E3DAB0         合肥润枝生态农业有限公司             其它
# 31184  0FE8B560B158ADCA9EBC9B403DCDC164       杭州康诺柏奥生物科技有限公司         生物医药产业
# 31185  0F41FA18792B3FA49BF19944F3A7EF0C  成都海光集成电路设计有限公司苏州分公司         电子核心产业
#
# ...

# %% [markdown]
# # add_desc

# %%
add_des=pd.read_json('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/2月数据/战新分类/add_desc.json',lines=True)

# %%
add_des
# Out:
#                            company_id  \
# 0    21CCBD1F7874ABC1FF39C185595E4D12
# 1    065191EAD032D419407F6EF702EABBA4
# 2    0F9029827A54A6220FA61D1A8282ADBC
# 3    DA94D74DAF0970DF74B2623B59260097
# 4    F5F1D34A9736BE4B084058F502B47FCE
# ..                                ...
# 701  83A9F261E457E6D646C8F53034A9A5DB
# 702  267B69EECA174C0FF00321C6D3BA7982
# 703  B35253622E9FFF51E7D91E755DE02CA9
# 704  B56374348C2F5DF374F58F54555A37B7
# 705  38BF76154F1EA1BDC69CCA8BD010140F
#
#                                            description              updated_at
# 0    武汉大根科技发展有限公司，是一家专注于云计算、大数据、人工智能领域的综合性服务公司，在行业内... 2022-02-07 07:56:11.164
# 1    郑州胜今耐磨科技有限公司是一家集科、工、贸为一体的股份制企业，坐落于美丽的黄帝故里新郑，专业... 2022-02-07 07:56:14.340
# 2    福建贵合源建设有限公司成立于2017年6月，为建筑施工企业，公司注册资本1000万元，具有较... 2022-02-07 07:56:57.288
# 3    公司概况厦门海川润泽物联网科技有限公司是物联网产品及技术解决方案提供商。公司集产品研发、销售... 2022-02-07 07:56:58.474
# 4    公司简介浙江引领电气有限公司位于浙江省乐清市经济开发区，交通便利、环境优雅。注册资金1000... 2022-02-07 07:57:00.194
# ...

# %%
add_des[add_des['company_id']=='0F41FA18792B3FA49BF19944F3A7EF0C']
# Out:
#                            company_id  \
# 462  0F41FA18792B3FA49BF19944F3A7EF0C
#
#                                            description              updated_at
# 462  海光集成电路设计有限公司苏州分公司是海光集成电路设计有限公司在苏州设立的分公司。海光集成电路... 2022-02-07 15:07:46.476
