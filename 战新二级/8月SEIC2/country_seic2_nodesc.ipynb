# %%
import pandas as pd
import os
os.chdir('D:\数据\全国数据\战兴分类\战新二级分类\country_0818')
from sqlalchemy import create_engine
from sklearn.metrics import classification_report
pd.set_option('max_rows',100)
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company',echo=False)

# %% [markdown]
# # tier_mapping

# %%
tier_mapping=pd.read_excel(r'D:\数据\全国数据\战兴分类\战新二级分类\tier_mapping.xlsx')
tier_mapping
# Out:
#     code_tier1           name  code_tier2
# 0          1.0      新一代信息技术产业         NaN
# 1          2.0       高端装备制造产业         NaN
# 2          3.0          新材料产业         NaN
# 3          4.0           生物产业         NaN
# 4          5.0        新能源汽车产业         NaN
# 5          6.0          新能源产业         NaN
# 6          7.0         节能环保产业         NaN
# 7          8.0         数字创意产业         NaN
# 8          9.0          相关服务业         NaN
# 9         -1.0             其它         NaN
# 10         NaN      下一代信息网络产业         1.1
# 11         NaN         电子核心产业         1.2
# 12         NaN  新兴软件和新型信息技术服务         1.3
# 13         NaN  互联网与云计算、大数据服务         1.4
# 14         NaN           人工智能         1.5
# 15         NaN       智能制造装备产业         2.1
# 16         NaN         航空装备产业         2.2
# 17         NaN        卫星及应用产业         2.3
# 18         NaN       轨道交通装备产业         2.4
# 19         NaN       海洋工程装备产业         2.5
# 20         NaN         先进钢铁材料         3.1
# 21         NaN       先进有色金属材料         3.2
# 22         NaN      先进石化化工新材料         3.3
# 23         NaN      先进无机非金属材料         3.4
# 24         NaN  高性能纤维及制品和复合材料         3.5
# 25         NaN          前沿新材料         3.6
# 26         NaN        新材料相关服务         3.7
# 27         NaN         生物医药产业         4.1
# 28         NaN       生物医学工程产业         4.2
# 29         NaN      生物农业及相关产业         4.3
# 30         NaN         生物质能产业         4.4
# 31         NaN          其他生物业         4.5
# 32         NaN      新能源汽车整车制造         5.1
# 33         NaN   新能源汽车装置、配件制造         5.2
# 34         NaN    新能源汽车相关设施制造         5.3
# 35         NaN      新能源汽车相关服务         5.4
# 36         NaN           核电产业         6.1
# 37         NaN           风能产业         6.2
# 38         NaN          太阳能产业         6.3
# 39         NaN   生物质能及其他新能源产业         6.4
# 40         NaN         智能电网产业         6.5
# 41         NaN         高效节能产业         7.1
# 42         NaN         先进环保产业         7.2
# 43         NaN       资源循环利用产业         7.3
# 44         NaN     数字创意技术设备制造         8.1
# 45         NaN       数字文化创意活动         8.2
# 46         NaN           设计服务         8.3
# 47         NaN      数字创意与融合服务         8.4
# 48         NaN     新技术与创新创业服务         9.1
# 49         NaN         其他相关服务         9.2
# 50         NaN             其它        -1.0

# %% [markdown]
# # compare

# %% [markdown]
# ## 全国数据战新二级分类

# %%
china_company_seic_lv2=pd.read_sql('select * FROM  company.china_company_seic_lv2',con=engine)
china_company_seic_lv2=china_company_seic_lv2[['company_id','seic_lv2']]
china_company_seic_lv2
# Out:
#                               company_id       seic_lv2
# 0       00001FF532C2D92470F99149D48C7820  新兴软件和新型信息技术服务
# 1       00002B5B4529376232011C86E1A588FF      先进无机非金属材料
# 2       00003DFB06D095BD2D6DE4A828C6CB5C       智能制造装备产业
# 3       00003E68CDE39A6DA970E85788FDB98D         先进环保产业
# 4       00003FCBDCE7E5340E6603C08DD6291A       智能制造装备产业
# ...                                  ...            ...
# 804431  FFFF8F3880B931A0EFC5A9BDAB9888B9  互联网与云计算、大数据服务
# 804432  FFFF9B34AD5B60CECBF0DA6C52F3B0F1       生物医学工程产业
# 804433  FFFFCFE0644923912519B1A1034E5E8D       数字文化创意活动
# 804434  FFFFE42F6484FEC563A1C55993BE494C             其它
# 804435  FFFFF51AB69F00656AE94BC3C57CC8D2         生物医药产业
#
# [804436 rows x 2 columns]

# %%
Company_nodesc=pd.read_excel('全国数据没有简介的公司.xlsx')
Company_nodesc
# Out:
#                            company_id       company_name       SEIC2
# 0    14CF94A2FC9A8355FF718447C59D5141       江苏德普检测技术有限公司          其它
# 1    1EE39C18BE31DE2F55CF13563265D2EF       苏州赤兔文化传媒有限公司    数字文化创意活动
# 2    1C5B94E0A285D62C3D6F082A23420645     常熟中信金桥科技服务有限公司  新技术与创新创业服务
# 3    24AFE59581F6B314CF6FA34752468487       昆山明创电子科技有限公司      先进钢铁材料
# 4    0B2BA507066E518AD0F25F55E43E86D3     派珂纳米科技（苏州）有限公司       前沿新材料
# ..                                ...                ...         ...
# 629  5C3E3DF212E9A7DBD2F4095F3FCBF7EC    国电电力宁夏新能源开发有限公司        风能产业
# 630  A50811AD4CF164F847D71B4F1A5DB2EA   辽宁中能电力实业集团有限责任公司        风能产业
# 631  1B05DB06619CAFD985CA13B8C3C7ACC8        兴安盟大金重工有限公司        风能产业
# 632  94E1D0D9242C4A4CCFD63A2F4FC702E2        江苏广恒新能源有限公司        风能产业
# 633  74BD4029A4420500254D7364C9B25259  中船重工海为（新疆）新能源有限公司        风能产业
#
# [634 rows x 3 columns]

# %%
Compare=pd.merge(Company_nodesc,china_company_seic_lv2,how='left',on='company_id')
Compare
# Out:
#                            company_id       company_name       SEIC2  \
# 0    14CF94A2FC9A8355FF718447C59D5141       江苏德普检测技术有限公司          其它
# 1    1EE39C18BE31DE2F55CF13563265D2EF       苏州赤兔文化传媒有限公司    数字文化创意活动
# 2    1C5B94E0A285D62C3D6F082A23420645     常熟中信金桥科技服务有限公司  新技术与创新创业服务
# 3    24AFE59581F6B314CF6FA34752468487       昆山明创电子科技有限公司      先进钢铁材料
# 4    0B2BA507066E518AD0F25F55E43E86D3     派珂纳米科技（苏州）有限公司       前沿新材料
# ..                                ...                ...         ...
# 629  5C3E3DF212E9A7DBD2F4095F3FCBF7EC    国电电力宁夏新能源开发有限公司        风能产业
# 630  A50811AD4CF164F847D71B4F1A5DB2EA   辽宁中能电力实业集团有限责任公司        风能产业
# 631  1B05DB06619CAFD985CA13B8C3C7ACC8        兴安盟大金重工有限公司        风能产业
# 632  94E1D0D9242C4A4CCFD63A2F4FC702E2        江苏广恒新能源有限公司        风能产业
# 633  74BD4029A4420500254D7364C9B25259  中船重工海为（新疆）新能源有限公司        风能产业
#
#        seic_lv2
# 0            其它
# 1      数字文化创意活动
# 2    新技术与创新创业服务
# 3        电子核心产业
# 4         前沿新材料
# ..          ...
# 629        风能产业
# 630        风能产业
# 631        风能产业
# 632        风能产业
# 633        风能产业
#
# [634 rows x 4 columns]

# %%
Compare['change']=Compare.apply(
    lambda ele: (ele['seic_lv2'] if (ele['seic_lv2'] in ele['SEIC2']) else ele['SEIC2'].split(",")[0].replace("[", "")) 
    if ("," in ele['SEIC2']) 
    else ele['SEIC2'],axis=1)

# %%
Compare
# Out:
#                            company_id       company_name       SEIC2  \
# 0    14CF94A2FC9A8355FF718447C59D5141       江苏德普检测技术有限公司          其它
# 1    1EE39C18BE31DE2F55CF13563265D2EF       苏州赤兔文化传媒有限公司    数字文化创意活动
# 2    1C5B94E0A285D62C3D6F082A23420645     常熟中信金桥科技服务有限公司  新技术与创新创业服务
# 3    24AFE59581F6B314CF6FA34752468487       昆山明创电子科技有限公司      先进钢铁材料
# 4    0B2BA507066E518AD0F25F55E43E86D3     派珂纳米科技（苏州）有限公司       前沿新材料
# ..                                ...                ...         ...
# 629  5C3E3DF212E9A7DBD2F4095F3FCBF7EC    国电电力宁夏新能源开发有限公司        风能产业
# 630  A50811AD4CF164F847D71B4F1A5DB2EA   辽宁中能电力实业集团有限责任公司        风能产业
# 631  1B05DB06619CAFD985CA13B8C3C7ACC8        兴安盟大金重工有限公司        风能产业
# 632  94E1D0D9242C4A4CCFD63A2F4FC702E2        江苏广恒新能源有限公司        风能产业
# 633  74BD4029A4420500254D7364C9B25259  中船重工海为（新疆）新能源有限公司        风能产业
#
#        seic_lv2      change
# 0            其它          其它
# 1      数字文化创意活动    数字文化创意活动
# 2    新技术与创新创业服务  新技术与创新创业服务
# 3        电子核心产业      先进钢铁材料
# 4         前沿新材料       前沿新材料
# ..          ...         ...
# 629        风能产业        风能产业
# 630        风能产业        风能产业
# 631        风能产业        风能产业
# 632        风能产业        风能产业
# 633        风能产业        风能产业
#
# [634 rows x 5 columns]

# %%
ttl_names = list(set(Compare['change'].drop_duplicates().tolist() + Compare['seic_lv2'].drop_duplicates().tolist()))
dict_target_names = dict(zip(ttl_names, range(len(ttl_names))))
dict_target_names
# Out:
# {'先进有色金属材料': 0,
#  '核电产业': 1,
#  '其他相关服务': 2,
#  '先进环保产业': 3,
#  '数字创意与融合服务': 4,
#  '人工智能': 5,
#  '轨道交通装备产业': 6,
#  '新能源汽车装置、配件制造': 7,
#  '先进钢铁材料': 8,
#  '生物质能及其他新能源产业': 9,
#  '生物质能产业': 10,
#  '太阳能产业': 11,
#  '海洋工程装备产业': 12,
#  '生物农业及相关产业': 13,
#  '其它': 14,
#  '设计服务': 15,
#  '前沿新材料': 16,
#  '生物医学工程产业': 17,
#  '数字文化创意活动': 18,
#  '智能制造装备产业': 19,
#  '数字创意技术设备制造': 20,
#  '互联网与云计算、大数据服务': 21,
#  '新能源汽车相关设施制造': 22,
#  '新材料相关服务': 23,
#  '新能源汽车相关服务': 24,
#  '先进无机非金属材料': 25,
#  '风能产业': 26,
#  '高性能纤维及制品和复合材料': 27,
#  '航空装备产业': 28,
#  '卫星及应用产业': 29,
#  '高效节能产业': 30,
#  '资源循环利用产业': 31,
#  '智能电网产业': 32,
#  '下一代信息网络产业': 33,
#  '新能源汽车整车制造': 34,
#  '新技术与创新创业服务': 35,
#  '其他生物业': 36,
#  '先进石化化工新材料': 37,
#  '新兴软件和新型信息技术服务': 38,
#  '生物医药产业': 39,
#  '电子核心产业': 40}

# %%
Compare.to_excel('Compare_nodesc.xlsx',encoding='utf-8',index=False)

# %%
Compare[Compare['SEIC2']=='其它'].sample(100)
# Out:
#                            company_id       company_name SEIC2       seic_lv2  \
# 385  DD305C3A88F362B6FB009C06D012E5DB        佛山市猛进科技有限公司    其它     新技术与创新创业服务
# 215  6AF429C89670018839BAECF2D6D655D4    安庆金辉煌电子科技股份有限公司    其它             其它
# 47   6EE3946D8140C3193CE90D6FBCEB6B23     张家港科伦斯汽车配件有限公司    其它             其它
# 366  06106147C90C344AD044EB7606F1E1DD         厦门上孚集团有限公司    其它           人工智能
# 402  AFC09B732C00921DC3D7E8B97EB43B5F     苏州欣为亮科电子科技有限公司    其它         电子核心产业
# 437  A3D7C219AA76E5524C163ADEEFB141F5         河北骄阳焊工有限公司    其它       智能制造装备产业
# 371  4580CC2E9D4C4A06CDF66290BFA29725     单导科技发展（广州）有限公司    其它          前沿新材料
# 525  59938E79F53884D2EE593F3EB7550577       东莞永华海棉制品有限公司    其它  高性能纤维及制品和复合材料
# 381  4FA467E0BD197BC34BEF0BCCE1A69557  南京民生源人防工程防护设备有限公司    其它             其它
# 290  BAFD6A1410EB03BAC294652EE586B510         浙江地球管业有限公司    其它             其它
# 220  E488D44D60804DED294B210897D430FE      安徽胜华波汽车电器有限公司    其它             其它
# 256  80A73F173198B84302EE083B991F7112         盐城麦宝卫浴有限公司    其它             其它
# 255  8ECEB5DB09E4D532771AC9FD1FFCD003     盛世瑶兰（深圳）科技有限公司    其它             其它
# 205  7314FE641946CB50EF5533F1DC78B914       上海上安机械施工有限公司    其它             其它
# 7    6FDEF83A58DBE1FBADAA3FBBAEABF4EC    帕玛自动化科技（苏州）有限公司    其它       智能制造装备产业
# 490  E39034BF4BC75B12F405903AE3219337    河南金佰利警用装备科技有限公司    其它         航空装备产业
# 15   0FB06A0D3B9A48B64FF496ACF8EA9B39       苏州星波动力科技有限公司    其它         航空装备产业
# 367  69B938132C7C135CA7CCE0B748135D21     深圳市智恩自动化科技有限公司    其它       智能制造装备产业
# 281  85047F9FBCF16E4AF9D22B664FDDC938    成都市成华区闵绕幕商贸有限公司    其它             其它
# 579  37C9DF89F6C43E3F0587C4D478173C6E    克劳斯智能科技（北京）有限公司    其它           人工智能
# 473  5B934F175A3A451245F433649B7A61BD       北京中航星通科技有限公司    其它        卫星及应用产业
# 395  45D3D65BB8FFA149DDCB03BB8521D2CB     攀枝花市汇杰工贸有限责任公司    其它         先进钢铁材料
# 218  8837D193AA7228FF0775C9E48E00D067    四川福安龙专用汽车科技有限公司    其它             其它
# 232  A2FAAD9D3DD7D7F0332A65C318356F8E       安徽宜民服饰股份有限公司    其它             其它
# 0    14CF94A2FC9A8355FF718447C59D5141       江苏德普检测技术有限公司    其它             其它
# 516  3BF9EB1520CA7C202BA0F152193FCD7C     青岛歌尔微电子研究院有限公司    其它         电子核心产业
# 589  038CAE4CECB466FB20BD8682E29EDE59     广东创基包装印刷科技有限公司    其它     数字创意技术设备制造
# 517  757ABE63D6AB34A820BFE6AD16B84ACF       北京锐学网络科技有限公司    其它       数字文化创意活动
# 272  B82E9703DF14A78EAA3EDC299A3247FC       黑龙江海之华化工有限公司    其它      先进石化化工新材料
# 572  AFA8BD8BE9148CABEE2BE63D79B895BC         浙江富邦阀门有限公司    其它           核电产业
# 166  A39799DECCA9101133DC1B74055C796F       无锡星友包装材料有限公司    其它             其它
# 500  39BFB4833BD6B3DA60CFB35D3A24EA75      四会市得盈五金制品有限公司    其它       先进有色金属材料
# 273  B40B65A69F689D64D5448DA9A523B7CA       珠海盾安热工科技有限公司    其它             其它
# 376  9197EB5D0BB6F044D77F3092C60FD256     中国电建集团河北工程有限公司    其它             其它
# 158  62F27E0D6F012FADF2A9FBAC575F14B6         江阴瑞江服饰有限公司    其它             其它
# 341  694B458F131F980513C31912C7BECE97         济宁任兴水产有限公司    其它      生物农业及相关产业
# 258  2E50D683FAE667BEF548A4C09BFADE18         上海鹿卢实业有限公司    其它  互联网与云计算、大数据服务
# 565  51800258F0374659DAB6E20D0B3DDACE       江苏劲桩基础工程有限公司    其它     新技术与创新创业服务
# 51   2C2BF5D20917D28A45470C4F5840A998   伊卡路斯（苏州）车辆系统有限公司    其它             其它
# 491  312EA3D7C508DDDF39AD399BB0D7E9A5       四川信诺天箭科技有限公司    其它         航空装备产业
# 581  ACFD410B3658C962B264280EB7C2A5B5       宁波道康智能科技有限公司    其它           人工智能
# 207  483A1D68517132E71DCEE02C0AF4644D       四川久益钢制设备有限公司    其它             其它
#
#     change
# 385     其它
# 215     其它
# 47      其它
# 366     其它
# 402     其它
# 437     其它
# 371     其它
# 525     其它
# 381     其它
# 290     其它
# 220     其它
# 256     其它
# 255     其它
# 205     其它
# 7       其它
# 490     其它
# 15      其它
# 367     其它
# 281     其它
# 579     其它
# 473     其它
# 395     其它
# 218     其它
# 250     其它
# 368     其它
# 275     其它
# 291     其它
# 420     其它
# 458     其它
# 418     其它
# 154     其它
# 441     其它
# 464     其它
# 503     其它
# 604     其它
# 335     其它
# 236     其它
# 252     其它
# 248     其它
# 571     其它
# 191     其它
# 120     其它
# 225     其它
# 262     其它
# 139     其它
# 187     其它
# 450     其它
# 269     其它
# 153     其它
# 200     其它
# 345     其它
# 138     其它
# 468     其它
# 242     其它
# 414     其它
# 217     其它
# 513     其它
# 25      其它
# 170     其它
# 454     其它
# 353     其它
# 61      其它
# 285     其它
# 425     其它
# 336     其它
# 347     其它
# 102     其它
# 507     其它
# 295     其它
# 155     其它
# 421     其它
# 307     其它
# 539     其它
# 492     其它
# 363     其它
# 310     其它
# 508     其它
# 267     其它
# 485     其它
# 499     其它
# 590     其它
# 232     其它
# 0       其它
# 516     其它
# 589     其它
# 517     其它
# 272     其它
# 572     其它
# 166     其它
# 500     其它
# 273     其它
# 376     其它
# 158     其它
# 341     其它
# 258     其它
# 565     其它
# 51      其它
# 491     其它
# 581     其它
# 207     其它

# %%
merged_SEIC2=Compare

# %% [markdown]
# # SEIC2

# %%
import warnings
warnings.filterwarnings('ignore')
merged_SEIC2['y_true'] = merged_SEIC2['change'].map(lambda x: dict_target_names[x])
merged_SEIC2['y_pred'] = merged_SEIC2['seic_lv2'].map(lambda x: dict_target_names[x])
perform = pd.DataFrame(classification_report(merged_SEIC2['y_true'].tolist(), merged_SEIC2['y_pred'].tolist(), target_names=dict_target_names.keys(), output_dict = 'dict')).transpose()
perform.sort_values('f1-score', ascending = False)
# Out:
#                precision    recall  f1-score     support
# 风能产业            1.000000  1.000000  1.000000   10.000000
# 新材料相关服务         0.900000  1.000000  0.947368    9.000000
# 卫星及应用产业         0.833333  1.000000  0.909091   10.000000
# 太阳能产业           0.750000  1.000000  0.857143   12.000000
# 设计服务            1.000000  0.666667  0.800000    6.000000
# 数字创意技术设备制造      0.666667  1.000000  0.800000    4.000000
# 先进环保产业          0.750000  0.857143  0.800000   28.000000
# 生物医学工程产业        1.000000  0.642857  0.782609   14.000000
# 新能源汽车相关服务       0.600000  1.000000  0.750000    3.000000
# 生物医药产业          0.578947  1.000000  0.733333   11.000000
# 资源循环利用产业        0.666667  0.800000  0.727273    5.000000
# 新能源汽车整车制造       0.555556  1.000000  0.714286    5.000000
# 前沿新材料           0.545455  1.000000  0.705882    6.000000
# 新兴软件和新型信息技术服务   0.565217  0.928571  0.702703   14.000000
# 高性能纤维及制品和复合材料   0.666667  0.727273  0.695652   11.000000
# 海洋工程装备产业        0.571429  0.888889  0.695652    9.000000
# 智能电网产业          0.588235  0.769231  0.666667   13.000000
# 电子核心产业          0.482759  1.000000  0.651163   14.000000
# 生物质能产业          0.538462  0.777778  0.636364    9.000000
# 数字创意与融合服务       0.466667  1.000000  0.636364    7.000000
# 新能源汽车装置、配件制造    0.750000  0.500000  0.600000    6.000000
# 互联网与云计算、大数据服务   0.600000  0.600000  0.600000   15.000000
# accuracy        0.580442  0.580442  0.580442    0.580442
# macro avg       0.523123  0.713370  0.572385  634.000000
# 智能制造装备产业        0.450980  0.766667  0.567901   30.000000
# weighted avg    0.716845  0.580442  0.567313  634.000000
# 先进有色金属材料        0.437500  0.777778  0.560000    9.000000
# 先进钢铁材料          0.444444  0.727273  0.551724   11.000000
# 航空装备产业          0.375000  1.000000  0.545455    6.000000
# 先进石化化工新材料       0.470588  0.615385  0.533333   13.000000
# 轨道交通装备产业        0.363636  0.800000  0.500000    5.000000
# 新能源汽车相关设施制造     0.500000  0.500000  0.500000    4.000000
# 数字文化创意活动        0.333333  1.000000  0.500000    3.000000
# 生物农业及相关产业       0.333333  0.909091  0.487805   11.000000
# 其它              0.900000  0.323741  0.476190  278.000000
# 先进无机非金属材料       0.384615  0.555556  0.454545    9.000000
# 高效节能产业          0.500000  0.400000  0.444444    5.000000
# 下一代信息网络产业       0.500000  0.250000  0.333333    8.000000
# 人工智能            0.200000  0.750000  0.315789    4.000000
# 新技术与创新创业服务      0.178571  0.714286  0.285714    7.000000
# 其他生物业           0.000000  0.000000  0.000000    5.000000
# 生物质能及其他新能源产业    0.000000  0.000000  0.000000    1.000000
# 核电产业            0.000000  0.000000  0.000000    1.000000
# 其他相关服务          0.000000  0.000000  0.000000    3.000000

# %% [markdown]
# # SEIC1

# %%
rst_tier1 = pd.merge(merged_SEIC2[['company_id','company_name','seic_lv2']], tier_mapping[['code_tier2', 'name']].dropna(), left_on = 'seic_lv2', right_on = 'name', how = 'left')
rst_tier1['code_tier1'] = rst_tier1['code_tier2'].map(lambda ele: int(str(ele).split(".")[0]))
rst_tier1 = pd.merge(rst_tier1, tier_mapping[['code_tier1', 'name']].dropna(), on = 'code_tier1', how = 'left')
rst_tier1 = rst_tier1[['company_id', 'name_y']].rename({'name_y': 'tier1'}, axis = 1)

# %%
test_tier1 = pd.merge(merged_SEIC2[['company_id','change']], tier_mapping[['code_tier2', 'name']].dropna(), left_on = 'change', right_on = 'name', how = 'left')
test_tier1['code_tier1'] = test_tier1['code_tier2'].map(lambda ele: int(str(ele).split(".")[0]))
test_tier1 = pd.merge(test_tier1, tier_mapping[['code_tier1', 'name']].dropna(), on = 'code_tier1', how = 'left')
test_tier1 = test_tier1[['company_id', 'name_y']].rename({'name_y': 'seic1'}, axis = 1)

# %%
merged_tier1 = pd.merge(rst_tier1, test_tier1, on = 'company_id', how = 'left')
ttl_names = list(set(merged_tier1['seic1'].drop_duplicates().tolist() + merged_tier1['tier1'].drop_duplicates().tolist()))
dict_target_names = dict(zip(ttl_names, range(len(ttl_names))))
dict_target_names
merged_tier1['y_true'] = merged_tier1['seic1'].map(lambda ele: dict_target_names[ele])
merged_tier1['y_pred'] = merged_tier1['tier1'].map(lambda ele: dict_target_names[ele])
perform_tier1 = pd.DataFrame(classification_report(merged_tier1['y_true'].tolist(), merged_tier1['y_pred'].tolist(), target_names=dict_target_names.keys(), output_dict = 'dict')).transpose()
perform_tier1.sort_values('f1-score', ascending = False)
# Out:
#               precision    recall  f1-score     support
# 新能源汽车产业        0.818182  1.000000  0.900000   18.000000
# 新能源产业          0.708333  0.918919  0.800000   37.000000
# 节能环保产业         0.761905  0.842105  0.800000   38.000000
# 生物产业           0.638889  0.920000  0.754098   50.000000
# 数字创意产业         0.588235  1.000000  0.740741   20.000000
# 新一代信息技术产业      0.581395  0.909091  0.709220   55.000000
# 新材料产业          0.587629  0.838235  0.690909   68.000000
# macro avg      0.625698  0.811876  0.676172  634.000000
# accuracy       0.637224  0.637224  0.637224    0.637224
# 高端装备制造产业       0.500000  0.866667  0.634146   60.000000
# weighted avg   0.737314  0.637224  0.611518  634.000000
# 其它             0.900000  0.323741  0.476190  278.000000
# 相关服务业          0.172414  0.500000  0.256410   10.000000
