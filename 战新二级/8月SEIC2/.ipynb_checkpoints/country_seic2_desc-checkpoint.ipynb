# %%
import pandas as pd
import os
os.chdir('D:\数据\全国数据\战兴分类\战新二级分类\country_0818')

# %% [markdown]
# # tier_mapping

# %%
tier_mapping=pd.read_excel(r'D:\数据\全国数据\战兴分类\战新二级分类\tier_mapping.xlsx')
tier_mapping
# Out:
#     code_tier1           name  code_tier2
# 0          1.0      新一代信息技术产业         NaN
# 1          2.0       高端装备制造产业         NaN
# 2          3.0          新材料产业         NaN
# 3          4.0           生物产业         NaN
# 4          5.0        新能源汽车产业         NaN
# 5          6.0          新能源产业         NaN
# 6          7.0         节能环保产业         NaN
# 7          8.0         数字创意产业         NaN
# 8          9.0          相关服务业         NaN
# 9         -1.0             其它         NaN
# 10         NaN      下一代信息网络产业         1.1
# 11         NaN         电子核心产业         1.2
# 12         NaN  新兴软件和新型信息技术服务         1.3
# 13         NaN  互联网与云计算、大数据服务         1.4
# 14         NaN           人工智能         1.5
# 15         NaN       智能制造装备产业         2.1
# 16         NaN         航空装备产业         2.2
# 17         NaN        卫星及应用产业         2.3
# 18         NaN       轨道交通装备产业         2.4
# 19         NaN       海洋工程装备产业         2.5
# 20         NaN         先进钢铁材料         3.1
# 21         NaN       先进有色金属材料         3.2
# 22         NaN      先进石化化工新材料         3.3
# 23         NaN      先进无机非金属材料         3.4
# 24         NaN  高性能纤维及制品和复合材料         3.5
# 25         NaN          前沿新材料         3.6
# 26         NaN        新材料相关服务         3.7
# 27         NaN         生物医药产业         4.1
# 28         NaN       生物医学工程产业         4.2
# 29         NaN      生物农业及相关产业         4.3
# 30         NaN         生物质能产业         4.4
# 31         NaN          其他生物业         4.5
# 32         NaN      新能源汽车整车制造         5.1
# 33         NaN   新能源汽车装置、配件制造         5.2
# 34         NaN    新能源汽车相关设施制造         5.3
# 35         NaN      新能源汽车相关服务         5.4
# 36         NaN           核电产业         6.1
# 37         NaN           风能产业         6.2
# 38         NaN          太阳能产业         6.3
# 39         NaN   生物质能及其他新能源产业         6.4
# 40         NaN         智能电网产业         6.5
# 41         NaN         高效节能产业         7.1
# 42         NaN         先进环保产业         7.2
# 43         NaN       资源循环利用产业         7.3
# 44         NaN     数字创意技术设备制造         8.1
# 45         NaN       数字文化创意活动         8.2
# 46         NaN           设计服务         8.3
# 47         NaN      数字创意与融合服务         8.4
# 48         NaN     新技术与创新创业服务         9.1
# 49         NaN         其他相关服务         9.2
# 50         NaN             其它        -1.0

# %% [markdown]
# # compare

# %%
Company_desc=pd.read_excel('全国数据含有简介的公司.xlsx')
merged_SEIC2
# Out:
#                             company_id      company_name          SEIC2
# 0     5D05A2C5AF45E397CFF0FF451700A22D    平安医疗健康管理股份有限公司         其他相关服务
# 1     00FCB9092015A0642940DF8E82F1B8DD    西门子（深圳）磁共振有限公司       生物医学工程产业
# 2     E54E29095C21F113F67A38FB3EB28BA6    杭州海兴电力科技股份有限公司         智能电网产业
# 3     D1CEA95D3707DE01E015646B9AE91E5E    华道数据处理（苏州）有限公司  互联网与云计算、大数据服务
# 4     979E7A8A019A5DC84632A3C6CADC1997      苏州盛派网络科技有限公司  新兴软件和新型信息技术服务
# ...                                ...               ...            ...
# 1033  9EF91129FEDE90D3F6FB84B8ADDF4E49   苏州一柒艺匠供应链管理有限公司             其它
# 1034  706CE1EA4FB5D07B28C7EFD068A3ABA6        今创集团股份有限公司       轨道交通装备产业
# 1035  703193AC92CE6A251F761B8EB84961D9      深圳丹邦科技股份有限公司         电子核心产业
# 1036  CE75ADDD2DC35CC56C53094810AD105A    北京中科晶上科技股份有限公司         电子核心产业
# 1037  BCAA825DAB6C8738DACCEAC4259706A3  北京阳光诺和药物研究股份有限公司         生物医药产业
#
# [1038 rows x 3 columns]

# %%
compare['change']=compare.apply(
    lambda ele: (ele['tier2'] if (ele['tier2'] in ele['SEIC2']) else ele['SEIC2'].split(",")[0].replace("[", "")) 
    if ("," in ele['SEIC2']) 
    else ele['SEIC2'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5ff5e5a15078> in <module>
# ----> 1 compare['change']=compare.apply(
#       2     lambda ele: (ele['tier2'] if (ele['tier2'] in ele['SEIC2']) else ele['SEIC2'].split(",")[0].replace("[", ""))
#       3     if ("," in ele['SEIC2'])
#       4     else ele['SEIC2'],axis=1)
#
# NameError: name 'compare' is not defined

# %%
compare
# Out:
#                            company_id          SEIC2    company_name  \
# 0    D4A0B99B510F4DD3A4958677CC6E4EA3  新兴软件和新型信息技术服务   奇安信科技集团股份有限公司
# 1    4EAF90A74ADB4BA77FDA6E64285F192B  互联网与云计算、大数据服务     优刻得科技股份有限公司
# 2    E1FCB80A311330E77AD192A015278BEC         电子核心产业    深圳光峰科技股份有限公司
# 3    2707E15C84151C5CCB0F4D288E17DDF8      下一代信息网络产业  科大国盾量子技术股份有限公司
# 4    1E0621610D0AA17006384ED5BF5D30B8           人工智能      虹软科技股份有限公司
# ..                                ...            ...             ...
# 686  3A4867D7C787F397C34187D9383FDC9C         先进钢铁材料    智房工业科技股份有限公司
# 687  24D7B73567B677FB979F1466AE22827B         先进钢铁材料      江苏荣程锻造有限公司
# 688  F510D88638CB6EB0CAE3DC866F6F7973         先进钢铁材料    合肥紫金钢管股份有限公司
# 689  EB26F560066147F452315DA59301DFA7         先进钢铁材料   青州惠泽新材料科技有限公司
# 690  E2BC19143ACBEC9C8701FFF5CB93C24F         先进钢铁材料      南京钢铁联合有限公司
#
#              tier2         change
# 0    新兴软件和新型信息技术服务  新兴软件和新型信息技术服务
# 1    互联网与云计算、大数据服务  互联网与云计算、大数据服务
# 2           电子核心产业         电子核心产业
# 3        下一代信息网络产业      下一代信息网络产业
# 4             人工智能           人工智能
# ..             ...            ...
# 686      先进无机非金属材料         先进钢铁材料
# 687         先进钢铁材料         先进钢铁材料
# 688         先进钢铁材料         先进钢铁材料
# 689         先进钢铁材料         先进钢铁材料
# 690         先进钢铁材料         先进钢铁材料
#
# [691 rows x 5 columns]

# %%
compare.to_excel('compare.xlsx',encoding='utf-8',index=False)

# %%
ttl_names = list(set(merged_SEIC2['change'].drop_duplicates().tolist() + merged_SEIC2['tier2'].drop_duplicates().tolist()))
dict_target_names = dict(zip(ttl_names, range(len(ttl_names))))
dict_target_names
# Out:
# {'人工智能': 0,
#  '卫星及应用产业': 1,
#  '新能源汽车整车制造': 2,
#  '高效节能产业': 3,
#  '生物质能及其他新能源产业': 4,
#  '先进环保产业': 5,
#  '风能产业': 6,
#  '新能源汽车装置、配件制造': 7,
#  '新能源汽车相关服务': 8,
#  '核电产业': 9,
#  '其它': 10,
#  '航空装备产业': 11,
#  '新能源汽车相关设施制造': 12,
#  '资源循环利用产业': 13,
#  '先进有色金属材料': 14,
#  '下一代信息网络产业': 15,
#  '前沿新材料': 16,
#  '先进钢铁材料': 17,
#  '轨道交通装备产业': 18,
#  '生物农业及相关产业': 19,
#  '生物医药产业': 20,
#  '先进石化化工新材料': 21,
#  '高性能纤维及制品和复合材料': 22,
#  '数字创意技术设备制造': 23,
#  '先进无机非金属材料': 24,
#  '数字创意与融合服务': 25,
#  '互联网与云计算、大数据服务': 26,
#  '太阳能产业': 27,
#  '新技术与创新创业服务': 28,
#  '其他相关服务': 29,
#  '设计服务': 30,
#  '新兴软件和新型信息技术服务': 31,
#  '智能电网产业': 32,
#  '海洋工程装备产业': 33,
#  '数字文化创意活动': 34,
#  '智能制造装备产业': 35,
#  '生物质能产业': 36,
#  '其他生物业': 37,
#  '电子核心产业': 38,
#  '生物医学工程产业': 39}

# %% [markdown]
# # SEIC2

# %%
import warnings
warnings.filterwarnings('ignore')
merged_SEIC2['y_true'] = merged_SEIC2['change'].map(lambda x: dict_target_names[x])
merged_SEIC2['y_pred'] = merged_SEIC2['tier2'].map(lambda x: dict_target_names[x])
perform = pd.DataFrame(classification_report(merged_SEIC2['y_true'].tolist(), merged_SEIC2['y_pred'].tolist(), target_names=dict_target_names.keys(), output_dict = 'dict')).transpose()
perform.sort_values('f1-score', ascending = False)
# Out:
#                precision    recall  f1-score     support
# 卫星及应用产业         1.000000  1.000000  1.000000    5.000000
# 航空装备产业          0.928571  0.928571  0.928571   14.000000
# 风能产业            1.000000  0.833333  0.909091   12.000000
# 设计服务            0.800000  1.000000  0.888889    4.000000
# 先进环保产业          0.838710  0.896552  0.866667   29.000000
# 太阳能产业           0.923077  0.800000  0.857143   15.000000
# 生物医药产业          0.821429  0.821429  0.821429   56.000000
# 前沿新材料           0.785714  0.846154  0.814815   13.000000
# 轨道交通装备产业        0.916667  0.733333  0.814815   15.000000
# 先进有色金属材料        0.826087  0.760000  0.791667   25.000000
# 核电产业            0.818182  0.750000  0.782609   12.000000
# 先进石化化工新材料       0.913043  0.656250  0.763636   32.000000
# 生物医学工程产业        0.795918  0.696429  0.742857   56.000000
# 电子核心产业          0.709677  0.758621  0.733333   29.000000
# 新技术与创新创业服务      0.640000  0.842105  0.727273   19.000000
# 海洋工程装备产业        0.625000  0.833333  0.714286    6.000000
# 人工智能            0.657143  0.766667  0.707692   30.000000
# 先进钢铁材料          0.636364  0.777778  0.700000    9.000000
# 新能源汽车整车制造       0.800000  0.615385  0.695652   13.000000
# weighted avg    0.725127  0.687954  0.689802  689.000000
# accuracy        0.687954  0.687954  0.687954    0.687954
# 数字创意技术设备制造      0.636364  0.700000  0.666667   10.000000
# 数字创意与融合服务       0.666667  0.666667  0.666667    3.000000
# 其他生物业           0.666667  0.666667  0.666667    6.000000
# 互联网与云计算、大数据服务   0.796296  0.558442  0.656489   77.000000
# macro avg       0.653763  0.670378  0.639727  689.000000
# 数字文化创意活动        0.541667  0.684211  0.604651   19.000000
# 新能源汽车装置、配件制造    0.428571  1.000000  0.600000    9.000000
# 智能电网产业          0.550000  0.611111  0.578947   18.000000
# 高性能纤维及制品和复合材料   1.000000  0.400000  0.571429   20.000000
# 生物农业及相关产业       0.400000  1.000000  0.571429    6.000000
# 高效节能产业          0.666667  0.500000  0.571429    4.000000
# 下一代信息网络产业       0.562500  0.529412  0.545455   17.000000
# 生物质能产业          0.363636  1.000000  0.533333    4.000000
# 新能源汽车相关设施制造     0.600000  0.428571  0.500000   14.000000
# 新兴软件和新型信息技术服务   0.391304  0.666667  0.493151   27.000000
# 其他相关服务          0.666667  0.363636  0.470588   11.000000
# 先进无机非金属材料       0.380952  0.571429  0.457143   14.000000
# 智能制造装备产业        0.533333  0.380952  0.444444   21.000000
# 其它              0.363636  0.571429  0.444444    7.000000
# 资源循环利用产业        0.500000  0.200000  0.285714    5.000000
# 生物质能及其他新能源产业    0.000000  0.000000  0.000000    2.000000
# 新能源汽车相关服务       0.000000  0.000000  0.000000    1.000000

# %% [markdown]
# # SEIC1

# %%
rst_tier1 = pd.merge(merged_SEIC2[['company_id','company_name','tier2']], tier_mapping[['code_tier2', 'name']].dropna(), left_on = 'tier2', right_on = 'name', how = 'left')
rst_tier1
# Out:
#                            company_id    company_name          tier2  \
# 0    D4A0B99B510F4DD3A4958677CC6E4EA3   奇安信科技集团股份有限公司  新兴软件和新型信息技术服务
# 1    4EAF90A74ADB4BA77FDA6E64285F192B     优刻得科技股份有限公司  互联网与云计算、大数据服务
# 2    E1FCB80A311330E77AD192A015278BEC    深圳光峰科技股份有限公司         电子核心产业
# 3    2707E15C84151C5CCB0F4D288E17DDF8  科大国盾量子技术股份有限公司      下一代信息网络产业
# 4    1E0621610D0AA17006384ED5BF5D30B8      虹软科技股份有限公司           人工智能
# ..                                ...             ...            ...
# 684  3A4867D7C787F397C34187D9383FDC9C    智房工业科技股份有限公司      先进无机非金属材料
# 685  24D7B73567B677FB979F1466AE22827B      江苏荣程锻造有限公司         先进钢铁材料
# 686  F510D88638CB6EB0CAE3DC866F6F7973    合肥紫金钢管股份有限公司         先进钢铁材料
# 687  EB26F560066147F452315DA59301DFA7   青州惠泽新材料科技有限公司         先进钢铁材料
# 688  E2BC19143ACBEC9C8701FFF5CB93C24F      南京钢铁联合有限公司         先进钢铁材料
#
#      code_tier2           name
# 0           1.3  新兴软件和新型信息技术服务
# 1           1.4  互联网与云计算、大数据服务
# 2           1.2         电子核心产业
# 3           1.1      下一代信息网络产业
# 4           1.5           人工智能
# ..          ...            ...
# 684         3.4      先进无机非金属材料
# 685         3.1         先进钢铁材料
# 686         3.1         先进钢铁材料
# 687         3.1         先进钢铁材料
# 688         3.1         先进钢铁材料
#
# [689 rows x 5 columns]

# %%
rst_tier1['code_tier1'] = rst_tier1['code_tier2'].map(lambda ele: int(str(ele).split(".")[0]))
rst_tier1
# Out:
#                            company_id    company_name          tier2  \
# 0    D4A0B99B510F4DD3A4958677CC6E4EA3   奇安信科技集团股份有限公司  新兴软件和新型信息技术服务
# 1    4EAF90A74ADB4BA77FDA6E64285F192B     优刻得科技股份有限公司  互联网与云计算、大数据服务
# 2    E1FCB80A311330E77AD192A015278BEC    深圳光峰科技股份有限公司         电子核心产业
# 3    2707E15C84151C5CCB0F4D288E17DDF8  科大国盾量子技术股份有限公司      下一代信息网络产业
# 4    1E0621610D0AA17006384ED5BF5D30B8      虹软科技股份有限公司           人工智能
# ..                                ...             ...            ...
# 684  3A4867D7C787F397C34187D9383FDC9C    智房工业科技股份有限公司      先进无机非金属材料
# 685  24D7B73567B677FB979F1466AE22827B      江苏荣程锻造有限公司         先进钢铁材料
# 686  F510D88638CB6EB0CAE3DC866F6F7973    合肥紫金钢管股份有限公司         先进钢铁材料
# 687  EB26F560066147F452315DA59301DFA7   青州惠泽新材料科技有限公司         先进钢铁材料
# 688  E2BC19143ACBEC9C8701FFF5CB93C24F      南京钢铁联合有限公司         先进钢铁材料
#
#      code_tier2           name  code_tier1
# 0           1.3  新兴软件和新型信息技术服务           1
# 1           1.4  互联网与云计算、大数据服务           1
# 2           1.2         电子核心产业           1
# 3           1.1      下一代信息网络产业           1
# 4           1.5           人工智能           1
# ..          ...            ...         ...
# 684         3.4      先进无机非金属材料           3
# 685         3.1         先进钢铁材料           3
# 686         3.1         先进钢铁材料           3
# 687         3.1         先进钢铁材料           3
# 688         3.1         先进钢铁材料           3
#
# [689 rows x 6 columns]

# %%
rst_tier1 = pd.merge(rst_tier1, tier_mapping[['code_tier1', 'name']].dropna(), on = 'code_tier1', how = 'left')
rst_tier1
# Out:
#                            company_id    company_name          tier2  \
# 0    D4A0B99B510F4DD3A4958677CC6E4EA3   奇安信科技集团股份有限公司  新兴软件和新型信息技术服务
# 1    4EAF90A74ADB4BA77FDA6E64285F192B     优刻得科技股份有限公司  互联网与云计算、大数据服务
# 2    E1FCB80A311330E77AD192A015278BEC    深圳光峰科技股份有限公司         电子核心产业
# 3    2707E15C84151C5CCB0F4D288E17DDF8  科大国盾量子技术股份有限公司      下一代信息网络产业
# 4    1E0621610D0AA17006384ED5BF5D30B8      虹软科技股份有限公司           人工智能
# ..                                ...             ...            ...
# 684  3A4867D7C787F397C34187D9383FDC9C    智房工业科技股份有限公司      先进无机非金属材料
# 685  24D7B73567B677FB979F1466AE22827B      江苏荣程锻造有限公司         先进钢铁材料
# 686  F510D88638CB6EB0CAE3DC866F6F7973    合肥紫金钢管股份有限公司         先进钢铁材料
# 687  EB26F560066147F452315DA59301DFA7   青州惠泽新材料科技有限公司         先进钢铁材料
# 688  E2BC19143ACBEC9C8701FFF5CB93C24F      南京钢铁联合有限公司         先进钢铁材料
#
#      code_tier2         name_x  code_tier1     name_y
# 0           1.3  新兴软件和新型信息技术服务           1  新一代信息技术产业
# 1           1.4  互联网与云计算、大数据服务           1  新一代信息技术产业
# 2           1.2         电子核心产业           1  新一代信息技术产业
# 3           1.1      下一代信息网络产业           1  新一代信息技术产业
# 4           1.5           人工智能           1  新一代信息技术产业
# ..          ...            ...         ...        ...
# 684         3.4      先进无机非金属材料           3      新材料产业
# 685         3.1         先进钢铁材料           3      新材料产业
# 686         3.1         先进钢铁材料           3      新材料产业
# 687         3.1         先进钢铁材料           3      新材料产业
# 688         3.1         先进钢铁材料           3      新材料产业
#
# [689 rows x 7 columns]

# %%
rst_tier1 = rst_tier1[['company_id', 'name_y']].rename({'name_y': 'tier1'}, axis = 1)
rst_tier1
# Out:
#                            company_id      tier1
# 0    D4A0B99B510F4DD3A4958677CC6E4EA3  新一代信息技术产业
# 1    4EAF90A74ADB4BA77FDA6E64285F192B  新一代信息技术产业
# 2    E1FCB80A311330E77AD192A015278BEC  新一代信息技术产业
# 3    2707E15C84151C5CCB0F4D288E17DDF8  新一代信息技术产业
# 4    1E0621610D0AA17006384ED5BF5D30B8  新一代信息技术产业
# ..                                ...        ...
# 684  3A4867D7C787F397C34187D9383FDC9C      新材料产业
# 685  24D7B73567B677FB979F1466AE22827B      新材料产业
# 686  F510D88638CB6EB0CAE3DC866F6F7973      新材料产业
# 687  EB26F560066147F452315DA59301DFA7      新材料产业
# 688  E2BC19143ACBEC9C8701FFF5CB93C24F      新材料产业
#
# [689 rows x 2 columns]

# %%
test_tier1 = pd.merge(merged_SEIC2[['company_id','change']], tier_mapping[['code_tier2', 'name']].dropna(), left_on = 'change', right_on = 'name', how = 'left')
test_tier1
# Out:
#                            company_id         change  code_tier2  \
# 0    D4A0B99B510F4DD3A4958677CC6E4EA3  新兴软件和新型信息技术服务         1.3
# 1    4EAF90A74ADB4BA77FDA6E64285F192B  互联网与云计算、大数据服务         1.4
# 2    E1FCB80A311330E77AD192A015278BEC         电子核心产业         1.2
# 3    2707E15C84151C5CCB0F4D288E17DDF8      下一代信息网络产业         1.1
# 4    1E0621610D0AA17006384ED5BF5D30B8           人工智能         1.5
# ..                                ...            ...         ...
# 684  3A4867D7C787F397C34187D9383FDC9C         先进钢铁材料         3.1
# 685  24D7B73567B677FB979F1466AE22827B         先进钢铁材料         3.1
# 686  F510D88638CB6EB0CAE3DC866F6F7973         先进钢铁材料         3.1
# 687  EB26F560066147F452315DA59301DFA7         先进钢铁材料         3.1
# 688  E2BC19143ACBEC9C8701FFF5CB93C24F         先进钢铁材料         3.1
#
#               name
# 0    新兴软件和新型信息技术服务
# 1    互联网与云计算、大数据服务
# 2           电子核心产业
# 3        下一代信息网络产业
# 4             人工智能
# ..             ...
# 684         先进钢铁材料
# 685         先进钢铁材料
# 686         先进钢铁材料
# 687         先进钢铁材料
# 688         先进钢铁材料
#
# [689 rows x 4 columns]

# %%
test_tier1['code_tier1'] = test_tier1['code_tier2'].map(lambda ele: int(str(ele).split(".")[0]))
test_tier1
# Out:
#                            company_id         change  code_tier2  \
# 0    D4A0B99B510F4DD3A4958677CC6E4EA3  新兴软件和新型信息技术服务         1.3
# 1    4EAF90A74ADB4BA77FDA6E64285F192B  互联网与云计算、大数据服务         1.4
# 2    E1FCB80A311330E77AD192A015278BEC         电子核心产业         1.2
# 3    2707E15C84151C5CCB0F4D288E17DDF8      下一代信息网络产业         1.1
# 4    1E0621610D0AA17006384ED5BF5D30B8           人工智能         1.5
# ..                                ...            ...         ...
# 684  3A4867D7C787F397C34187D9383FDC9C         先进钢铁材料         3.1
# 685  24D7B73567B677FB979F1466AE22827B         先进钢铁材料         3.1
# 686  F510D88638CB6EB0CAE3DC866F6F7973         先进钢铁材料         3.1
# 687  EB26F560066147F452315DA59301DFA7         先进钢铁材料         3.1
# 688  E2BC19143ACBEC9C8701FFF5CB93C24F         先进钢铁材料         3.1
#
#               name  code_tier1
# 0    新兴软件和新型信息技术服务           1
# 1    互联网与云计算、大数据服务           1
# 2           电子核心产业           1
# 3        下一代信息网络产业           1
# 4             人工智能           1
# ..             ...         ...
# 684         先进钢铁材料           3
# 685         先进钢铁材料           3
# 686         先进钢铁材料           3
# 687         先进钢铁材料           3
# 688         先进钢铁材料           3
#
# [689 rows x 5 columns]

# %%
test_tier1 = pd.merge(test_tier1, tier_mapping[['code_tier1', 'name']].dropna(), on = 'code_tier1', how = 'left')
test_tier1 = test_tier1[['company_id', 'name_y']].rename({'name_y': 'seic1'}, axis = 1)
test_tier1

merged_tier1 = pd.merge(rst_tier1, test_tier1, on = 'company_id', how = 'left')

ttl_names = list(set(merged_tier1['seic1'].drop_duplicates().tolist() + merged_tier1['tier1'].drop_duplicates().tolist()))
dict_target_names = dict(zip(ttl_names, range(len(ttl_names))))
dict_target_names
merged_tier1['y_true'] = merged_tier1['seic1'].map(lambda ele: dict_target_names[ele])
merged_tier1['y_pred'] = merged_tier1['tier1'].map(lambda ele: dict_target_names[ele])
perform_tier1 = pd.DataFrame(classification_report(merged_tier1['y_true'].tolist(), merged_tier1['y_pred'].tolist(), target_names=dict_target_names.keys(), output_dict = 'dict')).transpose()
perform_tier1.sort_values('f1-score', ascending = False)
# Out:
#               precision    recall  f1-score     support
# 生物产业           0.883212  0.945312  0.913208  128.000000
# 新能源汽车产业        0.853659  0.945946  0.897436   37.000000
# 新材料产业          0.940000  0.831858  0.882629  113.000000
# 新一代信息技术产业      0.840659  0.850000  0.845304  180.000000
# weighted avg   0.842757  0.837446  0.838257  689.000000
# 节能环保产业         0.861111  0.815789  0.837838   38.000000
# accuracy       0.837446  0.837446  0.837446    0.837446
# macro avg      0.774700  0.796074  0.781286  689.000000
# 新能源产业          0.814815  0.745763  0.778761   59.000000
# 高端装备制造产业       0.814815  0.721311  0.765217   61.000000
# 数字创意产业         0.697674  0.833333  0.759494   36.000000
# 相关服务业          0.677419  0.700000  0.688525   30.000000
# 其它             0.363636  0.571429  0.444444    7.000000
