# %%
import pandas as pd
import os
os.chdir('D:\数据\全国数据\战兴分类\战新二级分类\country_0818')
from sqlalchemy import create_engine
from sklearn.metrics import classification_report
pd.set_option('max_rows',100)
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company',echo=False)

# %% [markdown]
# # tier_mapping

# %%
tier_mapping=pd.read_excel(r'D:\数据\全国数据\战兴分类\战新二级分类\tier_mapping.xlsx')
tier_mapping
# Out:
#     code_tier1           name  code_tier2
# 0          1.0      新一代信息技术产业         NaN
# 1          2.0       高端装备制造产业         NaN
# 2          3.0          新材料产业         NaN
# 3          4.0           生物产业         NaN
# 4          5.0        新能源汽车产业         NaN
# 5          6.0          新能源产业         NaN
# 6          7.0         节能环保产业         NaN
# 7          8.0         数字创意产业         NaN
# 8          9.0          相关服务业         NaN
# 9         -1.0             其它         NaN
# 10         NaN      下一代信息网络产业         1.1
# 11         NaN         电子核心产业         1.2
# 12         NaN  新兴软件和新型信息技术服务         1.3
# 13         NaN  互联网与云计算、大数据服务         1.4
# 14         NaN           人工智能         1.5
# 15         NaN       智能制造装备产业         2.1
# 16         NaN         航空装备产业         2.2
# 17         NaN        卫星及应用产业         2.3
# 18         NaN       轨道交通装备产业         2.4
# 19         NaN       海洋工程装备产业         2.5
# 20         NaN         先进钢铁材料         3.1
# 21         NaN       先进有色金属材料         3.2
# 22         NaN      先进石化化工新材料         3.3
# 23         NaN      先进无机非金属材料         3.4
# 24         NaN  高性能纤维及制品和复合材料         3.5
# 25         NaN          前沿新材料         3.6
# 26         NaN        新材料相关服务         3.7
# 27         NaN         生物医药产业         4.1
# 28         NaN       生物医学工程产业         4.2
# 29         NaN      生物农业及相关产业         4.3
# 30         NaN         生物质能产业         4.4
# 31         NaN          其他生物业         4.5
# 32         NaN      新能源汽车整车制造         5.1
# 33         NaN   新能源汽车装置、配件制造         5.2
# 34         NaN    新能源汽车相关设施制造         5.3
# 35         NaN      新能源汽车相关服务         5.4
# 36         NaN           核电产业         6.1
# 37         NaN           风能产业         6.2
# 38         NaN          太阳能产业         6.3
# 39         NaN   生物质能及其他新能源产业         6.4
# 40         NaN         智能电网产业         6.5
# 41         NaN         高效节能产业         7.1
# 42         NaN         先进环保产业         7.2
# 43         NaN       资源循环利用产业         7.3
# 44         NaN     数字创意技术设备制造         8.1
# 45         NaN       数字文化创意活动         8.2
# 46         NaN           设计服务         8.3
# 47         NaN      数字创意与融合服务         8.4
# 48         NaN     新技术与创新创业服务         9.1
# 49         NaN         其他相关服务         9.2
# 50         NaN             其它        -1.0

# %% [markdown]
# # compare

# %% [markdown]
# ## 全国数据战新二级分类

# %%
china_company_seic_lv2=pd.read_sql('select * FROM  company.china_company_seic_lv2',con=engine)
china_company_seic_lv2=china_company_seic_lv2[['company_id','seic_lv2']]
china_company_seic_lv2
# Out:
#                               company_id       seic_lv2
# 0       00001FF532C2D92470F99149D48C7820  新兴软件和新型信息技术服务
# 1       00002B5B4529376232011C86E1A588FF      先进无机非金属材料
# 2       00003DFB06D095BD2D6DE4A828C6CB5C       智能制造装备产业
# 3       00003E68CDE39A6DA970E85788FDB98D         先进环保产业
# 4       00003FCBDCE7E5340E6603C08DD6291A       智能制造装备产业
# ...                                  ...            ...
# 804431  FFFF8F3880B931A0EFC5A9BDAB9888B9  互联网与云计算、大数据服务
# 804432  FFFF9B34AD5B60CECBF0DA6C52F3B0F1       生物医学工程产业
# 804433  FFFFCFE0644923912519B1A1034E5E8D       数字文化创意活动
# 804434  FFFFE42F6484FEC563A1C55993BE494C             其它
# 804435  FFFFF51AB69F00656AE94BC3C57CC8D2         生物医药产业
#
# [804436 rows x 2 columns]

# %%
Company_desc=pd.read_excel('全国数据含有简介的公司.xlsx')
Company_desc
# Out:
#                             company_id      company_name          SEIC2
# 0     5D05A2C5AF45E397CFF0FF451700A22D    平安医疗健康管理股份有限公司  互联网与云计算、大数据服务
# 1     00FCB9092015A0642940DF8E82F1B8DD    西门子（深圳）磁共振有限公司       生物医学工程产业
# 2     E54E29095C21F113F67A38FB3EB28BA6    杭州海兴电力科技股份有限公司         智能电网产业
# 3     D1CEA95D3707DE01E015646B9AE91E5E    华道数据处理（苏州）有限公司  互联网与云计算、大数据服务
# 4     979E7A8A019A5DC84632A3C6CADC1997      苏州盛派网络科技有限公司  新兴软件和新型信息技术服务
# ...                                ...               ...            ...
# 1286  002DC04A6639BD92F4328BB7C0E5988D         山西天然气有限公司         生物质能产业
# 1287  0043088007B5541D8514FF6DEFC3F54B      邯郸黑猫炭黑有限责任公司             其它
# 1288  04A4392BD7D7169457949E0F95B25ED8  北京中关村软件园孵化服务有限公司     新技术与创新创业服务
# 1289  B82EBC4AAFD217549199CC0E12CA8AA7      杭州亿塔检测技术有限公司     新技术与创新创业服务
# 1290  1CDD8BA9BCB1AE2D99A19C2F4BE0014E     东莞市高鑫检测设备有限公司     新技术与创新创业服务
#
# [1291 rows x 3 columns]

# %%
Compare=pd.merge(Company_desc,china_company_seic_lv2,how='left',on='company_id')
Compare
# Out:
#                             company_id      company_name          SEIC2  \
# 0     5D05A2C5AF45E397CFF0FF451700A22D    平安医疗健康管理股份有限公司  互联网与云计算、大数据服务
# 1     00FCB9092015A0642940DF8E82F1B8DD    西门子（深圳）磁共振有限公司       生物医学工程产业
# 2     E54E29095C21F113F67A38FB3EB28BA6    杭州海兴电力科技股份有限公司         智能电网产业
# 3     D1CEA95D3707DE01E015646B9AE91E5E    华道数据处理（苏州）有限公司  互联网与云计算、大数据服务
# 4     979E7A8A019A5DC84632A3C6CADC1997      苏州盛派网络科技有限公司  新兴软件和新型信息技术服务
# ...                                ...               ...            ...
# 1286  002DC04A6639BD92F4328BB7C0E5988D         山西天然气有限公司         生物质能产业
# 1287  0043088007B5541D8514FF6DEFC3F54B      邯郸黑猫炭黑有限责任公司             其它
# 1288  04A4392BD7D7169457949E0F95B25ED8  北京中关村软件园孵化服务有限公司     新技术与创新创业服务
# 1289  B82EBC4AAFD217549199CC0E12CA8AA7      杭州亿塔检测技术有限公司     新技术与创新创业服务
# 1290  1CDD8BA9BCB1AE2D99A19C2F4BE0014E     东莞市高鑫检测设备有限公司     新技术与创新创业服务
#
#            seic_lv2
# 0            生物医药产业
# 1          生物医学工程产业
# 2            智能电网产业
# 3     互联网与云计算、大数据服务
# 4     新兴软件和新型信息技术服务
# ...             ...
# 1286         生物质能产业
# 1287         生物质能产业
# 1288     新技术与创新创业服务
# 1289     新技术与创新创业服务
# 1290     新技术与创新创业服务
#
# [1291 rows x 4 columns]

# %%
Compare['change']=Compare.apply(
    lambda ele: (ele['seic_lv2'] if (ele['seic_lv2'] in ele['SEIC2']) else ele['SEIC2'].split(",")[0].replace("[", "")) 
    if ("," in ele['SEIC2']) 
    else ele['SEIC2'],axis=1)

# %%
Compare
# Out:
#                             company_id      company_name          SEIC2  \
# 0     5D05A2C5AF45E397CFF0FF451700A22D    平安医疗健康管理股份有限公司  互联网与云计算、大数据服务
# 1     00FCB9092015A0642940DF8E82F1B8DD    西门子（深圳）磁共振有限公司       生物医学工程产业
# 2     E54E29095C21F113F67A38FB3EB28BA6    杭州海兴电力科技股份有限公司         智能电网产业
# 3     D1CEA95D3707DE01E015646B9AE91E5E    华道数据处理（苏州）有限公司  互联网与云计算、大数据服务
# 4     979E7A8A019A5DC84632A3C6CADC1997      苏州盛派网络科技有限公司  新兴软件和新型信息技术服务
# ...                                ...               ...            ...
# 1286  002DC04A6639BD92F4328BB7C0E5988D         山西天然气有限公司         生物质能产业
# 1287  0043088007B5541D8514FF6DEFC3F54B      邯郸黑猫炭黑有限责任公司             其它
# 1288  04A4392BD7D7169457949E0F95B25ED8  北京中关村软件园孵化服务有限公司     新技术与创新创业服务
# 1289  B82EBC4AAFD217549199CC0E12CA8AA7      杭州亿塔检测技术有限公司     新技术与创新创业服务
# 1290  1CDD8BA9BCB1AE2D99A19C2F4BE0014E     东莞市高鑫检测设备有限公司     新技术与创新创业服务
#
#            seic_lv2         change
# 0            生物医药产业  互联网与云计算、大数据服务
# 1          生物医学工程产业       生物医学工程产业
# 2            智能电网产业         智能电网产业
# 3     互联网与云计算、大数据服务  互联网与云计算、大数据服务
# 4     新兴软件和新型信息技术服务  新兴软件和新型信息技术服务
# ...             ...            ...
# 1286         生物质能产业         生物质能产业
# 1287         生物质能产业             其它
# 1288     新技术与创新创业服务     新技术与创新创业服务
# 1289     新技术与创新创业服务     新技术与创新创业服务
# 1290     新技术与创新创业服务     新技术与创新创业服务
#
# [1291 rows x 5 columns]

# %%
Compare.to_excel('Compare_desc_0915.xlsx',encoding='utf-8',index=False)

# %%
ttl_names = list(set(Compare['change'].drop_duplicates().tolist() + Compare['seic_lv2'].drop_duplicates().tolist()))
dict_target_names = dict(zip(ttl_names, range(len(ttl_names))))
dict_target_names
# Out:
# {'先进钢铁材料': 0,
#  '其它': 1,
#  '智能制造装备产业': 2,
#  '先进有色金属材料': 3,
#  '资源循环利用产业': 4,
#  '新技术与创新创业服务': 5,
#  '生物质能产业': 6,
#  '先进石化化工新材料': 7,
#  '新能源汽车相关服务': 8,
#  '新兴软件和新型信息技术服务': 9,
#  '其他相关服务': 10,
#  '前沿新材料': 11,
#  '其他生物业': 12,
#  '生物医学工程产业': 13,
#  '新能源汽车相关设施制造': 14,
#  '先进无机非金属材料': 15,
#  '人工智能': 16,
#  '数字创意与融合服务': 17,
#  '数字文化创意活动': 18,
#  '高效节能产业': 19,
#  '轨道交通装备产业': 20,
#  '新材料相关服务': 21,
#  '先进环保产业': 22,
#  '设计服务': 23,
#  '海洋工程装备产业': 24,
#  '数字创意技术设备制造': 25,
#  '互联网与云计算、大数据服务': 26,
#  '核电产业': 27,
#  '生物医药产业': 28,
#  '下一代信息网络产业': 29,
#  '卫星及应用产业': 30,
#  '太阳能产业': 31,
#  '高性能纤维及制品和复合材料': 32,
#  '新能源汽车装置、配件制造': 33,
#  '电子核心产业': 34,
#  '新能源汽车整车制造': 35,
#  '生物农业及相关产业': 36,
#  '智能电网产业': 37,
#  '航空装备产业': 38,
#  '风能产业': 39}

# %%
merged_SEIC2=Compare

# %% [markdown]
# # SEIC2

# %%
import warnings
warnings.filterwarnings('ignore')
merged_SEIC2['y_true'] = merged_SEIC2['change'].map(lambda x: dict_target_names[x])
merged_SEIC2['y_pred'] = merged_SEIC2['seic_lv2'].map(lambda x: dict_target_names[x])
perform = pd.DataFrame(classification_report(merged_SEIC2['y_true'].tolist(), merged_SEIC2['y_pred'].tolist(), target_names=dict_target_names.keys(), output_dict = 'dict')).transpose()
perform.sort_values('f1-score', ascending = False)
# Out:
#                precision    recall  f1-score      support
# 航空装备产业          0.952381  1.000000  0.975610    20.000000
# 高性能纤维及制品和复合材料   1.000000  0.937500  0.967742    16.000000
# 卫星及应用产业         0.923077  1.000000  0.960000    12.000000
# 生物医药产业          0.965116  0.954023  0.959538    87.000000
# 新材料相关服务         0.900000  1.000000  0.947368     9.000000
# 新能源汽车装置、配件制造    0.944444  0.944444  0.944444    18.000000
# 先进有色金属材料        0.971429  0.894737  0.931507    38.000000
# 核电产业            0.846154  1.000000  0.916667    11.000000
# 风能产业            0.888889  0.941176  0.914286    17.000000
# 生物医学工程产业        0.981481  0.815385  0.890756    65.000000
# 设计服务            0.800000  1.000000  0.888889    12.000000
# 先进石化化工新材料       0.884058  0.884058  0.884058    69.000000
# 数字创意与融合服务       0.833333  0.937500  0.882353    16.000000
# 新能源汽车整车制造       1.000000  0.769231  0.869565    13.000000
# 太阳能产业           0.826087  0.904762  0.863636    21.000000
# 电子核心产业          0.783133  0.955882  0.860927    68.000000
# 先进环保产业          0.987421  0.762136  0.860274   206.000000
# 轨道交通装备产业        0.882353  0.833333  0.857143    18.000000
# 先进钢铁材料          0.777778  0.913043  0.840000    23.000000
# weighted avg    0.853800  0.830364  0.830386  1291.000000
# accuracy        0.830364  0.830364  0.830364     0.830364
# 其他生物业           0.823529  0.823529  0.823529    17.000000
# 前沿新材料           0.823529  0.823529  0.823529    17.000000
# 高效节能产业          0.789474  0.833333  0.810811    18.000000
# 人工智能            0.761905  0.864865  0.810127    37.000000
# 新兴软件和新型信息技术服务   0.711864  0.933333  0.807692    45.000000
# macro avg       0.790594  0.842800  0.802482  1291.000000
# 数字创意技术设备制造      0.909091  0.714286  0.800000    14.000000
# 智能制造装备产业        0.742424  0.844828  0.790323    58.000000
# 生物质能产业          0.642857  1.000000  0.782609     9.000000
# 新能源汽车相关设施制造     0.631579  1.000000  0.774194    12.000000
# 先进无机非金属材料       0.705882  0.857143  0.774194    28.000000
# 数字文化创意活动        0.709677  0.846154  0.771930    26.000000
# 智能电网产业          0.769231  0.769231  0.769231    26.000000
# 生物农业及相关产业       0.615385  1.000000  0.761905    16.000000
# 资源循环利用产业        0.687500  0.846154  0.758621    13.000000
# 互联网与云计算、大数据服务   0.880597  0.648352  0.746835    91.000000
# 海洋工程装备产业        0.590909  0.928571  0.722222    14.000000
# 下一代信息网络产业       0.709677  0.687500  0.698413    32.000000
# 其它              0.827586  0.510638  0.631579    47.000000
# 新技术与创新创业服务      0.393939  1.000000  0.565217    13.000000
# 其他相关服务          0.750000  0.333333  0.461538    18.000000
# 新能源汽车相关服务       0.000000  0.000000  0.000000     1.000000

# %% [markdown]
# # SEIC1

# %%
rst_tier1 = pd.merge(merged_SEIC2[['company_id','company_name','seic_lv2']], tier_mapping[['code_tier2', 'name']].dropna(), left_on = 'seic_lv2', right_on = 'name', how = 'left')
rst_tier1['code_tier1'] = rst_tier1['code_tier2'].map(lambda ele: int(str(ele).split(".")[0]))
rst_tier1 = pd.merge(rst_tier1, tier_mapping[['code_tier1', 'name']].dropna(), on = 'code_tier1', how = 'left')
rst_tier1 = rst_tier1[['company_id', 'name_y']].rename({'name_y': 'tier1'}, axis = 1)

# %%
test_tier1 = pd.merge(merged_SEIC2[['company_id','change']], tier_mapping[['code_tier2', 'name']].dropna(), left_on = 'change', right_on = 'name', how = 'left')
test_tier1['code_tier1'] = test_tier1['code_tier2'].map(lambda ele: int(str(ele).split(".")[0]))
test_tier1 = pd.merge(test_tier1, tier_mapping[['code_tier1', 'name']].dropna(), on = 'code_tier1', how = 'left')
test_tier1 = test_tier1[['company_id', 'name_y']].rename({'name_y': 'seic1'}, axis = 1)

# %%
merged_tier1 = pd.merge(rst_tier1, test_tier1, on = 'company_id', how = 'left')
ttl_names = list(set(merged_tier1['seic1'].drop_duplicates().tolist() + merged_tier1['tier1'].drop_duplicates().tolist()))
dict_target_names = dict(zip(ttl_names, range(len(ttl_names))))
dict_target_names
merged_tier1['y_true'] = merged_tier1['seic1'].map(lambda ele: dict_target_names[ele])
merged_tier1['y_pred'] = merged_tier1['tier1'].map(lambda ele: dict_target_names[ele])
perform_tier1 = pd.DataFrame(classification_report(merged_tier1['y_true'].tolist(), merged_tier1['y_pred'].tolist(), target_names=dict_target_names.keys(), output_dict = 'dict')).transpose()
perform_tier1.sort_values('f1-score', ascending = False)
# Out:
#               precision    recall  f1-score      support
# 生物产业           0.934010  0.948454  0.941176   194.000000
# 新材料产业          0.903382  0.935000  0.918919   200.000000
# 新一代信息技术产业      0.890071  0.919414  0.904505   273.000000
# 新能源汽车产业        0.872340  0.931818  0.901099    44.000000
# 数字创意产业         0.853333  0.941176  0.895105    68.000000
# accuracy       0.886909  0.886909  0.886909     0.886909
# 节能环保产业         0.984536  0.805907  0.886311   237.000000
# weighted avg   0.892831  0.886909  0.885898  1291.000000
# 新能源产业          0.837500  0.893333  0.864516    75.000000
# 高端装备制造产业       0.798561  0.909836  0.850575   122.000000
# macro avg      0.851108  0.860203  0.848823  1291.000000
# 相关服务业          0.609756  0.806452  0.694444    31.000000
# 其它             0.827586  0.510638  0.631579    47.000000
