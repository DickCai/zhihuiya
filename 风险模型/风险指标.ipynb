# %%
import pandas as pd
import os
import numpy as np
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/风险模型/风险指标')
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
engine_retrain=create_engine('mysql+pymysql://company:company@192.168.16.244/company_retrain',echo=False)

# %% [markdown]
# # patent_invalid_ratio

# %%
patent_invalid_ratio=pd.read_csv("patent_invalid_ratio.csv")
patent_invalid_ratio
# Out:
#                               company_id  \
# 0       386BABE504634D3836AAFA822834D4BD
# 1       83F97CF216B44DC626117253138FAF7F
# 2       CE9C88AF2A5C112F39842FCA24946E62
# 3       3274201CB3F96CA9742FE18B72EAD8BD
# 4       A108A2FC64E6BA7B62B0004870A9F607
# ...                                  ...
# 976343  60BFCF16C62B57357F59E0676E81433E
# 976344  F51145924FAADF86FFAED862D4B5BBCB
# 976345  6B341D2E95EF833E9640CAD5E1DD5CDA
# 976346  0FEBAC64C411E57542C71BDA74E4BBDC
# 976347  CF0044A0F31D961B1F97A6AF63CE675A
#
#                                       ans_id  patent_invalid_ratio
# 0       f1594319-cdab-4f2e-b557-f1c0cb75cc04              0.838095
# 1       0ebc4bd2-f44e-4aa7-97b4-1179fb446c1a              0.357798
# 2       d04eb3cd-c67b-41b2-bd8d-85077b428c47              0.168539
# 3       cd41e409-c108-4d9f-8045-ddf329934d92              0.789474
# 4       e8d48af5-3c3b-4401-8c99-5662ad1a174a              1.000000
# ...                                      ...                   ...
# 976343  b4949b1e-1398-4a27-acd5-54b67dae77d1              0.000000
# 976344  2ff70e4e-b4d5-4783-8efe-e6ab5c7584be              0.000000
# 976345  727e2aef-ca4b-4f90-8b25-a1fbc4518c96              0.000000
# 976346  15e81561-2b32-4ef4-a728-e09c3c0fe36d              0.000000
# 976347  ccc01a68-5273-11ec-aaa6-62122d1e8f3e              0.000000
#
# [976348 rows x 3 columns]

# %%
v230_original=pd.read_sql('select * from v230_detail',con=engine_retrain)
v230_original_name=v230_original[['company_id','seic_lv1','seic_lv2','ans_id']]
v230_original_name
# Out:
#                                company_id   seic_lv1       seic_lv2  \
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F         其它             其它
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E       生物产业      生物农业及相关产业
# 2        0027683A8AB4217205D5BE751D3A6D4E         其它             其它
# 3        0034953AE8F88E6DD07C2809226C2A17         其它             其它
# 4        003D83E767259BB08EC3F13BA588C53D   高端装备制造产业       智能制造装备产业
# ...                                   ...        ...            ...
# 1077642  FF7923665B15F13461D87DDA4D3E282E         其它             其它
# 1077643  FF985ECAFEB9221E6A1938ED023E7A4E         其它             其它
# 1077644  FF99E88C41B48D6536FE40EBDDD72CEC  新一代信息技术产业  新兴软件和新型信息技术服务
# 1077645  FFBED44A7463AA6EE49D5DC46C5A8F17      新能源产业         智能电网产业
# 1077646  FFF18DDED6DDE300664F9F5916AF3353  新一代信息技术产业  新兴软件和新型信息技术服务
#
#                                        ans_id
# 0        510a7ce0-2df4-4051-bf8b-e80d22a7474a
# 1        6f15bdd4-61d2-43ab-9a35-e7cbb828de0b
# 2        fdbf9f50-4818-464b-b604-751e084690f2
# 3        6cc781fe-6ca6-4fd0-90d8-1db582f0e12b
# 4        dedf552f-0a26-47f7-b534-c6d9d1be9e0b
# ...                                       ...
# 1077642  b1210a02-99e7-4654-b506-cd03ade9740a
# 1077643                                  <NA>
# 1077644                                  <NA>
# 1077645  7ee2793f-e003-467d-8cfa-e24336601cc0
# 1077646  5e2ca39b-91d9-401d-a8db-59899628b62e
#
# [1077647 rows x 4 columns]

# %%
patent_invalid_ratio
# Out:
#                               company_id  \
# 0       386BABE504634D3836AAFA822834D4BD
# 1       83F97CF216B44DC626117253138FAF7F
# 2       CE9C88AF2A5C112F39842FCA24946E62
# 3       3274201CB3F96CA9742FE18B72EAD8BD
# 4       A108A2FC64E6BA7B62B0004870A9F607
# ...                                  ...
# 976343  60BFCF16C62B57357F59E0676E81433E
# 976344  F51145924FAADF86FFAED862D4B5BBCB
# 976345  6B341D2E95EF833E9640CAD5E1DD5CDA
# 976346  0FEBAC64C411E57542C71BDA74E4BBDC
# 976347  CF0044A0F31D961B1F97A6AF63CE675A
#
#                                       ans_id  patent_invalid_ratio  \
# 0       f1594319-cdab-4f2e-b557-f1c0cb75cc04              0.838095
# 1       0ebc4bd2-f44e-4aa7-97b4-1179fb446c1a              0.357798
# 2       d04eb3cd-c67b-41b2-bd8d-85077b428c47              0.168539
# 3       cd41e409-c108-4d9f-8045-ddf329934d92              0.789474
# 4       e8d48af5-3c3b-4401-8c99-5662ad1a174a              1.000000
# ...                                      ...                   ...
# 976343  b4949b1e-1398-4a27-acd5-54b67dae77d1              0.000000
# 976344  2ff70e4e-b4d5-4783-8efe-e6ab5c7584be              0.000000
# 976345  727e2aef-ca4b-4f90-8b25-a1fbc4518c96              0.000000
# 976346  15e81561-2b32-4ef4-a728-e09c3c0fe36d              0.000000
# 976347  ccc01a68-5273-11ec-aaa6-62122d1e8f3e              0.000000
#
#              company_name
# 0          苏州昆拓热控系统股份有限公司
# 1           浙江联洋新材料股份有限公司
# 2              无锡麟力科技有限公司
# 3       无锡市苏立成汽车空调压缩机有限公司
# 4              上海易环实业有限公司
# ...                   ...
# 976343     汇智博研（北京）科技有限公司
# 976344      东营市鲁鹏石油机械有限公司
# 976345       云南原守古法糖业有限公司
# 976346       广西新塑管道科技有限公司
# 976347    四川中科易达新能源科技有限公司
#
# [976348 rows x 4 columns]

# %% [markdown]
# # 测试集

# %%
risk_test=pd.read_excel('/Users/caicaiqijun/智慧牙/数据/全国数据/测试样本/风险模型/测试集/风险模型测试集聚合后.xlsx')
risk_test=pd.merge(risk_test,v230_original_name,on='company_id')
risk_test
# Out:
#               company_name  label source source_list  level  \
# 0             广西春茂投资股份有限公司      1     ST      ['ST']      1
# 1           江苏良晋电子商务股份有限公司      1     ST      ['ST']      1
# 2              沈阳商业城股份有限公司      1     ST      ['ST']      1
# 3               乐美电商股份有限公司      1     ST      ['ST']      1
# 4         深圳市易订云网络科技股份有限公司      1     ST      ['ST']      1
# ...                    ...    ...    ...         ...    ...
# 2391  上海来益生物药物研究开发中心有限责任公司      0   PCT5    ['PCT5']      1
# 2392         北京京东方技术开发有限公司      0   PCT5    ['PCT5']      1
# 2393        广州中智融通金融科技有限公司      0   PCT5    ['PCT5']      1
# 2394          恺博座椅机械部件有限公司      0   PCT5    ['PCT5']      1
# 2395        西安隆基绿能建筑科技有限公司      0   PCT5    ['PCT5']      1
#
#                 clean_name                        company_id      total  \
# 0             广西春茂投资股份有限公司  59AA6D434BDDB66592063D42CE59E692   7.015092
# 1           江苏良晋电子商务股份有限公司  EAAD024167EB06B5D1C97F8FBE0A59F9   0.638710
# 2              沈阳商业城股份有限公司  38800649F434261E7F1586C369C9AC05   6.888028
# 3               乐美电商股份有限公司  6B83096E88917292FB8B832F6B2EF3C3   0.867167
# 4         深圳市易订云网络科技股份有限公司  7A2F37E22C61D26D47FCA12954A1F48E   0.705365
# ...                    ...                               ...        ...
# 2391  上海来益生物药物研究开发中心有限责任公司  C9EA278C7AD48EF976F2D5AB0A21B41F  37.189502
# 2392         北京京东方技术开发有限公司  915090F769B30C0DE7D7797901160760  55.217514
# 2393        广州中智融通金融科技有限公司  06464D0D4CFC0A4F92B162A441A4C7D1  47.955397
# 2394          恺博座椅机械部件有限公司  EE30DAF2677EE4368332B0487EA2F457  58.166428
# 2395        西安隆基绿能建筑科技有限公司  8A1FDCC15A3CC35DFCA2A6BACC454B1B  36.136150
#
#        seic_lv1       seic_lv2                                ans_id
# 0      高端装备制造产业       智能制造装备产业  86bfcf18-fca7-4de0-8e1c-dfe1bc465ae2
# 1     新一代信息技术产业      下一代信息网络产业                                  <NA>
# 2            其它             其它                                  <NA>
# 3     新一代信息技术产业  互联网与云计算、大数据服务  7889ad28-09df-42f6-b9e4-1706b9c6bce0
# 4     新一代信息技术产业  互联网与云计算、大数据服务                                  <NA>
# ...         ...            ...                                   ...
# 2391       生物产业         生物医药产业  1534bc62-68c8-494d-9bda-840bd84ee4f4
# 2392      相关服务业     新技术与创新创业服务  0091d920-9e02-44c3-8084-47b5685c39a2
# 2393  新一代信息技术产业  新兴软件和新型信息技术服务  fa890ff0-9a2b-4333-8b43-6ebcce5e4096
# 2394         其它             其它  34d9ef74-3cc8-412b-afdc-1005e262bde0
# 2395      新能源产业          太阳能产业  08ed875f-87f9-41fc-a0c3-9b45e2658490
#
# [2396 rows x 11 columns]

# %%
risk_test=pd.merge(risk_test,patent_invalid_ratio[['company_id','patent_invalid_ratio']],on='company_id')
risk_test
# Out:
#               company_name  label source source_list  level  \
# 0             广西春茂投资股份有限公司      1     ST      ['ST']      1
# 1               乐美电商股份有限公司      1     ST      ['ST']      1
# 2             杭州仁盈科技股份有限公司      1     ST      ['ST']      1
# 3         云南云投生态环境科技股份有限公司      1     ST      ['ST']      1
# 4               熊猫金控股份有限公司      1     ST      ['ST']      1
# ...                    ...    ...    ...         ...    ...
# 2289  上海来益生物药物研究开发中心有限责任公司      0   PCT5    ['PCT5']      1
# 2290         北京京东方技术开发有限公司      0   PCT5    ['PCT5']      1
# 2291        广州中智融通金融科技有限公司      0   PCT5    ['PCT5']      1
# 2292          恺博座椅机械部件有限公司      0   PCT5    ['PCT5']      1
# 2293        西安隆基绿能建筑科技有限公司      0   PCT5    ['PCT5']      1
#
#                 clean_name                        company_id      total  \
# 0             广西春茂投资股份有限公司  59AA6D434BDDB66592063D42CE59E692   7.015092
# 1               乐美电商股份有限公司  6B83096E88917292FB8B832F6B2EF3C3   0.867167
# 2             杭州仁盈科技股份有限公司  4505BAB094F058A54507F40D9B5F994D  16.288171
# 3         云南云投生态环境科技股份有限公司  A1C210BB91F3C6CFEE3E5A5BF44CFC0E  42.059961
# 4               熊猫金控股份有限公司  84ABC66652EA601DD5EBB549C7C9EB1D   9.056696
# ...                    ...                               ...        ...
# 2289  上海来益生物药物研究开发中心有限责任公司  C9EA278C7AD48EF976F2D5AB0A21B41F  37.189502
# 2290         北京京东方技术开发有限公司  915090F769B30C0DE7D7797901160760  55.217514
# 2291        广州中智融通金融科技有限公司  06464D0D4CFC0A4F92B162A441A4C7D1  47.955397
# 2292          恺博座椅机械部件有限公司  EE30DAF2677EE4368332B0487EA2F457  58.166428
# 2293        西安隆基绿能建筑科技有限公司  8A1FDCC15A3CC35DFCA2A6BACC454B1B  36.136150
#
#        seic_lv1       seic_lv2                                ans_id  \
# 0      高端装备制造产业       智能制造装备产业  86bfcf18-fca7-4de0-8e1c-dfe1bc465ae2
# 1     新一代信息技术产业  互联网与云计算、大数据服务  7889ad28-09df-42f6-b9e4-1706b9c6bce0
# 2     新一代信息技术产业           人工智能  253cb079-dc77-4ae3-816b-61a0c5481a33
# 3          生物产业      生物农业及相关产业  8a0a48af-08d9-4b21-9c68-861d28b087de
# 4     新一代信息技术产业  互联网与云计算、大数据服务  3c8d9fb4-4c4e-4f32-b2d9-ea20369e7df8
# ...         ...            ...                                   ...
# 2289       生物产业         生物医药产业  1534bc62-68c8-494d-9bda-840bd84ee4f4
# 2290      相关服务业     新技术与创新创业服务  0091d920-9e02-44c3-8084-47b5685c39a2
# 2291  新一代信息技术产业  新兴软件和新型信息技术服务  fa890ff0-9a2b-4333-8b43-6ebcce5e4096
# 2292         其它             其它  34d9ef74-3cc8-412b-afdc-1005e262bde0
# 2293      新能源产业          太阳能产业  08ed875f-87f9-41fc-a0c3-9b45e2658490
#
#       patent_invalid_ratio
# 0                 0.975000
# 1                 1.000000
# 2                 0.739130
# 3                 0.121212
# 4                 1.000000
# ...                    ...
# 2289              0.404580
# 2290              0.010837
# 2291              0.085366
# 2292              0.010438
# 2293              0.000000
#
# [2294 rows x 12 columns]

# %% [markdown]
# # IV值

# %%
patent_invalid_ratio_iv=pd.read_excel('失效专利占比阈值 (version 1).xlsx',sheet_name='patent_invalid_ratio')
patent_invalid_ratio_iv
# Out:
#    good   bad  total  good_pct   bad_pct  total_pct  bad_rate       woe  \
# 0   161   716    877  0.245053  0.043924   0.051716  0.816420  1.719022
# 1    87   859    946  0.132420  0.052696   0.055785  0.908034  0.921437
# 2    70  1661   1731  0.106545  0.101896   0.102076  0.959561  0.044618
# 3    27  1147   1174  0.041096  0.070364   0.069230  0.977002 -0.537771
# 4    37   819    856  0.056317  0.050242   0.050478  0.956776  0.114132
# 5    13   876    889  0.019787  0.053739   0.052424  0.985377 -0.999119
# 6    42  1439   1481  0.063927  0.088277   0.087333  0.971641 -0.322736
# 7    99  6234   6333  0.150685  0.382431   0.373452  0.984368 -0.931356
# 8    10  1125   1135  0.015221  0.069014   0.066930  0.991189 -1.511656
# 9   111  1425   1536  0.168950  0.087418   0.090577  0.927734  0.658901
#
#          iv    iv_sum  bins_left  bins_right               feature     负样本占比  \
# 0  0.345746  0.828504      0.000       0.172  patent_invalid_ratio  0.245053
# 1  0.073461  0.828504      0.172       0.261  patent_invalid_ratio  0.132420
# 2  0.000207  0.828504      0.261       0.400  patent_invalid_ratio  0.106545
# 3  0.015739  0.828504      0.400       0.479  patent_invalid_ratio  0.041096
# 4  0.000693  0.828504      0.479       0.536  patent_invalid_ratio  0.056317
# 5  0.033922  0.828504      0.536       0.588  patent_invalid_ratio  0.019787
# 6  0.007859  0.828504      0.588       0.667  patent_invalid_ratio  0.063927
# 7  0.215838  0.828504      0.667       0.963  patent_invalid_ratio  0.150685
# 8  0.081317  0.828504      0.963       0.997  patent_invalid_ratio  0.015221
# 9  0.053721  0.828504      0.997       1.010  patent_invalid_ratio  0.168950
#
#      全部企业占比
# 0  0.680377
# 1  0.046359
# 2  0.052927
# 3  0.025122
# 4  0.028648
# 5  0.010693
# 6  0.022334
# 7  0.044247
# 8  0.002096
# 9  0.087197

# %%
#cut_list=optimize_bins.query('feature=="company_incre_apno_cnt_halfy"')['cut'].sort_values().tolist()
#risk_test['bins']=0
start=risk_test.columns.tolist().index('patent_invalid_ratio')
for s in risk_test.columns[start:]:
    #cut_list=optimize_bins.query('feature=="@s"')['cut'].sort_values().tolist()
    cut_list=patent_invalid_ratio_iv[patent_invalid_ratio_iv['feature']=="patent_invalid_ratio"]['bins_right'].sort_values().tolist()
    risk_test[s+'_bins']=0
    for l,i in enumerate(risk_test[s]):
        for j,k in enumerate(cut_list):   
            if np.isnan(i):
                risk_test[s+'_bins'].iloc[l]=0
                break
                #continue
            elif i>k:
                pass
                #continue
            #elif j>0 and k>=i>cut_list[j-1]:
            #else i>=cut_list[j-1]:
            else:
                risk_test[s+'_bins'].iloc[l]=j
                break
#risk_test.iloc[l].append(pd.Series([j-1]))
# Out:
# /Users/caicaiqijun/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
risk_test
# Out:
#               company_name  label source source_list  level  \
# 0             广西春茂投资股份有限公司      1     ST      ['ST']      1
# 1               乐美电商股份有限公司      1     ST      ['ST']      1
# 2             杭州仁盈科技股份有限公司      1     ST      ['ST']      1
# 3         云南云投生态环境科技股份有限公司      1     ST      ['ST']      1
# 4               熊猫金控股份有限公司      1     ST      ['ST']      1
# ...                    ...    ...    ...         ...    ...
# 2289  上海来益生物药物研究开发中心有限责任公司      0   PCT5    ['PCT5']      1
# 2290         北京京东方技术开发有限公司      0   PCT5    ['PCT5']      1
# 2291        广州中智融通金融科技有限公司      0   PCT5    ['PCT5']      1
# 2292          恺博座椅机械部件有限公司      0   PCT5    ['PCT5']      1
# 2293        西安隆基绿能建筑科技有限公司      0   PCT5    ['PCT5']      1
#
#                 clean_name                        company_id      total  \
# 0             广西春茂投资股份有限公司  59AA6D434BDDB66592063D42CE59E692   7.015092
# 1               乐美电商股份有限公司  6B83096E88917292FB8B832F6B2EF3C3   0.867167
# 2             杭州仁盈科技股份有限公司  4505BAB094F058A54507F40D9B5F994D  16.288171
# 3         云南云投生态环境科技股份有限公司  A1C210BB91F3C6CFEE3E5A5BF44CFC0E  42.059961
# 4               熊猫金控股份有限公司  84ABC66652EA601DD5EBB549C7C9EB1D   9.056696
# ...                    ...                               ...        ...
# 2289  上海来益生物药物研究开发中心有限责任公司  C9EA278C7AD48EF976F2D5AB0A21B41F  37.189502
# 2290         北京京东方技术开发有限公司  915090F769B30C0DE7D7797901160760  55.217514
# 2291        广州中智融通金融科技有限公司  06464D0D4CFC0A4F92B162A441A4C7D1  47.955397
# 2292          恺博座椅机械部件有限公司  EE30DAF2677EE4368332B0487EA2F457  58.166428
# 2293        西安隆基绿能建筑科技有限公司  8A1FDCC15A3CC35DFCA2A6BACC454B1B  36.136150
#
#        seic_lv1       seic_lv2                                ans_id  \
# 0      高端装备制造产业       智能制造装备产业  86bfcf18-fca7-4de0-8e1c-dfe1bc465ae2
# 1     新一代信息技术产业  互联网与云计算、大数据服务  7889ad28-09df-42f6-b9e4-1706b9c6bce0
# 2     新一代信息技术产业           人工智能  253cb079-dc77-4ae3-816b-61a0c5481a33
# 3          生物产业      生物农业及相关产业  8a0a48af-08d9-4b21-9c68-861d28b087de
# 4     新一代信息技术产业  互联网与云计算、大数据服务  3c8d9fb4-4c4e-4f32-b2d9-ea20369e7df8
# ...         ...            ...                                   ...
# 2289       生物产业         生物医药产业  1534bc62-68c8-494d-9bda-840bd84ee4f4
# 2290      相关服务业     新技术与创新创业服务  0091d920-9e02-44c3-8084-47b5685c39a2
# 2291  新一代信息技术产业  新兴软件和新型信息技术服务  fa890ff0-9a2b-4333-8b43-6ebcce5e4096
# 2292         其它             其它  34d9ef74-3cc8-412b-afdc-1005e262bde0
# 2293      新能源产业          太阳能产业  08ed875f-87f9-41fc-a0c3-9b45e2658490
#
#       patent_invalid_ratio  patent_invalid_ratio_bins
# 0                 0.975000                          8
# 1                 1.000000                          9
# 2                 0.739130                          7
# 3                 0.121212                          0
# 4                 1.000000                          9
# ...                    ...                        ...
# 2289              0.404580                          3
# 2290              0.010837                          0
# 2291              0.085366                          0
# 2292              0.010438                          0
# 2293              0.000000                          0
#
# [2294 rows x 13 columns]

# %%
csv_to_dict=[]
sample=risk_test
start=sample.columns.tolist().index('patent_invalid_ratio_bins')
for i in sample.columns[start:]: 
    grouped = sample.groupby(i)['label']
    result_df = grouped.agg([('good', lambda y: (y == 1).sum()),
        ('bad', lambda y: (y == 0).sum()),
        ('total', 'count')])
    result_df['good_pct']=result_df['good']/result_df['good'].sum()
    result_df['bad_pct']=result_df['bad']/result_df['bad'].sum()
    result_df['range']=result_df['good_pct']-result_df['bad_pct']
    result_df.reset_index(inplace=True)
    result_df['good_rate']=result_df['good'].cumsum()/result_df['good'].sum()
    result_df['bad_rate']=result_df['bad'].cumsum()/result_df['bad'].sum() 
    result_df['ks']=abs(result_df['good_rate']-result_df['bad_rate'])
    nums=len(result_df)
    columns=result_df.columns.values
    for i in range(nums):
        dt = {}
        for v in columns:
            dt['feature']=columns[0]
            if v==columns[0]:
                document = result_df[i:i + 1]
                dt['bins']=document[v][i]
            else:
                document = result_df[i:i + 1]
                dt[v] = document[v][i]
        csv_to_dict.append(dt)
test_sample_total=pd.DataFrame(csv_to_dict)
test_sample_total['woe']=np.log(test_sample_total['good_pct']/test_sample_total['bad_pct'])
test_sample_total['feature']=test_sample_total['feature'].str.split('_b', 1, expand=True).get(0)
test_sample_total['woe'].replace([np.inf,-np.inf],0,inplace=True)

# %%
test_sample_total
# Out:
#                 feature  bins  good  bad  total  good_pct   bad_pct     range  \
# 0  patent_invalid_ratio     0    51  775    826  0.058621  0.544242 -0.485621
# 1  patent_invalid_ratio     1    26  248    274  0.029885  0.174157 -0.144272
# 2  patent_invalid_ratio     2    29  210    239  0.033333  0.147472 -0.114139
# 3  patent_invalid_ratio     3    27   67     94  0.031034  0.047051 -0.016016
# 4  patent_invalid_ratio     4    20   43     63  0.022989  0.030197 -0.007208
# 5  patent_invalid_ratio     5    14   19     33  0.016092  0.013343  0.002749
# 6  patent_invalid_ratio     6    20   24     44  0.022989  0.016854  0.006135
# 7  patent_invalid_ratio     7   346   26    372  0.397701  0.018258  0.379443
# 8  patent_invalid_ratio     8    77    0     77  0.088506  0.000000  0.088506
# 9  patent_invalid_ratio     9   260   12    272  0.298851  0.008427  0.290424
#
#    good_rate  bad_rate        ks       woe
# 0   0.058621  0.544242  0.485621 -2.228306
# 1   0.088506  0.718399  0.629893 -1.762600
# 2   0.121839  0.865871  0.744032 -1.487080
# 3   0.152874  0.912921  0.760048 -0.416124
# 4   0.175862  0.943118  0.767256 -0.272736
# 5   0.191954  0.956461  0.764507  0.187350
# 6   0.214943  0.973315  0.758372  0.310410
# 7   0.612644  0.991573  0.378929  3.081074
# 8   0.701149  0.991573  0.290424  0.000000
# 9   1.000000  1.000000  0.000000  3.568507

# %%
# test_quanguo_bins['score']=test_quanguo_bins['score'].round(5)
# test_quanguo=pd.merge(test_quanguo_bins,test_sample_total,on=['feature','score'],how='left')
test_quanguo=test_sample_total
test_quanguo['IV']=test_quanguo['woe']*test_quanguo['range']
test_quanguo['IV_SUM']=test_quanguo.groupby('feature')['IV'].transform('sum')
test_quanguo['max_ks']=test_quanguo.groupby('feature')['ks'].transform('max')
#test_quanguo.drop_duplicates(subset=['feature','woe'],keep='first',inplace=True)
#test_quanguo.replace([np.inf,-np.inf],0,inplace=True)
test_quanguo
# Out:
#                 feature  bins  good  bad  total  good_pct   bad_pct     range  \
# 0  patent_invalid_ratio     0    51  775    826  0.058621  0.544242 -0.485621
# 1  patent_invalid_ratio     1    26  248    274  0.029885  0.174157 -0.144272
# 2  patent_invalid_ratio     2    29  210    239  0.033333  0.147472 -0.114139
# 3  patent_invalid_ratio     3    27   67     94  0.031034  0.047051 -0.016016
# 4  patent_invalid_ratio     4    20   43     63  0.022989  0.030197 -0.007208
# 5  patent_invalid_ratio     5    14   19     33  0.016092  0.013343  0.002749
# 6  patent_invalid_ratio     6    20   24     44  0.022989  0.016854  0.006135
# 7  patent_invalid_ratio     7   346   26    372  0.397701  0.018258  0.379443
# 8  patent_invalid_ratio     8    77    0     77  0.088506  0.000000  0.088506
# 9  patent_invalid_ratio     9   260   12    272  0.298851  0.008427  0.290424
#
#    good_rate  bad_rate        ks       woe        IV    IV_SUM    max_ks
# 0   0.058621  0.544242  0.485621 -2.228306  1.082112  3.722659  0.767256
# 1   0.088506  0.718399  0.629893 -1.762600  0.254294  3.722659  0.767256
# 2   0.121839  0.865871  0.744032 -1.487080  0.169733  3.722659  0.767256
# 3   0.152874  0.912921  0.760048 -0.416124  0.006665  3.722659  0.767256
# 4   0.175862  0.943118  0.767256 -0.272736  0.001966  3.722659  0.767256
# 5   0.191954  0.956461  0.764507  0.187350  0.000515  3.722659  0.767256
# 6   0.214943  0.973315  0.758372  0.310410  0.001904  3.722659  0.767256
# 7   0.612644  0.991573  0.378929  3.081074  1.169091  3.722659  0.767256
# 8   0.701149  0.991573  0.290424  0.000000  0.000000  3.722659  0.767256
# 9   1.000000  1.000000  0.000000  3.568507  1.036379  3.722659  0.767256

# %%
test_quanguo.to_excel('bins.xlsx',encoding='utf-8',index=False)

# %%
def plot_ks(i):
    duration=test_quanguo[test_quanguo['feature']==i]
    title=duration.feature.iloc[1]
    p_event=duration['good_rate'].tolist()
    p_nonevent=duration['bad_rate'].tolist()
    ks_max_idx=duration.ks.argmax()
    a=np.array(duration['bins'].value_counts().sort_index().index.to_list())
    pp=[*a]
    ks_score=duration.ks.max()
    
    plt.title(title, fontdict={'fontsize': 14})
    #plt.xlabel('Threshold', fontdict={'fontsize': 12})
    plt.ylabel('Cumulative probability', fontdict={'fontsize': 12})

    plt.plot([*a], p_event, color="r", label="Cumulative events",marker='o')
    plt.plot([*a], p_nonevent, color="b", label="Cumulative non-events",marker='o')

    plt.vlines(pp[ks_max_idx], ymin=p_event[ks_max_idx],
               ymax=p_nonevent[ks_max_idx], color="k", linestyles="--")

    # Set KS value inside plot
    pos_x = pp[ks_max_idx] + 0.02
    #pos_x = pp[ks_max_idx] 
    #print(pos_x)
    pos_y = 0.5 * (p_nonevent[ks_max_idx] + p_event[ks_max_idx])
    #print(pos_y)
    text = "KS: {:.2%} at {:.2f}".format(ks_score, pp[ks_max_idx])
    plt.text(pos_x, pos_y, text, fontsize=12, rotation_mode="anchor")

    plt.legend(loc='lower right')

# %%
plt.figure(figsize=(30,40))
for i,w in enumerate(sorted(test_quanguo.feature.unique()),1):
    plt.plot(ax=plt.subplot(10,5,i))
    plot_ks(w)
