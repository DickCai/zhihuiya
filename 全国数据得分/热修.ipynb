# %%
import pandas as pd
import os
os.chdir('/Users/caicaiqijun/Downloads')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # v2_0

# %%
v2_0=pd.read_parquet('v2.0')
v2_0
# Out:
#                           company_id      score rating rating_lv2  \
# 0   CE8D6FEB9A5E117FDB40912BCFB1F5B6   4.629496      E          A
# 1   D010CC131040EC45DC97171D11A05691  10.616487      D          A
# 2   F1294BCF700184FE55B7FC52C6EEA807  15.174558      E          E
# 3   E3BB6D5338C95E34F8EBC1ED864C4AF3  13.763637      A          A
# 4   DE54858ABB3DA56EDA8EE2DD97D1667E   8.964179      E          D
# 5   91A174539720B7A6A36A3A762C997BB2  14.892309      A          A
# 6   1BD472E5B82B57FA0C4627DF569AE9CE  22.526664      A          A
# 7   C3D5FA2D17418D531F93A402FDC9D7CF  18.382674      A          A
# 8   16A689785F92EF28D85A7862CFB36047  51.002714      A          A
# 9   DB0C338E9F2A7C9051E4F5AB1A786FCE  17.171122      A          A
# 10  AD7B562CC674D22C448A4814E4D2905B  10.437155      D          C
# 11  C04E4FA5054A141BADC478A0CA5C198E   7.686735      E          E
# 12  333502DE36200053F3FF7F82E069959E   2.940013      E          E
# ...

# %% [markdown]
# ## score_dimension

# %%
score_dimension=v2_0[['company_id','score_dimension']]
score_dimension['fundamental']=score_dimension['score_dimension'].str.get('fundamental')
score_dimension['fundamental_rating_lv2']=score_dimension['score_dimension'].str.get('fundamental_rating_lv2')
score_dimension['rd_scale_and_stability']=score_dimension['score_dimension'].str.get('rd_scale_and_stability')
score_dimension['rd_scale_and_stability_rating']=score_dimension['score_dimension'].str.get('rd_scale_and_stability_rating')
score_dimension['rd_scale_and_stability_rating_lv2']=score_dimension['score_dimension'].str.get('rd_scale_and_stability_rating_lv2')
score_dimension['tech_influence']=score_dimension['score_dimension'].str.get('tech_influence')
score_dimension['tech_influence_rating']=score_dimension['score_dimension'].str.get('tech_influence_rating_lv2')
score_dimension['tech_layout']=score_dimension['score_dimension'].str.get('tech_layout')
score_dimension['tech_layout_rating']=score_dimension['score_dimension'].str.get('tech_layout_rating')
score_dimension['tech_layout_rating_lv2']=score_dimension['score_dimension'].str.get('tech_layout_rating_lv2')
score_dimension['tech_quality']=score_dimension['score_dimension'].str.get('tech_quality')
score_dimension['tech_quality_rating']=score_dimension['score_dimension'].str.get('tech_quality_rating')
score_dimension['tech_quality_rating_lv2']=score_dimension['score_dimension'].str.get('tech_quality_rating_lv2')

# %%
score_dimension
# Out:
#                           company_id  \
# 0   CE8D6FEB9A5E117FDB40912BCFB1F5B6
# 1   D010CC131040EC45DC97171D11A05691
# 2   F1294BCF700184FE55B7FC52C6EEA807
# 3   E3BB6D5338C95E34F8EBC1ED864C4AF3
# 4   DE54858ABB3DA56EDA8EE2DD97D1667E
# 5   91A174539720B7A6A36A3A762C997BB2
# 6   1BD472E5B82B57FA0C4627DF569AE9CE
# 7   C3D5FA2D17418D531F93A402FDC9D7CF
# 8   16A689785F92EF28D85A7862CFB36047
# 9   DB0C338E9F2A7C9051E4F5AB1A786FCE
# 10  AD7B562CC674D22C448A4814E4D2905B
# 11  C04E4FA5054A141BADC478A0CA5C198E
# 12  333502DE36200053F3FF7F82E069959E
# 13  D10BAE4CCD400B230105F3D7DC1F05FC
# 14  9EA4DD46578CBC793E52202FF10D2B5A
# 15  50D1CCCDECE891408998C7964DBBED68
#
#                                       score_dimension  fundamental  \
# 0   {'fundamental': 0.09852794463214283, 'fundamen...     0.098528
# 1   {'fundamental': 5.530186480875285, 'fundamenta...     5.530186
# 2   {'fundamental': 0.2882582706428571, 'fundament...     0.288258
# ...

# %% [markdown]
# ## original_detail

# %%
original_detail=v2_0[['company_id','original_detail']]
original_detail['active_inventor_ratio']=original_detail['original_detail'].str.get('active_inventor_ratio')
original_detail['actual_capital_formatted']=original_detail['original_detail'].str.get('actual_capital_formatted')
original_detail['ans_id']=original_detail['original_detail'].str.get('ans_id')
original_detail['apno_cnt']=original_detail['original_detail'].str.get('apno_cnt')
original_detail['apno_cnt_valid_5y']=original_detail['original_detail'].str.get('apno_cnt_valid_5y')
original_detail['avg_3y_cnt']=original_detail['original_detail'].str.get('avg_3y_cnt')
original_detail['avg_cited_by_cnt']=original_detail['original_detail'].str.get('avg_cited_by_cnt')
original_detail['avg_funding_interval']=original_detail['original_detail'].str.get('avg_funding_interval')
original_detail['avg_remaining_life_span']=original_detail['original_detail'].str.get('avg_remaining_life_span')
original_detail['avg_technology_score']=original_detail['original_detail'].str.get('avg_technology_score')
original_detail['city']=original_detail['original_detail'].str.get('city')
original_detail['company_id']=original_detail['original_detail'].str.get('company_id')
original_detail['company_name']=original_detail['original_detail'].str.get('company_name')
original_detail['core_patents_cited_by_cnt']=original_detail['original_detail'].str.get('core_patents_cited_by_cnt')

original_detail['core_patents_cited_by_ratio']=original_detail['original_detail'].str.get('core_patents_cited_by_ratio')
original_detail['country_cnt']=original_detail['original_detail'].str.get('country_cnt')
original_detail['duration']=original_detail['original_detail'].str.get('duration')
original_detail['external_licensing_cnt']=original_detail['original_detail'].str.get('external_licensing_cnt')
original_detail['granted_invention_cnt']=original_detail['original_detail'].str.get('granted_invention_cnt')
original_detail['granted_invention_cnt_pb_1y']=original_detail['original_detail'].str.get('granted_invention_cnt_pb_1y')
original_detail['granted_invention_cnt_pb_original_2y']=original_detail['original_detail'].str.get('granted_invention_cnt_pb_original_2y')
original_detail['granted_invention_ratio']=original_detail['original_detail'].str.get('granted_invention_ratio')
original_detail['in_examing_ratio']=original_detail['original_detail'].str.get('in_examing_ratio')
original_detail['invention_ratio']=original_detail['original_detail'].str.get('invention_ratio')
original_detail['invention_stability']=original_detail['original_detail'].str.get('invention_stability')
original_detail['inventor_cnt']=original_detail['original_detail'].str.get('inventor_cnt')
original_detail['ip_dependency']=original_detail['original_detail'].str.get('ip_dependency')
original_detail['joint_applicant_cnt']=original_detail['original_detail'].str.get('joint_applicant_cnt')

original_detail['joint_application_cnt']=original_detail['original_detail'].str.get('joint_application_cnt')
original_detail['money_q25_sum_weighted']=original_detail['original_detail'].str.get('money_q25_sum_weighted')
original_detail['most_cited_patents_value']=original_detail['original_detail'].str.get('most_cited_patents_value')
original_detail['most_recent_money_q25_formatted']=original_detail['original_detail'].str.get('most_recent_money_q25_formatted')
original_detail['most_recent_time']=original_detail['original_detail'].str.get('most_recent_time')
original_detail['non_design_apno_cnt']=original_detail['original_detail'].str.get('non_design_apno_cnt')
original_detail['num_certificates']=original_detail['original_detail'].str.get('num_certificates')
original_detail['num_members']=original_detail['original_detail'].str.get('num_members')
original_detail['num_trademarks_registered_5y']=original_detail['original_detail'].str.get('num_trademarks_registered_5y')
original_detail['num_trademarks_total_5y']=original_detail['original_detail'].str.get('num_trademarks_total_5y')
original_detail['patent_valid_ratio']=original_detail['original_detail'].str.get('patent_valid_ratio')
original_detail['patenting_growth_ratio']=original_detail['original_detail'].str.get('patenting_growth_ratio')
original_detail['pct_apno_cnt']=original_detail['original_detail'].str.get('pct_apno_cnt')
original_detail['province']=original_detail['original_detail'].str.get('province')

original_detail['public']=original_detail['original_detail'].str.get('public')
original_detail['qualification']=original_detail['original_detail'].str.get('qualification')
original_detail['qualify_certificate']=original_detail['original_detail'].str.get('qualify_certificate')
original_detail['reg_3y_avg']=original_detail['original_detail'].str.get('reg_3y_avg')
original_detail['reg_capital_formatted']=original_detail['original_detail'].str.get('reg_capital_formatted')
original_detail['reg_num_5y']=original_detail['original_detail'].str.get('reg_num_5y')
original_detail['rounds']=original_detail['original_detail'].str.get('rounds')
original_detail['seic_lv1']=original_detail['original_detail'].str.get('seic_lv1')
original_detail['seic_lv2']=original_detail['original_detail'].str.get('seic_lv2')
original_detail['self_cited_by_ratio']=original_detail['original_detail'].str.get('self_cited_by_ratio')
original_detail['status']=original_detail['original_detail'].str.get('status')
original_detail['tech_global_concentration']=original_detail['original_detail'].str.get('tech_global_concentration')
original_detail['tech_width']=original_detail['original_detail'].str.get('tech_width')
original_detail['top5_current_impact_index']=original_detail['original_detail'].str.get('top5_current_impact_index')

original_detail['total_patent_award_score']=original_detail['original_detail'].str.get('total_patent_award_score')
original_detail['value_avg']=original_detail['original_detail'].str.get('value_avg')
original_detail['value_sum']=original_detail['original_detail'].str.get('value_sum')
original_detail['value_top10_avg']=original_detail['original_detail'].str.get('value_top10_avg')
original_detail['value_top5_avg']=original_detail['original_detail'].str.get('value_top5_avg')

# %%
original_detail[['company_id','apno_cnt','value_sum']]
# Out:
#                           company_id  apno_cnt  value_sum
# 0   CE8D6FEB9A5E117FDB40912BCFB1F5B6         2        NaN
# 1   D010CC131040EC45DC97171D11A05691         2        NaN
# 2   F1294BCF700184FE55B7FC52C6EEA807        25    84000.0
# 3   E3BB6D5338C95E34F8EBC1ED864C4AF3         1        NaN
# 4   DE54858ABB3DA56EDA8EE2DD97D1667E         4        NaN
# 5   91A174539720B7A6A36A3A762C997BB2         5    10600.0
# 6   1BD472E5B82B57FA0C4627DF569AE9CE         1        NaN
# 7   C3D5FA2D17418D531F93A402FDC9D7CF         1     3500.0
# 8   16A689785F92EF28D85A7862CFB36047        47   236100.0
# 9   DB0C338E9F2A7C9051E4F5AB1A786FCE         2        NaN
# 10  AD7B562CC674D22C448A4814E4D2905B         1     3400.0
# 11  C04E4FA5054A141BADC478A0CA5C198E         1        NaN
# 12  333502DE36200053F3FF7F82E069959E         0        NaN
# 13  D10BAE4CCD400B230105F3D7DC1F05FC        47  1469000.0
# 14  9EA4DD46578CBC793E52202FF10D2B5A         1        NaN
# ...

# %% [markdown]
# # v2_1

# %%
v2_1=pd.read_parquet('v2.1')
v2_1
# Out:
#                           company_id      score rating rating_lv2  \
# 0   CE8D6FEB9A5E117FDB40912BCFB1F5B6   4.554828      E          A
# 1   D010CC131040EC45DC97171D11A05691   9.830450      D          A
# 2   F1294BCF700184FE55B7FC52C6EEA807  25.678793      E          E
# 3   E3BB6D5338C95E34F8EBC1ED864C4AF3   4.110382      A          A
# 4   DE54858ABB3DA56EDA8EE2DD97D1667E   8.735511      E          D
# 5   91A174539720B7A6A36A3A762C997BB2   7.409772      A          A
# 6   1BD472E5B82B57FA0C4627DF569AE9CE  13.085808      A          A
# 7   C3D5FA2D17418D531F93A402FDC9D7CF   9.071959      D          C
# 8   16A689785F92EF28D85A7862CFB36047  35.975814      D          A
# 9   DB0C338E9F2A7C9051E4F5AB1A786FCE   7.327650      A          A
# 10  AD7B562CC674D22C448A4814E4D2905B  10.818372      A          A
# 11  C04E4FA5054A141BADC478A0CA5C198E   6.900697      E          E
# 12  333502DE36200053F3FF7F82E069959E   2.636799      E          E
# ...
