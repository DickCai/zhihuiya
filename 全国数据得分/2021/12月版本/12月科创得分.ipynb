# %%
import pandas as pd
import os
os.chdir(r'D:\数据\全国数据\全国数据得分\全国数据得分更新12月\quanguo_12th')
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company_test',echo=False)
pd.set_option('max_rows',200)
pd.set_option('max_columns',200)
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 12 月分数

# %% [markdown]
# ## total

# %%
total=pd.read_parquet('total.parquet')

# %%
total.set_index('company_id',inplace=True)

# %%
total
# Out:
#                                     company_name   seic_lv1       seic_lv2  \
# company_id
# 6ADC8F4FC710980A54D1FB1C710D00DB  无锡弘金环保科技集团有限公司     节能环保产业         先进环保产业
# 6AEBE61BDC7DE66E2E8A92FC13B42652    山东翔迈智能科技有限公司  新一代信息技术产业           人工智能
# 6AF350482B95A26449FB1FBA92F86651    四川光华水电工程有限公司    新能源汽车产业    新能源汽车相关设施制造
# 6B24971C713FD86A97C31FC92927D15D    苏州慧动信息科技有限公司  新一代信息技术产业  新兴软件和新型信息技术服务
# 6B456404DD4424E02721D4B430173D25    山西国药智信科技有限公司       生物产业         生物医药产业
# ...                                          ...        ...            ...
# 9069F2313D16DB2130699177D0464053      长沙兴茂投资有限公司      新材料产业       先进有色金属材料
# 9077251F81E9E59FC5262C642795071C      长兴展鹏纺织有限公司         其它             其它
# 9080C04BEDAF3C5B3A7BADFD09A7EA9F     昌宁双胞胎饲料有限公司       生物产业      生物农业及相关产业
# 90B072E2F9ECA35BBAAD0BE034704EBA    上海芭欧通信技术有限公司  新一代信息技术产业      下一代信息网络产业
# 90B1FC29B2D842E74E527E5507861CCE    湖南尔旭环保科技有限公司     节能环保产业         先进环保产业
#
# ...

# %%
total[total['company_name']=='杭州首掌文化传媒有限公司']
# Out:
#                                   company_name seic_lv1   seic_lv2  apno_cnt  \
# company_id
# 1CF84A126894CCA7678A13D12F81C256  杭州首掌文化传媒有限公司   数字创意产业  数字创意与融合服务       NaN
#
#                                   patent  nonpatent     total  rank_total  \
# company_id
# 1CF84A126894CCA7678A13D12F81C256     0.0   4.735148  4.735148    600308.0
#
#                                   rank_seic_lv1 rating_seic_lv1  \
# company_id
# 1CF84A126894CCA7678A13D12F81C256        30799.0               E
#
#                                   rank_seic_lv2 rating_seic_lv2
# company_id
# 1CF84A126894CCA7678A13D12F81C256         4919.0               C

# %%
total[total['company_name']=='杭州首掌文化传媒有限公司']
# Out:
# Empty DataFrame
# Columns: [company_name, seic_lv1, seic_lv2, apno_cnt, patent, nonpatent, total, rank_total, rank_seic_lv1, rating_seic_lv1, rank_seic_lv2, rating_seic_lv2]
# Index: []

# %%
total.sort_values('total',ascending=False)
# Out:
#                                     company_name seic_lv1    seic_lv2  \
# company_id
# 5F541FCEDCBD305A0498DBE52F5A10BA  奥比中光科技集团股份有限公司   数字创意产业  数字创意技术设备制造
# 348757E983F0C55D275B952DFCF30EE3    成都极米科技股份有限公司   数字创意产业  数字创意技术设备制造
# 448C7D67AAC13E2714CE84ED5E0A9F02      北京仁光科技有限公司   数字创意产业  数字创意技术设备制造
# B7E2B30CD171F7F5FD6A2888D615871A  深圳创维-RGB电子有限公司   数字创意产业  数字创意技术设备制造
# BB94700161B5A486516E738B825E8FBD  成都索贝数码科技股份有限公司   数字创意产业  数字创意技术设备制造
# ...                                          ...      ...         ...
# 0AF350DA3FD33A9B59172E7CBBE1C141    金阳亿动视通工程有限公司   数字创意产业  数字创意技术设备制造
# 44135CF7C9A3270452DB0BE4034D5904  深圳市宇邦德电子科技有限公司   数字创意产业  数字创意技术设备制造
# 1EC191D917CC4EE9E5EF1982AE0A027F    深圳市新视通科技有限公司   数字创意产业  数字创意技术设备制造
# FF13784B23172E62CEBF3B95C0E0D4DE  保定存帧影视科技股份有限公司   数字创意产业  数字创意技术设备制造
# 08227F47B1F002EC995D458728CB3355    广梦科技（深圳）有限公司   数字创意产业  数字创意技术设备制造
#
#                                   apno_cnt     patent  nonpatent      total  \
# company_id
# ...

# %%
total[total['company_name']=='江苏兴业智慧建筑科技有限公司']
# Out:
#                                     company_name seic_lv1 seic_lv2  apno_cnt  \
# company_id
# 20475D111B83E4F563EB1AECCB59E25E  江苏兴业智慧建筑科技有限公司   数字创意产业     设计服务      21.0
#
#                                      patent  nonpatent      total  rank_total  \
# company_id
# 20475D111B83E4F563EB1AECCB59E25E  19.980099   8.043863  28.023961    152094.0
#
#                                   rank_seic_lv1 rating_seic_lv1  \
# company_id
# 20475D111B83E4F563EB1AECCB59E25E         4713.0               B
#
#                                   rank_seic_lv2 rating_seic_lv2
# company_id
# 20475D111B83E4F563EB1AECCB59E25E         1183.0               A

# %% [markdown]
# ## 地址

# %%
address=pd.read_csv('地址.csv')

# %%
address.set_index('company_id',inplace=True)

# %%
Score=pd.merge(total,address,how='left',on='company_id')

# %%
Score
# Out:
#                                     company_name   seic_lv1       seic_lv2  \
# company_id
# 6ADC8F4FC710980A54D1FB1C710D00DB  无锡弘金环保科技集团有限公司     节能环保产业         先进环保产业
# 6AEBE61BDC7DE66E2E8A92FC13B42652    山东翔迈智能科技有限公司  新一代信息技术产业           人工智能
# 6AF350482B95A26449FB1FBA92F86651    四川光华水电工程有限公司    新能源汽车产业    新能源汽车相关设施制造
# 6B24971C713FD86A97C31FC92927D15D    苏州慧动信息科技有限公司  新一代信息技术产业  新兴软件和新型信息技术服务
# 6B456404DD4424E02721D4B430173D25    山西国药智信科技有限公司       生物产业         生物医药产业
# ...                                          ...        ...            ...
# 9069F2313D16DB2130699177D0464053      长沙兴茂投资有限公司      新材料产业       先进有色金属材料
# 9077251F81E9E59FC5262C642795071C      长兴展鹏纺织有限公司         其它             其它
# 9080C04BEDAF3C5B3A7BADFD09A7EA9F     昌宁双胞胎饲料有限公司       生物产业      生物农业及相关产业
# 90B072E2F9ECA35BBAAD0BE034704EBA    上海芭欧通信技术有限公司  新一代信息技术产业      下一代信息网络产业
# 90B1FC29B2D842E74E527E5507861CCE    湖南尔旭环保科技有限公司     节能环保产业         先进环保产业
#
# ...

# %%
 Digital=Score[Score['seic_lv2']=='数字创意技术设备制造']

# %%
Digital
# Out:
#                                     company_name seic_lv1    seic_lv2  \
# company_id
# 84D3D959D75F30E75A849AE04AB77685   东莞市小禾电子科技有限公司   数字创意产业  数字创意技术设备制造
# 8C930BE92F5B57CCDEE47327961BFAA2    深圳市微众芯科技有限公司   数字创意产业  数字创意技术设备制造
# B642782BA640DD20FEB0BCFDEA3CD862    青岛鸿永广告材料有限公司   数字创意产业  数字创意技术设备制造
# CB01A558F56018119A06077AF388AA81    深圳市源智通科技有限公司   数字创意产业  数字创意技术设备制造
# CE84FE5F72287A38BC015B6FF607ECC4     深圳市吉邦科技有限公司   数字创意产业  数字创意技术设备制造
# ...                                          ...      ...         ...
# 34EA1CB2472EEA8B7165EBCE0B779DFE     深圳市衡硕科技有限公司   数字创意产业  数字创意技术设备制造
# 3999DDE4C2D99DBC755C3C66C2CC7A65  露曦（北京）科技发展有限公司   数字创意产业  数字创意技术设备制造
# 3EBEDEFBBC6CBFDA15FE004FF938EC53     深圳市麦视科技有限公司   数字创意产业  数字创意技术设备制造
# 592562E24BACE95F819A4059028A5FB1    江西博星数码科技有限公司   数字创意产业  数字创意技术设备制造
# 79A50402DC7C19BFAF37715A745C875A      深圳泽乐科技有限公司   数字创意产业  数字创意技术设备制造
#
#                                   apno_cnt     patent  nonpatent      total  \
# company_id
# ...

# %%
Digital['address_city'].value_counts().head(100)
# Out:
# 北京市         11354
# 上海市          2380
# 广州市          2235
# 深圳市          1882
# 杭州市          1047
# 天津市           956
# 成都市           877
# 武汉市           757
# 南京市           567
# 厦门市           549
# 重庆市           318
# 苏州市           303
# 西安市           289
# 合肥市           236
# 郑州市           220
# 青岛市           218
# 福州市           215
# 长沙市           204
# 大连市           181
# 石家庄市          135
# 贵阳市           133
# 宁波市           132
# 珠海市           124
# 济南市           112
# 沈阳市           109
# 南昌市           108
# 佛山市           107
# 金华市           106
# 哈尔滨市          105
# 东莞市            95
# 无锡市            91
# 泉州市            90
# 太原市            89
# 长春市            87
# 海口市            87
# 温州市            82
# 徐州市            73
# 中山市            67
# 常州市            67
# 绍兴市            58
# 澄迈县            57
# 昆明市            55
# 绵阳市            51
# 南宁市            50
# 嘉兴市            44
# 唐山市            41
# 芜湖市            41
# 汕头市            40
# 三亚市            37
# 廊坊市            36
# ...

# %%
Digital[Digital['address_city']=='北京市']['total'].mean()
# Out:
# 10.617763008831647

# %%
Digital[Digital['address_city']=='上海市']['total'].mean()
# Out:
# 10.396486067970063

# %% [markdown]
# ## 分数分布区间

# %%
test_quanguo_11_score=total

# %%
Score_5=test_quanguo_11_score[(test_quanguo_11_score['total']>=0) &(test_quanguo_11_score['total']<5)]
Score_10=test_quanguo_11_score[(test_quanguo_11_score['total']>=5) &(test_quanguo_11_score['total']<10)]
Score_15=test_quanguo_11_score[(test_quanguo_11_score['total']>=10) &(test_quanguo_11_score['total']<15)]
Score_20=test_quanguo_11_score[(test_quanguo_11_score['total']>=15) &(test_quanguo_11_score['total']<20)]
Score_25=test_quanguo_11_score[(test_quanguo_11_score['total']>=20) &(test_quanguo_11_score['total']<25)]
Score_30=test_quanguo_11_score[(test_quanguo_11_score['total']>=25) &(test_quanguo_11_score['total']<30)]
Score_35=test_quanguo_11_score[(test_quanguo_11_score['total']>=30) &(test_quanguo_11_score['total']<35)]
Score_40=test_quanguo_11_score[(test_quanguo_11_score['total']>=35) &(test_quanguo_11_score['total']<40)]
Score_45=test_quanguo_11_score[(test_quanguo_11_score['total']>=40) &(test_quanguo_11_score['total']<45)]
Score_50=test_quanguo_11_score[(test_quanguo_11_score['total']>=45) &(test_quanguo_11_score['total']<50)]
Score_55=test_quanguo_11_score[(test_quanguo_11_score['total']>=50) &(test_quanguo_11_score['total']<55)]
Score_60=test_quanguo_11_score[(test_quanguo_11_score['total']>=55) &(test_quanguo_11_score['total']<60)]
Score_65=test_quanguo_11_score[(test_quanguo_11_score['total']>=60) &(test_quanguo_11_score['total']<65)]
Score_70=test_quanguo_11_score[(test_quanguo_11_score['total']>=65) &(test_quanguo_11_score['total']<70)]
Score_75=test_quanguo_11_score[(test_quanguo_11_score['total']>=70) &(test_quanguo_11_score['total']<75)]
Score_80=test_quanguo_11_score[(test_quanguo_11_score['total']>=75) &(test_quanguo_11_score['total']<80)]
Score_85=test_quanguo_11_score[(test_quanguo_11_score['total']>=80) &(test_quanguo_11_score['total']<85)]
Score_90=test_quanguo_11_score[(test_quanguo_11_score['total']>=85) &(test_quanguo_11_score['total']<90)]
Score_95=test_quanguo_11_score[(test_quanguo_11_score['total']>=90) &(test_quanguo_11_score['total']<95)]
Score_100=test_quanguo_11_score[(test_quanguo_11_score['total']>=95) &(test_quanguo_11_score['total']<100)]
Score_105=test_quanguo_11_score[(test_quanguo_11_score['total']>=100) &(test_quanguo_11_score['total']<105)]
Score_110=test_quanguo_11_score[(test_quanguo_11_score['total']>=105) &(test_quanguo_11_score['total']<110)]
Score_111=test_quanguo_11_score[(test_quanguo_11_score['total']>=110)]

# %%
print('Score_5的数量:',Score_5.shape[0])
print('Score_10的数量:',Score_10.shape[0])
print('Score_15的数量:',Score_15.shape[0])
print('Score_20的数量:',Score_20.shape[0])
print('Score_25的数量:',Score_25.shape[0])
print('Score_30的数量:',Score_30.shape[0])
print('Score_35的数量:',Score_35.shape[0])
print('Score_40的数量:',Score_40.shape[0])
print('Score_45的数量:',Score_45.shape[0])
print('Score_50的数量:',Score_50.shape[0])
print('Score_55的数量:',Score_55.shape[0])
print('Score_60的数量:',Score_60.shape[0])
print('Score_65的数量:',Score_65.shape[0])
print('Score_70的数量:',Score_70.shape[0])
print('Score_75的数量:',Score_75.shape[0])
print('Score_80的数量:',Score_80.shape[0])
print('Score_85的数量:',Score_85.shape[0])
print('Score_90的数量:',Score_90.shape[0])
print('Score_95的数量:',Score_95.shape[0])
print('Score_100的数量:',Score_100.shape[0])
print('Score_105的数量:',Score_105.shape[0])
print('Score_110的数量:',Score_110.shape[0])
print('Score_111的数量:',Score_111.shape[0])
# Out:
# Score_5的数量: 248684
# Score_10的数量: 165616
# Score_15的数量: 174805
# Score_20的数量: 103950
# Score_25的数量: 78365
# Score_30的数量: 56296
# Score_35的数量: 39116
# Score_40的数量: 26486
# Score_45的数量: 18794
# Score_50的数量: 13939
# Score_55的数量: 10185
# Score_60的数量: 7535
# Score_65的数量: 5544
# Score_70的数量: 3904
# Score_75的数量: 3179
# Score_80的数量: 1989
# Score_85的数量: 1126
# Score_90的数量: 453
# Score_95的数量: 129
# Score_100的数量: 18
# Score_105的数量: 0
# Score_110的数量: 0
# Score_111的数量: 0

# %%
total['rating_seic_lv2'].value_counts()
# Out:
# E    288010
# C    192030
# D    192028
# A    144032
# B    144013
# Name: rating_seic_lv2, dtype: int64

# %%
a=pd.DataFrame(total['seic_lv2'].value_counts())

# %%
a
# Out:
#                seic_lv2
# 其它               211020
# 智能制造装备产业          93138
# 电子核心产业            55234
# 新兴软件和新型信息技术服务     54769
# 生物农业及相关产业         53687
# 先进环保产业            43764
# 先进无机非金属材料         35651
# 互联网与云计算、大数据服务     35321
# 先进石化化工新材料         31398
# 智能电网产业            31340
# 人工智能              30778
# 新技术与创新创业服务        30597
# 数字文化创意活动          28702
# 生物医学工程产业          26075
# 下一代信息网络产业         23885
# 生物医药产业            21405
# 先进有色金属材料          19053
# 先进钢铁材料            16418
# 高效节能产业            15109
# 数字创意与融合服务         11396
# 海洋工程装备产业           9290
# 高性能纤维及制品和复合材料      8452
# 设计服务               8194
# 太阳能产业              8161
# 轨道交通装备产业           8147
# 数字创意技术设备制造         8139
# 资源循环利用产业           7619
# 其他相关服务             5088
# 生物质能产业             5035
# 航空装备产业             4541
# 前沿新材料              3953
# 新能源汽车相关设施制造        3309
# 新能源汽车装置、配件制造       2623
# 其他生物业              2378
# 风能产业               1904
# 核电产业               1897
# 卫星及应用产业            1178
# ...

# %%
a.reset_index(inplace=True)
a
# Out:
#             index  seic_lv2
# 0              其它    211020
# 1        智能制造装备产业     93138
# 2          电子核心产业     55234
# 3   新兴软件和新型信息技术服务     54769
# 4       生物农业及相关产业     53687
# 5          先进环保产业     43764
# 6       先进无机非金属材料     35651
# 7   互联网与云计算、大数据服务     35321
# 8       先进石化化工新材料     31398
# 9          智能电网产业     31340
# 10           人工智能     30778
# 11     新技术与创新创业服务     30597
# 12       数字文化创意活动     28702
# 13       生物医学工程产业     26075
# 14      下一代信息网络产业     23885
# 15         生物医药产业     21405
# 16       先进有色金属材料     19053
# 17         先进钢铁材料     16418
# 18         高效节能产业     15109
# 19      数字创意与融合服务     11396
# 20       海洋工程装备产业      9290
# 21  高性能纤维及制品和复合材料      8452
# 22           设计服务      8194
# 23          太阳能产业      8161
# 24       轨道交通装备产业      8147
# 25     数字创意技术设备制造      8139
# 26       资源循环利用产业      7619
# 27         其他相关服务      5088
# 28         生物质能产业      5035
# 29         航空装备产业      4541
# 30          前沿新材料      3953
# 31    新能源汽车相关设施制造      3309
# ...

# %%
a.rename(columns={'index':'seic'},inplace=True)

# %%
a
# Out:
#              seic  seic_lv2
# 0              其它    211020
# 1        智能制造装备产业     93138
# 2          电子核心产业     55234
# 3   新兴软件和新型信息技术服务     54769
# 4       生物农业及相关产业     53687
# 5          先进环保产业     43764
# 6       先进无机非金属材料     35651
# 7   互联网与云计算、大数据服务     35321
# 8       先进石化化工新材料     31398
# 9          智能电网产业     31340
# 10           人工智能     30778
# 11     新技术与创新创业服务     30597
# 12       数字文化创意活动     28702
# 13       生物医学工程产业     26075
# 14      下一代信息网络产业     23885
# 15         生物医药产业     21405
# 16       先进有色金属材料     19053
# 17         先进钢铁材料     16418
# 18         高效节能产业     15109
# 19      数字创意与融合服务     11396
# 20       海洋工程装备产业      9290
# 21  高性能纤维及制品和复合材料      8452
# 22           设计服务      8194
# 23          太阳能产业      8161
# 24       轨道交通装备产业      8147
# 25     数字创意技术设备制造      8139
# 26       资源循环利用产业      7619
# 27         其他相关服务      5088
# 28         生物质能产业      5035
# 29         航空装备产业      4541
# 30          前沿新材料      3953
# 31    新能源汽车相关设施制造      3309
# ...

# %%
total.loc['A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
# company_name        华为技术有限公司
# seic_lv1           新一代信息技术产业
# seic_lv2           下一代信息网络产业
# apno_cnt            225652.0
# patent             66.370183
# nonpatent          18.883681
# total              85.253864
# rank_total             553.0
# rank_seic_lv1          244.0
# rating_seic_lv1            A
# rank_seic_lv2           50.0
# rating_seic_lv2            A
# Name: A70A3E493E6B6E9C3D1CDA03B6279CAA, dtype: object

# %%
total.sort_values('total',ascending=False).head(100)
# Out:
#                                          company_name   seic_lv1  \
# company_id
# 66328D3F25518BB03F4BE6FE3360E076        京东方科技集团股份有限公司  新一代信息技术产业
# 223A24992E2387E93FC4DAE6F36F74C0           北京旷视科技有限公司  新一代信息技术产业
# 69B22BD76B62602B2E420928AB87BD67      宁德时代新能源科技股份有限公司    新能源汽车产业
# AEFE51DB9676F369A594054748320B19         浙江中控技术股份有限公司   高端装备制造产业
# 0DC7CE6184A517E768F29F1DE00C6590         绿盟科技集团股份有限公司  新一代信息技术产业
# E372D1FDC7C48C3AAF31E5EF52E9E995           科大讯飞股份有限公司  新一代信息技术产业
# 16C90A6C342F9363625383F8E8632DDA         北京辰安科技股份有限公司  新一代信息技术产业
# DC7802B75438F44ED32F967C81847DD7       上海联影医疗科技股份有限公司       生物产业
# 286C56991AE947ACE389D5385ADF62B2        北京智芯微电子科技有限公司  新一代信息技术产业
# 5026E7AE51040D315A548CC1BA837F34     深圳迈瑞生物医疗电子股份有限公司       生物产业
# 31DD96D9B3973E7A3E028E41A8F4BE6D         珠海格力电器股份有限公司     节能环保产业
# 7FF2FB01EFC34FB849604E1943988ACA         武汉华中数控股份有限公司   高端装备制造产业
# 6DF2B2E6FD691BF8EA703B35A74CD220     安徽科大讯飞医疗信息技术有限公司       生物产业
# ...

# %%
total['total'].max()
# Out:
# 99.27057695432038

# %%
total['total'].min()
# Out:
# 0.06340860140357141

# %%
# %matplotlib qt5
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(total['total'],bins=23,ax=axes[0])
ax2=sns.distplot(total['total'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(total['total'],bins=23,kde=False,ax=axes[2])
ax1.set_title('全国12月数据的密度分布')
ax2.set_title('全国12月数据点实际的分布')
ax3.set_title('全国12月数据数量分布')
# Out:
# Text(0.5, 1.0, '全国12月数据数量分布')

# %%
total['total'].hist(bins=23)

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 960113 entries, 6ADC8F4FC710980A54D1FB1C710D00DB to 90B1FC29B2D842E74E527E5507861CCE
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   company_name     960113 non-null  string
#  1   seic_lv1         960113 non-null  string
#  2   seic_lv2         960113 non-null  string
#  3   apno_cnt         864448 non-null  float64
#  4   patent           960113 non-null  float64
#  5   nonpatent        960113 non-null  float64
#  6   total            960113 non-null  float64
#  7   rank_total       960113 non-null  float64
#  8   rank_seic_lv1    960113 non-null  float64
#  9   rating_seic_lv1  960113 non-null  object
#  10  rank_seic_lv2    960113 non-null  float64
#  11  rating_seic_lv2  960113 non-null  object
# dtypes: float64(7), object(2), string(3)
# memory usage: 127.5+ MB

# %% [markdown]
# ### 三个版本都在top100的公司

# %%
Polairs=pd.read_sql('select * from Polairs',con=engine)

# %%
Polairs.set_index('company_id',inplace=True)
Polairs
# Out:
#                                        company_name   seic_lv1  rank_total_09  \
# company_id
# 03F84079F6C9B53B3A56AC208C123DC2   武汉绿色网络信息服务有限责任公司  新一代信息技术产业           87.0
# 04F4AA343744D1FAFD42D0D9D29CFEC9       苏州科达科技股份有限公司  新一代信息技术产业           57.0
# 0578D4686E90F15E123EB53D06E39E57   深圳市亚辉龙生物科技股份有限公司       生物产业           45.0
# 08C25FD609E2CC5453EE80467FD5F0EE       浙江众合科技股份有限公司  新一代信息技术产业           48.0
# 0BDCAB99DB27EDFE313C1113D4D122E7       中译语通科技股份有限公司  新一代信息技术产业           35.0
# 0DC7CE6184A517E768F29F1DE00C6590       绿盟科技集团股份有限公司  新一代信息技术产业            8.0
# 0F24DCBEFC027FFCCF68EF8F93B7FEA2      TCL科技集团股份有限公司  新一代信息技术产业           25.0
# 10407063B0FF5E37EFE6FCB323DA7256    深圳市理邦精密仪器股份有限公司       生物产业           65.0
# 1103E54999A92835DDEDE8D544B76585        欣旺达电子股份有限公司  新一代信息技术产业           34.0
# 13DF3CD44DD2F9FC3A1429405DF971A9    上海复旦微电子集团股份有限公司  新一代信息技术产业           28.0
# 16C90A6C342F9363625383F8E8632DDA       北京辰安科技股份有限公司  新一代信息技术产业            6.0
# ...

# %%
Polairs=pd.merge(Polairs,total[['rank_total']],how='left',on='company_id')

# %%
Polairs[Polairs['rank_total']>100]
# Out:
#                                        company_name   seic_lv1  rank_total_09  \
# company_id
# 03F84079F6C9B53B3A56AC208C123DC2   武汉绿色网络信息服务有限责任公司  新一代信息技术产业           87.0
# 88EDEC7A82A9C8AFBB30FB5B3FEDFC2A       杭州当虹科技股份有限公司  新一代信息技术产业           83.0
# 99089797F62F5429B3918BBB66D2529F        土巴兔集团股份有限公司  新一代信息技术产业           73.0
# 9A7A0F48633749D6DB1C178A8A67DDF4           银江股份有限公司  新一代信息技术产业           80.0
# A182FAE8188CF2CCEE65F20FE3830EBA     青岛海尔生物医疗股份有限公司       生物产业           81.0
# A3DA26173D54E125823C5241F0C232B2         天合光能股份有限公司      新能源产业           64.0
# A70A3E493E6B6E9C3D1CDA03B6279CAA           华为技术有限公司  新一代信息技术产业            3.0
# AA995A3304465DD4F0246E1551834B73       北京百度网讯科技有限公司  新一代信息技术产业           55.0
# AEC10D659D1F3D52B82EE138B31A1C6A  上海微电子装备（集团）股份有限公司   高端装备制造产业           18.0
# D1C395E40563E1E808F327374CE5BE93     竹间智能科技（上海）有限公司  新一代信息技术产业           86.0
# ECF6C9F643F5887B59B21B2C5463EAAF        马鞍山钢铁股份有限公司      新材料产业           88.0
#
# ...

# %% [markdown]
# ## detail

# %%
detail=pd.read_parquet('detail.parquet')

# %%
detail.set_index('company_id',inplace=True)
detail
# Out:
#                                     company_name   seic_lv1  \
# company_id
# 6ADC8F4FC710980A54D1FB1C710D00DB  无锡弘金环保科技集团有限公司     节能环保产业
# 6AEBE61BDC7DE66E2E8A92FC13B42652    山东翔迈智能科技有限公司  新一代信息技术产业
# 6AF350482B95A26449FB1FBA92F86651    四川光华水电工程有限公司    新能源汽车产业
# 6B24971C713FD86A97C31FC92927D15D    苏州慧动信息科技有限公司  新一代信息技术产业
# 6B456404DD4424E02721D4B430173D25    山西国药智信科技有限公司       生物产业
# ...                                          ...        ...
# 9069F2313D16DB2130699177D0464053      长沙兴茂投资有限公司      新材料产业
# 9077251F81E9E59FC5262C642795071C      长兴展鹏纺织有限公司         其它
# 9080C04BEDAF3C5B3A7BADFD09A7EA9F     昌宁双胞胎饲料有限公司       生物产业
# 90B072E2F9ECA35BBAAD0BE034704EBA    上海芭欧通信技术有限公司  新一代信息技术产业
# 90B1FC29B2D842E74E527E5507861CCE    湖南尔旭环保科技有限公司     节能环保产业
#
#                                                                 ans_id  \
# company_id
# 6ADC8F4FC710980A54D1FB1C710D00DB  36929b4d-f49e-471d-8b75-f3679671de01
# 6AEBE61BDC7DE66E2E8A92FC13B42652  5dfe6f31-a326-471f-84af-da1e8c72b58e
# ...

# %%
detail.loc['CCF710C9EF06156EF7B6F6162720F82A'].T
# Out:
# company_name                                             桂林洁宇环保科技有限责任公司
# seic_lv1                                                         节能环保产业
# ans_id                             f3a321f6-6345-4f68-968f-744cf86fd160
# money_q25_sum_weighted                                                0
# avg_funding_interval                                                  0
# most_recent_money_q25_formatted                                       0
# most_recent_time                                                      0
# reg_capital_formatted                                         0.0282893
# actual_capital_formatted                                      0.0281988
# duration                                                        0.13259
# rounds                                                                0
# num_certificates                                                      0
# qualification                                                         0
# ...

# %% [markdown]
# ## original

# %%
original=pd.read_parquet('original.parquet')
original
# Out:
#                               company_id    company_name   seic_lv1  \
# 0       6ADC8F4FC710980A54D1FB1C710D00DB  无锡弘金环保科技集团有限公司     节能环保产业
# 1       6AEBE61BDC7DE66E2E8A92FC13B42652    山东翔迈智能科技有限公司  新一代信息技术产业
# 2       6AF350482B95A26449FB1FBA92F86651    四川光华水电工程有限公司    新能源汽车产业
# 3       6B24971C713FD86A97C31FC92927D15D    苏州慧动信息科技有限公司  新一代信息技术产业
# 4       6B456404DD4424E02721D4B430173D25    山西国药智信科技有限公司       生物产业
# ...                                  ...             ...        ...
# 960108  9069F2313D16DB2130699177D0464053      长沙兴茂投资有限公司      新材料产业
# 960109  9077251F81E9E59FC5262C642795071C      长兴展鹏纺织有限公司         其它
# 960110  9080C04BEDAF3C5B3A7BADFD09A7EA9F     昌宁双胞胎饲料有限公司       生物产业
# 960111  90B072E2F9ECA35BBAAD0BE034704EBA    上海芭欧通信技术有限公司  新一代信息技术产业
# 960112  90B1FC29B2D842E74E527E5507861CCE    湖南尔旭环保科技有限公司     节能环保产业
#
#                                       ans_id  money_q25_sum_weighted  \
# 0       36929b4d-f49e-471d-8b75-f3679671de01                     NaN
# ...

# %%
original[original['company_id']=='AEC10D659D1F3D52B82EE138B31A1C6A'].T
# Out:
#                                                                652267
# company_id                           AEC10D659D1F3D52B82EE138B31A1C6A
# company_name                                        上海微电子装备（集团）股份有限公司
# seic_lv1                                                    新一代信息技术产业
# ans_id                           a4d46e3a-fb51-429b-8a94-93b2194ba59e
# money_q25_sum_weighted                                 23309690.47619
# avg_funding_interval                                         1.525114
# most_recent_money_q25_formatted                             6150000.0
# most_recent_time                                             2.975342
# reg_capital_formatted                                     147023788.0
# actual_capital_formatted                                  111512662.0
# duration                                                    19.808219
# rounds                                                            4.0
# ...

# %% [markdown]
# ## dimesion

# %%
dimesion=pd.read_parquet('dimesion.parquet')
dimesion
# Out:
#                               company_id    company_name   seic_lv1  \
# 0       6ADC8F4FC710980A54D1FB1C710D00DB  无锡弘金环保科技集团有限公司     节能环保产业
# 1       6AEBE61BDC7DE66E2E8A92FC13B42652    山东翔迈智能科技有限公司  新一代信息技术产业
# 2       6AF350482B95A26449FB1FBA92F86651    四川光华水电工程有限公司    新能源汽车产业
# 3       6B24971C713FD86A97C31FC92927D15D    苏州慧动信息科技有限公司  新一代信息技术产业
# 4       6B456404DD4424E02721D4B430173D25    山西国药智信科技有限公司       生物产业
# ...                                  ...             ...        ...
# 960108  9069F2313D16DB2130699177D0464053      长沙兴茂投资有限公司      新材料产业
# 960109  9077251F81E9E59FC5262C642795071C      长兴展鹏纺织有限公司         其它
# 960110  9080C04BEDAF3C5B3A7BADFD09A7EA9F     昌宁双胞胎饲料有限公司       生物产业
# 960111  90B072E2F9ECA35BBAAD0BE034704EBA    上海芭欧通信技术有限公司  新一代信息技术产业
# 960112  90B1FC29B2D842E74E527E5507861CCE    湖南尔旭环保科技有限公司     节能环保产业
#
#              seic_lv2  fundamental  rd_scale_and_stability  tech_influence  \
# ...

# %%
wl=dimesion[dimesion['seic_lv2']=='下一代信息网络产业']
wl
# Out:
#                               company_id    company_name   seic_lv1  \
# 23      6DADB4A0591F4A034940A811A5004F31   广州创铠珑信息科技有限公司  新一代信息技术产业
# 25      6E0AC3471C6BA957DDB4A32693F7D32C    湖州慧微电子科技有限公司  新一代信息技术产业
# 61      71D5E2F971FC881A16667B0B31EBE1CF     广州市力为电子有限公司  新一代信息技术产业
# 130     77F397679F2A0A366DED42BF801236D1     东莞市洪本电子有限公司  新一代信息技术产业
# 146     7AFA33D30A382317EF2504C5909D53E3    嘉兴众行信息科技有限公司  新一代信息技术产业
# ...                                  ...             ...        ...
# 960041  8940D682C6FE0BE7217F67066D0D0275    广西工信电子科技有限公司  新一代信息技术产业
# 960056  8B851BC3430E01F26BBB6AB9885062C3  北京浩阳创想网络科技有限公司  新一代信息技术产业
# 960079  8E1280CD5A947BB7A73890D9BA83DED2     深圳九龙进出口有限公司  新一代信息技术产业
# 960095  8F3D9A1F69C6C0169AD7260694977B66  广东华盈中天信息科技有限公司  新一代信息技术产业
# 960111  90B072E2F9ECA35BBAAD0BE034704EBA    上海芭欧通信技术有限公司  新一代信息技术产业
#
#          seic_lv2  fundamental  rd_scale_and_stability  tech_influence  \
# 23      下一代信息网络产业     0.160879                4.698742        1.953870
# ...

# %%
# %matplotlib inline
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(wl['tech_influence'],bins=23,ax=axes[0])
ax2=sns.distplot(wl['tech_influence'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(wl['tech_influence'],bins=23,kde=False,ax=axes[2])
ax1.set_title('fundamental数据的密度分布')
ax2.set_title('fundamental数据点实际的分布')
ax3.set_title('fundamental数据数量分布')

# %%
dimesion['fundamental'][0]
# Out:
# 0.16087923186428568

# %%
dimesion[dimesion['company_name']=='湖南金锐科技有限公司'].T
# Out:
#                                                              527363
# company_id                         C3974AE4B246A39F8BE1A48C13BA07F3
# company_name                                             湖南金锐科技有限公司
# seic_lv1                                                  新一代信息技术产业
# seic_lv2                                                  下一代信息网络产业
# fundamental                                                0.217367
# rd_scale_and_stability                                     2.726104
# tech_influence                                             2.225726
# tech_layout                                                9.005238
# tech_quality                                                16.7301
# rd_scale_and_stability_rating_lv1                                 D
# tech_quality_rating_lv1                                           B
# tech_influence_rating_lv1                                         C
# tech_layout_rating_lv1                                            A
# ...

# %%
dimesion[dimesion['company_name']=='杭州首掌文化传媒有限公司'].T
# Out:
#                                                              164961
# company_id                         1CF84A126894CCA7678A13D12F81C256
# company_name                                           杭州首掌文化传媒有限公司
# seic_lv1                                                     数字创意产业
# seic_lv2                                                  数字创意与融合服务
# fundamental                                                3.671413
# rd_scale_and_stability                                     1.063734
# tech_influence                                                  0.0
# tech_layout                                                     0.0
# tech_quality                                                    0.0
# rd_scale_and_stability_rating_lv1                                 E
# tech_quality_rating_lv1                                           E
# tech_influence_rating_lv1                                         E
# tech_layout_rating_lv1                                            E
# ...

# %%
dimesion[dimesion['seic_lv2']=='数字文化创意活动']['tech_influence'].mean()
# Out:
# 0.6716469660474012

# %%
dimesion[(dimesion['seic_lv2']=='数字文化创意活动')&(dimesion['tech_influence_rating_lv2']=='E')]['tech_influence'].mean()
# Out:
# 0.08680596672163501

# %% [markdown]
# ### fundamental

# %%
# %matplotlib inline
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(dimesion['fundamental'],bins=23,ax=axes[0])
ax2=sns.distplot(dimesion['fundamental'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(dimesion['fundamental'],bins=23,kde=False,ax=axes[2])
ax1.set_title('fundamental数据的密度分布')
ax2.set_title('fundamental数据点实际的分布')
ax3.set_title('fundamental数据数量分布')
# Out:
# Text(0.5, 1.0, 'fundamental数据数量分布')

# %%
dimesion['fundamental'].max()
# Out:
# 9.225552830832145

# %%
dimesion['fundamental'].min()
# Out:
# 0.035119343228571416

# %% [markdown]
# ### rd_scale_and_stability

# %%
# %matplotlib inline
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(dimesion['rd_scale_and_stability'],bins=23,ax=axes[0])
ax2=sns.distplot(dimesion['rd_scale_and_stability'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(dimesion['rd_scale_and_stability'],bins=23,kde=False,ax=axes[2])
ax1.set_title('rd_scale_and_stability数据的密度分布')
ax2.set_title('rd_scale_and_stability数据点实际的分布')
ax3.set_title('rd_scale_and_stability数据数量分布')
# Out:
# Text(0.5, 1.0, 'rd_scale_and_stability数据数量分布')

# %%
dimesion['rd_scale_and_stability'].max()
# Out:
# 33.998322426216724

# %%
dimesion['rd_scale_and_stability'].min()
# Out:
# 0.0

# %% [markdown]
# ### tech_influence

# %%
# %matplotlib inline
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(dimesion['tech_influence'],bins=23,ax=axes[0])
ax2=sns.distplot(dimesion['tech_influence'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(dimesion['tech_influence'],bins=23,kde=False,ax=axes[2])
ax1.set_title('tech_influence数据的密度分布')
ax2.set_title('tech_influence数据点实际的分布')
ax3.set_title('tech_influence数据数量分布')
# Out:
# Text(0.5, 1.0, 'tech_influence数据数量分布')

# %%
dimesion['tech_influence'].max()
# Out:
# 12.679741817704224

# %%
dimesion['tech_influence'].min()
# Out:
# 0.0

# %% [markdown]
# ###  tech_layout

# %%
# %matplotlib inline
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(dimesion['tech_layout'],bins=23,ax=axes[0])
ax2=sns.distplot(dimesion['tech_layout'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(dimesion['tech_layout'],bins=23,kde=False,ax=axes[2])
ax1.set_title('tech_layout数据的密度分布')
ax2.set_title('tech_layout数据点实际的分布')
ax3.set_title('tech_layout数据数量分布')
# Out:
# Text(0.5, 1.0, 'tech_layout数据数量分布')

# %%
dimesion['tech_layout'].max()
# Out:
# 16.599000861843027

# %%
dimesion['tech_layout'].min()
# Out:
# 0.0

# %% [markdown]
# ### tech_quality

# %%
# %matplotlib inline
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(dimesion['tech_quality'],bins=23,ax=axes[0])
ax2=sns.distplot(dimesion['tech_quality'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(dimesion['tech_quality'],bins=23,kde=False,ax=axes[2])
ax1.set_title('tech_quality数据的密度分布')
ax2.set_title('tech_quality数据点实际的分布')
ax3.set_title('tech_quality数据数量分布')
# Out:
# Text(0.5, 1.0, 'tech_quality数据数量分布')

# %%
dimesion['tech_quality'].max()
# Out:
# 27.497604097262926

# %%
dimesion['tech_quality'].min()
# Out:
# 0.0

# %% [markdown]
# # 11月分数

# %% [markdown]
# ## test_quanguo_11_score

# %%
test_quanguo_11_score=pd.read_sql('select * from test_quanguo_score',con=engine)

# %%
test_quanguo_11_score.set_index('company_id',inplace=True)
test_quanguo_11_score
# Out:
#                                      company_name  seic_lv1     patent  \
# company_id
# 00001FF532C2D92470F99149D48C7820   中科点击（辽宁）科技有限公司        其它   0.000000
# 00002B5B4529376232011C86E1A588FF     江门市葵峰混凝土有限公司        其它   3.663991
# 00003DFB06D095BD2D6DE4A828C6CB5C       合肥德良机械有限公司        其它   3.071957
# 00003E68CDE39A6DA970E85788FDB98D       杭州弥奥科技有限公司        其它  11.074602
# 00003FCBDCE7E5340E6603C08DD6291A      广东格瑞克科技有限公司  高端装备制造产业   7.902760
# ...                                           ...       ...        ...
# FFFF9B34AD5B60CECBF0DA6C52F3B0F1   声佗医疗科技（上海）有限公司      生物产业  46.512241
# FFFFCFE0644923912519B1A1034E5E8D       武汉已为科技有限公司        其它  13.200368
# FFFFE42F6484FEC563A1C55993BE494C  广东泰索斯营销策划服务有限公司    数字创意产业  14.922533
# FFFFF51AB69F00656AE94BC3C57CC8D2    广西草本源中药饮片有限公司      生物产业  16.215699
# FFFFFBA85B6D854ABC614B7219A0F258     江苏浦贝智能科技有限公司  高端装备制造产业  27.829072
#
#                                   nonpatent      total  rank_total  rank_seic  \
# company_id
# ...

# %%
# %matplotlib qt5
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(test_quanguo_11_score['total'],bins=23,ax=axes[0])
ax2=sns.distplot(test_quanguo_11_score['total'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(test_quanguo_11_score['total'],bins=23,kde=False,ax=axes[2])
ax1.set_title('全国11月数据的密度分布')
ax2.set_title('全国11月数据点实际的分布')
ax3.set_title('全国11月数据数量分布')
# Out:
# Text(0.5, 1.0, '全国11月数据数量分布')

# %% [markdown]
# ## test_quanguo_11_detailscore

# %%
test_quanguo_11_detailscore=pd.read_sql('select * from test_quanguo_detailscore',con=engine)

# %%
test_quanguo_11_detailscore.set_index("company_id",inplace=True)

# %% [markdown]
# # Compare

# %%
Compare=pd.merge(test_quanguo_11_score,total,on='company_id',how='left',suffixes=['_11','_12'])

# %%
Compare
# Out:
#                                   company_name_11 seic_lv1_11  patent_11  \
# company_id
# 00001FF532C2D92470F99149D48C7820   中科点击（辽宁）科技有限公司          其它   0.000000
# 00002B5B4529376232011C86E1A588FF     江门市葵峰混凝土有限公司          其它   3.663991
# 00003DFB06D095BD2D6DE4A828C6CB5C       合肥德良机械有限公司          其它   3.071957
# 00003E68CDE39A6DA970E85788FDB98D       杭州弥奥科技有限公司          其它  11.074602
# 00003FCBDCE7E5340E6603C08DD6291A      广东格瑞克科技有限公司    高端装备制造产业   7.902760
# ...                                           ...         ...        ...
# FFFF9B34AD5B60CECBF0DA6C52F3B0F1   声佗医疗科技（上海）有限公司        生物产业  46.512241
# FFFFCFE0644923912519B1A1034E5E8D       武汉已为科技有限公司          其它  13.200368
# FFFFE42F6484FEC563A1C55993BE494C  广东泰索斯营销策划服务有限公司      数字创意产业  14.922533
# FFFFF51AB69F00656AE94BC3C57CC8D2    广西草本源中药饮片有限公司        生物产业  16.215699
# FFFFFBA85B6D854ABC614B7219A0F258     江苏浦贝智能科技有限公司    高端装备制造产业  27.829072
#
#                                   nonpatent_11   total_11  rank_total_11  \
# ...

# %%
Compare['rank_total_12']=Compare.rank_total_12.rank(method='dense',ascending=False)

# %%
Compare['rank_total_gap']=abs(Compare['rank_total_12']-Compare['rank_total_11'])

# %%
Compare.sort_values('rank_total_gap',ascending=False).head(100)
# Out:
#                                      company_name_11 seic_lv1_11  patent_11  \
# company_id
# 321AE1F037FFF370C8E50CAF7CBCA0B6          潍坊友容实业有限公司          其它   0.000000
# 1DFD8CD2F1511B11CBD522AC21350A93        广东高驰运动科技有限公司          其它   0.000000
# FE8D5C8A9E2BD27DF8B3FF196BE9DC13          株洲齿轮股份有限公司          其它   2.125672
# 831902E6353E52DCF9235EFEF5618E18       南通立方新材料科技有限公司       新材料产业   0.000000
# 08616067580582884B0DD315A9C62CD6        天马轴承集团股份有限公司    高端装备制造产业   0.000000
# A25A21424FA5F3238EE2FFC847D8FAA7        青岛建设集团股份有限公司          其它   0.000000
# 9D69925AB642A4EA943E22B18CFB455E      云南省建筑科学研究院有限公司          其它   2.770257
# 9C88A82C31F0829C4A35A0651F187DEE        安徽华米健康科技有限公司          其它   0.000000
# DDB25F529A0D376C3D82F22C517FB0DB        沈阳中北真空技术有限公司          其它   0.000000
# CCFFE22353128C5F89C10342265A7288        上海洲跃生物科技有限公司        生物产业  49.656579
# F61B1B20DF701FFDBBB7B17A929E2CCE        中国东方电气集团有限公司          其它   0.000000
# ...

# %% [markdown]
# # 细节分对比

# %%
def diff(cid,base,new):
    a=pd.concat([base.loc[cid],new.loc[cid]],axis=1)
    a.columns=['q3','q4']
    for i in a.index:
        try:
            a.loc[i,'gap'] = float(a.loc[i,'q3'])-float(a.loc[i,'q4'])
        except:
            a.loc[i,'gap'] = pd.NaT
    a.sort_values('gap',ascending=False,inplace=True)
    return a

# %%
diff('AEC10D659D1F3D52B82EE138B31A1C6A',test_quanguo_11_score,total)
# Out:
#                                              q3                 q4       gap
# total                                 94.085867          89.330664  4.755203
# nonpatent                             29.221899           24.47604  4.745859
# patent                                64.863968          64.854624  0.009344
# apno_cnt                                 3638.0             3674.0     -36.0
# rank_total                                 28.0              179.0    -151.0
# company_name                  上海微电子装备（集团）股份有限公司  上海微电子装备（集团）股份有限公司       NaT
# seic_lv1                               高端装备制造产业          新一代信息技术产业       NaT
# rank_seic                                   4.0                NaN       NaN
# rating                                        A                NaN       NaT
# qualification    {'单项冠军产品企业', '瞪羚企业', '高新技术企业'}                NaN       NaT
# status                                   ACTIVE                NaN       NaT
# ...

# %%
diff('AEC10D659D1F3D52B82EE138B31A1C6A',test_quanguo_11_detailscore,detail)
# Out:
#                                                                    q3  \
# num_certificates                                             8.804249
# reg_growth_ratio                                             1.394606
# patenting_growth_ratio                                       0.010776
# external_licensing_cnt                                            0.0
# core_patents_cited_by_cnt                                    0.014889
# invention_ratio                                              9.064018
# granted_invention_cnt                                        8.347156
# value_top5_avg                                               3.368523
# avg_remaining_life_span                                      2.698355
# value_sum                                                    1.799462
# granted_invention_ratio                                      1.082589
# value_avg                                                        0.35
# ...

# %%
import pandas as pd
import os
os.chdir('D:\数据')

# %% [markdown]
# # to_data

# %%
to_data=pd.read_parquet('to_data.parquet')

# %%
a=to_data[to_data['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
a
# Out:
#                               company_id      score  \
# 535812  A70A3E493E6B6E9C3D1CDA03B6279CAA  98.939684
#
#                                              score_detail  \
# 535812  [{'dimension_name': 'fundamental', 'indicators...
#
#                                           original_detail     created_at  \
# 535812  {'active_inventor_ratio': 0.05135, 'actual_cap...  1640597727000
#
#            updated_at
# 535812  1640597727000

# %%
a.to_json('a.json',lines=True,orient="records",force_ascii=True)

# %%
a=a.explode("score_detail")

# %%
a
# Out:
#                               company_id      score  \
# 535812  A70A3E493E6B6E9C3D1CDA03B6279CAA  98.939684
# 535812  A70A3E493E6B6E9C3D1CDA03B6279CAA  98.939684
# 535812  A70A3E493E6B6E9C3D1CDA03B6279CAA  98.939684
# 535812  A70A3E493E6B6E9C3D1CDA03B6279CAA  98.939684
# 535812  A70A3E493E6B6E9C3D1CDA03B6279CAA  98.939684
#
#                                              score_detail  \
# 535812  {'dimension_name': 'fundamental', 'indicators'...
# 535812  {'dimension_name': 'rd_scale_and_stability', '...
# 535812  {'dimension_name': 'tech_influence', 'indicato...
# 535812  {'dimension_name': 'tech_layout', 'indicators'...
# 535812  {'dimension_name': 'tech_quality', 'indicators...
#
#                                           original_detail     created_at  \
# 535812  {'active_inventor_ratio': 0.05135, 'actual_cap...  1640597727000
# 535812  {'active_inventor_ratio': 0.05135, 'actual_cap...  1640597727000
# 535812  {'active_inventor_ratio': 0.05135, 'actual_cap...  1640597727000
# ...

# %%
a.to_json()
# Out:
# 535812    {'dimension_name': 'fundamental', 'indicators'...
# 535812    {'dimension_name': 'rd_scale_and_stability', '...
# 535812    {'dimension_name': 'tech_influence', 'indicato...
# 535812    {'dimension_name': 'tech_layout', 'indicators'...
# 535812    {'dimension_name': 'tech_quality', 'indicators...
# Name: score_detail, dtype: object
