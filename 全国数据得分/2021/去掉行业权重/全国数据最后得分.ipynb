# %%
import pandas as pd
import os
import json
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns
## 设置属性防止中文乱码
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company',echo=False)

# %% [markdown]
# # v2_quanguo_df_before_manualweights_0728

# %%
v2_quanguo=pd.read_sql('SELECT * FROM v2_quanguo_df_before_manualweights_0728',con=engine)

# %%
v2_quanguo
# Out:
#                               company_id      company_name  \
# 0       3CF2C649AD53C40591A9EE3FB3A8D9D7        河北唐银钢铁有限公司
# 1       55E8650B2B120F51963EC9AFAD21BE7C  泰来县长江新能源锅炉制造有限公司
# 2       925D2A4D7B11412C4583B931AC70ACFA      北京瑞智顺杰科技有限公司
# 3       DB2C235A8F0C8643F39142D18B81B742   吉林省装库创意科技股份有限公司
# 4       16297557454101CC3B78B7DB008B0720      湖州天硒生物科技有限公司
# ...                                  ...               ...
# 808797  A00DB8D2C3E4CB3F985DC50D57D492E6      北京力城通捷技术有限公司
# 808798  55D074691A940B0FE51C065D9EAC5AEE   中内凯思汽车新动力系统有限公司
# 808799  4B0D1FF8A5CE750336A6536BAC3BD317        山东澳兴科技有限公司
# 808800  A78518458C2D9BF74A287DCB7FF40563        四会固立家具有限公司
# 808801  2B003045B367D1ED7A0DBA5792F204D3     苏州技达易精密机械有限公司
#
#         patenting_growth_ratio  active_inventor_ratio  invention_stability  \
# 0                     0.008103                    0.0             1.129976
# 1                     0.008103                    0.0             0.000000
# ...

# %%
v2_quanguo.columns
# Out:
# Index(['company_id', 'company_name', 'patenting_growth_ratio',
#        'active_inventor_ratio', 'invention_stability', 'self_cited_by_ratio',
#        'apno_cnt', 'non_design_apno_cnt', 'avg_3y_cnt', 'reg_num',
#        'reg_3y_avg', 'reg_growth_ratio', 'num_trademarks_total',
#        'num_trademarks_registered', 'joint_application_cnt',
#        'joint_applicant_cnt', 'num_members', 'avg_technology_score',
#        'ip_dependency', 'total_patent_award_score', 'granted_invention_cnt',
#        'granted_invention_ratio', 'invention_ratio', 'value_sum', 'value_avg',
#        'value_top5_avg', 'in_examing_ratio', 'avg_remaining_life_span',
#        'avg_cited_by_cnt', 'core_patents_cited_by_cnt',
#        'core_patents_cited_by_ratio', 'most_cited_patents_value',
#        'external_licensing_cnt', 'top5_current_impact_index',
#        'tech_global_concentration', 'tech_width', 'country_cnt',
#        'pct_apno_cnt', 'num_certificates', 'rounds', 'money_q25_sum_weighted',
# ...

# %% [markdown]
# ## 总分

# %%
v2_quanguo['总分']=v2_quanguo['patenting_growth_ratio']+v2_quanguo['active_inventor_ratio']+v2_quanguo['invention_stability']+\
v2_quanguo['self_cited_by_ratio']+v2_quanguo['apno_cnt']+v2_quanguo['non_design_apno_cnt']+v2_quanguo['avg_3y_cnt']+\
v2_quanguo['reg_num']+v2_quanguo['reg_3y_avg']+v2_quanguo['reg_growth_ratio']+v2_quanguo['num_trademarks_total']+\
v2_quanguo['num_trademarks_registered']+v2_quanguo['joint_application_cnt']+v2_quanguo['joint_applicant_cnt']+v2_quanguo['num_members']+\
v2_quanguo['avg_technology_score']+v2_quanguo['ip_dependency']+v2_quanguo['total_patent_award_score']+v2_quanguo['granted_invention_cnt']+\
v2_quanguo['granted_invention_ratio']+v2_quanguo['invention_ratio']+v2_quanguo['value_sum']+v2_quanguo['value_avg']+\
v2_quanguo['value_top5_avg']+v2_quanguo['in_examing_ratio']+v2_quanguo['avg_remaining_life_span']+v2_quanguo['avg_cited_by_cnt']+\
v2_quanguo['core_patents_cited_by_cnt']+v2_quanguo['core_patents_cited_by_ratio']+v2_quanguo['most_cited_patents_value']+\
v2_quanguo['external_licensing_cnt']+v2_quanguo['top5_current_impact_index']+v2_quanguo['tech_global_concentration']+v2_quanguo['tech_width']+\
v2_quanguo['country_cnt']+v2_quanguo['pct_apno_cnt']+v2_quanguo['num_certificates']+v2_quanguo['rounds']+\
v2_quanguo['money_q25_sum_weighted']+v2_quanguo['most_recent_money_q25_formatted']+v2_quanguo['most_recent_time']+\
v2_quanguo['avg_funding_interval']+v2_quanguo['reg_capital_formatted']+v2_quanguo['actual_capital_formatted']+v2_quanguo['duration']+\
v2_quanguo['publish']+v2_quanguo['qualification']

# %% [markdown]
# ## 专利总分

# %%
v2_quanguo['专利总分']=v2_quanguo['patenting_growth_ratio']+v2_quanguo['active_inventor_ratio']+v2_quanguo['invention_stability']+\
v2_quanguo['self_cited_by_ratio']+v2_quanguo['apno_cnt']+v2_quanguo['non_design_apno_cnt']+v2_quanguo['avg_3y_cnt']+\
v2_quanguo['joint_application_cnt']+v2_quanguo['joint_applicant_cnt']+v2_quanguo['avg_technology_score']+v2_quanguo['ip_dependency']+\
v2_quanguo['total_patent_award_score']+v2_quanguo['granted_invention_cnt']+v2_quanguo['granted_invention_ratio']+v2_quanguo['invention_ratio']+\
v2_quanguo['value_sum']+v2_quanguo['value_avg']+v2_quanguo['value_top5_avg']+v2_quanguo['in_examing_ratio']+\
v2_quanguo['avg_remaining_life_span']+v2_quanguo['avg_cited_by_cnt']+v2_quanguo['core_patents_cited_by_cnt']+\
v2_quanguo['core_patents_cited_by_ratio']+v2_quanguo['most_cited_patents_value']+v2_quanguo['external_licensing_cnt']+\
v2_quanguo['top5_current_impact_index']+v2_quanguo['tech_global_concentration']+v2_quanguo['tech_width']+v2_quanguo['country_cnt']+\
v2_quanguo['pct_apno_cnt']

# %% [markdown]
# ## 非专利总分

# %%
v2_quanguo['非专利总分']=v2_quanguo['reg_num']+v2_quanguo['reg_3y_avg']+v2_quanguo['reg_growth_ratio']+v2_quanguo['num_trademarks_total']+\
v2_quanguo['num_trademarks_registered']+v2_quanguo['num_members']+v2_quanguo['num_certificates']+v2_quanguo['rounds']+\
v2_quanguo['money_q25_sum_weighted']+v2_quanguo['most_recent_money_q25_formatted']+\
v2_quanguo['most_recent_time']+v2_quanguo['avg_funding_interval']+\
v2_quanguo['reg_capital_formatted']+v2_quanguo['actual_capital_formatted']+v2_quanguo['duration']+v2_quanguo['publish']+\
v2_quanguo['qualification']

# %%
v2_quanguo
# Out:
#                               company_id      company_name  \
# 0       3CF2C649AD53C40591A9EE3FB3A8D9D7        河北唐银钢铁有限公司
# 1       55E8650B2B120F51963EC9AFAD21BE7C  泰来县长江新能源锅炉制造有限公司
司
#
#         patenting_growth_ratio  active_inventor_ratio  invention_stability  \
# ...

# %%
v2_quanguo_formant['rank']=v2_quanguo_formant.总分.rank(method='dense',ascending=False)
v2_quanguo_formant['专利_rank']=v2_quanguo_formant.专利总分.rank(method='dense',ascending=False)
v2_quanguo_formant['非专利_rank']=v2_quanguo_formant.非专利总分.rank(method='dense',ascending=False)

# %%
v2_quanguo_formant['总分'].max()
# Out:
# 96.98395076518368

# %% [markdown]
# ## 总分rank

# %%
v2_quanguo_formant.sort_values('rank').head(100)[['company_id','战略性新兴产业一层分类','company_name','总分','rank',
                                                  '专利_rank','专利总分','非专利_rank','非专利总分']]
# Out:
#                               company_id 战略性新兴产业一层分类        company_name  \
# 654951  66328D3F25518BB03F4BE6FE3360E076   新一代信息技术产业       京东方科技集团股份有限公司
# 377477  D4A0B99B510F4DD3A4958677CC6E4EA3   新一代信息技术产业       奇安信科技集团股份有限公司
# 697419  16C90A6C342F9363625383F8E8632DDA   新一代信息技术产业        北京辰安科技股份有限公司
# 634020  4EAF90A74ADB4BA77FDA6E64285F192B   新一代信息技术产业         优刻得科技股份有限公司
# 253730  AEFE51DB9676F369A594054748320B19    高端装备制造产业        浙江中控技术股份有限公司
# 151303  E730775A563ACC2F3F5102AD6D0DD4BA   新一代信息技术产业          威创集团股份有限公司
# 313754  3757089B5260ECE5CADB643694FEEBCD   新一代信息技术产业     山东新北洋信息技术股份有限公司
# 627898  E372D1FDC7C48C3AAF31E5EF52E9E995   新一代信息技术产业          科大讯飞股份有限公司
# 670231  D044FFDF22B2FE05140A7B11AEE280D7   新一代信息技术产业        上海依图网络科技有限公司
# 500793  348757E983F0C55D275B952DFCF30EE3   新一代信息技术产业        成都极米科技股份有限公司
# 474015  88EDEC7A82A9C8AFBB30FB5B3FEDFC2A   新一代信息技术产业        杭州当虹科技股份有限公司
# 397204  31DD96D9B3973E7A3E028E41A8F4BE6D          其它        珠海格力电器股份有限公司
# ...

# %% [markdown]
# ## 专利分rank

# %%
v2_quanguo_formant.sort_values('专利_rank').head(100)[['company_id','战略性新兴产业一层分类','company_name','总分','rank',
                                                  '专利_rank','专利总分','非专利_rank','非专利总分']]
# Out:
#                               company_id 战略性新兴产业一层分类         company_name  \
# 264169  7B0ED517F0CAB9197BCE19592B5E54BC          其它         中国恩菲工程技术有限公司
# 712478  60ABBC0D124F6F4C311E0BAD01914C08    高端装备制造产业       哈工大机器人集团股份有限公司
# 441625  32D2A7FD1996C28D811BB1C14213FEB9   新一代信息技术产业      哈尔滨工大正元信息技术有限公司
# 654951  66328D3F25518BB03F4BE6FE3360E076   新一代信息技术产业        京东方科技集团股份有限公司
# 219939  AE90AAC492775EE87C65883E3BF5C5DC   新一代信息技术产业         大唐移动通信设备有限公司
# 727028  B4AF81BAC62B3DF1D793ECE18CCD94A8        生物产业         江苏豪森药业集团有限公司
# 618123  D60D059F3D80A9D0148B46CA17B1CFFA    高端装备制造产业   恒锋工具股份有限公司
#
#         patenting_growth_ratio  active_inventor_ratio  invention_stability  \
# 618123                0.008103               4.919534             1.129976
#
#         self_cited_by_ratio  apno_cnt  non_design_apno_cnt  avg_3y_cnt  ...  \
# 618123             0.263158  9.101582             0.197368    0.101485  ...
#
#         avg_funding_interval  reg_capital_formatted  actual_capital_formatted  \
# 618123                   0.0               0.357143                       0.0
#
#         duration  value_top10_avg  version  publish  qualification         总分  \
# 618123  0.357143         111560.0       v2        5              0  61.963005
#
#           rank
# 618123  6937.0
#
# [1 rows x 54 columns]

# %%
v2_quanguo_formant['战略性新兴产业一层分类'].value_counts()
# Out:
# 其它           396680
# 新一代信息技术产业    133041
# 高端装备制造产业      99892
# 新材料产业         55181
# 生物产业          54380
# 节能环保产业        40425
# 数字创意产业        14231
# 新能源产业          9352
# 相关服务业          3751
# 新能源汽车产业        1823
# Name: 战略性新兴产业一层分类, dtype: int64

# %% [markdown]
# # 行业分布

# %% [markdown]
# ## 新一代信息技术产业

# %%
v2_quanguo_formant_New_IT=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='新一代信息技术产业']
v2_quanguo_formant_New_IT['rank'].mean()
# Out:
# 368224.1545989582

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(v2_quanguo_formant_New_IT['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(v2_quanguo_formant_New_IT['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(v2_quanguo_formant_New_IT['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 高端装备制造产业

# %%
High_equ=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='高端装备制造产业']
High_equ['rank'].mean()
# Out:
# 348481.29430785245

# %%
# %matplotlib qt5

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(High_equ['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(High_equ['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(High_equ['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 新材料产业

# %%
New_material=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='新材料产业']
New_material['rank'].mean()
# Out:
# 314467.0501984379

# %%
# %matplotlib qt5

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(New_material['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(New_material['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(New_material['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 生物产业

# %%
Biolo=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='生物产业']
Biolo['rank'].mean()
# Out:
# 293516.4447958808

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(Biolo['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(Biolo['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(Biolo['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ##  节能环保产业

# %%
Energy=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='节能环保产业']
Energy['rank'].mean()
# Out:
# 335801.9763512678

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(Energy['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(Energy['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(Energy['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 数字创意产业

# %%
Digital_creativity=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='数字创意产业']
Digital_creativity['rank'].mean()
# Out:
# 444601.0151781322

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(Digital_creativity['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(Digital_creativity['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(Digital_creativity['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 新能源产业

# %%
New_enregy=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='新能源产业']
New_enregy['rank'].mean()
# Out:
# 321685.4020530368

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(New_enregy['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(New_enregy['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(New_enregy['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 相关服务业

# %%
Related_services=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='相关服务业']
Related_services['rank'].mean()
# Out:
# 380825.69341508934

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(Related_services['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(Related_services['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(Related_services['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 新能源汽车产业

# %%
New_car=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='新能源汽车产业']
New_car['rank'].mean()
# Out:
# 252323.74986286342

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(New_car['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(New_car['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(New_car['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# ## 其它

# %%
Other=v2_quanguo_formant[v2_quanguo_formant['战略性新兴产业一层分类']=='其它']
Other['rank'].mean()
# Out:
# 381245.63601139456

# %%
fig,axes=plt.subplots(1,3,figsize=(20,6))
ax1=sns.distplot(Other['总分'],bins=23,ax=axes[0])
ax2=sns.distplot(Other['总分'],bins=23,rug=True,kde=False,ax=axes[1])
ax3=sns.distplot(Other['总分'],bins=23,kde=False,ax=axes[2])
ax1.set_title('修改分箱后的数据的密度分布')
ax2.set_title('修改分箱后的数据点实际的分布')
ax3.set_title('修改分箱后的数据数量分布')
# Out:
# Text(0.5, 1.0, '修改分箱后的数据数量分布')

# %% [markdown]
# # 前一万名

# %% [markdown]
# ## 100

# %%
v2_quanguo_formant.sort_values('总分',ascending=False,inplace=True)
v2_quanguo_formant_100=v2_quanguo_formant[['company_id','战略性新兴产业一层分类','company_name','总分','rank',
                                                  '专利_rank','专利总分','非专利_rank','非专利总分']][:100]
v2_quanguo_formant_100
# Out:
#                               company_id 战略性新兴产业一层分类        company_name  \
# 654951  66328D3F25518BB03F4BE6FE3360E076   新一代信息技术产业       京东方科技集团股份有限公司
# 377477  D4A0B99B510F4DD3A4958677CC6E4EA3   新一代信息技术产业       奇安信科技集团股份有限公司
# 697419  16C90A6C342F9363625383F8E8632DDA   新一代信息技术产业        北京辰安科技股份有限公司
# 634020  4EAF90A74ADB4BA77FDA6E64285F192B   新一代信息技术产业         优刻得科技股份有限公司
# 253730  AEFE51DB9676F369A594054748320B19    高端装备制造产业        浙江中控技术股份有限公司
# 151303  E730775A563ACC2F3F5102AD6D0DD4BA   新一代信息技术产业          威创集团股份有限公司
# 313754  3757089B5260ECE5CADB643694FEEBCD   新一代信息技术产业     山东新北洋信息技术股份有限公司
# 627898  E372D1FDC7C48C3AAF31E5EF52E9E995   新一代信息技术产业          科大讯飞股份有限公司
# 670231  D044FFDF22B2FE05140A7B11AEE280D7   新一代信息技术产业        上海依图网络科技有限公司
# 500793  348757E983F0C55D275B952DFCF30EE3   新一代信息技术产业        成都极米科技股份有限公司
# 474015  88EDEC7A82A9C8AFBB30FB5B3FEDFC2A   新一代信息技术产业        杭州当虹科技股份有限公司
# 397204  31DD96D9B3973E7A3E028E41A8F4BE6D          其它        珠海格力电器股份有限公司
# ...

# %%
v2_quanguo_formant_100['战略性新兴产业一层分类'].value_counts()
# Out:
# 新一代信息技术产业    67
# 生物产业         11
# 高端装备制造产业      7
# 其它            5
# 新能源汽车产业       4
# 新能源产业         3
# 节能环保产业        1
# 相关服务业         1
# 数字创意产业        1
# Name: 战略性新兴产业一层分类, dtype: int64

# %%
v2_quanguo_formant_100[v2_quanguo_formant_100['战略性新兴产业一层分类']=='其它']
# Out:
#                               company_id 战略性新兴产业一层分类    company_name  \
# 397204  31DD96D9B3973E7A3E028E41A8F4BE6D          其它    珠海格力电器股份有限公司
# 494859  67DD2BD7A0B5085B211804247F15B36D          其它  安徽江淮汽车集团股份有限公司
# 203206  282DF3B201AEEF6A07B7BDC99871D3C1          其它      海尔智家股份有限公司
# 211426  25792CA04478481196BDDA39917E298E          其它    中国工商银行股份有限公司
# 13067   2E7FE420744647175A088B68978371B1          其它  哈尔滨博实自动化股份有限公司
#
#                总分  rank  专利_rank       专利总分  非专利_rank      非专利总分
# 397204  92.095931  12.0    161.0  44.385708      64.0  47.710223
# 494859  88.307555  50.0   1029.0  42.888079     167.0  45.419476
# 203206  87.055435  67.0    427.0  43.825802     385.0  43.229632
# 211426  87.023997  68.0   2712.0  41.141732     138.0  45.882265
# 13067   86.193955  91.0   3633.0  40.369017     141.0  45.824938

# %% [markdown]
# ## 10000

# %%
v2_quanguo_formant.sort_values('总分',ascending=False,inplace=True)
v2_quanguo_formant_10000=v2_quanguo_formant[['company_id','战略性新兴产业一层分类','company_name','总分','rank',
                                                  '专利_rank','专利总分','非专利_rank','非专利总分']][:10000]
v2_quanguo_formant_10000
# Out:
#                               company_id 战略性新兴产业一层分类      company_name  \
# 654951  66328D3F25518BB03F4BE6FE3360E076   新一代信息技术产业     京东方科技集团股份有限公司
# 377477  D4A0B99B510F4DD3A4958677CC6E4EA3   新一代信息技术产业     奇安信科技集团股份有限公司
# 697419  16C90A6C342F9363625383F8E8632DDA   新一代信息技术产业      北京辰安科技股份有限公司
# 634020  4EAF90A74ADB4BA77FDA6E64285F192B   新一代信息技术产业       优刻得科技股份有限公司
# 253730  AEFE51DB9676F369A594054748320B19    高端装备制造产业      浙江中控技术股份有限公司
# ...                                  ...         ...               ...
# 460997  8027D0FCC74D5993071D117B8C285E1E    高端装备制造产业   北京博瑞莱智能科技集团有限公司
# 796634  02944CE4600F9DE959FFEFEB935C3E47   新一代信息技术产业  沃民高新科技（北京）股份有限公司
# 740336  851A2DDCAB35DCCFD756C430D2C8362A          其它       无限极（中国）有限公司
# 684842  EEBDDE6134FFF96FF61A489561B4BDE0        生物产业   上海中科新生命生物科技有限公司
# 722984  B777E5248EA3B5E2A248880872098180          其它     贵阳铝镁设计研究院有限公司
#
#                总分    rank  专利_rank       专利总分  非专利_rank      非专利总分
# ...

# %%
v2_quanguo_formant_10000['战略性新兴产业一层分类'].value_counts()
# Out:
# 新一代信息技术产业    3097
# 其它           2751
# 生物产业         1277
# 高端装备制造产业     1195
# 新材料产业         810
# 节能环保产业        395
# 新能源产业         225
# 数字创意产业        112
# 新能源汽车产业        76
# 相关服务业          62
# Name: 战略性新兴产业一层分类, dtype: int64

# %%
v2_quanguo_formant_10000[v2_quanguo_formant_10000['战略性新兴产业一层分类']=='其它'].head(1000)
# Out:
#                               company_id 战略性新兴产业一层分类            company_name  \
# 397204  31DD96D9B3973E7A3E028E41A8F4BE6D          其它            珠海格力电器股份有限公司
# 494859  67DD2BD7A0B5085B211804247F15B36D          其它          安徽江淮汽车集团股份有限公司
# 203206  282DF3B201AEEF6A07B7BDC99871D3C1          其它              海尔智家股份有限公司
# 211426  25792CA04478481196BDDA39917E298E          其它            中国工商银行股份有限公司
# 13067   2E7FE420744647175A088B68978371B1          其它          哈尔滨博实自动化股份有限公司
# 587428  58A2BB5A9F2C6C24A808A008EA10726C          其它            中国农业银行股份有限公司
# 322698  23D3C2B079792ED62EBF90D4220E728D          其它              中国银行股份有限公司
# 175121  F4D7E171C0A65248471F6D907FC9908F          其它            北汽福田汽车股份有限公司
# 245583  B902DDA0987D0B296CA8744F2B8C9799          其它        深圳市建筑科学研究院股份有限公司
# 677568  DCB6731F41BFCC5F6C169F5F1804EDE5          其它            常州星宇车灯股份有限公司
# 653755  662964C35AFB0560580DCF270FF2C135          其它              欧普照明股份有限公司
# ...
