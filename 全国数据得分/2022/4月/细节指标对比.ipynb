# %%
import pandas as pd
import os
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company_retrain',echo=False)
pd.set_option('max_rows',100)
pd.set_option('max_columns',100)
import numpy as np

# %% [markdown]
# # 穿透后原始值

# %%
national_company_alldata_2101=pd.read_sql('select * from national_company_alldata_202204',con=engine)
national_company_alldata_2101
# Out:
#                                company_id      company_name   seic_lv1  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7      绵阳数智生物科技有限公司       生物产业
# 1        0014A83C9B038292B6E0DB202479DEB9      苏州载道网络科技有限公司  新一代信息技术产业
# 2        001CE08C53F7BD9A821358DD21C50C88          中航证券有限公司      相关服务业
# 3        0067F4DD86BE9866BD8E617D2B88E821    重庆纳川山隅重工设备有限公司   高端装备制造产业
# 4        006A322857D17795374D7749C2C32538     中山市钜泰硅胶科技有限公司      新材料产业
# ...                                   ...               ...        ...
# 1108555  FFAB34674A8102C9D503B26D73E8D44F       浙江众焊联科技有限公司   高端装备制造产业
# 1108556  FFB2CCFAC37353C551D5377EEC23108F     滁州岳众汽车零部件有限公司         其它
# 1108557  FFB6D6F6BE7C5ED2550299D6094F9C71  浙江大升旅行用品科技股份有限公司         其它
# 1108558  FFC4CEC75FA040BC86DFABE24A94CB23      广州必望信息技术有限公司  新一代信息技术产业
# 1108559  FFE318C4EA741399699C17DE9C533DC7      厦门文杉信息科技有限公司  新一代信息技术产业
#
#               seic_lv2                                ans_id  inventor_cnt  \
# ...

# %% [markdown]
# # 穿透前的原始值

# %%
test_quanguo_original=pd.read_sql('select * from test_quanguo_original',con=engine)
test_quanguo_original
# Out:
#                                company_id   seic_lv2  \
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F         其它
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E  生物农业及相关产业
# 2        0027683A8AB4217205D5BE751D3A6D4E         其它
# 3        0034953AE8F88E6DD07C2809226C2A17         其它
# 4        003D83E767259BB08EC3F13BA588C53D   智能制造装备产业
# ...                                   ...        ...
# 1053546  FED7E3FAC46D1723AFFBE0FDFE415EF9   轨道交通装备产业
# 1053547  FF41E884CA1DCE7CF71AE2905EAB3457     先进环保产业
# 1053548  FF828D60E29A82AAEC71B2E221B21C4D       人工智能
# 1053549  FFB8D187EF1495AE8D841BB8EFD7A970  下一代信息网络产业
# 1053550  FFF08C781D50E5DDF36A0F6232CFBBAE  先进无机非金属材料
#
#          actual_capital_formatted   duration  reg_capital_formatted  \
# 0                        120000.0   5.002740              3000000.0
# 1                        200000.0  28.358904              5000000.0
# 2                      98000000.0   8.975342             98000000.0
# ...

# %%
test_quanguo_original.columnsumns
# Out:
# Index(['company_id', 'avg_cited_by_cnt', 'country_cnt', 'patent_valid_ratio',
#        'value_top10_avg', 'granted_invention_cnt', 'joint_applicant_cnt',
#        'invention_stability', 'avg_remaining_life_span', 'ans_id',
#        'granted_invention_cnt_pb_1y', 'self_cited_by_ratio',
#        'top5_current_impact_index', 'value_top5_avg', 'invention_ratio',
#        'external_licensing_cnt', 'core_patents_cited_by_cnt',
#        'non_design_apno_cnt', 'apno_cnt_valid_5y', 'avg_3y_cnt',
#        'company_name', 'pct_apno_cnt', 'granted_invention_ratio',
#        'inventor_cnt', 'granted_invention_cnt_pb_original_2y',
#        'total_patent_award_score', 'core_patents_cited_by_ratio',
#        'ip_dependency', 'active_inventor_ratio', 'most_cited_patents_value',
#        'tech_width', 'tech_global_concentration', 'apno_cnt',
#        'joint_application_cnt', 'avg_technology_score', 'value_avg',
#        'value_sum', 'patenting_growth_ratio', 'in_examing_ratio', 'public',
# ...

# %% [markdown]
# # 子孙公司集团穿透

# %%
group=pd.read_csv('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/4月/子孙公司穿透/子孙穿透的集团公司.csv')
group
# Out:
#                                group_id         group_name
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
# [35971 rows x 2 columns]

# %% [markdown]
# # 细节指标对比

# %% [markdown]
# ## 专利

# %% [markdown]
# ### apno_cnt

# %%
group_apno_cnt=pd.merge(group,national_company_alldata_2101[['company_id','apno_cnt','ans_id']],left_on='group_id',right_on='company_id')
group_apno_cnt=pd.merge(group_apno_cnt,test_quanguo_original[['company_id','apno_cnt']],on='company_id',suffixes=['_after','_front'])
group_apno_cnt['gap']=group_apno_cnt['apno_cnt_after']-group_apno_cnt['apno_cnt_front']
group_apno_cnt.fillna(0,inplace=True)
group_apno_cnt
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  apno_cnt_after  \
# 0      A02A26EE99279988724E6DB975824856          5786.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4          1361.0
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD             5.0
# ...

# %%
group_apno_cnt[group_apno_cnt['gap']<0]
# Out:
#                                group_id         group_name  \
# 591    480C38C743ED7C8B0CB5218217E1FBF5         中策橡胶集团有限公司
# 604    5A8561A8DD635420D9F7887AAEA35C69       厦门松元电子股份有限公司
# 940    B9BDDC323B356EBF50A5B43282BCAF9D    天添爱（青岛）生物科技有限公司
# 3392   269B77630951A308D770122AF90B05C0         长光卫星技术有限公司
# 3580   DA40693147B30C3074FA6E617BA9469A   博奥赛斯（天津）生物科技有限公司
# 3595   A25DC230AE336036DC73C9BAAD06ABA9        深圳市拔超科技有限公司
# 3813   0EDB6B1DC431F95D503637DEBD8E9617   江苏科创车联网产业研究院有限公司
# 3958   56C543C47B612E78D5760715DDC19676         浙江恒澜科技有限公司
# 4010   0433D76653BDFF6123B2578D55BD6F34       沈阳万合胶业股份有限公司
# 4376   3DDF4E86E7601C14921ADC250D1E9FDD      希迪克康养产业发展有限公司
# 4491   238FB36749E856949B8EFB9F72D59C9B      宁波圣莱达电器股份有限公司
# 5233   FCC722151BFC9C4737D54D33B4D0602E        厦门益和丰食品有限公司
# 5290   B58301EB2E5CF719806C534F1295C654       北京云迹科技股份有限公司
# 5420   C648DC0D3A4671F755F626F3B02C8E40     象辑科技（武汉）股份有限公司
# 5476   BF16D298F7502A02B3C36D8DDC8D1D19     成都希盟泰克科技发展有限公司
# ...

# %% [markdown]
# ### value_sum

# %%
value_sum_cnt=pd.merge(group,national_company_alldata_2101[['company_id','value_sum','ans_id']],left_on='group_id',right_on='company_id')
value_sum_cnt=pd.merge(value_sum_cnt,test_quanguo_original[['company_id','value_sum']],on='company_id',suffixes=['_after','_front'])
value_sum_cnt['gap']=value_sum_cnt['value_sum_after']-value_sum_cnt['value_sum_front']
value_sum_cnt.fillna(0,inplace=True)
value_sum_cnt
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  value_sum_after  \
# 0      A02A26EE99279988724E6DB975824856      110340000.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       25868000.0
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD           6800.0
# ...

# %%
value_sum_cnt[value_sum_cnt['gap']<0]
# Out:
#                                group_id       group_name  \
# 235    780ECB56C0B5638815791A24E6B1253D    中玻（陕西）新技术有限公司
# 269    237D6ECEC7579E41E48A5B570738512F  湖南优尔康悬浮拼装地板有限公司
# 342    5BCC169A7ECE37B4007D8FC25D8CBD66    深圳市优点智联科技有限公司
# 431    941C926966FCE349AA493CE1EC4C01EE     广州商脉网络科技有限公司
# 591    480C38C743ED7C8B0CB5218217E1FBF5       中策橡胶集团有限公司
# ...                                 ...              ...
# 35723  BC97865AFD955F1C5DFF9B4935CE7FEE       浙江茶荟家居有限公司
# 35818  5D2EB7346FC3117231EECAF694112823     山西天朔电动汽车有限公司
# 35841  41F1DE6EA69098BB4EB01ECC87A1B405     上海第升环保科技有限公司
# 35848  D69EC4E26A7C6AAE7F6DB64C8C69D470    温州市润新机械制造有限公司
# 35863  8B17428E529CBDEFFAF32EB182FA81F8      深圳市环中科技有限公司
#
#                              company_id  value_sum_after  \
# 235    780ECB56C0B5638815791A24E6B1253D         400700.0
# 269    237D6ECEC7579E41E48A5B570738512F          69600.0
# 342    5BCC169A7ECE37B4007D8FC25D8CBD66          62200.0
# ...

# %% [markdown]
# ### avg_3y_cnt

# %%
avg_3y_cnt=pd.merge(group,national_company_alldata_2101[['company_id','avg_3y_cnt','ans_id']],left_on='group_id',right_on='company_id')
avg_3y_cnt=pd.merge(avg_3y_cnt,test_quanguo_original[['company_id','avg_3y_cnt']],on='company_id',suffixes=['_after','_front'])
avg_3y_cnt['gap']=avg_3y_cnt['avg_3y_cnt_after']-avg_3y_cnt['avg_3y_cnt_front']
avg_3y_cnt.fillna(0,inplace=True)
avg_3y_cnt
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  avg_3y_cnt_after  \
# 0      A02A26EE99279988724E6DB975824856        576.000000
# 1      0E72391F0D136A1F42C55B07BF1ABAA4        118.666667
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD          1.666667
# ...

# %%
avg_3y_cnt[avg_3y_cnt['gap']>0]
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  avg_3y_cnt_after  \
# 0      A02A26EE99279988724E6DB975824856        576.000000
# 1      0E72391F0D136A1F42C55B07BF1ABAA4        118.666667
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD          1.666667
# ...

# %% [markdown]
# ## 非专利

# %% [markdown]
# ### num_members

# %%
num_members_cnt=pd.merge(group,national_company_alldata_2101[['company_id','num_members','ans_id']],left_on='group_id',right_on='company_id')
num_members_cnt=pd.merge(num_members_cnt,test_quanguo_original[['company_id','num_members']],on='company_id',suffixes=['_after','_front'])
num_members_cnt['gap']=num_members_cnt['num_members_after']-num_members_cnt['num_members_front']
num_members_cnt.fillna(0,inplace=True)
num_members_cnt
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35942  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35943  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35944  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35945  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35946  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  num_members_after  \
# 0      A02A26EE99279988724E6DB975824856               16.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                0.0
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD                0.0
# ...

# %%
num_members_cnt[num_members_cnt['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
#                                group_id group_name  \
# 11747  A70A3E493E6B6E9C3D1CDA03B6279CAA   华为技术有限公司
#
#                              company_id  num_members_after  \
# 11747  A70A3E493E6B6E9C3D1CDA03B6279CAA               68.0
#
#                                      ans_id  num_members_front  gap
# 11747  f039e90a-679c-4c50-ab06-72d03d496c4f               68.0  0.0

# %%
num_members_cnt[num_members_cnt['gap']<0]
# Out:
# Empty DataFrame
# Columns: [group_id, group_name, company_id, num_members_after, ans_id, num_members_front, gap]
# Index: []

# %% [markdown]
# ### money_q25_sum_weighted

# %%
money_q25_sum_weighted=pd.merge(group,national_company_alldata_2101[['company_id','money_q25_sum_weighted','ans_id']],left_on='group_id',right_on='company_id')
money_q25_sum_weighted=pd.merge(money_q25_sum_weighted ,test_quanguo_original[['company_id','money_q25_sum_weighted']],on='company_id',suffixes=['_after','_front'])
money_q25_sum_weighted.fillna(0,inplace=True)
money_q25_sum_weighted['gap']=money_q25_sum_weighted['money_q25_sum_weighted_after']-money_q25_sum_weighted['money_q25_sum_weighted_front']
money_q25_sum_weighted
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  money_q25_sum_weighted_after  \
# 0      A02A26EE99279988724E6DB975824856                  5.634190e+08
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                  8.785714e+05
# ...

# %%
money_q25_sum_weighted[money_q25_sum_weighted['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
#                                group_id group_name  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA   华为技术有限公司
#
#                              company_id  money_q25_sum_weighted_after  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA                  8.897823e+07
#
#                                      ans_id  money_q25_sum_weighted_front  \
# 11759  f039e90a-679c-4c50-ab06-72d03d496c4f                           0.0
#
#                 gap
# 11759  8.897823e+07

# %%
len(money_q25_sum_weighted[money_q25_sum_weighted['gap']<0])
# Out:
# 14

# %% [markdown]
# ### avg_funding_interval

# %%
avg_funding_interval=pd.merge(group,national_company_alldata_2101[['company_id','avg_funding_interval','ans_id']],left_on='group_id',right_on='company_id')
avg_funding_interval=pd.merge(avg_funding_interval ,test_quanguo_original[['company_id','avg_funding_interval']],on='company_id',suffixes=['_after','_front'])
avg_funding_interval.fillna(0,inplace=True)
avg_funding_interval['gap']=avg_funding_interval['avg_funding_interval_after']-avg_funding_interval['avg_funding_interval_front']
avg_funding_interval
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  avg_funding_interval_after  \
# 0      A02A26EE99279988724E6DB975824856                    1.378082
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                    0.000000
# ...

# %%
avg_funding_interval[avg_funding_interval['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
#                                group_id group_name  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA   华为技术有限公司
#
#                              company_id  avg_funding_interval_after  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA                    5.011872
#
#                                      ans_id  avg_funding_interval_front  \
# 11759  f039e90a-679c-4c50-ab06-72d03d496c4f                         0.0
#
#             gap
# 11759  5.011872

# %%
avg_funding_interval[avg_funding_interval['gap']>0]
# Out:
#                                group_id        group_name  \
# 0      A02A26EE99279988724E6DB975824856      浙江正泰电器股份有限公司
# 12     A915BE896FFAE1B916B3B76450D5D232      北新集团建材股份有限公司
# 19     ECDBDED6B6307BC5E032B0620098E9BB        厦门建发股份有限公司
# 20     381134624E0AD9EA13B799AEB6F15D9C    中信国安信息产业股份有限公司
# 22     506B5B9FA8C757EE77C025DDAE9A74E6    四川东材科技集团股份有限公司
# ...                                 ...               ...
# 35858  48BE60D865B9874C3022F87C85C410A4      南京金合能源材料有限公司
# 35874  BF644B0C7FC5A2C6557293967522E087      中科可控信息产业有限公司
# 35890  68ACF26F96CBE222D9CAE660BD2D3672  时时同云科技（成都）有限责任公司
# 35929  FAAA5BAA01280D7FA85F8B682C9972D6      长沙安迪生物科技有限公司
# 35953  ED41D2E53192D4F8AA68740063A69752    国能中电能源集团有限责任公司
#
#                              company_id  avg_funding_interval_after  \
# 0      A02A26EE99279988724E6DB975824856                    1.378082
# 12     A915BE896FFAE1B916B3B76450D5D232                    0.912055
# ...

# %% [markdown]
# ### most_recent_money_q25_formatted

# %%
most_recent_money_q25_formatted=pd.merge(group,national_company_alldata_2101[['company_id','most_recent_money_q25_formatted','ans_id']],left_on='group_id',right_on='company_id')
most_recent_money_q25_formatted=pd.merge(most_recent_money_q25_formatted ,test_quanguo_original[['company_id','most_recent_money_q25_formatted']],on='company_id',suffixes=['_after','_front'])
most_recent_money_q25_formatted.fillna(0,inplace=True)
most_recent_money_q25_formatted['gap']=most_recent_money_q25_formatted['most_recent_money_q25_formatted_after']-most_recent_money_q25_formatted['most_recent_money_q25_formatted_front']
most_recent_money_q25_formatted
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  \
# 0      A02A26EE99279988724E6DB975824856
# 1      0E72391F0D136A1F42C55B07BF1ABAA4
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD
# 3      BE40DDC269BCA615ABCE10A28CE8E902
# 4      46B64E8C0AFE7BC6890AE568993354ED
# ...

# %% [markdown]
# ##### most_recent_money_q25_formatted[most_recent_money_q25_formatted['gap']>0]

# %% [markdown]
# ### most_recent_time

# %%
most_recent_time=pd.merge(group,national_company_alldata_2101[['company_id','most_recent_time','ans_id']],left_on='group_id',right_on='company_id')
most_recent_time=pd.merge(most_recent_time,test_quanguo_original[['company_id','most_recent_time']],on='company_id',suffixes=['_after','_front'])
most_recent_time.fillna(0,inplace=True)
most_recent_time['gap']=most_recent_time['most_recent_time_after']-most_recent_time['most_recent_time_front']
most_recent_time
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  most_recent_time_after  \
# 0      A02A26EE99279988724E6DB975824856                0.676712
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                6.126027
# ...

# %%
most_recent_time[most_recent_time['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
#                                group_id group_name  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA   华为技术有限公司
#
#                              company_id  most_recent_time_after  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA                1.057534
#
#                                      ans_id  most_recent_time_front       gap
# 11759  f039e90a-679c-4c50-ab06-72d03d496c4f                     0.0  1.057534

# %%
most_recent_time[most_recent_time['gap']<0]
# Out:
#                                group_id      group_name  \
# 0      A02A26EE99279988724E6DB975824856    浙江正泰电器股份有限公司
# 11     953000B68C8BBAED4AAD0E54CA7DD842        通威股份有限公司
# 22     506B5B9FA8C757EE77C025DDAE9A74E6  四川东材科技集团股份有限公司
# 32     AD17A657DC7669AD0639441DE92AA6AA      辽宁成大股份有限公司
# 88     45E38A252ACB040DF3B9BFA716A36A90    中盐金坛盐化有限责任公司
# ...                                 ...             ...
# 35638  0E809C6168265CEED77C55CB98A30011    武汉易维科技股份有限公司
# 35642  B9A4B9AEFE61422D7F476A29A95A9963  福建阿石创新材料股份有限公司
# 35662  C5D775CCF73FBE38993F525165D875B3    蚌埠火鹤制药股份有限公司
# 35766  B0E281DB5109BC683943175DBD902F4F    浙江佐力药业股份有限公司
# 35820  EAC0C6E8BB2F0414070884AC6B75DF96    北京北交新能科技有限公司
#
#                              company_id  most_recent_time_after  \
# 0      A02A26EE99279988724E6DB975824856                0.676712
# 11     953000B68C8BBAED4AAD0E54CA7DD842                1.961644
# 22     506B5B9FA8C757EE77C025DDAE9A74E6                2.271233
# ...

# %% [markdown]
# ### reg_capital_formatted

# %%
reg_capital_formatted=pd.merge(group,national_company_alldata_2101[['company_id','reg_capital_formatted','ans_id']],left_on='group_id',right_on='company_id')
reg_capital_formatted=pd.merge(reg_capital_formatted,test_quanguo_original[['company_id','reg_capital_formatted']],on='company_id',suffixes=['_after','_front'])
reg_capital_formatted.fillna(0,inplace=True)
reg_capital_formatted['gap']=reg_capital_formatted['reg_capital_formatted_after']-reg_capital_formatted['reg_capital_formatted_front']
reg_capital_formatted
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  reg_capital_formatted_after  \
# 0      A02A26EE99279988724E6DB975824856                 2.149974e+09
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                 2.123311e+09
# ...

# %%
reg_capital_formatted[reg_capital_formatted['gap']<0]
# Out:
#                                group_id        group_name  \
# 496    795B113A7EB8930F9AFCC8638F5C198B   塞力斯医疗科技集团股份有限公司
# 620    AEBC1440F94229C06484019571CB977F    北京百华悦邦科技股份有限公司
# 788    F600BD886018C5C620E83146E174B9D8      佳都科技集团股份有限公司
# 1033   586758AFDF197098909CF015423E475E  宁波理工环境能源科技股份有限公司
# 1074   1AE99B34C08969E3F5D6AB7458FE2660        泰豪科技股份有限公司
# ...                                 ...               ...
# 33920  71C9E1439246C2BC7E5C20441258F049    杭州天地数码科技股份有限公司
# 34348  BFB1D8A37BAA8D388B50835E415931AB    江苏力星通用钢球股份有限公司
# 34477  BF7D187541492BA85B1903303D5F2DB2      迪瑞医疗科技股份有限公司
# 34579  3A7A0A53FC37F4D1717EE1D895EA85A2        汇纳科技股份有限公司
# 35657  8CBF8D7845B1D8CD7F7D8AEB33FDD070     上海英威腾工业技术有限公司
#
#                              company_id  reg_capital_formatted_after  \
# 496    795B113A7EB8930F9AFCC8638F5C198B                 2.050190e+08
# 620    AEBC1440F94229C06484019571CB977F                 1.301331e+08
# ...

# %% [markdown]
# ### actual_capital_formatted

# %%
actual_capital_formatted=pd.merge(group,national_company_alldata_2101[['company_id','actual_capital_formatted','ans_id']],left_on='group_id',right_on='company_id')
actual_capital_formatted=pd.merge(actual_capital_formatted,test_quanguo_original[['company_id','actual_capital_formatted']],on='company_id',suffixes=['_after','_front'])
actual_capital_formatted.fillna(0,inplace=True)
actual_capital_formatted['gap']=actual_capital_formatted['actual_capital_formatted_after']-actual_capital_formatted['actual_capital_formatted_front']
actual_capital_formatted
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  actual_capital_formatted_after  \
# 0      A02A26EE99279988724E6DB975824856                    2.149974e+09
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                    2.123311e+09
# ...

# %%
actual_capital_formatted[actual_capital_formatted['gap']<0]
# Out:
#                                group_id           group_name  \
# 91     0A64ACDF151696322201094142F0C555        浙江康恩贝制药股份有限公司
# 132    7FD431219107564C62AABD99E01A3DE3       航天时代电子技术股份有限公司
# 140    03769E44A70015077816200A2DEC34F4     乐普（北京）医疗器械股份有限公司
# 185    5D386338B800D219F9C183699297D8B3          唐人神集团股份有限公司
# 248    A3EEB289126AA76E53915CED5966A7C3           星光农机股份有限公司
# ...                                 ...                  ...
# 35619  6872B9FDA0F5D817E658A35CF7DE5D9C         上海敦孚机电科技有限公司
# 35622  9539DA427F6EE63C0FEA8F8A31B58C0F    广东皮阿诺科学艺术家居股份有限公司
# 35657  8CBF8D7845B1D8CD7F7D8AEB33FDD070        上海英威腾工业技术有限公司
# 35794  8F21E72A1C4B9ECF3EF4EEF211EAEE3E       江苏大烨智能电气股份有限公司
# 35903  4BD1A65A71ECEFC5C6384CC5A4E35902  麦加芯彩新材料科技（上海）股份有限公司
#
#                              company_id  actual_capital_formatted_after  \
# 91     0A64ACDF151696322201094142F0C555                    0.000000e+00
# 132    7FD431219107564C62AABD99E01A3DE3                    1.302640e+07
# ...

# %% [markdown]
# ### duration

# %%
duration=pd.merge(group,national_company_alldata_2101[['company_id','duration','ans_id']],left_on='group_id',right_on='company_id')
duration=pd.merge(duration,test_quanguo_original[['company_id','duration']],on='company_id',suffixes=['_after','_front'])
duration.fillna(0,inplace=True)
duration['gap']=duration['duration_after']-duration['duration_front']
duration
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  duration_after  \
# 0      A02A26EE99279988724E6DB975824856       24.709589
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       41.441096
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD       11.917808
# ...

# %%
duration[duration['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
#                                group_id group_name  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA   华为技术有限公司
#
#                              company_id  duration_after  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA       34.605479
#
#                                      ans_id  duration_front       gap
# 11759  f039e90a-679c-4c50-ab06-72d03d496c4f       34.545205  0.060274

# %%
duration[duration['gap']<0]
# Out:
# Empty DataFrame
# Columns: [group_id, group_name, company_id, duration_after, ans_id, duration_front, gap]
# Index: []

# %% [markdown]
# ### rounds

# %%
rounds=pd.merge(group,national_company_alldata_2101[['company_id','rounds','ans_id']],left_on='group_id',right_on='company_id')
rounds=pd.merge(rounds,test_quanguo_original[['company_id','rounds']],on='company_id',suffixes=['_after','_front'])
rounds.fillna(0,inplace=True)
rounds['gap']=rounds['rounds_after']-rounds['rounds_front']
rounds
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  rounds_after  \
# 0      A02A26EE99279988724E6DB975824856          10.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4           1.0
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD           0.0
# ...

# %%
rounds[rounds['gap']>0]
# Out:
#                                group_id        group_name  \
# 0      A02A26EE99279988724E6DB975824856      浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4      株洲硬质合金集团有限公司
# 7      EB2C7FEFD5E6E9E1241C3B07D4A3BEE7    国家电投集团东北电力有限公司
# 11     953000B68C8BBAED4AAD0E54CA7DD842          通威股份有限公司
# 12     A915BE896FFAE1B916B3B76450D5D232      北新集团建材股份有限公司
# ...                                 ...               ...
# 35925  1C61E453C6EFF5BE2A85DD1ECBA14498    厦门求实智能网络设备有限公司
# 35929  FAAA5BAA01280D7FA85F8B682C9972D6      长沙安迪生物科技有限公司
# 35946  C47F91354F903C572F450FADF29B208C          云南玉溪水松纸厂
# 35947  1FE6935E9BD502C25DBB0665B573D94B  来复赛尔（厦门）生物科技有限公司
# 35953  ED41D2E53192D4F8AA68740063A69752    国能中电能源集团有限责任公司
#
#                              company_id  rounds_after  \
# 0      A02A26EE99279988724E6DB975824856          10.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4           1.0
# 7      EB2C7FEFD5E6E9E1241C3B07D4A3BEE7           1.0
# ...

# %% [markdown]
# ### num_certificates

# %%
num_certificates=pd.merge(group,national_company_alldata_2101[['company_id','num_certificates','ans_id']],left_on='group_id',right_on='company_id')
num_certificates=pd.merge(num_certificates,test_quanguo_original[['company_id','num_certificates']],on='company_id',suffixes=['_after','_front'])
num_certificates.fillna(0,inplace=True)
num_certificates['gap']=num_certificates['num_certificates_after']-num_certificates['num_certificates_front']
num_certificates
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  num_certificates_after  \
# 0      A02A26EE99279988724E6DB975824856                  3185.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                    18.0
# ...

# %%
num_certificates[num_certificates['gap']>0]
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# 5      E74AEFDEB7B483290A94A41E2258389B     嘉兴恒杰生物制药股份有限公司
# ...                                 ...                ...
# 35963  489BFD764D977258379BE1036876824D       江西新力传感科技有限公司
# 35965  DD0C5E91FA0256D2B4854E86BAF7555C    东台市唐洋带锯机械有限责任公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  num_certificates_after  \
# 0      A02A26EE99279988724E6DB975824856                  3185.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                    18.0
# ...

# %% [markdown]
# ### reg_num_5y

# %%
reg_num_5y=pd.merge(group,national_company_alldata_2101[['company_id','reg_num_5y','ans_id']],left_on='group_id',right_on='company_id')
reg_num_5y=pd.merge(reg_num_5y,test_quanguo_original[['company_id','reg_num_5y']],on='company_id',suffixes=['_after','_front'])
reg_num_5y.fillna(0,inplace=True)
reg_num_5y['gap']=reg_num_5y['reg_num_5y_after']-reg_num_5y['reg_num_5y_front']
reg_num_5y
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  reg_num_5y_after  \
# 0      A02A26EE99279988724E6DB975824856             292.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4               4.0
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD              19.0
# ...

# %%
reg_num_5y[reg_num_5y['gap']>0]
# Out:
#                                group_id      group_name  \
# 0      A02A26EE99279988724E6DB975824856    浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4    株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD  北京景瑞星琳园林绿化有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED    华夏幸福基业股份有限公司
# 5      E74AEFDEB7B483290A94A41E2258389B  嘉兴恒杰生物制药股份有限公司
# ...                                 ...             ...
# 35955  D5EF1599FB84B952B07625D323FB0D3E    深圳市和亦弛科技有限公司
# 35956  80E56EFE13FDCC3CB4D91465D824C79E     北京希地码科技有限公司
# 35957  1F6BDA5376EC26D57117707F8158FEB6  沧州中兴实业集团有限责任公司
# 35963  489BFD764D977258379BE1036876824D    江西新力传感科技有限公司
# 35964  E7265FB7F6D9D04A75F6E8DD8D8686B4   上海硕乐自动化设备有限公司
#
#                              company_id  reg_num_5y_after  \
# 0      A02A26EE99279988724E6DB975824856             292.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4               4.0
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD              19.0
# ...

# %% [markdown]
# ### num_trademarks_total_5y

# %%
num_trademarks_total_5y=pd.merge(group,national_company_alldata_2101[['company_id','num_trademarks_total_5y','ans_id']],left_on='group_id',right_on='company_id')
num_trademarks_total_5y=pd.merge(num_trademarks_total_5y,test_quanguo_original[['company_id','num_trademarks_total_5y']],on='company_id',suffixes=['_after','_front'])
num_trademarks_total_5y.fillna(0,inplace=True)
num_trademarks_total_5y['gap']=num_trademarks_total_5y['num_trademarks_total_5y_after']-num_trademarks_total_5y['num_trademarks_total_5y_front']
num_trademarks_total_5y
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  num_trademarks_total_5y_after  \
# 0      A02A26EE99279988724E6DB975824856                          650.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                           48.0
# ...

# %%
num_trademarks_total_5y[num_trademarks_total_5y['gap']>0]
# Out:
#                                group_id        group_name  \
# 0      A02A26EE99279988724E6DB975824856      浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4      株洲硬质合金集团有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902      湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED      华夏幸福基业股份有限公司
# 5      E74AEFDEB7B483290A94A41E2258389B    嘉兴恒杰生物制药股份有限公司
# ...                                 ...               ...
# 35951  1B758D2FCE1B46194B0479D176D9E621  山东山汽工程机械（集团）有限公司
# 35953  ED41D2E53192D4F8AA68740063A69752    国能中电能源集团有限责任公司
# 35961  3A162BE21C015388150607DB498613F6    苏州市兴丰强纺织科技有限公司
# 35963  489BFD764D977258379BE1036876824D      江西新力传感科技有限公司
# 35965  DD0C5E91FA0256D2B4854E86BAF7555C   东台市唐洋带锯机械有限责任公司
#
#                              company_id  num_trademarks_total_5y_after  \
# 0      A02A26EE99279988724E6DB975824856                          650.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                           48.0
# ...

# %% [markdown]
# ### num_trademarks_registered_5y

# %%
num_trademarks_registered_5y=pd.merge(group,national_company_alldata_2101[['company_id','num_trademarks_registered_5y','ans_id']],left_on='group_id',right_on='company_id')
num_trademarks_registered_5y=pd.merge(num_trademarks_registered_5y,test_quanguo_original[['company_id','num_trademarks_registered_5y']],on='company_id',suffixes=['_after','_front'])
num_trademarks_registered_5y.fillna(0,inplace=True)
num_trademarks_registered_5y['gap']=num_trademarks_registered_5y['num_trademarks_registered_5y_after']-num_trademarks_registered_5y['num_trademarks_registered_5y_front']
num_trademarks_registered_5y
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  num_trademarks_registered_5y_after  \
# 0      A02A26EE99279988724E6DB975824856                               307.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                                 6.0
# ...

# %%
num_trademarks_registered_5y[num_trademarks_registered_5y['gap']>0]
# Out:
#                                group_id        group_name  \
# 0      A02A26EE99279988724E6DB975824856      浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4      株洲硬质合金集团有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902      湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED      华夏幸福基业股份有限公司
# 5      E74AEFDEB7B483290A94A41E2258389B    嘉兴恒杰生物制药股份有限公司
# ...                                 ...               ...
# 35945  98C36D40C45A6BEFDC62ABF1AE2ABF75     惠州市康赢盛世实业有限公司
# 35947  1FE6935E9BD502C25DBB0665B573D94B  来复赛尔（厦门）生物科技有限公司
# 35951  1B758D2FCE1B46194B0479D176D9E621  山东山汽工程机械（集团）有限公司
# 35953  ED41D2E53192D4F8AA68740063A69752    国能中电能源集团有限责任公司
# 35965  DD0C5E91FA0256D2B4854E86BAF7555C   东台市唐洋带锯机械有限责任公司
#
#                              company_id  num_trademarks_registered_5y_after  \
# 0      A02A26EE99279988724E6DB975824856                               307.0
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                                 6.0
# ...

# %% [markdown]
# ### reg_growth_ratio

# %%
reg_growth_ratio=pd.merge(group,national_company_alldata_2101[['company_id','reg_growth_ratio','ans_id']],left_on='group_id',right_on='company_id')
reg_growth_ratio=pd.merge(reg_growth_ratio,test_quanguo_original[['company_id','reg_growth_ratio']],on='company_id',suffixes=['_after','_front'])
reg_growth_ratio.fillna(0,inplace=True)
reg_growth_ratio['gap']=reg_growth_ratio['reg_growth_ratio_after']-reg_growth_ratio['reg_growth_ratio_front']
reg_growth_ratio
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  reg_growth_ratio_after  \
# 0      A02A26EE99279988724E6DB975824856               -0.153198
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                0.224745
# ...

# %%
reg_growth_ratio[reg_growth_ratio['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
#                                group_id group_name  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA   华为技术有限公司
#
#                              company_id  reg_growth_ratio_after  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA                0.135836
#
#                                      ans_id  reg_growth_ratio_front       gap
# 11759  f039e90a-679c-4c50-ab06-72d03d496c4f                0.129074  0.006762

# %%
reg_growth_ratio[reg_growth_ratio['gap']>0]
# Out:
#                                group_id      group_name  \
# 1      0E72391F0D136A1F42C55B07BF1ABAA4    株洲硬质合金集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED    华夏幸福基业股份有限公司
# 5      E74AEFDEB7B483290A94A41E2258389B  嘉兴恒杰生物制药股份有限公司
# 7      EB2C7FEFD5E6E9E1241C3B07D4A3BEE7  国家电投集团东北电力有限公司
# 9      814D22A34096EF07E919D914CAD63915      北京忆芯科技有限公司
# ...                                 ...             ...
# 35949  F99A6DC78A4C911094848A6ED5B02155   辽宁实远新能源股份有限公司
# 35956  80E56EFE13FDCC3CB4D91465D824C79E     北京希地码科技有限公司
# 35957  1F6BDA5376EC26D57117707F8158FEB6  沧州中兴实业集团有限责任公司
# 35963  489BFD764D977258379BE1036876824D    江西新力传感科技有限公司
# 35964  E7265FB7F6D9D04A75F6E8DD8D8686B4   上海硕乐自动化设备有限公司
#
#                              company_id  reg_growth_ratio_after  \
# 1      0E72391F0D136A1F42C55B07BF1ABAA4                0.224745
# 4      46B64E8C0AFE7BC6890AE568993354ED                0.264911
# 5      E74AEFDEB7B483290A94A41E2258389B                1.000000
# ...

# %% [markdown]
# ### reg_3y_avg

# %%
reg_3y_avg=pd.merge(group,national_company_alldata_2101[['company_id','reg_3y_avg','ans_id']],left_on='group_id',right_on='company_id')
reg_3y_avg=pd.merge(reg_3y_avg,test_quanguo_original[['company_id','reg_3y_avg']],on='company_id',suffixes=['_after','_front'])
reg_3y_avg.fillna(0,inplace=True)
reg_3y_avg['gap']=reg_3y_avg['reg_3y_avg_after']-reg_3y_avg['reg_3y_avg_front']
reg_3y_avg
# Out:
#                                group_id         group_name  \
# 0      A02A26EE99279988724E6DB975824856       浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4       株洲硬质合金集团有限公司
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD     北京景瑞星琳园林绿化有限公司
# 3      BE40DDC269BCA615ABCE10A28CE8E902       湖北大江化工集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED       华夏幸福基业股份有限公司
# ...                                 ...                ...
# 35966  789B2EFA8671091221EB20B667043759      浙江三花汽车零部件有限公司
# 35967  6B8A27573E6C4104631849FE5D48EA28       广东泽和环保科技有限公司
# 35968  A9A032EBEFCB5367D4AF13BB98BCA8B8  浙江鸿盛新材料科技集团股份有限公司
# 35969  815DB53474016F277ED9999EAF2144A8    佛吉亚歌乐电子（丰城）有限公司
# 35970  FA4CD8F441E6992DE7D84FD1A77FA598       陕西五洲矿业股份有限公司
#
#                              company_id  reg_3y_avg_after  \
# 0      A02A26EE99279988724E6DB975824856         49.000000
# 1      0E72391F0D136A1F42C55B07BF1ABAA4          1.000000
# 2      740C8AEF86DF2BCC4C050AB4DB50FEBD          3.333333
# ...

# %%
reg_3y_avg[reg_3y_avg['company_id']=='A70A3E493E6B6E9C3D1CDA03B6279CAA']
# Out:
#                                group_id group_name  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA   华为技术有限公司
#
#                              company_id  reg_3y_avg_after  \
# 11759  A70A3E493E6B6E9C3D1CDA03B6279CAA         69.666667
#
#                                      ans_id  reg_3y_avg_front   gap
# 11759  f039e90a-679c-4c50-ab06-72d03d496c4f         55.666667  14.0

# %%
reg_3y_avg[reg_3y_avg['gap']>0]
# Out:
#                                group_id      group_name  \
# 0      A02A26EE99279988724E6DB975824856    浙江正泰电器股份有限公司
# 1      0E72391F0D136A1F42C55B07BF1ABAA4    株洲硬质合金集团有限公司
# 4      46B64E8C0AFE7BC6890AE568993354ED    华夏幸福基业股份有限公司
# 5      E74AEFDEB7B483290A94A41E2258389B  嘉兴恒杰生物制药股份有限公司
# 7      EB2C7FEFD5E6E9E1241C3B07D4A3BEE7  国家电投集团东北电力有限公司
# ...                                 ...             ...
# 35955  D5EF1599FB84B952B07625D323FB0D3E    深圳市和亦弛科技有限公司
# 35956  80E56EFE13FDCC3CB4D91465D824C79E     北京希地码科技有限公司
# 35957  1F6BDA5376EC26D57117707F8158FEB6  沧州中兴实业集团有限责任公司
# 35963  489BFD764D977258379BE1036876824D    江西新力传感科技有限公司
# 35964  E7265FB7F6D9D04A75F6E8DD8D8686B4   上海硕乐自动化设备有限公司
#
#                              company_id  reg_3y_avg_after  \
# 0      A02A26EE99279988724E6DB975824856         49.000000
# 1      0E72391F0D136A1F42C55B07BF1ABAA4          1.000000
# 4      46B64E8C0AFE7BC6890AE568993354ED          5.333333
# ...
