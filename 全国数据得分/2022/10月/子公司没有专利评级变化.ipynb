# %%
import pandas as pd
import numpy as np
import os
pd.set_option('max_rows',500)
pd.set_option('max_columns',500)
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/10月/子孙公司没有ans_id评级提升')
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company_v23',echo=False)

# %% [markdown]
# # test_quanguo_ficoscore

# %%
test_quanguo_ficoscore=pd.read_sql('select * from test_quanguo_ficoscore',con=engine)
test_quanguo_ficoscore
# Out:
#                                company_id      company_name       tffi  \
# 0        001AB5688EB4EDAD3714AA08326D0BAB    安徽盛世长隆建设工程有限公司   8.931989
# 1        019BA5B6CF7C63B4655D86A823DE4B3F      浙江宏印智造包装有限公司  22.710327
# 2        0263562135BCF2CD771BFAD1FC1078A5      深圳市英得尔实业有限公司  27.398337
# 3        03B44DBE108C5D442BB8BA9BF4BC3654   苏州市江海通讯发展实业有限公司  40.941447
# 4        05669B8D71A0130E3E18AF050FCAC614   格林美电子设备（天津）有限公司  20.366544
# ...                                   ...               ...        ...
# 1128752  2A9A3619C697A2D06E7855F0AA81E361     杭州盈动达精密机械有限公司  25.430793
# 1128753  2B032234E7ADC1ED44B95F7A7DF5591A    齐齐哈尔强能酒业制造有限公司  14.530514
# 1128754  2B0DFF5C73A42CEE6133DFFDE3BA27CC      杭州励测检测技术有限公司   4.931458
# 1128755  2B3B15F2A8C65D5B4D3BAFBD620A5675        四川国纳科技有限公司  47.117687
# 1128756  2B42B5A67E6EB97D26DF6606CB2EDA3D  凯盛信息显示材料（池州）有限公司  42.529496
#
#                fico 调整等距分箱
# 0        349.125941    CCC
# 1        424.906797    CCC
# 2        450.690853    CCC
# ...

# %% [markdown]
# # test_group_ficoscore

# %%
test_group_ficoscor=pd.read_sql('select * from test_group_ficoscore',con=engine)
test_group_ficoscor
# Out:
#                              company_id    company_name       tffi  \
# 0      01D3E442F1315A8B3B3C476A3F3864C4   宁波路润冷却器制造有限公司  35.284520
# 1      0C5528EDFBAD5272E772255F1F0A0922  深圳瑞捷工程咨询股份有限公司  47.558276
# 2      154AD6BF518E5C54E9D5C244F4FAD9BD    云南白药集团股份有限公司  78.483434
# 3      17502A1F0870FC0EFCF9EB61C95DA380   昆山慧赢通互联科技有限公司  18.353831
# 4      276F5104DAFCAE379BA846156AE477C8   深圳市概念智慧科技有限公司  40.827433
# ...                                 ...             ...        ...
# 82790  CD0D7A6341CA6799DA96DD8772361574      宁波三灵电子有限公司  40.655524
# 82791  DAEDD52D036F34023D0EBF1114FD84CB  洛阳涧光特种装备股份有限公司  62.524660
# 82792  E1CDD7F0DAD2D3C12EC25134D3477B2E   武汉达梦数据库股份有限公司  78.721005
# 82793  EBDC505CAAB6624C63C50360FF1FA213    中山尚洋科技股份有限公司  52.302997
# 82794  ED296E92873E3FFCB0F28649F566DBCD    佛山市玖伍柒科技有限公司  25.351794
#
#              fico 调整等距分箱
# 0      494.064861      B
# 1      561.570519     BB
# 2      731.658886    AAA
# 3      400.946072    CCC
# 4      524.550882     BB
# ...

# %%
test_group_ficoscor.query('company_id=="0A418D4891DBA969B125E818A5A4E7B7"')
# Out:
#                             company_id company_name       tffi        fico  \
# 6600  0A418D4891DBA969B125E818A5A4E7B7   晶科能源股份有限公司  76.825485  722.540167
#
#      调整等距分箱
# 6600     AA

# %% [markdown]
# # test_group_original

# %%
test_group_original=pd.read_sql('select * from test_group_original',con=engine)
test_group_original
# Out:
#                              company_id province city   seic_lv1  \
# 0      01D3E442F1315A8B3B3C476A3F3864C4      浙江省  宁波市         其它
# 1      0C5528EDFBAD5272E772255F1F0A0922      广东省  深圳市      相关服务业
# 2      154AD6BF518E5C54E9D5C244F4FAD9BD      云南省  昆明市       生物产业
# 3      17502A1F0870FC0EFCF9EB61C95DA380      江苏省  苏州市  新一代信息技术产业
# 4      276F5104DAFCAE379BA846156AE477C8      广东省  深圳市  新一代信息技术产业
# ...                                 ...      ...  ...        ...
# 82790  CD0D7A6341CA6799DA96DD8772361574      浙江省  宁波市  新一代信息技术产业
# 82791  DAEDD52D036F34023D0EBF1114FD84CB      河南省  洛阳市   高端装备制造产业
# 82792  E1CDD7F0DAD2D3C12EC25134D3477B2E      湖北省  武汉市  新一代信息技术产业
# 82793  EBDC505CAAB6624C63C50360FF1FA213      广东省  中山市  新一代信息技术产业
# 82794  ED296E92873E3FFCB0F28649F566DBCD      广东省  佛山市      相关服务业
#
#             seic_lv2  status    company_name  \
# 0                 其它  ACTIVE   宁波路润冷却器制造有限公司
# 1         新技术与创新创业服务  ACTIVE  深圳瑞捷工程咨询股份有限公司
# 2             生物医药产业  ACTIVE    云南白药集团股份有限公司
# ...

# %%
test_group_original.query('company_id=="E8F720300BD7DF52C23209A17475ED42"').T
# Out:
#                                                                      62243
# company_id                                E8F720300BD7DF52C23209A17475ED42
# province                                                               江苏省
# city                                                                   苏州市
# seic_lv1                                                         新一代信息技术产业
# seic_lv2                                                     互联网与云计算、大数据服务
# status                                                              ACTIVE
# company_name                                               智慧芽信息科技（苏州）有限公司
# ans_id                                fe23f8a8-ebc0-4a77-826a-8fd1b5f5259f
# apno_cnt                                                               117
# non_design_apno_cnt                                                     71
# joint_application_cnt                                                   65
# ...

# %% [markdown]
# # test_quanguo_original

# %%
test_quanguo_original=pd.read_sql('select * from test_quanguo_original',con=engine)
test_quanguo_original
# Out:
#                                company_id province   city   seic_lv1  \
# 0        001AB5688EB4EDAD3714AA08326D0BAB      安徽省    芜湖市   高端装备制造产业
# 1        019BA5B6CF7C63B4655D86A823DE4B3F      浙江省    温州市         其它
# 2        0263562135BCF2CD771BFAD1FC1078A5      广东省    深圳市     数字创意产业
# 3        03B44DBE108C5D442BB8BA9BF4BC3654      江苏省    苏州市  新一代信息技术产业
# 4        05669B8D71A0130E3E18AF050FCAC614      天津市    天津市  新一代信息技术产业
# ...                                   ...      ...    ...        ...
# 1128752  2A9A3619C697A2D06E7855F0AA81E361      浙江省    杭州市   高端装备制造产业
# 1128753  2B032234E7ADC1ED44B95F7A7DF5591A     黑龙江省  齐齐哈尔市         其它
# 1128754  2B0DFF5C73A42CEE6133DFFDE3BA27CC      浙江省    杭州市      相关服务业
# 1128755  2B3B15F2A8C65D5B4D3BAFBD620A5675      四川省    成都市      新材料产业
# 1128756  2B42B5A67E6EB97D26DF6606CB2EDA3D      安徽省    池州市      新材料产业
#
#            seic_lv2  status      company_name  \
# 0          轨道交通装备产业  ACTIVE    安徽盛世长隆建设工程有限公司
# ...

# %%
test_quanguo_original.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['company_id','invention_stability']]
# Out:
#                               company_id  invention_stability
# 985483  A70A3E493E6B6E9C3D1CDA03B6279CAA          3991.497708

# %%
test_quanguo_original['invention_stability'].value_counts()
# Out:
# 0.000000     496449
# 0.316228     137230
# 0.632456      58241
# 0.421637      24962
# 0.948683      23859
#               ...
# 24.415159         1
# 13.543756         1
# 16.437085         1
# 14.722998         1
# 20.161570         1
# Name: invention_stability, Length: 12696, dtype: int64

# %% [markdown]
# # 集团公司ans_id数量

# %% [markdown]
# SELECT * FROM
# (SELECT DISTINCT group_id FROM finance_data.pingan_corptree_delinvest_companyid  where root_company=0)  pcda left join
# (SELECT group_id,COUNT(ans_id) as num FROM (SELECT * from finance_data.pingan_corptree_delinvest_companyid  where root_company=0) GROUP by group_id ) pc
# on pcda.group_id=pc.group_id

# %%
group_ans_id=pd.read_csv('子孙ans_id.csv')
group_ans_id
# Out:
#                                group_id                        group_id.1  num
# 0      B4D2F8A2485BDC0F4634280ADA70EF99  B4D2F8A2485BDC0F4634280ADA70EF99    4
# 1      B7C01D5C80C629D485B1E43887013382  B7C01D5C80C629D485B1E43887013382    1
# 2      B1756F68CCFEC11BCD2D2B9FE01D1ED9  B1756F68CCFEC11BCD2D2B9FE01D1ED9   50
# 3      B0304DA8447BA2953C5257291DC98693  B0304DA8447BA2953C5257291DC98693   11
# 4      B11497556472A9F8B5AD3BF185FCFF12  B11497556472A9F8B5AD3BF185FCFF12    2
# ...                                 ...                               ...  ...
# 82707  56F7300C3FBD998FB99F687D1343DA05  56F7300C3FBD998FB99F687D1343DA05    1
# 82708  093A3BD4FC9437C6B7380934795DAA84  093A3BD4FC9437C6B7380934795DAA84    1
# 82709  0607189D988D3012217E17AC6786D9ED  0607189D988D3012217E17AC6786D9ED    0
# 82710  0E291E5A88FAB9BB940B249E0D1AC530  0E291E5A88FAB9BB940B249E0D1AC530    1
# 82711  05FAACDBE2BDD12DD0DD0C704BFCC1F5  05FAACDBE2BDD12DD0DD0C704BFCC1F5    1
#
# ...

# %%
group_ans_id.query('group_id=="B6709A41F27F1BF5FA7E2648EAB9971B"')
# Out:
#                                group_id                        group_id.1  num
# 48415  B6709A41F27F1BF5FA7E2648EAB9971B  B6709A41F27F1BF5FA7E2648EAB9971B    2

# %%
group_ans_id_1=group_ans_id.query('num==0')
group_ans_id_1
# Out:
#                                group_id                        group_id.1  num
# 18     647451E2A13E4AA5843A52FEED55CBD0  647451E2A13E4AA5843A52FEED55CBD0    0
# 23     66D4FDA1376BEE478704B32C4B91594B  66D4FDA1376BEE478704B32C4B91594B    0
# 24     633C56440268203F355816E28F6E26EA  633C56440268203F355816E28F6E26EA    0
# 27     67BE7F61CA8ACC205573DB3C120351BF  67BE7F61CA8ACC205573DB3C120351BF    0
# 28     650729FAB974519007C495A423A693BD  650729FAB974519007C495A423A693BD    0
# ...                                 ...                               ...  ...
# 82677  B13AF3130D5D346F9FDC41CFBA6F59C3  B13AF3130D5D346F9FDC41CFBA6F59C3    0
# 82685  171D2223CD0DA225A4909941C5AD1237  171D2223CD0DA225A4909941C5AD1237    0
# 82693  FD4ADE88144DB19D068CF743C10AC12D  FD4ADE88144DB19D068CF743C10AC12D    0
# 82699  A6E09426813038187B0C1D7DFAD9B939  A6E09426813038187B0C1D7DFAD9B939    0
# 82709  0607189D988D3012217E17AC6786D9ED  0607189D988D3012217E17AC6786D9ED    0
#
# ...

# %% [markdown]
# # 评级level

# %%
rating_level=pd.read_excel('评级level.xlsx')
rating_level
# Out:
#   rating  level
# 0    AAA      1
# 1     AA      2
# 2      A      3
# 3    BBB      4
# 4     BB      5
# 5      B      6
# 6    CCC      7
# 7     CC      8
# 8      C      9

# %% [markdown]
# # 评级合并

# %%
rating_mer=pd.merge(pingan_group[['company_id','rating_v2']],test_quanguo_ficoscore[['company_id','company_name','调整等距分箱']],on='company_id')
rating_mer=pd.merge(rating_mer,test_group_ficoscor[['company_id','调整等距分箱']],on='company_id',suffixes=['_singe','group'])
rating_mer
# Out:
#                              company_id rating_v2          company_name  \
# 0      A39F1D42C65AB33E7D0E4414B281E19B        BB          浙江宝仁和中科技有限公司
# 1      6A5D59B9C5A3FC1A9A7B7993C1F27711        BB        无锡佳健医疗器械股份有限公司
# 2      34AB49DE378FF3B1B1DEABC8DEFD5CD7       BBB       上海百事通信息技术股份有限公司
# 3      E31BF5E77B36F036A3A6E1E1C9867C2E       AAA            中国中化股份有限公司
# 4      71D73387A12CFD5C1D93A3797250BCEC         B         广州亚威特精密模具有限公司
# ...                                 ...       ...                   ...
# 79955  38BF7AB10B262D6D261630345D676662       BBB         上海大族富创得科技有限公司
# 79956  9ED3417EBB799D2226403922EFA9AB0A         B        山西潞安郭庄煤业有限责任公司
# 79957  88E3FDC7B20F77811DF480D2540A9A16        BB              苏柏科技有限公司
# 79958  242395565112EF94C80725F05F05E2B4       CCC  恒信东方儿童（广州）文化产业发展有限公司
# 79959  80C02ECAC6F13BCECFC2106D2169E8BD        CC          长沙益友建筑科技有限公司
#
#       调整等距分箱_singe 调整等距分箱group
# 0               BB          BB
# 1               BB          BB
# ...

# %%
rating_mer.query('rating_v2!=调整等距分箱group')
# Out:
#                              company_id rating_v2      company_name  \
# 9176   A4BA0B16E07C7B3FA9C2111EB4425287         B      北京晓程科技股份有限公司
# 9177   80AD77358951495E74C9AD4387DEB064         B      苏州恒星医用材料有限公司
# 9178   5B2A02F56DE8057D891A297DAAA3EDBB         B  浙江万马集团特种电子电缆有限公司
# 9179   846235357C2F9E3D21AF2836997A351C         B        深圳欧赛技术有限公司
# 9180   9A305287A55F735EF74E54323A788B05         B    广东东研网络科技股份有限公司
# ...                                 ...       ...               ...
# 79865  BD313998330921A5E5B2B11992D97D93         C      北京花开软件技术有限公司
# 79866  50B1699064CF42E9629F03DB4AB99D7D         C     深圳狮子城文化股份有限公司
# 79867  D385729EA406AE5CECE1FDFE3FEC777A        CC        北京五黑科技有限公司
# 79868  2F633CA37292E337F245F4602DB92346        CC     玉环市鼎凰液压工具有限公司
# 79869  A15DFE2D0D77E7DDAA48A66970647BD7        CC     深圳市北方图锐科技有限公司
#
#       调整等距分箱_singe 调整等距分箱group rating_group  level_group rating_signle  \
# 9176            BB          BB            B            6            BB
# ...

# %%
rating_mer=pd.merge(rating_mer,rating_level,left_on='rating_v2',right_on='rating')
rating_mer=pd.merge(rating_mer,rating_level,left_on='调整等距分箱_singe',right_on='rating',suffixes=['_group','_signle'])
rating_mer=pd.merge(rating_mer,rating_level,left_on='调整等距分箱group',right_on='rating')
rating_mer
# Out:
#                              company_id rating_v2     company_name  \
# 0      A39F1D42C65AB33E7D0E4414B281E19B        BB     浙江宝仁和中科技有限公司
# 1      6A5D59B9C5A3FC1A9A7B7993C1F27711        BB   无锡佳健医疗器械股份有限公司
# 2      6485117A73EF9C688CD03494492FDEAD        BB   宁波耀华电气科技有限责任公司
# 3      C46C47B2A6B411889A15DAA6D89B717A        BB  箭牌智能科技（张家港）有限公司
# 4      69C67542E5104A787CB11DE94DA6B45D        BB      企知道网络技术有限公司
# ...                                 ...       ...              ...
# 79955  F01E065B05EEA77732F4E7B102C5A7AD         C   北京京驰无限通信技术有限公司
# 79956  BCAF19D9961A8FAFC1E32CF6F1054F14         C    河南鲁班物联网科技有限公司
# 79957  2A454B0A592406B9C548F6AF626DE173         C       中国技术创新有限公司
# 79958  1EEEFE4ACFD99F3C7DBD9934DFCD2D41         C    智管家（大连）科技有限公司
# 79959  B996DD35AAFD3C082C0E88B20BE43E01         C    北京恒昌健科技集团有限公司
#
#       调整等距分箱_singe 调整等距分箱group rating_group  level_group rating_signle  \
# 0               BB          BB           BB            5            BB
# ...

# %%
rating_mer.query("level_group>level_signle").to_excel('评级倒挂.xlsx',encoding='utf-8',index=False)

# %%
 rating_pro
# Out:
#                              company_id rating_v2 调整等距分箱
# 2      34AB49DE378FF3B1B1DEABC8DEFD5CD7       BBB     BB
# 3      E31BF5E77B36F036A3A6E1E1C9867C2E       AAA    BBB
# 4      71D73387A12CFD5C1D93A3797250BCEC         B      C
# 5      E7EA35FE4D4CE03F4DA8A72B5A888AD4       CCC      C
# 6      408D1EB291BC4CC15506BF19FDC97CBA        BB    CCC
# ...                                 ...       ...    ...
# 79711  0F1334C8938CE4E5FD7943439A57644C       CCC      C
# 79712  DE1EEA5BE7E377B6760D21B2047B15A7        BB      B
# 79714  32D1495369BC46B12E96A5BEDD87DDE3        AA      B
# 79717  60F2C92351F966D02A79BC4B620401E5       BBB     CC
# 79720  9ED3417EBB799D2226403922EFA9AB0A         B    CCC
#
# [37088 rows x 3 columns]

# %%
group_ans_id_1_pro=pd.merge(group_ans_id_1,rating_pro,left_on='group_id',right_on='company_id')
group_ans_id_1_pro
# Out:
#                              group_id                        group_id.1  num  \
# 0    716F6A4EA9EE0DFC289B24E76419C0D1  716F6A4EA9EE0DFC289B24E76419C0D1    0
# 1    F523B35844F71C4912367BB73AB80DC2  F523B35844F71C4912367BB73AB80DC2    0
# 2    D3C833EC6119A8663C8E0000A67A984C  D3C833EC6119A8663C8E0000A67A984C    0
# 3    AFBD0389AB0DA0412E00F72EB4DD54EA  AFBD0389AB0DA0412E00F72EB4DD54EA    0
# 4    12D5BEB0E3FCE61BEFA121572B5FFFAE  12D5BEB0E3FCE61BEFA121572B5FFFAE    0
# ..                                ...                               ...  ...
# 480  CDF49E884875889288BD0F59C71D6B6C  CDF49E884875889288BD0F59C71D6B6C    0
# 481  D7C37A49C48518DC9097518217F6C7F2  D7C37A49C48518DC9097518217F6C7F2    0
# 482  DDB5B9C26E2357285981C70DDBC37F4E  DDB5B9C26E2357285981C70DDBC37F4E    0
# 483  3AC5BC6B1FD7A0911A6A77B3203ED979  3AC5BC6B1FD7A0911A6A77B3203ED979    0
# 484  3FA42448BA3551A5A2111D449DDA9301  3FA42448BA3551A5A2111D449DDA9301    0
#
# ...

# %%
group_ans_id_1_pro.head(100)
# Out:
#                             group_id                        group_id.1  num  \
# 0   67BE7F61CA8ACC205573DB3C120351BF  67BE7F61CA8ACC205573DB3C120351BF    0
# 1   F89D78E9ADA02789CADD0348D8175CB3  F89D78E9ADA02789CADD0348D8175CB3    0
# 2   C3493BB3F08439B4F4C5673CE2D547D4  C3493BB3F08439B4F4C5673CE2D547D4    0
# 3   716F6A4EA9EE0DFC289B24E76419C0D1  716F6A4EA9EE0DFC289B24E76419C0D1    0
# 4   200B9620F17DFF4A0374AA57417DE7A7  200B9620F17DFF4A0374AA57417DE7A7    0
# 5   EDD232F55FA1CE39621A4FB081122918  EDD232F55FA1CE39621A4FB081122918    0
# 6   F523B35844F71C4912367BB73AB80DC2  F523B35844F71C4912367BB73AB80DC2    0
# 7   E987EC436E970363FF7996465339FCF4  E987EC436E970363FF7996465339FCF4    0
# 8   D3C833EC6119A8663C8E0000A67A984C  D3C833EC6119A8663C8E0000A67A984C    0
# 9   CFC8BC8EF3E59C280924718420160589  CFC8BC8EF3E59C280924718420160589    0
# 10  C6DF16EBC6F1B07A4FBD1B843A9A6340  C6DF16EBC6F1B07A4FBD1B843A9A6340    0
# ...

# %%
group_ans_id_1_pro.query('group_id=="D4EC2D4FA74BB23C78DA0D5A066CFDB8"')
# Out:
#                            group_id                        group_id.1  num  \
# 2  D4EC2D4FA74BB23C78DA0D5A066CFDB8  D4EC2D4FA74BB23C78DA0D5A066CFDB8    1
#
#                          company_id    company_name       tffi        fico  \
# 2  D4EC2D4FA74BB23C78DA0D5A066CFDB8  四川旅投航空旅游有限责任公司  25.668921  441.179063
#
#   调整等距分箱_group 调整等距分箱_sing
# 2            B           C

# %% [markdown]
# -- 同一个company_id不同的ans_id
# SELECT * FROM(
# SELECT group_id,company_id,COUNT(DISTINCT ans_id) num FROM finance_data.pingan_corptree_delinvest_companyid GROUP by group_id,company_id
# having COUNT(DISTINCT ans_id)>1 and company_id is not null)

# %% [markdown]
# # joint_application_cnt倒挂问题

# %% [markdown]
# SELECT * FROM(
# select company_id,joint_application_cnt as joint_application_cnt_group FROM npd_st.pingan_group_allindicator_1104) a
# join (SELECT company_id,original_detail.joint_application_cnt as joint_application_cnt FROM npd_st.looping_raw_metric where version='20221025') b
# on a.company_id=b.company_id and joint_application_cnt>joint_application_cnt_group

# %% [markdown]
# # pingan_group

# %%
pingan_group=pd.read_parquet('1.parquet')
pingan_group
# Out:
#                              company_id  \
# 0      A39F1D42C65AB33E7D0E4414B281E19B
# 1      6A5D59B9C5A3FC1A9A7B7993C1F27711
# 2      34AB49DE378FF3B1B1DEABC8DEFD5CD7
# 3      E31BF5E77B36F036A3A6E1E1C9867C2E
# 4      71D73387A12CFD5C1D93A3797250BCEC
# ...                                 ...
# 79634  38BF7AB10B262D6D261630345D676662
# 79635  9ED3417EBB799D2226403922EFA9AB0A
# 79636  88E3FDC7B20F77811DF480D2540A9A16
# 79637  242395565112EF94C80725F05F05E2B4
# 79638  80C02ECAC6F13BCECFC2106D2169E8BD
#
#                                            score_summary  \
# 0      {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# 1      {'rating': 'B', 'rating_lv2': 'B', 'rating_v2'...
# 2      {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# 3      {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# 4      {'rating': 'C', 'rating_lv2': 'C', 'rating_v2'...
# ...                                                  ...
# 79634  {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# ...

# %%
pingan_group['rating_v2']=pingan_group['score_summary'].map(lambda x:x['rating_v2'])
pingan_group['score_v2']=pingan_group['score_summary'].map(lambda x:x['score_v2'])
pingan_group
# Out:
#                              company_id  \
# 0      A39F1D42C65AB33E7D0E4414B281E19B
# 1      6A5D59B9C5A3FC1A9A7B7993C1F27711
# 2      34AB49DE378FF3B1B1DEABC8DEFD5CD7
# 3      E31BF5E77B36F036A3A6E1E1C9867C2E
# 4      71D73387A12CFD5C1D93A3797250BCEC
# ...                                 ...
# 79634  38BF7AB10B262D6D261630345D676662
# 79635  9ED3417EBB799D2226403922EFA9AB0A
# 79636  88E3FDC7B20F77811DF480D2540A9A16
# 79637  242395565112EF94C80725F05F05E2B4
# 79638  80C02ECAC6F13BCECFC2106D2169E8BD
#
#                                            score_summary  \
# 0      {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# 1      {'rating': 'B', 'rating_lv2': 'B', 'rating_v2'...
# 2      {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# 3      {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# 4      {'rating': 'C', 'rating_lv2': 'C', 'rating_v2'...
# ...                                                  ...
# 79634  {'rating': 'A', 'rating_lv2': 'A', 'rating_v2'...
# ...

# %%
a=pingan_group['score_summary'][0]

# %%
a
# Out:
# {'rating': 'C',
#  'rating_lv2': 'C',
#  'rating_v2': 'B',
#  'score': 25.56593596,
#  'score_v2': 440.61264778}

# %% [markdown]
# ## joint_application_cnt_group

# %%
joint_application_cnt_group=pd.read_csv('joint_application_cnt.csv')
joint_application_cnt_group
# Out:
#                              company_id  joint_application_cnt_group  \
# 0      54C6FF52F7827E1E239C35E58B701116                            1
# 1      AB5AEC78AC7656248DF668FA75C689B5                            0
# 2      8FC446D8970C0D77B8D8039D947A6395                            9
# 3      45D5ED0913A4CFD4A8C7C838B7DD762C                           24
# 4      76BD94C64F881D59DF0543067258585F                           88
# ...                                 ...                          ...
# 79755  7B770CC379AE0ED9ECD8796CDE8E6694                            0
# 79756  642473B657583B439D84BBFA3BD6A862                           10
# 79757  43ABFCF36682DD92B65813A0A91D61AB                            0
# 79758  50BAD995CA577D3C1917C03F6A0BB6CE                           21
# 79759  812DEBA5C767831262104687A5B82638                            0
#
#                            company_id.1  joint_application_cnt
# 0      54C6FF52F7827E1E239C35E58B701116                      1
# ...

# %%
joint_application_ans_id=pd.merge(group_ans_id_1,joint_application_cnt_group,left_on='group_id',right_on='company_id')

# %%
joint_application_ans_id.query('joint_application_cnt_group!=joint_application_cnt')
# Out:
#                                group_id                        group_id.1  \
# 12     F7E6E63CD98D9B653EA232122FF4F2DB  F7E6E63CD98D9B653EA232122FF4F2DB
# 119    DB76A0054EDF20E2DF4AA8B9C5BBF584  DB76A0054EDF20E2DF4AA8B9C5BBF584
# 159    0DE81AE514E050C33AD8B7724A286520  0DE81AE514E050C33AD8B7724A286520
# 161    658329E9D9C8E3F82C15C887F51C5A0E  658329E9D9C8E3F82C15C887F51C5A0E
# 162    658329E9D9C8E3F82C15C887F51C5A0E  658329E9D9C8E3F82C15C887F51C5A0E
# ...                                 ...                               ...
# 11226  88A6136ECEC145B8CC453CDC9E743F2C  88A6136ECEC145B8CC453CDC9E743F2C
# 11332  714D513F4AC2262FE4A8BA03D22B4432  714D513F4AC2262FE4A8BA03D22B4432
# 11390  399EA3C1F6D2528360C5FB5B082AB9AE  399EA3C1F6D2528360C5FB5B082AB9AE
# 11460  DDB5B9C26E2357285981C70DDBC37F4E  DDB5B9C26E2357285981C70DDBC37F4E
# 11473  EF2AE3B3B551398243ED0E219C4DF919  EF2AE3B3B551398243ED0E219C4DF919
#
#        num                        company_id  joint_application_cnt_group  \
# ...

# %%
group_ans_id_1
# Out:
#                                group_id                        group_id.1  num
# 18     647451E2A13E4AA5843A52FEED55CBD0  647451E2A13E4AA5843A52FEED55CBD0    0
# 23     66D4FDA1376BEE478704B32C4B91594B  66D4FDA1376BEE478704B32C4B91594B    0
# 24     633C56440268203F355816E28F6E26EA  633C56440268203F355816E28F6E26EA    0
# 27     67BE7F61CA8ACC205573DB3C120351BF  67BE7F61CA8ACC205573DB3C120351BF    0
# 28     650729FAB974519007C495A423A693BD  650729FAB974519007C495A423A693BD    0
# ...                                 ...                               ...  ...
# 82677  B13AF3130D5D346F9FDC41CFBA6F59C3  B13AF3130D5D346F9FDC41CFBA6F59C3    0
# 82685  171D2223CD0DA225A4909941C5AD1237  171D2223CD0DA225A4909941C5AD1237    0
# 82693  FD4ADE88144DB19D068CF743C10AC12D  FD4ADE88144DB19D068CF743C10AC12D    0
# 82699  A6E09426813038187B0C1D7DFAD9B939  A6E09426813038187B0C1D7DFAD9B939    0
# 82709  0607189D988D3012217E17AC6786D9ED  0607189D988D3012217E17AC6786D9ED    0
#
# ...

# %% [markdown]
# # 集团公司hotfix

# %%
group_hotfix=pd.read_csv('集团公司hotfix.csv')
group_hotfix
# Out:
#                             company_id    score_v2 rating_v2
# 0     A2201A1DA8B596D19005CF1E947C870A  677.247938        AA
# 1     A2201A1DA8B596D19005CF1E947C870A  677.247938        AA
# 2     05ACB2C40DDD1B6D7230B5E2ACFD73B5  501.400197         B
# 3     190D8F2DE3C41453B87C44A9C46F64EB  427.924790       CCC
# 4     27ACFF84AE56CFF91E836F8CA22D01EE  669.834401         A
# ...                                ...         ...       ...
# 7375  B8659636779C17C6404DE42657735D87  622.498218       BBB
# 7376  BDAEEE04D9E943A893ED2C7716985364  555.382584        BB
# 7377  C2E7E2E3DB9F024A0798989361CB4E9B  717.565853        AA
# 7378  D62C054C409F9A56ACD46FD0CD808DED  342.523638        CC
# 7379  DEFAF1CFF9E35B3F557A0CF4CFB7D075  550.692792        BB
#
# [7380 rows x 3 columns]

# %% [markdown]
# ## 对比

# %%
Compare=pd.merge(group_hotfix,pingan_group[['company_id','rating_v2','score_v2']],on='company_id',suffixes=['_hot','_sin'])
Compare
# Out:
#                             company_id  score_v2_hot rating_v2_hot  \
# 0     A2201A1DA8B596D19005CF1E947C870A    677.247938            AA
# 1     A2201A1DA8B596D19005CF1E947C870A    677.247938            AA
# 2     A2201A1DA8B596D19005CF1E947C870A    677.247938            AA
# 3     05ACB2C40DDD1B6D7230B5E2ACFD73B5    501.400197             B
# 4     190D8F2DE3C41453B87C44A9C46F64EB    427.924790           CCC
# ...                                ...           ...           ...
# 7375  B8659636779C17C6404DE42657735D87    622.498218           BBB
# 7376  BDAEEE04D9E943A893ED2C7716985364    555.382584            BB
# 7377  C2E7E2E3DB9F024A0798989361CB4E9B    717.565853            AA
# 7378  D62C054C409F9A56ACD46FD0CD808DED    342.523638            CC
# 7379  DEFAF1CFF9E35B3F557A0CF4CFB7D075    550.692792            BB
#
#      rating_v2_sin  score_v2_sin
# 0               AA    677.247938
# 1               AA    677.247938
# 2               AA    677.247938
# ...

# %%
import numpy as np

# %%
Compare['rating_change']=np.where(Compare['rating_v2_hot']==Compare['rating_v2_sin'],1,0)
Compare['score_v2_change']=np.where(Compare['score_v2_hot']==Compare['score_v2_sin'],1,0)
Compare
# Out:
#                             company_id  score_v2_hot rating_v2_hot  \
# 0     A2201A1DA8B596D19005CF1E947C870A    677.247938            AA
# 1     A2201A1DA8B596D19005CF1E947C870A    677.247938            AA
# 2     A2201A1DA8B596D19005CF1E947C870A    677.247938            AA
# 3     05ACB2C40DDD1B6D7230B5E2ACFD73B5    501.400197             B
# 4     190D8F2DE3C41453B87C44A9C46F64EB    427.924790           CCC
# ...                                ...           ...           ...
# 7375  B8659636779C17C6404DE42657735D87    622.498218           BBB
# 7376  BDAEEE04D9E943A893ED2C7716985364    555.382584            BB
# 7377  C2E7E2E3DB9F024A0798989361CB4E9B    717.565853            AA
# 7378  D62C054C409F9A56ACD46FD0CD808DED    342.523638            CC
# 7379  DEFAF1CFF9E35B3F557A0CF4CFB7D075    550.692792            BB
#
#      rating_v2_sin  score_v2_sin  rating_change  score_v2_change
# 0               AA    677.247938              1                1
# ...

# %%
Compare['score_v2_change'].value_counts()
# Out:
# 1    5537
# 0    1843
# Name: score_v2_change, dtype: int64

# %%
Compare.query('rating_change==0')
# Out:
#                             company_id  score_v2_hot rating_v2_hot  \
# 197   83A59413EE3C9541B37DECF11864D1B5    439.526627             B
# 573   1120ACD7E0D19376EA9DCE2BB8EA6738    451.234292             B
# 614   3E182640BBA9FA98685B7F762572E54A    596.564909           BBB
# 758   11FADB62C3B83C9D5080E7D0CF1AC30F    322.500400            CC
# 807   0749A83A5B618B7DF5149981A51A6F41    580.132703           BBB
# 813   2B7CF45E51816C6026E52E7CC82F72A4    350.968224           CCC
# 866   E08585EAD022E071C722AC39AAF6A89A    568.382766           BBB
# 977   5F95FA29683E5F9E9F0860B4CEF8C030    444.535186             B
# 1019  9FE85DD26D6621BABDACE68E385A3DA6    441.647306             B
# 1045  C9B27064C5C477D2A8C8AF7848014831    440.042704             B
# 1048  07D79C275D885B46AF02BDF4A5354695    634.064029             A
# 1074  75A30038B81B7491F8338CAB694333FD    510.376939            BB
# 1088  33D01F4FA021574756E93AA1CD7D3A13    677.124409            AA
# ...

# %% [markdown]
# # 细节指标对比

# %%
compare_original_group=pd.merge(group_ans_id_1_pro,test_group_original,left_on='group_id',right_on='company_id')
compare_original_group
# Out:
#                               group_id                        group_id.1  num  \
# 0     67BE7F61CA8ACC205573DB3C120351BF  67BE7F61CA8ACC205573DB3C120351BF    0
# 1     F89D78E9ADA02789CADD0348D8175CB3  F89D78E9ADA02789CADD0348D8175CB3    0
# 2     C3493BB3F08439B4F4C5673CE2D547D4  C3493BB3F08439B4F4C5673CE2D547D4    0
# 3     716F6A4EA9EE0DFC289B24E76419C0D1  716F6A4EA9EE0DFC289B24E76419C0D1    0
# 4     200B9620F17DFF4A0374AA57417DE7A7  200B9620F17DFF4A0374AA57417DE7A7    0
# ...                                ...                               ...  ...
# 3679  2D5A34A22B1631C1ECFBF0EE6B720936  2D5A34A22B1631C1ECFBF0EE6B720936    0
# 3680  ED6D0F4114BF1FCD0436FF9D0E33C35B  ED6D0F4114BF1FCD0436FF9D0E33C35B    0
# 3681  2D20BC482CE0C74ED9442718D51EF525  2D20BC482CE0C74ED9442718D51EF525    0
# 3682  3FA42448BA3551A5A2111D449DDA9301  3FA42448BA3551A5A2111D449DDA9301    0
# 3683  171D2223CD0DA225A4909941C5AD1237  171D2223CD0DA225A4909941C5AD1237    0
#
# ...

# %%
compare_original=pd.merge(compare_original_group,test_quanguo_original,left_on='group_id',right_on='company_id',suffixes=['_gr','_si'])
compare_original
# Out:
#                               group_id                        group_id.1  num  \
# 0     67BE7F61CA8ACC205573DB3C120351BF  67BE7F61CA8ACC205573DB3C120351BF    0
# 1     F89D78E9ADA02789CADD0348D8175CB3  F89D78E9ADA02789CADD0348D8175CB3    0
# 2     C3493BB3F08439B4F4C5673CE2D547D4  C3493BB3F08439B4F4C5673CE2D547D4    0
# 3     716F6A4EA9EE0DFC289B24E76419C0D1  716F6A4EA9EE0DFC289B24E76419C0D1    0
# 4     200B9620F17DFF4A0374AA57417DE7A7  200B9620F17DFF4A0374AA57417DE7A7    0
# ...                                ...                               ...  ...
# 3735  2D5A34A22B1631C1ECFBF0EE6B720936  2D5A34A22B1631C1ECFBF0EE6B720936    0
# 3736  ED6D0F4114BF1FCD0436FF9D0E33C35B  ED6D0F4114BF1FCD0436FF9D0E33C35B    0
# 3737  2D20BC482CE0C74ED9442718D51EF525  2D20BC482CE0C74ED9442718D51EF525    0
# 3738  3FA42448BA3551A5A2111D449DDA9301  3FA42448BA3551A5A2111D449DDA9301    0
# 3739  171D2223CD0DA225A4909941C5AD1237  171D2223CD0DA225A4909941C5AD1237    0
#
# ...

# %%
a=compare_original[['company_id','apno_cnt_gr','apno_cnt_si']]

# %%
a.query('apno_cnt_gr>apno_cnt_si')
# Out:
#                             company_id  apno_cnt_gr  apno_cnt_si
# 42    DB76A0054EDF20E2DF4AA8B9C5BBF584           55           30
# 53    658329E9D9C8E3F82C15C887F51C5A0E          229          124
# 54    658329E9D9C8E3F82C15C887F51C5A0E          229          124
# 55    658329E9D9C8E3F82C15C887F51C5A0E          229          124
# 56    658329E9D9C8E3F82C15C887F51C5A0E          229          124
# ...                                ...          ...          ...
# 3360  EF3F81812C4CCFFAE02C2DD989A9713B          214          120
# 3383  7A798C398F28757B87B84403620667B8           13            0
# 3682  714D513F4AC2262FE4A8BA03D22B4432           41           26
# 3729  DDB5B9C26E2357285981C70DDBC37F4E           13            4
# 3739  171D2223CD0DA225A4909941C5AD1237            2            0
#
# [196 rows x 3 columns]

# %%
test_group_original.columns
# Out:
# Index(['company_id', 'province', 'city', 'seic_lv1', 'seic_lv2', 'status',
#        'company_name', 'ans_id', 'apno_cnt', 'non_design_apno_cnt',
#        'joint_application_cnt', 'joint_applicant_cnt', 'reg_num',
#        'num_trademarks_total', 'num_trademarks_registered', 'num_members',
#        'total_patent_award_score', 'granted_invention_cnt',
#        'core_patents_cited_by_cnt', 'external_licensing_cnt', 'country_cnt',
#        'pct_apno_cnt', 'num_certificates', 'rounds', 'apno_cnt_valid_5y',
#        'non_design_pct_apno_cnt', 'granted_invention_cnt_pb_1y',
#        'granted_invention_cnt_pb_original_2y', 'num_trademarks_total_5y',
#        'num_trademarks_registered_5y', 'reg_num_5y', 'num_certificates_valid',
#        'patenting_growth_ratio', 'active_inventor_ratio',
#        'invention_stability', 'self_cited_by_ratio', 'avg_3y_cnt',
#        'reg_3y_avg', 'reg_growth_ratio', 'avg_technology_score',
# ...

# %%
compare_original.fillna(0,inplace=True)

# %% [markdown]
# ## apno_cnt

# %%
compare_original['apno_cnt_gap']=np.sign(compare_original.apno_cnt_gr-compare_original.apno_cnt_si).astype(int)
compare_original['apno_cnt_gap'].value_counts()
# Out:
#  0    3539
#  1     196
# -1       5
# Name: apno_cnt_gap, dtype: int64

# %%
compare_original.query('apno_cnt_gap==-1')[['company_id','apno_cnt_gr','apno_cnt_si']]
# Out:
#                             company_id  apno_cnt_gr  apno_cnt_si
# 1425  137DFDC4596E17C9C7E40F6F78B65D8E            7           19
# 2057  23F90BB00E662C14B3934D611F4323D8          102          103
# 2122  46E25C602B182BD56C1269946748209C          206          224
# 2736  25B1DFD1F20589A7806DC3831E4E05A9            0            4
# 2875  52852ECD29B8F811819B5F6F15F1D520           41           44

# %%
compare_original['apno_cnt_gap'].value_counts()
# Out:
# 0    4758
# Name: apno_cnt_gap, dtype: int64

# %% [markdown]
# ## non_design_apno_cnt

# %%
compare_original['non_design_apno_cnt_gap']=np.sign(compare_original.non_design_apno_cnt_gr-compare_original.non_design_apno_cnt_si).astype(int)
compare_original['non_design_apno_cnt_gap'].value_counts()
# Out:
#  0    3541
#  1     194
# -1       5
# Name: non_design_apno_cnt_gap, dtype: int64

# %% [markdown]
# ## joint_application_cnt

# %%
compare_original['joint_application_cnt_gap']=np.sign(compare_original.joint_application_cnt_gr-compare_original.joint_application_cnt_si).astype(int)
compare_original['joint_application_cnt_gap'].value_counts()
# Out:
# 1    2704
# 0    1036
# Name: joint_application_cnt_gap, dtype: int64

# %% [markdown]
# ## joint_applicant_cnt

# %%
compare_original['joint_applicant_cnt_gap']=np.sign(compare_original.joint_applicant_cnt_gr-compare_original.joint_applicant_cnt_si).astype(int)
compare_original['joint_applicant_cnt_gap'].value_counts()
# Out:
# 0    3222
# 1     518
# Name: joint_applicant_cnt_gap, dtype: int64

# %% [markdown]
# ## total_patent_award_score

# %%
compare_original['total_patent_award_score_gap']=np.sign(compare_original.total_patent_award_score_gr-compare_original.total_patent_award_score_si).astype(int)
compare_original['total_patent_award_score_gap'].value_counts()
# Out:
# 0    3740
# Name: total_patent_award_score_gap, dtype: int64

# %% [markdown]
# ## granted_invention_cnt

# %%
compare_original['granted_invention_cnt_gap']=np.sign(compare_original.granted_invention_cnt_gr-compare_original.granted_invention_cnt_si).astype(int)
compare_original['granted_invention_cnt_gap'].value_counts()
# Out:
#  0    3663
#  1      75
# -1       2
# Name: granted_invention_cnt_gap, dtype: int64

# %% [markdown]
# ## core_patents_cited_by_cnt

# %%
compare_original['core_patents_cited_by_cnt_gap']=np.sign(compare_original.core_patents_cited_by_cnt_gr-compare_original.core_patents_cited_by_cnt_si).astype(int)
compare_original['core_patents_cited_by_cnt_gap'].value_counts()
# Out:
#  0    3689
#  1      40
# -1      11
# Name: core_patents_cited_by_cnt_gap, dtype: int64

# %% [markdown]
# ## external_licensing_cnt

# %%
compare_original['external_licensing_cnt_gap']=np.sign(compare_original.external_licensing_cnt_gr-compare_original.external_licensing_cnt_si).astype(int)
compare_original['external_licensing_cnt_gap'].value_counts()
# Out:
# 0    3739
# 1       1
# Name: external_licensing_cnt_gap, dtype: int64

# %% [markdown]
# ## pct_apno_cnt

# %%
compare_original['pct_apno_cnt_gap']=np.sign(compare_original.pct_apno_cnt_gr-compare_original.pct_apno_cnt_si).astype(int)
compare_original['pct_apno_cnt_gap'].value_counts()
# Out:
# 0    3687
# 1      53
# Name: pct_apno_cnt_gap, dtype: int64

# %% [markdown]
# ## apno_cnt_valid_5y

# %%
compare_original['apno_cnt_valid_5y_gap']=np.sign(compare_original.apno_cnt_valid_5y_gr-compare_original.apno_cnt_valid_5y_si).astype(int)
compare_original['apno_cnt_valid_5y_gap'].value_counts()
# Out:
#  0    3563
#  1     173
# -1       4
# Name: apno_cnt_valid_5y_gap, dtype: int64

# %% [markdown]
# ## non_design_pct_apno_cnt

# %%
compare_original['non_design_pct_apno_cnt_gap']=np.sign(compare_original.non_design_pct_apno_cnt_gr-compare_original.non_design_pct_apno_cnt_si).astype(int)
compare_original['non_design_pct_apno_cnt_gap'].value_counts()
# Out:
# 0    3687
# 1      53
# Name: non_design_pct_apno_cnt_gap, dtype: int64

# %% [markdown]
# ## granted_invention_cnt_pb_1y

# %%
compare_original['granted_invention_cnt_pb_1y_gap']=np.sign(compare_original.granted_invention_cnt_pb_1y_gr-compare_original.granted_invention_cnt_pb_1y_si).astype(int)
compare_original['granted_invention_cnt_pb_1y_gap'].value_counts()
# Out:
#  0    3722
#  1      16
# -1       2
# Name: granted_invention_cnt_pb_1y_gap, dtype: int64

# %% [markdown]
# ## granted_invention_cnt_pb_original_2y

# %%
compare_original['granted_invention_cnt_pb_original_2y_gap']=np.sign(compare_original.granted_invention_cnt_pb_1y_gr-compare_original.granted_invention_cnt_pb_1y_si).astype(int)
compare_original['granted_invention_cnt_pb_original_2y_gap'].value_counts()
# Out:
#  0    3722
#  1      16
# -1       2
# Name: granted_invention_cnt_pb_original_2y_gap, dtype: int64

# %% [markdown]
# ## patenting_growth_ratio

# %%
compare_original[['company_id','patenting_growth_ratio_gr','patenting_growth_ratio_si']]
# Out:
#                             company_id  patenting_growth_ratio_gr  \
# 0     67BE7F61CA8ACC205573DB3C120351BF                   1.309401
# 1     F89D78E9ADA02789CADD0348D8175CB3                  -0.147197
# 2     C3493BB3F08439B4F4C5673CE2D547D4                 999.000000
# 3     716F6A4EA9EE0DFC289B24E76419C0D1                   0.732051
# 4     200B9620F17DFF4A0374AA57417DE7A7                   0.247219
# ...                                ...                        ...
# 3735  2D5A34A22B1631C1ECFBF0EE6B720936                 998.000000
# 3736  ED6D0F4114BF1FCD0436FF9D0E33C35B                  -0.225403
# 3737  2D20BC482CE0C74ED9442718D51EF525                   0.172604
# 3738  3FA42448BA3551A5A2111D449DDA9301                 998.000000
# 3739  171D2223CD0DA225A4909941C5AD1237                 999.000000
#
#       patenting_growth_ratio_si
# 0                      1.309401
# 1                     -0.147197
# 2                    999.000000
# 3                      0.732051
# ...

# %%
compare_original['patenting_growth_ratio_gap']=np.sign(compare_original.patenting_growth_ratio_gr-compare_original.patenting_growth_ratio_si).astype(int)
compare_original['patenting_growth_ratio_gap'].value_counts()
# Out:
#  0    3594
# -1      76
#  1      70
# Name: patenting_growth_ratio_gap, dtype: int64

# %% [markdown]
# ##  active_inventor_ratio

# %%
compare_original['active_inventor_ratio_gap']=np.sign(compare_original.active_inventor_ratio_gr-compare_original.active_inventor_ratio_si).astype(int)
compare_original['active_inventor_ratio_gap'].value_counts()
# Out:
# 0    3714
# 1      26
# Name: active_inventor_ratio_gap, dtype: int64

# %% [markdown]
# ## invention_stability

# %%
compare_original['invention_stability_gap']=np.sign(compare_original.invention_stability_gr-compare_original.invention_stability_si).astype(int)
compare_original['invention_stability_gap'].value_counts()
# Out:
#  0    3231
#  1     282
# -1     227
# Name: invention_stability_gap, dtype: int64

# %% [markdown]
# ## self_cited_by_ratio

# %%
compare_original['self_cited_by_ratio_gap']=np.sign(compare_original.self_cited_by_ratio_gr-compare_original.self_cited_by_ratio_si).astype(int)
compare_original['self_cited_by_ratio_gap'].value_counts()
# Out:
#  0    3621
#  1     101
# -1      18
# Name: self_cited_by_ratio_gap, dtype: int64

# %% [markdown]
# ## avg_3y_cnt

# %%
compare_original['avg_3y_cnt_gap']=np.sign(compare_original.avg_3y_cnt_gr-compare_original.avg_3y_cnt_si).astype(int)
compare_original['avg_3y_cnt_gap'].value_counts()
# Out:
#  0    3637
#  1      99
# -1       4
# Name: avg_3y_cnt_gap, dtype: int64

# %% [markdown]
# ## avg_technology_score

# %%
compare_original['avg_technology_score_gap']=np.sign(compare_original.avg_technology_score_gr-compare_original.avg_technology_score_si).astype(int)
compare_original['avg_technology_score_gap'].value_counts()
# Out:
#  0    2802
# -1     474
#  1     464
# Name: avg_technology_score_gap, dtype: int64

# %% [markdown]
# ## ip_dependency

# %%
compare_original['ip_dependency_gap']=np.sign(compare_original.ip_dependency_gr-compare_original.ip_dependency_si).astype(int)
compare_original['ip_dependency_gap'].value_counts()
# Out:
# 0    3738
# 1       2
# Name: ip_dependency_gap, dtype: int64

# %% [markdown]
# ## granted_invention_ratio

# %%
compare_original['granted_invention_ratio_gap']=np.sign(compare_original.granted_invention_ratio_gr-compare_original.granted_invention_ratio_si).astype(int)
compare_original['granted_invention_ratio_gap'].value_counts()
# Out:
#  0    3602
# -1     118
#  1      20
# Name: granted_invention_ratio_gap, dtype: int64

# %% [markdown]
# ## invention_ratio

# %%
compare_original['invention_ratio_gap']=np.sign(compare_original.invention_ratio_gr-compare_original.invention_ratio_si).astype(int)
compare_original['invention_ratio_gap'].value_counts()
# Out:
#  0    3571
#  1     121
# -1      48
# Name: invention_ratio_gap, dtype: int64

# %% [markdown]
# ## value_sum

# %%
compare_original['value_sum_gap']=np.sign(compare_original.value_sum_gr-compare_original.value_sum_si).astype(int)
compare_original['value_sum_gap'].value_counts()
# Out:
#  0    3567
#  1     172
# -1       1
# Name: value_sum_gap, dtype: int64

# %% [markdown]
# ## value_avg

# %%
compare_original['value_avg_gap']=np.sign(compare_original.value_avg_gr-compare_original.value_avg_si).astype(int)
compare_original['value_avg_gap'].value_counts()
# Out:
#  0    3567
# -1     104
#  1      69
# Name: value_avg_gap, dtype: int64

# %% [markdown]
# ## value_top5_avg

# %%
compare_original['value_top5_avg_gap']=np.sign(compare_original.value_top5_avg_gr-compare_original.value_top5_avg_si).astype(int)
compare_original['value_top5_avg_gap'].value_counts()
# Out:
#  0    3662
#  1      76
# -1       2
# Name: value_top5_avg_gap, dtype: int64

# %% [markdown]
# ## value_top10_avg

# %%
compare_original['value_top10_avg_gap']=np.sign(compare_original.value_top10_avg_gr-compare_original.value_top10_avg_si).astype(int)
compare_original['value_top10_avg_gap'].value_counts()
# Out:
#  0    3636
#  1      85
# -1      19
# Name: value_top10_avg_gap, dtype: int64

# %% [markdown]
# ## in_examing_ratio

# %%
compare_original['in_examing_ratio_gap']=np.sign(compare_original.in_examing_ratio_gr-compare_original.in_examing_ratio_si).astype(int)
compare_original['in_examing_ratio_gap'].value_counts()
# Out:
#  0    3565
#  1     145
# -1      30
# Name: in_examing_ratio_gap, dtype: int64

# %% [markdown]
# ## avg_remaining_life_span

# %%
compare_original['avg_remaining_life_span_gap']=np.sign(compare_original.avg_remaining_life_span_gr-compare_original.avg_remaining_life_span_si).astype(int)
compare_original['avg_remaining_life_span_gap'].value_counts()
# Out:
#  0    1390
# -1    1203
#  1    1147
# Name: avg_remaining_life_span_gap, dtype: int64

# %%
compare_original[['company_id','avg_remaining_life_span_gr','avg_remaining_life_span_si']]
# Out:
#                             company_id  avg_remaining_life_span_gr  \
# 0     67BE7F61CA8ACC205573DB3C120351BF                    7.111376
# 1     F89D78E9ADA02789CADD0348D8175CB3                    9.215306
# 2     C3493BB3F08439B4F4C5673CE2D547D4                   18.089096
# 3     716F6A4EA9EE0DFC289B24E76419C0D1                   10.851272
# 4     200B9620F17DFF4A0374AA57417DE7A7                    9.712055
# ...                                ...                         ...
# 3735  2D5A34A22B1631C1ECFBF0EE6B720936                    8.183733
# 3736  ED6D0F4114BF1FCD0436FF9D0E33C35B                    7.452377
# 3737  2D20BC482CE0C74ED9442718D51EF525                   11.203321
# 3738  3FA42448BA3551A5A2111D449DDA9301                   11.000913
# 3739  171D2223CD0DA225A4909941C5AD1237                    0.000000
#
#       avg_remaining_life_span_si
# 0                       7.111376
# 1                       9.215306
# 2                      18.089096
# ...

# %% [markdown]
# ## avg_cited_by_cnt

# %%
compare_original['avg_cited_by_cnt_gap']=np.sign(compare_original.avg_cited_by_cnt_gr-compare_original.avg_cited_by_cnt_si).astype(int)
compare_original['avg_cited_by_cnt_gap'].value_counts()
# Out:
#  0    3598
# -1      82
#  1      60
# Name: avg_cited_by_cnt_gap, dtype: int64

# %% [markdown]
# ## core_patents_cited_by_ratio

# %%
compare_original['core_patents_cited_by_ratio_gap']=np.sign(compare_original.core_patents_cited_by_ratio_gr-compare_original.core_patents_cited_by_ratio_si).astype(int)
compare_original['core_patents_cited_by_ratio_gap'].value_counts()
# Out:
#  0    3689
# -1      26
#  1      25
# Name: core_patents_cited_by_ratio_gap, dtype: int64

# %% [markdown]
# ## most_cited_patents_value

# %%
compare_original['most_cited_patents_value_gap']=np.sign(compare_original.most_cited_patents_value_gr-compare_original.most_cited_patents_value_si).astype(int)
compare_original['most_cited_patents_value_gap'].value_counts()
# Out:
#  0    3680
#  1      54
# -1       6
# Name: most_cited_patents_value_gap, dtype: int64

# %% [markdown]
# ## top5_current_impact_index

# %%
compare_original['top5_current_impact_index_gap']=np.sign(compare_original.top5_current_impact_index_gr-compare_original.top5_current_impact_index_si).astype(int)
compare_original['top5_current_impact_index_gap'].value_counts()
# Out:
#  0    3437
#  1     197
# -1     106
# Name: top5_current_impact_index_gap, dtype: int64

# %% [markdown]
# ## tech_global_concentration

# %%
compare_original['tech_global_concentration_gap']=np.sign(compare_original.tech_global_concentration_gr-compare_original.tech_global_concentration_si).astype(int)
compare_original['tech_global_concentration_gap'].value_counts()
# Out:
#  0    2300
#  1     783
# -1     657
# Name: tech_global_concentration_gap, dtype: int64

# %% [markdown]
# ## tech_width

# %%
compare_original['tech_width_gap']=np.sign(compare_original.tech_global_concentration_gr-compare_original.tech_global_concentration_si).astype(int)
compare_original['tech_width_gap'].value_counts()
# Out:
#  0    2300
#  1     783
# -1     657
# Name: tech_width_gap, dtype: int64

# %% [markdown]
# ## patent_valid_ratio

# %%
compare_original['patent_valid_ratio_gap']=np.sign(compare_original.patent_valid_ratio_gr-compare_original.patent_valid_ratio_si).astype(int)
compare_original['patent_valid_ratio_gap'].value_counts()
# Out:
#  0    3562
# -1     110
#  1      68
# Name: patent_valid_ratio_gap, dtype: int64

# %% [markdown]
# ## inventor_cnt

# %%
compare_original['inventor_cnt_gap']=np.sign(compare_original.inventor_cnt_gr-compare_original.inventor_cnt_si).astype(int)
compare_original['inventor_cnt_gap'].value_counts()
# Out:
#  0    3602
#  1     134
# -1       4
# Name: inventor_cnt_gap, dtype: int64
