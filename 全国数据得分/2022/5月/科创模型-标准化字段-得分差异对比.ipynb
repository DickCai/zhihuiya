# %%
import pandas as pd
import os
from sqlalchemy import create_engine
engine_retrain=create_engine('mysql+pymysql://company:company@192.168.16.244/company_retrain',echo=False)
os.chdir(r'/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/5月/标准字段')

# %% [markdown]
# # 单个公司

# %% [markdown]
# ## looping_test_feature_switch_20220518_detailscore

# %%
looping_test_feature_switch_20220518_detailscore=pd.read_sql('select * from looping_test_feature_switch_20220518_detailscore',con=engine_retrain)

# %%
looping_test_feature_switch_20220518_detailscore.set_index('company_id',inplace=True)
looping_test_feature_switch_20220518_detailscore
# Out:
#                                       company_name   seic_lv1       seic_lv2  \
# company_id
# 0010D9F093B14CFFB85B71FAAF5E6253   深圳市铭盛鑫自动化设备有限公司   高端装备制造产业       智能制造装备产业
# 002BCB84178B20A363C4D506B5314D55    上海杰停智能交通科技有限公司  新一代信息技术产业           人工智能
# 002DB02EB6386F7EA503CEC078D3ED7F     江苏欧米伽环保工程有限公司     节能环保产业         先进环保产业
# 004FF311E29DA904D77EF6B45CDD9C29    桥田智能设备（浙江）有限公司   高端装备制造产业       智能制造装备产业
# 0052406681EF0F5944350C65E9620FD4      浙江神农泵业股份有限公司   高端装备制造产业       智能制造装备产业
# ...                                            ...        ...            ...
# FFAB34674A8102C9D503B26D73E8D44F       浙江众焊联科技有限公司   高端装备制造产业       智能制造装备产业
# FFB2CCFAC37353C551D5377EEC23108F     滁州岳众汽车零部件有限公司         其它             其它
# FFB6D6F6BE7C5ED2550299D6094F9C71  浙江大升旅行用品科技股份有限公司         其它             其它
# FFC4CEC75FA040BC86DFABE24A94CB23      广州必望信息技术有限公司  新一代信息技术产业  新兴软件和新型信息技术服务
# FFE318C4EA741399699C17DE9C533DC7      厦门文杉信息科技有限公司  新一代信息技术产业  互联网与云计算、大数据服务
#
# ...

# %% [markdown]
# ## looping_test_20220518_detailscore

# %%
looping_test_20220518_detailscore=pd.read_sql('select * from looping_test_20220518_detailscore',con=engine_retrain)

# %%
looping_test_20220518_detailscore.set_index('company_id',inplace=True)

# %%
looping_test_20220518_detailscore
# Out:
#                                       company_name   seic_lv1       seic_lv2  \
# company_id
# 0010D9F093B14CFFB85B71FAAF5E6253   深圳市铭盛鑫自动化设备有限公司   高端装备制造产业       智能制造装备产业
# 002BCB84178B20A363C4D506B5314D55    上海杰停智能交通科技有限公司  新一代信息技术产业           人工智能
# 002DB02EB6386F7EA503CEC078D3ED7F     江苏欧米伽环保工程有限公司     节能环保产业         先进环保产业
# 004FF311E29DA904D77EF6B45CDD9C29    桥田智能设备（浙江）有限公司   高端装备制造产业       智能制造装备产业
# 0052406681EF0F5944350C65E9620FD4      浙江神农泵业股份有限公司   高端装备制造产业       智能制造装备产业
# ...                                            ...        ...            ...
# FFAB34674A8102C9D503B26D73E8D44F       浙江众焊联科技有限公司   高端装备制造产业       智能制造装备产业
# FFB2CCFAC37353C551D5377EEC23108F     滁州岳众汽车零部件有限公司         其它             其它
# FFB6D6F6BE7C5ED2550299D6094F9C71  浙江大升旅行用品科技股份有限公司         其它             其它
# FFC4CEC75FA040BC86DFABE24A94CB23      广州必望信息技术有限公司  新一代信息技术产业  新兴软件和新型信息技术服务
# FFE318C4EA741399699C17DE9C533DC7      厦门文杉信息科技有限公司  新一代信息技术产业  互联网与云计算、大数据服务
#
# ...

# %% [markdown]
# ## 分数变化比较大的公司

# %%
entity_diff=pd.read_excel(r'单个公司标准化字段/大于0.3的公司全部信息.xlsx')

# %%
entity_diff['gap']=abs(entity_diff['group_518']-entity_diff['group_feature_518'])
entity_diff.sort_values('gap',ascending=False)
# Out:
#                              company_id      company_name  group_518  \
# 2646   402B5D5C12081E7F945AC047A44CDC81      浙江昱辉阳光能源有限公司     36.030
# 9209   DC07C8D5C1600495C5E884AB56EF7FD2   南京理工速必得科技股份有限公司     13.932
# 9003   D6890B414AE67FA54D2E80D6CD4FE0CC  辽宁科泰生物基因制药股份有限公司     21.999
# 2600   3EF329D3589A500CA671CFD3535B8F06         付临门支付有限公司     18.681
# 6990   A71F6F5A7C1250C8BAC2E43F8CFE44C0  深圳市特灵通数码通讯发展有限公司     15.208
# ...                                 ...               ...        ...
# 10548  FD67F3A60CAE03BDFAB264C06508E9DD    北京中邮万维通信技术有限公司      3.601
# 6164   93376F03177A74F92AA73E491668A0E0    北京因特莱斯网络技术有限公司      3.288
# 8816   D1D80384662EED21726A9641C7D0E196      上海摩麦信息技术有限公司      1.325
# 7240   AD87B8936E6DA0A03BCED190C48752D7      北京银通智博科技有限公司      1.263
# 10068  F1D0AED07670B05A4251F2A9BCE7D98C        大连智能能源有限公司      0.063
#
#        group_feature_518  sub_rate     gap
# 2646              22.226     0.383  13.804
# 9209               2.127     0.847  11.805
# ...

# %% [markdown]
# # 集团公司

# %% [markdown]
# ## looping_group_feature_switch_20220518_score

# %%
looping_group_feature_switch_20220518_detailscore=pd.read_sql('select * from looping_group_feature_switch_20220518_detailscore',con=engine_retrain)
looping_group_feature_switch_20220518_detailscore
# Out:
#                                company_id      company_name   seic_lv1  \
# 0        0010D9F093B14CFFB85B71FAAF5E6253   深圳市铭盛鑫自动化设备有限公司   高端装备制造产业
# 1        002BCB84178B20A363C4D506B5314D55    上海杰停智能交通科技有限公司  新一代信息技术产业
# 2        002DB02EB6386F7EA503CEC078D3ED7F     江苏欧米伽环保工程有限公司     节能环保产业
# 3        004FF311E29DA904D77EF6B45CDD9C29    桥田智能设备（浙江）有限公司   高端装备制造产业
# 4        0052406681EF0F5944350C65E9620FD4      浙江神农泵业股份有限公司   高端装备制造产业
# ...                                   ...               ...        ...
# 1108555  FFAB34674A8102C9D503B26D73E8D44F       浙江众焊联科技有限公司   高端装备制造产业
# 1108556  FFB2CCFAC37353C551D5377EEC23108F     滁州岳众汽车零部件有限公司         其它
# 1108557  FFB6D6F6BE7C5ED2550299D6094F9C71  浙江大升旅行用品科技股份有限公司         其它
# 1108558  FFC4CEC75FA040BC86DFABE24A94CB23      广州必望信息技术有限公司  新一代信息技术产业
# 1108559  FFE318C4EA741399699C17DE9C533DC7      厦门文杉信息科技有限公司  新一代信息技术产业
#
#               seic_lv2  avg_cited_by_cnt  avg_remaining_life_span  \
# ...

# %%
looping_group_feature_switch_20220518_detailscore.set_index('company_id',inplace=True)
looping_group_feature_switch_20220518_detailscore
# Out:
#                                       company_name   seic_lv1       seic_lv2  \
# company_id
# 0010D9F093B14CFFB85B71FAAF5E6253   深圳市铭盛鑫自动化设备有限公司   高端装备制造产业       智能制造装备产业
# 002BCB84178B20A363C4D506B5314D55    上海杰停智能交通科技有限公司  新一代信息技术产业           人工智能
# 002DB02EB6386F7EA503CEC078D3ED7F     江苏欧米伽环保工程有限公司     节能环保产业         先进环保产业
# 004FF311E29DA904D77EF6B45CDD9C29    桥田智能设备（浙江）有限公司   高端装备制造产业       智能制造装备产业
# 0052406681EF0F5944350C65E9620FD4      浙江神农泵业股份有限公司   高端装备制造产业       智能制造装备产业
# ...                                            ...        ...            ...
# FFAB34674A8102C9D503B26D73E8D44F       浙江众焊联科技有限公司   高端装备制造产业       智能制造装备产业
# FFB2CCFAC37353C551D5377EEC23108F     滁州岳众汽车零部件有限公司         其它             其它
# FFB6D6F6BE7C5ED2550299D6094F9C71  浙江大升旅行用品科技股份有限公司         其它             其它
# FFC4CEC75FA040BC86DFABE24A94CB23      广州必望信息技术有限公司  新一代信息技术产业  新兴软件和新型信息技术服务
# FFE318C4EA741399699C17DE9C533DC7      厦门文杉信息科技有限公司  新一代信息技术产业  互联网与云计算、大数据服务
#
# ...

# %% [markdown]
# ## looping_group_20220518_score

# %%
looping_group_20220518_detailscore=pd.read_sql('select * from looping_group_20220518_detailscore',con=engine_retrain)
looping_group_20220518_detailscore
# Out:
#                                company_id      company_name   seic_lv1  \
# 0        0010D9F093B14CFFB85B71FAAF5E6253   深圳市铭盛鑫自动化设备有限公司   高端装备制造产业
# 1        002BCB84178B20A363C4D506B5314D55    上海杰停智能交通科技有限公司  新一代信息技术产业
# 2        002DB02EB6386F7EA503CEC078D3ED7F     江苏欧米伽环保工程有限公司     节能环保产业
# 3        004FF311E29DA904D77EF6B45CDD9C29    桥田智能设备（浙江）有限公司   高端装备制造产业
# 4        0052406681EF0F5944350C65E9620FD4      浙江神农泵业股份有限公司   高端装备制造产业
# ...                                   ...               ...        ...
# 1108555  FFAB34674A8102C9D503B26D73E8D44F       浙江众焊联科技有限公司   高端装备制造产业
# 1108556  FFB2CCFAC37353C551D5377EEC23108F     滁州岳众汽车零部件有限公司         其它
# 1108557  FFB6D6F6BE7C5ED2550299D6094F9C71  浙江大升旅行用品科技股份有限公司         其它
# 1108558  FFC4CEC75FA040BC86DFABE24A94CB23      广州必望信息技术有限公司  新一代信息技术产业
# 1108559  FFE318C4EA741399699C17DE9C533DC7      厦门文杉信息科技有限公司  新一代信息技术产业
#
#               seic_lv2  avg_cited_by_cnt  avg_remaining_life_span  \
# ...

# %%
looping_group_20220518_detailscore.set_index('company_id',inplace=True)

# %%
looping_group_20220518_detailscore
# Out:
#                                       company_name   seic_lv1       seic_lv2  \
# company_id
# 0010D9F093B14CFFB85B71FAAF5E6253   深圳市铭盛鑫自动化设备有限公司   高端装备制造产业       智能制造装备产业
# 002BCB84178B20A363C4D506B5314D55    上海杰停智能交通科技有限公司  新一代信息技术产业           人工智能
# 002DB02EB6386F7EA503CEC078D3ED7F     江苏欧米伽环保工程有限公司     节能环保产业         先进环保产业
# 004FF311E29DA904D77EF6B45CDD9C29    桥田智能设备（浙江）有限公司   高端装备制造产业       智能制造装备产业
# 0052406681EF0F5944350C65E9620FD4      浙江神农泵业股份有限公司   高端装备制造产业       智能制造装备产业
# ...                                            ...        ...            ...
# FFAB34674A8102C9D503B26D73E8D44F       浙江众焊联科技有限公司   高端装备制造产业       智能制造装备产业
# FFB2CCFAC37353C551D5377EEC23108F     滁州岳众汽车零部件有限公司         其它             其它
# FFB6D6F6BE7C5ED2550299D6094F9C71  浙江大升旅行用品科技股份有限公司         其它             其它
# FFC4CEC75FA040BC86DFABE24A94CB23      广州必望信息技术有限公司  新一代信息技术产业  新兴软件和新型信息技术服务
# FFE318C4EA741399699C17DE9C533DC7      厦门文杉信息科技有限公司  新一代信息技术产业  互联网与云计算、大数据服务
#
# ...

# %% [markdown]
# ## 分数变化较大的公司

# %% [markdown]
# # 对比

# %%
### 不同版本对比
def diff(cid,base,new):
    a=pd.concat([base.loc[cid],new.loc[cid]],axis=1)
    a.columns=['affter','front']
    for i in a.index:
        try:
            a.loc[i,'gap'] = float(a.loc[i,'affter'])-float(a.loc[i,'front'])
        except:
            a.loc[i,'gap'] = pd.NaT
    a.sort_values('gap',ascending=False,inplace=True)
    return a

# %% [markdown]
# ## 单个公司

# %%
diff('402B5D5C12081E7F945AC047A44CDC81',looping_test_20220518_detailscore,looping_test_feature_switch_20220518_detailscore)
# Out:
#                                                                     affter  \
# num_certificates                                                  8.804249
# qualification                                                          5.0
# in_examing_ratio                                                  0.039137
# num_members                                                            0.0
# reg_capital_formatted                                             0.203571
# rounds                                                                 0.0
# reg_growth_ratio                                                       0.0
# avg_3y_cnt                                                             0.0
# reg_3y_avg                                                             0.0
# invention_ratio                                                   0.070617
# granted_invention_ratio                                            0.05911
# ...

# %% [markdown]
# ## 集团公司

# %%
diff('0008A4A3FA07A40CF926E298606B403F',looping_group_20220518_detailscore,looping_group_feature_switch_20220518_detailscore)
# Out:
#                                              affter          front       gap
# num_certificates                           8.804249       3.050683  5.753567
# qualification                                   3.0            0.0       3.0
# in_examing_ratio                                0.0            0.0       0.0
# num_members                                     0.0            0.0       0.0
# reg_capital_formatted                      0.056579       0.056579       0.0
# rounds                                          0.0            0.0       0.0
# reg_growth_ratio                            0.31974        0.31974       0.0
# avg_3y_cnt                                      0.0            0.0       0.0
# reg_3y_avg                                 0.097156       0.097156       0.0
# invention_ratio                                 0.0            0.0       0.0
# granted_invention_ratio                         0.0            0.0       0.0
# ...
