# %%
import pandas as pd
import os
os.chdir(r'/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/5月/标准字段/单个公司标准化字段')
pd.set_option('max_colwidth',1000)
pd.set_option('max_columns',100)
pd.set_option('max_rows',100)

# %% [markdown]
# # 标准化前

# %% [markdown]
# ## looping_test_sse_company_nonpatent_indicators

# %%
looping_test_sse_company_nonpatent_indicators=pd.read_csv('looping_test_sse_company_nonpatent_indicators.csv')

# %%
looping_test_sse_company_nonpatent_indicators
# Out:
#                                company_id   duration  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7   6.726027
# 1        0014A83C9B038292B6E0DB202479DEB9   4.989041
# 2        001CE08C53F7BD9A821358DD21C50C88  19.591781
# 3        0067F4DD86BE9866BD8E617D2B88E821   7.257534
# 4        006A322857D17795374D7749C2C32538  10.139726
# ...                                   ...        ...
# 1110047  C7C049CDA7F42E6D89B2D5351D6B0412        NaN
# 1110048  C85082D305A61A9633616A87858E156B        NaN
# 1110049  E586B12C6FBDBE45B224378D90FE78A8        NaN
# 1110050  F74C48AD2E7CF455975FBF6C1BC9F29C        NaN
# 1110051  FD9510BB0B4C5092BFEB060E5B3AFD91        NaN
#
#          actual_capital_formatted  reg_capital_formatted  \
# 0                    0.000000e+00           3.000000e+06
# 1                    0.000000e+00           1.000000e+06
# 2                    3.633573e+09           3.633573e+09
# 3                    0.000000e+00           7.000000e+06
# ...

# %%
looping_test_sse_company_nonpatent_indicators.columns
# Out:
# Index(['company_id', 'duration', 'actual_capital_formatted',
#        'reg_capital_formatted', 'ans_id', 'company_name', 'public',
#        'qualify_certificate', 'seic_lv1', 'seic_lv2', 'province', 'city',
#        'status', 'rounds', 'money_q25_sum_weighted',
#        'most_recent_money_q25_formatted', 'most_recent_time',
#        'avg_funding_interval', 'reg_num', 'reg_num_5y', 'reg_growth_ratio',
#        'reg_3y_avg', 'num_trademarks_registered', 'num_trademarks_total',
#        'num_trademarks_registered_5y', 'num_trademarks_total_5y',
#        'num_certificates', 'num_certificates_valid', 'num_members'],
#       dtype='object')

# %% [markdown]
# ###  qualify_certificate

# %%
qualify_certificate=looping_test_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','qualify_certificate']]
qualify_certificate
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1110047  C7C049CDA7F42E6D89B2D5351D6B0412
# 1110048  C85082D305A61A9633616A87858E156B
# 1110049  E586B12C6FBDBE45B224378D90FE78A8
# 1110050  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1110051  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
qualify_certificate[qualify_certificate['qualify_certificate'].notnull()]
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 4        006A322857D17795374D7749C2C32538
# 5        0097CB3253FA5EBCE4BB882305ACB03A
# 9        00D6CAD68E52953C9922B3AB737CEDC0
# ...                                   ...
# 1109342  FF21C6D8BC758928BCC2A5B6F411318A
# 1109344  FF55E3264CFCD701C92203516FE1A7D3
# 1109348  FFB2CCFAC37353C551D5377EEC23108F
# 1109350  FFC4CEC75FA040BC86DFABE24A94CB23
# 1109351  FFE318C4EA741399699C17DE9C533DC7
#
#                                        ans_id      company_name  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22      绵阳数智生物科技有限公司
# 1                                         NaN      苏州载道网络科技有限公司
# 4        e9aa448c-09db-4d69-8176-3368e8812bf7     中山市钜泰硅胶科技有限公司
# 5        28242ee9-180e-4301-8601-5c42ed2f8f0c  马鞍山市德善金属成型科技有限公司
# 9                                         NaN      上海铱芯信息科技有限公司
# ...                                       ...               ...
# ...

# %%
qualify_certificate.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')
# Out:
#                               company_id  \
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA
#
#                                       ans_id company_name   seic_lv2  \
# 929734  f039e90a-679c-4c50-ab06-72d03d496c4f     华为技术有限公司  下一代信息网络产业
#
#        qualify_certificate
# 929734              高新技术企业

# %% [markdown]
# ### num_certificates

# %%
num_certificates_front=looping_test_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','num_certificates']]
num_certificates_front
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1110047  C7C049CDA7F42E6D89B2D5351D6B0412
# 1110048  C85082D305A61A9633616A87858E156B
# 1110049  E586B12C6FBDBE45B224378D90FE78A8
# 1110050  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1110051  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
num_certificates_front[num_certificates_front['num_certificates'].notnull()]
# Out:
#                                company_id  \
# 4        006A322857D17795374D7749C2C32538
# 5        0097CB3253FA5EBCE4BB882305ACB03A
# 7        00B7A232CC0D73DFE36EE4BD25E40E05
# 10       00E0C127D47E8F4944B61BD0B4B8BACF
# 12       00FF6CBBF0320CB4961643084A2C6B0D
# ...                                   ...
# 1110014  FC9B796F3C2BA403F199A7C36FB16F00
# 1110015  FCF0BF7A64903D4D14CD8F25164AC0B5
# 1110016  FD0A215D887A77460445CDE541AB4653
# 1110017  FDEED7B67675594F2E6EBDDB3397EFC2
# 1110018  FF15DFCACF2B6956E935CE8E0142FC6B
#
#                                        ans_id      company_name   seic_lv2  \
# 4        e9aa448c-09db-4d69-8176-3368e8812bf7     中山市钜泰硅胶科技有限公司  先进无机非金属材料
# 5        28242ee9-180e-4301-8601-5c42ed2f8f0c  马鞍山市德善金属成型科技有限公司   先进有色金属材料
# 7        b51be918-8175-4bfe-9b44-50647094dcae       福建美美饰股份有限公司         其它
# 10                                        NaN      昆山恺博传动系统有限公司   智能制造装备产业
# 12       2fa9614b-d4a8-46de-a856-3f1f43f0cdc4      苏州运恒精冲科技有限公司     先进钢铁材料
# ...

# %%
num_certificates_front.query('company_id=="FFE318C4EA741399699C17DE9C533DC7"')
# Out:
#                                company_id ans_id  company_name       seic_lv2  \
# 1109351  FFE318C4EA741399699C17DE9C533DC7    NaN  厦门文杉信息科技有限公司  互联网与云计算、大数据服务
#
#          num_certificates
# 1109351               6.0

# %% [markdown]
# ### public

# %%
looping_test_sse_company_nonpatent_indicators[looping_test_sse_company_nonpatent_indicators['public'].notnull()]
# Out:
#                                company_id   duration  \
# 204      12FDB87639C672562BC16014B5E37D45  24.789041
# 212      13A6F11185EE00CA9BDA55A78A81029C  21.526027
# 318      1AFAC5D791C1F547C8E955A768620FA0  21.046575
# 396      217821701C22450438C955B27908AE1B  14.109589
# 455      2794EFA83AACEEBDD8E9108349082384  16.482192
# ...                                   ...        ...
# 1109011  E058AD3082A483A2C6EEEAB08B9AF45B  11.194521
# 1109057  E49C50CBD520D17F2CA59CEEF2066758  15.501370
# 1109095  E800AD3A38A536C7915266BFCCE48AF2  15.183562
# 1109169  EE955F86069DC67F4F8C7695CB1734B4  20.663014
# 1109340  FEF7ECB78AE80ED75E3914E675A7421B  19.939726
#
#          actual_capital_formatted  reg_capital_formatted  \
# 204                    30030000.0           3.003000e+07
# 212                   120000000.0           1.862851e+09
# 318                    22110000.0           3.777600e+07
# 396                   257545400.0           2.575454e+08
# ...

# %% [markdown]
# # 标准化后

# %% [markdown]
# ## looping_test_feature_switch_sse_company_nonpatent_indicators

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators=pd.read_csv('looping_test_feature_switch_20220509_sse_company_nonpatent_indicators.csv')
looping_test_feature_switch_sse_company_nonpatent_indicators
# Out:
#                                company_id   duration  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7   6.734247
# 1        0014A83C9B038292B6E0DB202479DEB9   4.997260
# 2        001CE08C53F7BD9A821358DD21C50C88  19.600000
# 3        0067F4DD86BE9866BD8E617D2B88E821   7.265753
# 4        006A322857D17795374D7749C2C32538  10.147945
# ...                                   ...        ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412        NaN
# 1109775  C85082D305A61A9633616A87858E156B        NaN
# 1109776  E586B12C6FBDBE45B224378D90FE78A8        NaN
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C        NaN
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91        NaN
#
#          actual_capital_formatted  reg_capital_formatted qualify_certificate  \
# 0                    0.000000e+00           3.000000e+06             科技型中小企业
# 1                    0.000000e+00           1.000000e+06                 NaN
# 2                    3.633573e+09           3.633573e+09                 NaN
# ...

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators.columns
# Out:
# Index(['company_id', 'duration', 'actual_capital_formatted',
#        'reg_capital_formatted', 'qualify_certificate', 'ans_id',
#        'company_name', 'seic_lv1', 'seic_lv2', 'province', 'city', 'status',
#        'public', 'rounds', 'money_q25_sum_weighted',
#        'most_recent_money_q25_formatted', 'most_recent_time',
#        'avg_funding_interval', 'reg_num', 'reg_num_5y', 'reg_growth_ratio',
#        'reg_3y_avg', 'num_trademarks_registered', 'num_trademarks_total',
#        'num_trademarks_registered_5y', 'num_trademarks_total_5y',
#        'num_certificates', 'num_certificates_valid', 'num_members'],
#       dtype='object')

# %%
certificates=looping_test_feature_switch_sse_company_nonpatent_indicators[['company_id','company_name','num_certificates','num_certificates_valid']]
certificates
# Out:
#                                company_id    company_name  num_certificates  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7    绵阳数智生物科技有限公司               NaN
# 1        0014A83C9B038292B6E0DB202479DEB9    苏州载道网络科技有限公司               NaN
# 2        001CE08C53F7BD9A821358DD21C50C88        中航证券有限公司               NaN
# 3        0067F4DD86BE9866BD8E617D2B88E821  重庆纳川山隅重工设备有限公司               NaN
# 4        006A322857D17795374D7749C2C32538   中山市钜泰硅胶科技有限公司               2.0
# ...                                   ...             ...               ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412             NaN               NaN
# 1109775  C85082D305A61A9633616A87858E156B             NaN               NaN
# 1109776  E586B12C6FBDBE45B224378D90FE78A8             NaN               NaN
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C             NaN               NaN
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91             NaN               NaN
#
#          num_certificates_valid
# ...

# %%
certificates.fillna(0,inplace=True)
# Out:
# /Users/caicaiqijun/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
import numpy as np

# %%
certificates['change']=np.where(certificates['num_certificates']==certificates['num_certificates_valid'],1,0)
# Out:
# /Users/caicaiqijun/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
certificates['change'].value_counts()
# Out:
# 1    1014151
# 0      95628
# Name: change, dtype: int64

# %%
certificates['gap']=abs(certificates['num_certificates']-certificates['num_certificates_valid'])
certificates
# Out:
# /Users/caicaiqijun/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                company_id    company_name  num_certificates  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7    绵阳数智生物科技有限公司               0.0
# 1        0014A83C9B038292B6E0DB202479DEB9    苏州载道网络科技有限公司               0.0
# 2        001CE08C53F7BD9A821358DD21C50C88        中航证券有限公司               0.0
# 3        0067F4DD86BE9866BD8E617D2B88E821  重庆纳川山隅重工设备有限公司               0.0
# 4        006A322857D17795374D7749C2C32538   中山市钜泰硅胶科技有限公司               2.0
# ...                                   ...             ...               ...
# ...

# %%
certificates.query('num_certificates>10 and num_certificates_valid<1.5').head(100)
# Out:
#                               company_id         company_name  \
# 11419   F534051B1A92F28B269A9C2AF8D1C18D          深圳市李森科技有限公司
# 18368   609C31A0C937BFA7F9A0DF90245443C3        深圳市荣通盛凯科技有限公司
# 20357   12F04A367EEACCFD334BEDF49D32BD54      喜德瑞采暖设备（上海）有限公司
# 25807   FC24FEC90B109CC79AE85C2C766D3D47           苏州信伟电器有限公司
# 27177   73248993A1EE9D7A624D5BF46F436765         湖北万众体育产业有限公司
# 34168   EA33E02C392F6FC214C125ED39CF02E4      无锡市金超威新能源科技有限公司
# 37866   36D9EE3AC595DA4CD2A9C50B28064665       广东智高文化创意股份有限公司
# 40560   2A5E46A46FDCE1A56111667CC66B534D       中电科声光电科技股份有限公司
# 53763   CDB6B2DFC5702F407C40555238F74028           深圳建扬技术有限公司
# 54354   015FEAE70735DA91E0D78CF161DA1C2E      广东老万格洛尼热能科技有限公司
# 60691   371C04D258B695F9F94AB64048650001      东莞市戴盛电源技术股份有限公司
# 72301   5786D4F2267C791B71420509303A74A5     主力智业（深圳）电器实业有限公司
# 82701   033B8FFAEE71F7E634B34F6C1848020C        中山市臻隆婴童用品有限公司
# 86677   69926DC90D9706B4231311F5CBDB30A8        福建新福达汽车工业有限公司
# ...

# %%
certificates[certificates['change']==0]
# Out:
#                                company_id  num_certificates  \
# 7        00B7A232CC0D73DFE36EE4BD25E40E05               1.0
# 25       02BEC1E8A5673AC8BD10AD040C21FF7D               2.0
# 32       03017316E4173808B24E85282F9CF932               5.0
# 36       037C7D1CEAB3856D73C8298771AC1238               7.0
# 57       054A6E1F31C851AFE6DB5CB245D35DCC               1.0
# ...                                   ...               ...
# 1109310  FADE4835C3E89B9802C9C1B56D437B6B               1.0
# 1109320  FC6F647F6921ABFECAAB9A18CFDA5C81               5.0
# 1109335  FE6AF2DD6D039435DFF1E7522009DB2B               1.0
# 1109348  FFB2CCFAC37353C551D5377EEC23108F               3.0
# 1109351  FFE318C4EA741399699C17DE9C533DC7               6.0
#
#          num_certificates_valid  change
# 7                           0.0       0
# 25                          1.0       0
# 32                          4.0       0
# 36                          3.0       0
# ...

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"').T
# Out:
#                                                                929734
# company_id                           A70A3E493E6B6E9C3D1CDA03B6279CAA
# duration                                                    34.673973
# actual_capital_formatted                                40341131820.0
# reg_capital_formatted                                   40441131820.0
# qualify_certificate                      国家企业技术中心__高新技术企业__国家技术创新示范企业
# ans_id                           f039e90a-679c-4c50-ab06-72d03d496c4f
# company_name                                                 华为技术有限公司
# seic_lv1                                                    新一代信息技术产业
# seic_lv2                                                    下一代信息网络产业
# province                                                          广东省
# city                                                              深圳市
# status                                                         ACTIVE
# ...

# %% [markdown]
# ### qualify_certificate

# %% [markdown]
# 测试点：
# 1、测试含有有效资质公司的总量
# 2、抽取含有公司过期资质的公司，测试过期的资质是否去掉
# 3、抽取测试case，对比结果一致性

# %%
qualify_certificate=looping_test_feature_switch_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','qualify_certificate']]
qualify_certificate
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412
# 1109775  C85082D305A61A9633616A87858E156B
# 1109776  E586B12C6FBDBE45B224378D90FE78A8
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
qualify_certificate[qualify_certificate['qualify_certificate'].notnull()]
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 4        006A322857D17795374D7749C2C32538
# 5        0097CB3253FA5EBCE4BB882305ACB03A
# 9        00D6CAD68E52953C9922B3AB737CEDC0
# 11       00F44911E943CA0DDA7BFF228A25AE33
# ...                                   ...
# 1109337  FE7FD982CC0FD9DF821A78CB5F9DCF63
# 1109340  FEF7ECB78AE80ED75E3914E675A7421B
# 1109342  FF21C6D8BC758928BCC2A5B6F411318A
# 1109344  FF55E3264CFCD701C92203516FE1A7D3
# 1109348  FFB2CCFAC37353C551D5377EEC23108F
#
#                                        ans_id      company_name  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22      绵阳数智生物科技有限公司
# 4        e9aa448c-09db-4d69-8176-3368e8812bf7     中山市钜泰硅胶科技有限公司
# 5        28242ee9-180e-4301-8601-5c42ed2f8f0c  马鞍山市德善金属成型科技有限公司
# 9                                         NaN      上海铱芯信息科技有限公司
# 11       fdc46f1a-cb8e-46a3-ac65-1e0589c91285        南通启汇电子有限公司
# ...                                       ...               ...
# ...

# %%
qualify_certificate.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')
# Out:
#                               company_id  \
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA
#
#                                       ans_id company_name   seic_lv2  \
# 929734  f039e90a-679c-4c50-ab06-72d03d496c4f     华为技术有限公司  下一代信息网络产业
#
#                  qualify_certificate
# 929734  国家企业技术中心__高新技术企业__国家技术创新示范企业

# %% [markdown]
# ### num_certificates_valid

# %% [markdown]
# 测试点：
# 1、测试含有有效资质证书的公司数量是否等于certificate_status状态等于有效或其它，并且deadline大于当前时间
# 2、测试certificate_status或deadline为空的数据计算时是否统计
# 3、抽取测试case，对比结果一致性

# %%
num_certificates_valid=looping_test_feature_switch_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','num_certificates_valid']]
num_certificates_valid
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412
# 1109775  C85082D305A61A9633616A87858E156B
# 1109776  E586B12C6FBDBE45B224378D90FE78A8
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['company_id','num_certificates_valid']]
# Out:
#                               company_id  num_certificates_valid
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA                  2917.0

# %%
num_certificates_valid[num_certificates_valid['num_certificates_valid'].notnull()]
# Out:
#                                company_id  \
# 4        006A322857D17795374D7749C2C32538
# 5        0097CB3253FA5EBCE4BB882305ACB03A
# 10       00E0C127D47E8F4944B61BD0B4B8BACF
# 12       00FF6CBBF0320CB4961643084A2C6B0D
# 16       015189558512396A2936336B9CAC6E5F
# ...                                   ...
# 1109342  FF21C6D8BC758928BCC2A5B6F411318A
# 1109345  FF7321F5E1966F60F9918A635A0F704B
# 1109348  FFB2CCFAC37353C551D5377EEC23108F
# 1109349  FFB6D6F6BE7C5ED2550299D6094F9C71
# 1109351  FFE318C4EA741399699C17DE9C533DC7
#
#                                        ans_id      company_name  \
# 4        e9aa448c-09db-4d69-8176-3368e8812bf7     中山市钜泰硅胶科技有限公司
# 5        28242ee9-180e-4301-8601-5c42ed2f8f0c  马鞍山市德善金属成型科技有限公司
# 10                                        NaN      昆山恺博传动系统有限公司
# 12       2fa9614b-d4a8-46de-a856-3f1f43f0cdc4      苏州运恒精冲科技有限公司
# 16       13014be5-851f-44b0-af45-5e5e2e1f823f     宁夏启玉生物新材料有限公司
# ...                                       ...               ...
# ...

# %% [markdown]
# ### num_certificates

# %% [markdown]
# 测试点：
# 1、测试含有有效资质证书的公司数量是否等于deadline大于当前时间
# 2、测试deadline为空的数据计算时是否统计
# 3、抽取测试case，对比结果一致性

# %%
num_certificates=looping_test_feature_switch_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','num_certificates']]
num_certificates
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412
# 1109775  C85082D305A61A9633616A87858E156B
# 1109776  E586B12C6FBDBE45B224378D90FE78A8
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
num_certificates[num_certificates['num_certificates'].notnull()]
# Out:
#                                company_id  \
# 4        006A322857D17795374D7749C2C32538
# 5        0097CB3253FA5EBCE4BB882305ACB03A
# 7        00B7A232CC0D73DFE36EE4BD25E40E05
# 10       00E0C127D47E8F4944B61BD0B4B8BACF
# 12       00FF6CBBF0320CB4961643084A2C6B0D
# ...                                   ...
# 1109342  FF21C6D8BC758928BCC2A5B6F411318A
# 1109345  FF7321F5E1966F60F9918A635A0F704B
# 1109348  FFB2CCFAC37353C551D5377EEC23108F
# 1109349  FFB6D6F6BE7C5ED2550299D6094F9C71
# 1109351  FFE318C4EA741399699C17DE9C533DC7
#
#                                        ans_id      company_name  \
# 4        e9aa448c-09db-4d69-8176-3368e8812bf7     中山市钜泰硅胶科技有限公司
# 5        28242ee9-180e-4301-8601-5c42ed2f8f0c  马鞍山市德善金属成型科技有限公司
# 7        b51be918-8175-4bfe-9b44-50647094dcae       福建美美饰股份有限公司
# 10                                        NaN      昆山恺博传动系统有限公司
# 12       2fa9614b-d4a8-46de-a856-3f1f43f0cdc4      苏州运恒精冲科技有限公司
# ...                                       ...               ...
# ...

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['company_id','num_certificates']]
# Out:
#                               company_id  num_certificates
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA            3844.0

# %% [markdown]
# ### actual_capital_formatted

# %% [markdown]
# 测试点
# 1、测试实缴资本为空跟为为0的数量
# 2、测试实缴资本货币的汇率
# 3、抽取测试case，对比结果一致性

# %%
actual_capital_formatted=looping_test_feature_switch_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','actual_capital_formatted']]
actual_capital_formatted
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412
# 1109775  C85082D305A61A9633616A87858E156B
# 1109776  E586B12C6FBDBE45B224378D90FE78A8
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['company_id','actual_capital_formatted']]
# Out:
#                               company_id  actual_capital_formatted
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA              4.034113e+10

# %%
b=150*4.1
b
# Out:
# 615.0

# %%
a=233588+124007
a
# Out:
# 357595

# %%
actual_capital_formatted[actual_capital_formatted['actual_capital_formatted']==0]
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 6        00A0E0A68BC2DE2BE695BB9791660817
# 8        00D4305688D93C81A4A6FA44EB151109
# ...                                   ...
# 1109335  FE6AF2DD6D039435DFF1E7522009DB2B
# 1109338  FECBA9D073D2A46F4882E5A30611819E
# 1109343  FF336FAE061CB2E0DCAE348C52749A30
# 1109345  FF7321F5E1966F60F9918A635A0F704B
# 1109346  FF90F1F21D0998DB02A2D3BBB506BF0E
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# 6        cb462e57-72df-4e54-82d1-8e81bc1410e0    广东青梅宝宝食品有限公司             其它
# ...

# %% [markdown]
# ### reg_capital_formatted

# %% [markdown]
# 测试点
# 1、测试注册资本为空跟为为0的数量一致性
# 2、测试注册资本货币的汇率
# 3、抽取测试case，对比结果一致性

# %%
reg_capital_formatted=looping_test_feature_switch_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','reg_capital_formatted']]
reg_capital_formatted
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412
# 1109775  C85082D305A61A9633616A87858E156B
# 1109776  E586B12C6FBDBE45B224378D90FE78A8
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
reg_capital_formatted[reg_capital_formatted['reg_capital_formatted']==0]
# Out:
#                                company_id  \
# 103      095E356D4E8FDAE28120076C25C6DD52
# 118      0B03E7BE5379F357C0EAC401D205683E
# 409      22F33F64D4921C7A570E6ADAFFF3D5BF
# 597      34310B619AF4DB5C1EA1DC95FBD64BCF
# 674      3BAB127F44F75492D6B2CFD6AD03DCBA
# ...                                   ...
# 1108007  7F9135BA1E1DCD411C1BBCE7E7811E49
# 1108247  95E903E84C6E5C2369CAF26F503F859E
# 1108437  A84DC929AA989669F5B710A6031318DA
# 1108525  B18766A969DF9F726542B2B77992BCA0
# 1108856  D0DA636D93C5D3F0CEF07CE17D67E660
#
#                                        ans_id            company_name  \
# 103      62099312-76a8-4269-8789-87db8468b1b7              迪欧国际贸易有限公司
# 118      60e39c97-ae26-4b95-a59e-fee4a9b8fa63            广东富山玻璃机械有限公司
# 409      5d7deb9e-5152-4033-9a33-3236d2b7479a    中石化石油机械股份有限公司承德江钻分公司
# 597                                       NaN                     NaN
# 674      c78a6a2b-b9f6-4a22-8862-9bbb0694a258            孝昌县鑫新养殖设备加工厂
# ...

# %%
reg_capital_formatted.query('company_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')
# Out:
#                               company_id  \
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA
#
#                                       ans_id company_name   seic_lv2  \
# 929734  f039e90a-679c-4c50-ab06-72d03d496c4f     华为技术有限公司  下一代信息网络产业
#
#         reg_capital_formatted
# 929734           4.044113e+10

# %%
a=700*4.1
a
# Out:
# 2869.9999999999995

# %% [markdown]
# ### money_q25_sum_weighted

# %% [markdown]
# 测试点
# 1、测试汇率是否转成正确
# 2、抽取测试case，对比结果一致性

# %%
money_q25_sum_weighted=looping_test_feature_switch_sse_company_nonpatent_indicators[['company_id','ans_id','company_name',
                                                                  'seic_lv2','money_q25_sum_weighted']]
money_q25_sum_weighted
# Out:
#                                company_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412
# 1109775  C85082D305A61A9633616A87858E156B
# 1109776  E586B12C6FBDBE45B224378D90FE78A8
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id    company_name       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22    绵阳数智生物科技有限公司         生物医药产业
# 1                                         NaN    苏州载道网络科技有限公司  新兴软件和新型信息技术服务
# 2                                         NaN        中航证券有限公司         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143  重庆纳川山隅重工设备有限公司       智能制造装备产业
# ...

# %%
money_q25_sum_weighted[money_q25_sum_weighted['money_q25_sum_weighted'].notnull()]
# Out:
#                                company_id  \
# 2        001CE08C53F7BD9A821358DD21C50C88
# 10       00E0C127D47E8F4944B61BD0B4B8BACF
# 16       015189558512396A2936336B9CAC6E5F
# 19       019E09E267C05E835C2BB957AE3F358A
# 37       038127C2A8F2487E7B1FCA3330CDABA0
# ...                                   ...
# 1109285  F8C69B70A798D6E67DFC993F56511EFE
# 1109297  FA19A130B3CFC6ADEADA328A624EBCD9
# 1109333  FE25F12EE039DD1872DB7AED9253F8BE
# 1109338  FECBA9D073D2A46F4882E5A30611819E
# 1109339  FECE687245C1BF01EEB70650D7DAFDE7
#
#                                        ans_id         company_name  \
# 2                                         NaN             中航证券有限公司
# 10                                        NaN         昆山恺博传动系统有限公司
# 16       13014be5-851f-44b0-af45-5e5e2e1f823f        宁夏启玉生物新材料有限公司
# 19                                        NaN       成都银海启明医院管理有限公司
# 37       da549079-4968-42b4-a8e1-c08f7d70ed52    重庆华悦生态环境工程研究院有限公司
# ...

# %%
money_q25_sum_weighted.query('company_id=="382869F8C6F39D716E07A4F571B05129"')
# Out:
#                               company_id  \
# 386512  382869F8C6F39D716E07A4F571B05129
#
#                                       ans_id     company_name seic_lv2  \
# 386512  c972756b-19fd-4e47-8c67-019b1848716a  美满芯盛（杭州）微电子有限公司   电子核心产业
#
#         money_q25_sum_weighted
# 386512                500000.0

# %%
money_q25_sum_weighted.query('company_id=="57C89374224FC58E5F51032EDE3DD835"')
# Out:
#                               company_id  \
# 631677  57C89374224FC58E5F51032EDE3DD835
#
#                                       ans_id   company_name seic_lv2  \
# 631677  bdd4fcfa-9f19-4a72-9764-cccc245afcbb  矽磐微电子（重庆）有限公司   电子核心产业
#
#         money_q25_sum_weighted
# 631677            3.333333e+06

# %% [markdown]
# ### public

# %% [markdown]
# 测试点
# 1、测试public的数量是否一致
# 2、抽测测试case，对比结果一致性

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators.query('company_id=="02E2B5505993DEE6009B5E40C1936E8F"')[['company_id','ans_id','company_name',
                                                                  'seic_lv2','public']]
# Out:
#                               company_id  \
# 719191  02E2B5505993DEE6009B5E40C1936E8F
#
#                                       ans_id    company_name seic_lv2 public
# 719191  feffd9af-7774-4981-9729-6f1f20c79c75  烟台张裕葡萄酿酒股份有限公司       其它     A股

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators[
    looping_test_feature_switch_sse_company_nonpatent_indicators['public'].notnull()][['company_id','public']]
# Out:
#                                company_id public
# 204      12FDB87639C672562BC16014B5E37D45    新三板
# 212      13A6F11185EE00CA9BDA55A78A81029C     A股
# 318      1AFAC5D791C1F547C8E955A768620FA0     A股
# 396      217821701C22450438C955B27908AE1B     A股
# 455      2794EFA83AACEEBDD8E9108349082384    新三板
# ...                                   ...    ...
# 1109011  E058AD3082A483A2C6EEEAB08B9AF45B    新三板
# 1109057  E49C50CBD520D17F2CA59CEEF2066758    新三板
# 1109095  E800AD3A38A536C7915266BFCCE48AF2    新三板
# 1109169  EE955F86069DC67F4F8C7695CB1734B4    新三板
# 1109340  FEF7ECB78AE80ED75E3914E675A7421B    新三板
#
# [11005 rows x 2 columns]

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators['public'].value_counts()
# Out:
# 新三板    6292
# A股     4713
# Name: public, dtype: int64

# %%
looping_test_feature_switch_sse_company_nonpatent_indicators.query('company_id=="02E2B5505993DEE6009B5E40C1936E8F"')
# Out:
#                               company_id   duration  actual_capital_formatted  \
# 719191  02E2B5505993DEE6009B5E40C1936E8F  24.657534               685464000.0
#
#         reg_capital_formatted qualify_certificate  \
# 719191            685464000.0                 NaN
#
#                                       ans_id    company_name seic_lv1  \
# 719191  feffd9af-7774-4981-9729-6f1f20c79c75  烟台张裕葡萄酿酒股份有限公司       其它
#
#        seic_lv2 province city  status public  rounds  money_q25_sum_weighted  \
# 719191       其它      山东省  烟台市  ACTIVE     A股     NaN                     NaN
#
#         most_recent_money_q25_formatted  most_recent_time  \
# 719191                              NaN               NaN
#
#         avg_funding_interval  reg_num  reg_num_5y  reg_growth_ratio  \
# 719191                   NaN      NaN         NaN               NaN
#
#         reg_3y_avg  num_trademarks_registered  num_trademarks_total  \
# 719191         NaN                      890.0                 969.0
# ...

# %% [markdown]
# # 集团公司指标标准化前

# %% [markdown]
# ## looping_group

# %%
looping_group=pd.read_csv('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/5月/ 集团公司标准化字段/looping_group_20220509_sse_company_nonpatent_indicators.csv')

# %%
looping_group
# Out:
#                                  group_id   duration  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7   6.731507
# 1        0014A83C9B038292B6E0DB202479DEB9   4.994521
# 2        001CE08C53F7BD9A821358DD21C50C88  19.597260
# 3        0067F4DD86BE9866BD8E617D2B88E821   7.263014
# 4        006A322857D17795374D7749C2C32538  10.145205
# ...                                   ...        ...
# 1110162  C7C049CDA7F42E6D89B2D5351D6B0412        NaN
# 1110163  C85082D305A61A9633616A87858E156B        NaN
# 1110164  E586B12C6FBDBE45B224378D90FE78A8        NaN
# 1110165  F74C48AD2E7CF455975FBF6C1BC9F29C        NaN
# 1110166  FD9510BB0B4C5092BFEB060E5B3AFD91        NaN
#
#          actual_capital_formatted  reg_capital_formatted  \
# 0                    0.000000e+00           3.000000e+06
# 1                    0.000000e+00           1.000000e+06
# 2                    3.633573e+09           3.633573e+09
# 3                    0.000000e+00           7.000000e+06
# ...

# %%
looping_group.query('group_id=="9502E1B5EDBAB4D66A1575245E66242D"')
# Out:
#                                 group_id   duration  actual_capital_formatted  \
# 765135  9502E1B5EDBAB4D66A1575245E66242D  21.224658              2.520000e+10
#
#         reg_capital_formatted                                ans_id  \
# 765135           2.520000e+10  471d93c8-b64e-49bc-9059-0a47de4bfa6b
#
#                         public  \
# 765135  ['港股/美股', 'A股', '新三板']
#
#                                          qualify_certificate seic_lv1  \
# 765135  ['专精特新小巨人', '高新技术企业', '瞪羚企业', '单项冠军产品企业', '科技型中小企业']    新材料产业
#
#         seic_lv2 province city  status  group_name  rounds  \
# 765135  先进有色金属材料      北京市  北京市  ACTIVE  中国铝业集团有限公司    49.0
#
#         money_q25_sum_weighted  most_recent_money_q25_formatted  \
# 765135            2.660987e+08                        1000000.0
#
#         most_recent_time  avg_funding_interval  reg_num  reg_num_5y  \
# 765135          0.624658              0.515696    465.0       370.0
#
# ...

# %% [markdown]
# ### qualify_certificate

# %%
qualify_certificate=looping_group[['group_id','ans_id','seic_lv2','qualify_certificate']]
qualify_certificate
# Out:
#                                  group_id  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7
# 1        0014A83C9B038292B6E0DB202479DEB9
# 2        001CE08C53F7BD9A821358DD21C50C88
# 3        0067F4DD86BE9866BD8E617D2B88E821
# 4        006A322857D17795374D7749C2C32538
# ...                                   ...
# 1110162  C7C049CDA7F42E6D89B2D5351D6B0412
# 1110163  C85082D305A61A9633616A87858E156B
# 1110164  E586B12C6FBDBE45B224378D90FE78A8
# 1110165  F74C48AD2E7CF455975FBF6C1BC9F29C
# 1110166  FD9510BB0B4C5092BFEB060E5B3AFD91
#
#                                        ans_id       seic_lv2  \
# 0        ed596d9b-ea93-41e5-a5d7-522ea72bae22         生物医药产业
# 1                                         NaN  新兴软件和新型信息技术服务
# 2                                         NaN         其他相关服务
# 3        5de5cd27-7cc7-4b88-b482-cf7ce5811143       智能制造装备产业
# 4        e9aa448c-09db-4d69-8176-3368e8812bf7      先进无机非金属材料
# ...                                       ...            ...
# ...

# %%
qualify_certificate.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')['qualify_certificate']
# Out:
# 929734    ['瞪羚企业', '高新技术企业']
# Name: qualify_certificate, dtype: object

# %% [markdown]
# ### public

# %%
looping_group.query('group_id=="9502E1B5EDBAB4D66A1575245E66242D"')[['group_id','public']]
# Out:
#                                 group_id                  public
# 765135  9502E1B5EDBAB4D66A1575245E66242D  ['港股/美股', 'A股', '新三板']

# %% [markdown]
# # 集团公司指标标准化后

# %% [markdown]
# ## looping_group_switc

# %%
looping_group_switc=pd.read_csv('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/5月/ 集团公司标准化字段/looping_group_feature_switch_20220509_sse_company_nonpatent_indicators.csv')

# %%
looping_group_switc
# Out:
#                                  group_id   duration  \
# 0        000FA681D1E7610073C53DA8CF8CF6A7   6.739726
# 1        0014A83C9B038292B6E0DB202479DEB9   5.002740
# 2        001CE08C53F7BD9A821358DD21C50C88  19.605479
# 3        0067F4DD86BE9866BD8E617D2B88E821   7.271233
# 4        006A322857D17795374D7749C2C32538  10.153425
# ...                                   ...        ...
# 1109774  C7C049CDA7F42E6D89B2D5351D6B0412        NaN
# 1109775  C85082D305A61A9633616A87858E156B        NaN
# 1109776  E586B12C6FBDBE45B224378D90FE78A8        NaN
# 1109777  F74C48AD2E7CF455975FBF6C1BC9F29C        NaN
# 1109778  FD9510BB0B4C5092BFEB060E5B3AFD91        NaN
#
#          actual_capital_formatted  reg_capital_formatted qualify_certificate  \
# 0                    0.000000e+00           3.000000e+06             科技型中小企业
# 1                    0.000000e+00           1.000000e+06                 NaN
# 2                    3.633573e+09           3.633573e+09              高新技术企业
# ...

# %%
looping_group_switc.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')
# Out:
#                                 group_id   duration  actual_capital_formatted  \
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA  34.679452              4.034113e+10
#
#         reg_capital_formatted                            qualify_certificate  \
# 929734           4.044113e+10  国家技术创新示范企业__瞪羚企业__上海市企业技术中心__高新技术企业__国家企业技术中心
#
#                                       ans_id company_name   seic_lv1  \
# 929734  f039e90a-679c-4c50-ab06-72d03d496c4f     华为技术有限公司  新一代信息技术产业
#
#          seic_lv2 province city  status public  rounds  \
# 929734  下一代信息网络产业      广东省  深圳市  ACTIVE    NaN     5.0
#
#         money_q25_sum_weighted  most_recent_money_q25_formatted  \
# 929734            1.220790e+08                       66201500.0
#
#         most_recent_time  avg_funding_interval  reg_num  reg_num_5y  \
# 929734          0.386301              3.945205   1081.0       490.0
#
#         reg_growth_ratio  reg_3y_avg  num_trademarks_registered  \
# ...

# %% [markdown]
# ### qualify_certificate

# %%
looping_group_switc.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')['qualify_certificate']
# Out:
# 929734    国家技术创新示范企业__瞪羚企业__上海市企业技术中心__高新技术企业__国家企业技术中心
# Name: qualify_certificate, dtype: object

# %% [markdown]
# ###  num_certificates_valid

# %%
looping_group_switc.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['group_id','num_certificates_valid']]
# Out:
#                                 group_id  num_certificates_valid
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA                  3115.0

# %% [markdown]
# ### num_certificates

# %%
looping_group_switc.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['group_id','num_certificates']]
# Out:
#                                 group_id  num_certificates
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA            4050.0

# %% [markdown]
# ### actual_capital_formatted

# %%
looping_group_switc.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['group_id','actual_capital_formatted']]
# Out:
#                                 group_id  actual_capital_formatted
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA              4.034113e+10

# %% [markdown]
# ### reg_capital_formatted

# %%
looping_group_switc.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['group_id','reg_capital_formatted']]
# Out:
#                                 group_id  reg_capital_formatted
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA           4.044113e+10

# %% [markdown]
# ### money_q25_sum_weighted

# %%
looping_group_switc.query('group_id=="3A2989A4DBD7BAD2594518A8FF4F9A9F"')[['group_id','rounds']]
# Out:
#                                 group_id  rounds
# 860100  3A2989A4DBD7BAD2594518A8FF4F9A9F     2.0

# %%
looping_group_switc.query('group_id=="A70A3E493E6B6E9C3D1CDA03B6279CAA"')[['group_id','public']]
# Out:
#                                 group_id public
# 929734  A70A3E493E6B6E9C3D1CDA03B6279CAA    NaN

# %% [markdown]
# ### public

# %%
looping_group_switc.query('group_id=="02E2B5505993DEE6009B5E40C1936E8F"')[['group_id','ans_id','company_name',
                                                                  'seic_lv2','public']]
# Out:
#                                 group_id  \
# 719191  02E2B5505993DEE6009B5E40C1936E8F
#
#                                       ans_id    company_name seic_lv2 public
# 719191  feffd9af-7774-4981-9729-6f1f20c79c75  烟台张裕葡萄酿酒股份有限公司       其它     A股

# %%
looping_group_switc['public'].notnull().sum()
# Out:
# 11838

# %%
looping_group_switc['public'].value_counts()
# Out:
# 新三板                     6598
# A股                      4710
# 港股                       183
# A股__港股                   170
# A股__新三板                  132
# A股__港股__中概股__美股           12
# 港股__新三板                   10
# A股__港股__新三板               10
# A股__港股__中概股                5
# 中概股__美股                    2
# A股__中概股                    2
# 港股__中概股                    1
# A股__中概股__新三板               1
# A股__港股__美股__中概股__新三板       1
# 中概股                        1
# Name: public, dtype: int64

# %%
looping_group_switc.query('public=="A股__港股__美股__中概股__新三板"')
# Out:
#                                 group_id   duration  actual_capital_formatted  \
# 765135  9502E1B5EDBAB4D66A1575245E66242D  21.232877              2.520000e+10
#
#         reg_capital_formatted  \
# 765135           2.520000e+10
#
#                                                                                                                                                                                                       qualify_certificate  \
# 765135  取消国家企业技术中心__湖北省隐形冠军示范__湖北省专精特新小巨人__专精特新小巨人__国家技术创新示范企业__单项冠军产品__北京市企业技术中心__国家企业技术中心__湖北省企业技术中心__高新技术企业__重庆市专精特新__江苏省企业技术中心__湖北省隐形冠军小巨人__贵州省企业技术中心__贵州省专精特新__科技型中小企业__山东省专精特新__山东省企业技术中心__河南省企业技术中心__瞪羚企业__河南省专精特新
#
#                                       ans_id company_name seic_lv1  seic_lv2  \
# 765135  471d93c8-b64e-49bc-9059-0a47de4bfa6b   中国铝业集团有限公司    新材料产业  先进有色金属材料
#
#        province city  status                public  rounds  \
# 765135      北京市  北京市  ACTIVE  A股__港股__美股__中概股__新三板    49.0
#
# ...

# %% [markdown]
# # group

# %%
group=pd.read_csv('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/4月/子孙公司穿透/子孙穿透的集团公司.csv')
group.head(100)
# Out:
#                             group_id              group_name
# 0   F9AA5CEA611A455F2D548C02542ACEB3            南京云起信息科技有限公司
# 1   F9A9FC21F39CB84604DE52E06CF77E5A           宁德扬科狮虎进出口有限公司
# 2   F9A389392AB5A08B1994557220F8640A            湖南红门金属建材有限公司
# 3   F99CBAEEB39E5BF7566B03E3D2DEBDE8           湖南省华芯医疗器械有限公司
# 4   F9963A18ED2149CA64D66E173017334E           绍兴金渔纺织新技术有限公司
# 5   F993EB0E972A366DE42ED8F031FCC113              山东山孚集团有限公司
# 6   F98F46B5C50AECF24C4D06FFA483B7B0          泰州友润电子科技股份有限公司
# 7   F97E7E60F760DB1866FD0021755987B3            北京鸣天液压技术有限公司
# 8   F96DDC164E33125DB6361D36DBA6BBFC           肇庆市威盛塑料科技有限公司
# 9   F96A92C9FE6D5022B8D011479BFBEBE6            江苏风云科技服务有限公司
# 10  F954793AC12507FB239375186F0FE60D          上海摩威环境科技股份有限公司
# 11  F94E3D52812466E06768B4825E344EBF            北京泛博科技有限责任公司
# 12  F938D1BACF875A9E20D2393151A40B42              中慧农牧股份有限公司
# 13  F92BEA042DAC442A07EF06D6E768DFA8            重庆清平机械有限责任公司
# ...
