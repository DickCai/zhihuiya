# %%
import pandas as pd
import os
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/5月/指标回溯')

# %% [markdown]
# # backtracking

# %%
##2012
Index_20120101=pd.read_parquet('20120101')
Index_20120201=pd.read_parquet('20120201')
Index_20120301=pd.read_parquet('20120301')
Index_20120401=pd.read_parquet('20120401')
##2020
Index_20200101=pd.read_parquet('20200101')
Index_20200201=pd.read_parquet('20200201')
Index_20200301=pd.read_parquet('20200301')
Index_20200401=pd.read_parquet('20200401')
##2022
Index_20220101=pd.read_parquet('20220101')
Index_20220201=pd.read_parquet('20220201')
Index_20220301=pd.read_parquet('20220301')
Index_20220401=pd.read_parquet('20220401')

# %%
Index_20120101
# Out:
#                                      ans_id                        company_id  \
# 0      8858f53c-3b44-4275-9f8c-441552544023  CD270BD5BE393D36B3174D9A2662CED5
# 1      929486fd-14ca-4560-8f71-f4b4670c6dae  76E310550890005F2FD344FB9D81A3C9
# 2      2caaebaf-546f-4e6b-9208-a79e83f1ca7b  670B3BCE25D485206D53888DFB479279
# 3      cc7ac4bb-c87e-4796-92f6-a60a87552662  4D88B40DF2155E28E9122FC85D7ADD6C
# 4      e176fe03-8b42-4e2b-b135-324bb166b774  4D97CFFA2CAC341FA80336E233A26254
# ...                                     ...                               ...
# 92623  abca3135-5d82-4ffe-97c3-b0e663a8c632  40209B8C9304A2D9B6D1A1E2254687FB
# 92624  365742da-2b38-4003-95f0-1ac4a5c6daec  E98913A814080F3962A8504C0DE8974F
# 92625  9d2f8322-ba72-4f3a-a54d-b513764992be  A667E83ECAD737C379FEC4D0B57FAB4B
# 92626  7904cb01-a6a6-48e7-8c81-1110a1e3f599  4CA0FA392E46884E51C8A41987AFBD44
# 92627  d4e0152b-e444-4575-8ae6-c8bfd394bcc6  AA87BB461FA66C107C72441E0F9E1FCF
#
# ...

# %%
Index_20120101.columns
# Out:
# Index(['ans_id', 'company_id', 'apno_cnt', 'non_design_apno_cnt',
#        'tech_global_concentration', 'tech_width', 'total_patent_award_score',
#        'pct_apno_cnt', 'invention_ratio', 'avg_cited_by_cnt',
#        'top5_current_impact_index', 'avg_remaining_life_span',
#        'patenting_growth_ratio', 'avg_3y_cnt', 'active_inventor_cnt',
#        'inventor_cnt', 'active_inventor_ratio', 'invention_stability',
#        'self_cited_by_ratio', 'joint_applicant_cnt', 'joint_application_cnt',
#        'country_cnt'],
#       dtype='object')

# %%
Index_20200201.query('company_id=="69B22BD76B62602B2E420928AB87BD67"').T
# Out:
#                                                          520521
# ans_id                     d3f13fba-15af-4d2d-a647-036a126f2e21
# company_id                     69B22BD76B62602B2E420928AB87BD67
# apno_cnt                                                   3654
# non_design_apno_cnt                                        3630
# tech_global_concentration                              0.001835
# tech_width                                            51.142857
# total_patent_award_score                                      8
# pct_apno_cnt                                                200
# invention_ratio                                        0.491516
# avg_cited_by_cnt                                        1.00301
# top5_current_impact_index                              1.762308
# avg_remaining_life_span                                11.78482
# patenting_growth_ratio                                 2.142675
# avg_3y_cnt                                                879.0
# ...

# %%
Index_20220101.sort_values('apno_cnt',ascending=False)
# Out:
#                                       ans_id  \
# 175363  4da64376-dd21-436a-b0b0-d7fc0bd7fd7b
# 54763   f039e90a-679c-4c50-ab06-72d03d496c4f
# 834032  8d839b9f-81ba-4ee8-abf3-1576273cfdc2
# 512454  98adf139-54fc-453f-8f7c-eeed722765c2
# 38494   301909a7-94d8-4138-ae9b-46a030fd8389
# ...                                      ...
# 334063  3ef7be5a-6229-11ec-8c34-6a0b3c9cb180
# 110943  60c72225-733c-4ded-a5f7-a24e292d88eb
# 110947  626d9e7f-9e28-49a8-b6cf-3cc2156b47f0
# 716197  60138284-d6fb-4360-bad3-37fea407bcdd
# 73264   958be546-a96a-4846-bd57-e8db10067536
#
#                               company_id  apno_cnt  non_design_apno_cnt  \
# 175363  A8C04C8DE3B4C8B4B2A29AFE61DFD3EF    269814               268643
# 54763   A70A3E493E6B6E9C3D1CDA03B6279CAA    225230               221400
# 834032  8B14C6CD92099D2B4C51613B3C8FD71D    180584               178486
# 512454  045F5647B6C18F9CBE44A4AF6F0AD989    110400               102886
# ...
