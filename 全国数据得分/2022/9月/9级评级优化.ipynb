# %%
import pandas as pd
import os
pd.set_option('max_rows',100)
pd.set_option('max_columns',100)
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company_v23',echo=False)

# %% [markdown]
# # update_ficoscore

# %%
update_ficoscore=pd.read_sql('select * from update_ficoscore',con=engine)
update_ficoscore
# Out:
#                              company_id cur_9level new_9level
# 0      1CCC3FA6C122DC1E1275EF529726DF97        CCC          B
# 1      2DCA6B4EADF9264DEFE4D17C3881F7BB        CCC          B
# 2      4C6DC053BEB383B634E234FEE6B016CD        CCC          B
# 3      8D3BAA58A434D16C0BBC809C10A4448F        CCC          B
# 4      E9ACF2A9DC68EE714ECA8B9506EDAD53        CCC          B
# ...                                 ...        ...        ...
# 36611  ADFB53B258BBF84A25E35B9981043FDC        CCC          B
# 36612  B81FEE3F41EE503A547BBC1BF6DB97BD        CCC          B
# 36613  C9020905B0FD0F5C4CECAB46A1F80AF9        CCC          B
# 36614  E5EB3FFA8845763EB2327E54ABF6BFBF        CCC          B
# 36615  ED810CA7BFE75C56F710C1FEE680BA9E        CCC          B
#
# [36616 rows x 3 columns]

# %%
update_ficoscore=pd.merge(update_ficoscore,test_quanguo_score[['company_id','company_name',
                                                              'total']],on='company_id')
update_ficoscore=pd.merge(update_ficoscore,update_original,on='company_id')
update_ficoscore
# Out:
#                              company_id cur_9level new_9level  \
# 0      1CCC3FA6C122DC1E1275EF529726DF97        CCC          B
# 1      2DCA6B4EADF9264DEFE4D17C3881F7BB        CCC          B
# 2      4C6DC053BEB383B634E234FEE6B016CD        CCC          B
# 3      8D3BAA58A434D16C0BBC809C10A4448F        CCC          B
# 4      E9ACF2A9DC68EE714ECA8B9506EDAD53        CCC          B
# ...                                 ...        ...        ...
# 36611  ADFB53B258BBF84A25E35B9981043FDC        CCC          B
# 36612  B81FEE3F41EE503A547BBC1BF6DB97BD        CCC          B
# 36613  C9020905B0FD0F5C4CECAB46A1F80AF9        CCC          B
# 36614  E5EB3FFA8845763EB2327E54ABF6BFBF        CCC          B
# 36615  ED810CA7BFE75C56F710C1FEE680BA9E        CCC          B
#
#             company_name      total                                ans_id  \
# 0         山东华夏茶联信息科技有限公司  11.301130  1c75cc0f-bbc8-46c8-93d5-b6360bedd633
# ...

# %%
update_ficoscore.query('company_id=="C2B3A55522AD2C3FB61BC476D1DD0709"')
# Out:
#                            company_id cur_9level new_9level  company_name  \
# 436  C2B3A55522AD2C3FB61BC476D1DD0709        CCC          B  山东三益园林绿化有限公司
#
#          total                                ans_id  value_sum  \
# 436  23.557181  2adc4a05-f1d4-44bc-817d-edaa62f083cb   653400.0
#
#      granted_invention_cnt_pb_original_2y  apno_cnt   duration qualification  \
# 436                                     0        21  13.153425            []
#
#      rounds  parent_is_aaa  china_patent_award  china_sicence_technology_award
# 436       2            NaN                 NaN                             NaN

# %%
update_ficoscore.query('duration>3 and rounds<1 and parent_is_aaa!=1 and china_patent_award!=1 and china_sicence_technology_award!=1 ')
# Out:
#                              company_id cur_9level new_9level  \
# 1      2DCA6B4EADF9264DEFE4D17C3881F7BB        CCC          B
# 156    AB1C0E509AFE7B0DE5838C143054790D        CCC          B
# 198    96BBE02DEE7F76D19842EC6476D75F2E        CCC          B
# 278    51CDC85F7C3F49FE17D1A1FCBE0921D1        CCC          B
# 282    7D1B94A5B54731688E16C2A4B78A0C0D        CCC          B
# ...                                 ...        ...        ...
# 35924  42F6D5EE10D14CB327C887623827FC8F        CCC          B
# 36208  DA2646695A654A3C5B639F9A193F9D70        CCC          B
# 36462  479829BC5624B261E5DCD2434BB0785A        CCC          B
# 36495  F10DD82A162CF9648395B645763EF0FC        CCC          B
# 36605  FDB1C1A2EA9F5099B7CB8CCEF0522B87        CCC          B
#
#            company_name      total                                ans_id  \
# 1        江苏澳洋健康产业股份有限公司  27.899495  3a4759da-b498-11ec-a8cd-baa018f5ce20
# ...

# %%
update_CCC=update_ficoscore.query('total>20 and value_sum<40000')

# %%
update_CCC.query('duration>3 and rounds<1 and parent_is_aaa!=1 and china_patent_award!=1 and china_sicence_technology_award!=1\
and(~qualification.str.contains("A"))',engine='python')
# Out:
# Empty DataFrame
# Columns: [company_id, cur_9level, new_9level, company_name, total, ans_id, value_sum, granted_invention_cnt_pb_original_2y, apno_cnt, duration, qualification, rounds, parent_is_aaa, china_patent_award, china_sicence_technology_award]
# Index: []

# %% [markdown]
# # update_original

# %%
update_original=pd.read_sql('select * from update_original',con=engine)
update_original
# Out:
#                              company_id                                ans_id  \
# 0      1CCC3FA6C122DC1E1275EF529726DF97  1c75cc0f-bbc8-46c8-93d5-b6360bedd633
# 1      2DCA6B4EADF9264DEFE4D17C3881F7BB  3a4759da-b498-11ec-a8cd-baa018f5ce20
# 2      4C6DC053BEB383B634E234FEE6B016CD  1bf930dd-0ff3-4cc3-b96a-73548c503e9e
# 3      8D3BAA58A434D16C0BBC809C10A4448F  4acf0198-032c-4d1d-beee-78a3f5b40763
# 4      E9ACF2A9DC68EE714ECA8B9506EDAD53  5f6dd139-70e9-4a43-8774-9f7266a42b66
# ...                                 ...                                   ...
# 36611  ADFB53B258BBF84A25E35B9981043FDC  7952fb56-888c-44b2-ba84-8308a896b348
# 36612  B81FEE3F41EE503A547BBC1BF6DB97BD  a8b9a886-a13e-11ec-aecd-720839791087
# 36613  C9020905B0FD0F5C4CECAB46A1F80AF9  ebb5648a-4226-42d4-ade2-6b24180df210
# 36614  E5EB3FFA8845763EB2327E54ABF6BFBF  098521bc-299e-4329-afbe-e0f53f4fee3f
# 36615  ED810CA7BFE75C56F710C1FEE680BA9E  580513e6-1257-11ed-9940-323aa916fc88
#
# ...

# %%
update_original.query('parent_is_aaa==1')
# Out:
#                              company_id                                ans_id  \
# 3      8D3BAA58A434D16C0BBC809C10A4448F  4acf0198-032c-4d1d-beee-78a3f5b40763
# 38     3FCCB0E40814A2C0E93DE897D44E3085  345961ae-66c2-11ec-8c34-6a0b3c9cb180
# 64     BF74F217F6AC740F09FC3DBA9C9F8F41  c53a1a2f-1de2-4aa3-b74f-94ca3e0a3eed
# 101    1A84C878ECEEF7E054DD879B6EE84DD0  14152109-f992-458a-a36c-b6be2d387692
# 163    8251F21798E15C16971BABA4E0BB06DA  2babe8b0-f402-11ec-b21e-5251e459860d
# ...                                 ...                                   ...
# 36468  C64196F3DDC50BC2F97AC41763D5B552  13c7a482-85b6-4b7c-b8b7-3993da919317
# 36498  208AC7C5A38F08E3A018660605C8C580  9c63268b-deaa-4fe3-a3f4-70f234df61dd
# 36501  7A6A7D8C101BC9D65F80E97AC6C7B3D9  a55dd0a3-9dfc-46f0-88b3-636db09c69f3
# 36552  4F494EA2410CB40509D99748C1DFBF71  d625f97a-c3cc-46d7-b3d5-8769653c91a8
# 36571  EA08B603E853DCEDCE87821C440B81C3  2758315c-7415-46b2-8577-a8466816617c
#
# ...

# %%
update_original['parent_is_aaa'].value_counts()
# Out:
# 1.0    998
# Name: parent_is_aaa, dtype: int64

# %% [markdown]
# # test_quanguo_ficoscore

# %%
test_quanguo_ficoscore=pd.read_sql('select * from test_quanguo_ficoscore',con=engine)
test_quanguo_ficoscore
# Out:
#                                company_id      company_name       tffi  \
# 0        0139C87DB0780832486E85D0EA8C4F96        广东维锐电器有限公司   7.090851
# 1        017DBD040AA44BF1A7BC8D8DF6EAA4A4  北京益泰牡丹电子工程有限责任公司  28.888453
# 2        03C86219FFB74036706201F2A90ADBEC      安宇（长泰）工贸有限公司  14.353274
# 3        0541622B8798C48785C76E303EEC7C9C      深圳市邦仕达科技有限公司   3.499896
# 4        05BCC1C6896C17FD3AA9F03D434A9DCA        湖北臻猪科技有限公司  20.634069
# ...                                   ...               ...        ...
# 1099403  F7934CD5EAE2DD4EFDE56F12FF679C9F      厦门国际银行股份有限公司  45.289259
# 1099404  F7D039CF0BF31E7C16B44F65923A4D1B     广州壹夹壹信息科技有限公司   4.963876
# 1099405  FB8D3616B0D31E0D390AC08FAEA33782      浙江卓凡印刷科技有限公司  29.866931
# 1099406  FC6B054A9CA8052E9D1794690D31A9B3      上海致菱金属制品有限公司  11.246454
# 1099407  FCDDC9EF84792690A5BBF95AAB5972CA      中旅国际会议展览有限公司   1.344736
#
#                fico 调整等距分箱
# 0        338.999681     CC
# 1        458.886492      B
# 2        378.943006    CCC
# ...

# %%
test_quanguo_ficoscore['调整等距分箱'].value_counts()
# Out:
# CCC    405456
# CC     288799
# B      168865
# C      164887
# BB      48396
# BBB     15305
# A        5740
# AA       1649
# AAA       311
# Name: 调整等距分箱, dtype: int64

# %% [markdown]
# # test_quanguo_original

# %%
test_quanguo_original=pd.read_sql('select * from test_quanguo_original',con=engine)
test_quanguo_original
# Out:
#                                company_id province city seic_lv1    seic_lv2  \
# 0        0139C87DB0780832486E85D0EA8C4F96      广东省  湛江市       其它          其它
# 1        017DBD040AA44BF1A7BC8D8DF6EAA4A4      北京市  北京市    新能源产业      智能电网产业
# 2        03C86219FFB74036706201F2A90ADBEC      福建省  漳州市    新材料产业   先进无机非金属材料
# 3        0541622B8798C48785C76E303EEC7C9C      广东省  深圳市   数字创意产业  数字创意技术设备制造
# 4        05BCC1C6896C17FD3AA9F03D434A9DCA      湖北省  荆门市     生物产业   生物农业及相关产业
# ...                                   ...      ...  ...      ...         ...
# 1099403  F7934CD5EAE2DD4EFDE56F12FF679C9F      福建省  厦门市    相关服务业      其他相关服务
# 1099404  F7D039CF0BF31E7C16B44F65923A4D1B      广东省  广州市   数字创意产业    数字文化创意活动
# 1099405  FB8D3616B0D31E0D390AC08FAEA33782      浙江省  温州市       其它          其它
# 1099406  FC6B054A9CA8052E9D1794690D31A9B3      上海市  上海市    新材料产业    先进有色金属材料
# 1099407  FCDDC9EF84792690A5BBF95AAB5972CA      北京市  北京市   数字创意产业   数字创意与融合服务
#
# ...

# %% [markdown]
# # test_quanguo_score

# %%
test_quanguo_score=pd.read_sql('select * from test_quanguo_score',con=engine)
test_quanguo_score
# Out:
#                                company_id      company_name seic_lv1  \
# 0        0139C87DB0780832486E85D0EA8C4F96        广东维锐电器有限公司       其它
# 1        017DBD040AA44BF1A7BC8D8DF6EAA4A4  北京益泰牡丹电子工程有限责任公司    新能源产业
# 2        03C86219FFB74036706201F2A90ADBEC      安宇（长泰）工贸有限公司    新材料产业
# 3        0541622B8798C48785C76E303EEC7C9C      深圳市邦仕达科技有限公司   数字创意产业
# 4        05BCC1C6896C17FD3AA9F03D434A9DCA        湖北臻猪科技有限公司     生物产业
# ...                                   ...               ...      ...
# 1099403  F7934CD5EAE2DD4EFDE56F12FF679C9F      厦门国际银行股份有限公司    相关服务业
# 1099404  F7D039CF0BF31E7C16B44F65923A4D1B     广州壹夹壹信息科技有限公司   数字创意产业
# 1099405  FB8D3616B0D31E0D390AC08FAEA33782      浙江卓凡印刷科技有限公司       其它
# 1099406  FC6B054A9CA8052E9D1794690D31A9B3      上海致菱金属制品有限公司    新材料产业
# 1099407  FCDDC9EF84792690A5BBF95AAB5972CA      中旅国际会议展览有限公司   数字创意产业
#
#            seic_lv2 province city  apno_cnt  status     patent  nonpatent  \
# ...

# %%
test_quanguo_ficoscore
# Out:
#                                company_id      company_name       tffi  \
# 0        0139C87DB0780832486E85D0EA8C4F96        广东维锐电器有限公司   7.090851
# 1        017DBD040AA44BF1A7BC8D8DF6EAA4A4  北京益泰牡丹电子工程有限责任公司  28.888453
# 2        03C86219FFB74036706201F2A90ADBEC      安宇（长泰）工贸有限公司  14.353274
# 3        0541622B8798C48785C76E303EEC7C9C      深圳市邦仕达科技有限公司   3.499896
# 4        05BCC1C6896C17FD3AA9F03D434A9DCA        湖北臻猪科技有限公司  20.634069
# ...                                   ...               ...        ...
# 1099403  F7934CD5EAE2DD4EFDE56F12FF679C9F      厦门国际银行股份有限公司  45.289259
# 1099404  F7D039CF0BF31E7C16B44F65923A4D1B     广州壹夹壹信息科技有限公司   4.963876
# 1099405  FB8D3616B0D31E0D390AC08FAEA33782      浙江卓凡印刷科技有限公司  29.866931
# 1099406  FC6B054A9CA8052E9D1794690D31A9B3      上海致菱金属制品有限公司  11.246454
# 1099407  FCDDC9EF84792690A5BBF95AAB5972CA      中旅国际会议展览有限公司   1.344736
#
#                fico 调整等距分箱
# 0        338.999681     CC
# 1        458.886492      B
# 2        378.943006    CCC
# ...

# %%
test_quanguo_fico=pd.merge(test_quanguo_score,test_quanguo_ficoscore[['company_id','调整等距分箱']],
                          on='company_id')
test_quanguo_fico=pd.merge(test_quanguo_fico,test_quanguo_original[['company_id','value_sum']],on='company_id')
test_quanguo_fico
# Out:
#                                company_id      company_name seic_lv1  \
# 0        0139C87DB0780832486E85D0EA8C4F96        广东维锐电器有限公司       其它
# 1        017DBD040AA44BF1A7BC8D8DF6EAA4A4  北京益泰牡丹电子工程有限责任公司    新能源产业
# 2        03C86219FFB74036706201F2A90ADBEC      安宇（长泰）工贸有限公司    新材料产业
# 3        0541622B8798C48785C76E303EEC7C9C      深圳市邦仕达科技有限公司   数字创意产业
# 4        05BCC1C6896C17FD3AA9F03D434A9DCA        湖北臻猪科技有限公司     生物产业
# ...                                   ...               ...      ...
# 1099403  F7934CD5EAE2DD4EFDE56F12FF679C9F      厦门国际银行股份有限公司    相关服务业
# 1099404  F7D039CF0BF31E7C16B44F65923A4D1B     广州壹夹壹信息科技有限公司   数字创意产业
# 1099405  FB8D3616B0D31E0D390AC08FAEA33782      浙江卓凡印刷科技有限公司       其它
# 1099406  FC6B054A9CA8052E9D1794690D31A9B3      上海致菱金属制品有限公司    新材料产业
# 1099407  FCDDC9EF84792690A5BBF95AAB5972CA      中旅国际会议展览有限公司   数字创意产业
#
#            seic_lv2 province city  apno_cnt  status     patent  nonpatent  \
# ...

# %%
value_sum=test_quanguo_fico.query('total>20 and value_sum<40000')

# %%
value_sum
# Out:
#                                company_id    company_name   seic_lv1  \
# 11       0F2E15179EF6ACD6F56660C63CBFE1FF   艾小本科技（武汉）有限公司  新一代信息技术产业
# 19       14E9F7A33A28949CD5C6B1582AC53201  郑州航大中天工业设计有限公司     数字创意产业
# 29       1E96F70F1A12603ABA4FF14AF392E2C2    海南兴源景观工程有限公司         其它
# 45       2DCA6B4EADF9264DEFE4D17C3881F7BB  江苏澳洋健康产业股份有限公司       生物产业
# 74       45DFB4BFFCCA39F39A29B82297AE2C8E   浙江正天新材料科技有限公司      新材料产业
# ...                                   ...             ...        ...
# 1099284  84995C76ED98323A3656DFD0BBE1D319    深圳市奥赛克科技有限公司         其它
# 1099300  9C3C4432275C4EBAE30F54FCEB95AF94    深圳涯岸潜水工程有限公司   高端装备制造产业
# 1099316  ADFB53B258BBF84A25E35B9981043FDC    湖北微伞医疗科技有限公司       生物产业
# 1099343  C4EC8EBFCB9F7A0AFC58F6B17ED460AC    泽汇渔业（光泽）有限公司       生物产业
# 1099385  E8D7DCCA17CB30F12F745B49661786C6     山东金泰山漆业有限公司      新材料产业
#
#               seic_lv2 province city  apno_cnt  status     patent  nonpatent  \
# ...
