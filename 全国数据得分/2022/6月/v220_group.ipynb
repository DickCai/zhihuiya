# %%
import pandas as pd
import os
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/6月/v220_group')
pd.set_option('max_rows',100)
pd.set_option('max_columns',100)

# %% [markdown]
# # 6月

# %%
v220_group_6=pd.read_parquet('1.parquet')
v220_group_6
# Out:
#                              company_id      score rating rating_lv2  \
# 0      037104ABF695434480112BA7ADDB22B6  35.850922      A          A
# 1      03883E352FEA3F8058BB65C6F19D37AE  34.499720      B          B
# 2      0482BE5FB05461753899653945CE003F  44.038051      A          A
# 3      08F9D27B865E3D6A4725018CBCD8376B  34.671243      B          B
# 4      0AA53DCAED205B42246ABF8E3531A829  28.791496      B          B
# ...                                 ...        ...    ...        ...
# 64532  F85B5F5935180917138DA0795AB8329B  44.609053      A          A
# 64533  FA082873F94B6E95FE30FC60ADDEF964  36.544666      A          A
# 64534  FB1F56D988B58933A5F3CA2C65C9B634  16.624731      C          B
# 64535  FCC722151BFC9C4737D54D33B4D0602E  29.152004      B          B
# 64536  FF60EAE87A689E9A18473B0932A4A23C  42.211039      A          A
#
#                                             score_detail  \
# 0      [{'dimension_name': 'fundamental', 'indicators...
# ...

# %% [markdown]
# ## score

# %%
v220_group_6_company_name=pd.merge(v220_group_6,original_detail[['company_id','company_name']],on='company_id')
v220_group_6_company_name
# Out:
#                              company_id      score rating rating_lv2  \
# 0      037104ABF695434480112BA7ADDB22B6  35.850922      A          A
# 1      03883E352FEA3F8058BB65C6F19D37AE  34.499720      B          B
# 2      0482BE5FB05461753899653945CE003F  44.038051      A          A
# 3      08F9D27B865E3D6A4725018CBCD8376B  34.671243      B          B
# 4      0AA53DCAED205B42246ABF8E3531A829  28.791496      B          B
# ...                                 ...        ...    ...        ...
# 64532  F85B5F5935180917138DA0795AB8329B  44.609053      A          A
# 64533  FA082873F94B6E95FE30FC60ADDEF964  36.544666      A          A
# 64534  FB1F56D988B58933A5F3CA2C65C9B634  16.624731      C          B
# 64535  FCC722151BFC9C4737D54D33B4D0602E  29.152004      B          B
# 64536  FF60EAE87A689E9A18473B0932A4A23C  42.211039      A          A
#
#                                             score_detail  \
# 0      [{'dimension_name': 'fundamental', 'indicators...
# ...

# %%
v220_group_6_company_name.sort_values('score',ascending=False).head(100)
# Out:
#                              company_id      score rating rating_lv2  \
# 49346  A70A3E493E6B6E9C3D1CDA03B6279CAA  97.142937      A          A
# 45348  0F24DCBEFC027FFCCF68EF8F93B7FEA2  97.058267      A          A
# 12878  C6175C21C2AD25AC1428B1AEE08303A7  97.057903      A          A
# 18799  31DD96D9B3973E7A3E028E41A8F4BE6D  96.992368      A          A
# 14648  06B274EB9A5BF6B5CEAF83C5AED88E59  96.933639      A          A
# 29390  BB651A916A5FC907E4E90EBDA727BDC3  96.900934      A          A
# 38320  D20A042931B04856A43ED66626D6377E  96.855278      A          A
# 19162  66328D3F25518BB03F4BE6FE3360E076  96.830604      A          A
# 12367  8B14C6CD92099D2B4C51613B3C8FD71D  96.743384      A          A
# 49592  32D8297B4419FB163A033388256F206C  96.729558      A          A
# 9028   C7C5CFD1FCCEE0F3734EF2CF98704F2A  96.689436      A          A
# 9157   837BAAE7E810FE33FF8D4F6FD6D4D5B3  96.587590      A          A
# 17967  28919DF19AE0EA76015C5C49BBA76C16  96.566793      A          A
# ...

# %%
v220_group_6_company_name[v220_group_6_company_name['company_name'].str.contains('抖音')]
# Out:
#                              company_id      score rating rating_lv2  \
# 14648  06B274EB9A5BF6B5CEAF83C5AED88E59  96.933639      A          A
#
#                                             score_detail  \
# 14648  [{'dimension_name': 'fundamental', 'indicators...
#
#                                          score_dimension  \
# 14648  {'fundamental': 17.433427592999998, 'fundament...
#
#                                          original_detail     created_at  \
# 14648  {'active_inventor_ratio': 0.0, 'actual_capital...  1655812532000
#
#           updated_at company_name
# 14648  1655812532000       抖音有限公司

# %% [markdown]
# ## score_detail

# %%
detaic={}
detaic_list=[]
for a ,company_id in zip(v220_group_6['score_detail'],v220_group_6['company_id']):
    detaic_dict={}
    for v  in a:
        new_v=v.get('indicators')
        for m in new_v:
            detaic_dict[m.get('name')]=m.get('score')
    #detaic_list.append(detaic_dict)
    detaic_dict["company_id"]=company_id
    detaic_list.append(detaic_dict)

# %%
detaic_list=pd.DataFrame(detaic_list)
detaic_list
# Out:
#        actual_capital_formatted  avg_funding_interval  duration  \
# 0                        0.2036                0.0000    0.0351
# 1                        0.0282                0.0000    0.1326
# 2                        0.0000                0.0000    0.2036
# 3                        0.1107                0.0000    0.1326
# 4                        0.2036                0.0000    0.1326
# ...                         ...                   ...       ...
# 64532                    0.1107                0.0000    0.1326
# 64533                    0.1107                0.0000    0.0351
# 64534                    0.1107                0.0000    0.0702
# 64535                    0.2036                0.0000    0.0351
# 64536                    0.0282                2.5116    0.1326
#
#        money_q25_sum_weighted  most_recent_money_q25_formatted  \
# 0                      0.9176                           0.0087
# 1                      0.0000                           0.0000
# ...

# %% [markdown]
# ## original_detail

# %%
original_detail=[]
for a ,company_id in zip(v220_group_6['original_detail'],v220_group_6['company_id']):
    a['company_id']=company_id
    original_detail.append(a)

# %%
original_detail=pd.DataFrame(original_detail)
original_detail
# Out:
#        active_inventor_ratio  actual_capital_formatted  \
# 0                    0.00000              9.582000e+07
# 1                    0.16667              4.000000e+06
# 2                    0.03922              0.000000e+00
# 3                    0.00000              2.173913e+07
# 4                    0.00000              1.470942e+09
# ...                      ...                       ...
# 64532                0.16667              3.000000e+07
# 64533                0.00000              2.000000e+07
# 64534                    NaN              2.575000e+07
# 64535                0.00000              6.380000e+07
# 64536                0.00000              3.333334e+06
#
#                                      ans_id  apno_cnt  apno_cnt_valid_5y  \
# 0      bfc25c3b-d2da-47c6-a031-71c5bce8a39c        31                 24
# 1      0921895f-8742-4743-89f1-3c7d624462ea        79                 21
# 2      a316b78c-95ec-4ab6-a17f-ae17a6d46026       103                 62
# ...

# %%
original_detail.columns
# Out:
# Index(['active_inventor_ratio', 'actual_capital_formatted', 'ans_id',
#        'apno_cnt', 'apno_cnt_valid_5y', 'avg_3y_cnt', 'avg_cited_by_cnt',
#        'avg_funding_interval', 'avg_remaining_life_span',
#        'avg_technology_score', 'city', 'company_id', 'company_name',
#        'core_patents_cited_by_cnt', 'core_patents_cited_by_ratio',
#        'country_cnt', 'duration', 'external_licensing_cnt',
#        'granted_invention_cnt', 'granted_invention_cnt_pb_1y',
#        'granted_invention_cnt_pb_original_2y', 'granted_invention_ratio',
#        'in_examing_ratio', 'invention_ratio', 'invention_stability',
#        'inventor_cnt', 'ip_dependency', 'joint_applicant_cnt',
#        'joint_application_cnt', 'money_q25_sum_weighted',
#        'most_cited_patents_value', 'most_recent_money_q25_formatted',
#        'most_recent_time', 'non_design_apno_cnt', 'non_design_pct_apno_cnt',
#        'num_certificates_valid', 'num_members', 'num_trademarks_registered',
# ...

# %% [markdown]
# # 5月

# %%
v220_group_5=pd.read_parquet('/Users/caicaiqijun/智慧牙/数据/全国数据/全国数据得分/2022/5月/月度更新/group')
v220_group_5
# Out:
#                                company_id      score rating rating_lv2  \
# 0        000D7B52500A55AC247542044FE7471C  28.993510      B          B
# 1        001BE466F09F96E0B02617460E7642EF   4.575254      E          E
# 2        0066413E00A1F9254DF9020CD4D5EE5F  25.829604      B          B
# 3        006C1A478C32B78E92BB5BD97B66E16D  40.232920      A          A
# 4        00769E6C128021ADEB3C7BFA142A92C0  20.842654      C          C
# ...                                   ...        ...    ...        ...
# 1065485  ABC34883A7A0AAE7F14A7FEBC413455A   7.228969      E          E
# 1065486  ABFAC3DAAD0D45F5F8451E80B8F5130A  11.620611      C          C
# 1065487  ABFAD8606E2FADD86676135BF674895C  27.270780      B          B
# 1065488  ABFC19A1E9FEAAFE6EC3CB177FF014DD  10.239883      C          D
# 1065489  AC1278AAF6FF1714623E0C0AFA6ED0C2   9.615220      D          D
#
#                                               score_detail  \
# ...

# %% [markdown]
# # compare

# %%
group_score=pd.merge(v220_group_6_company_name,v220_group_5[['company_id','score','rating_lv2']],
                    on='company_id',suffixes=['_06','_05'])
group_score
# Out:
#                              company_id   score_06 rating rating_lv2_06  \
# 0      037104ABF695434480112BA7ADDB22B6  35.850922      A             A
# 1      03883E352FEA3F8058BB65C6F19D37AE  34.499720      B             B
# 2      0482BE5FB05461753899653945CE003F  44.038051      A             A
# 3      08F9D27B865E3D6A4725018CBCD8376B  34.671243      B             B
# 4      0AA53DCAED205B42246ABF8E3531A829  28.791496      B             B
# ...                                 ...        ...    ...           ...
# 63895  F85B5F5935180917138DA0795AB8329B  44.609053      A             A
# 63896  FA082873F94B6E95FE30FC60ADDEF964  36.544666      A             A
# 63897  FB1F56D988B58933A5F3CA2C65C9B634  16.624731      C             B
# 63898  FCC722151BFC9C4737D54D33B4D0602E  29.152004      B             B
# 63899  FF60EAE87A689E9A18473B0932A4A23C  42.211039      A             A
#
#                                             score_detail  \
# ...

# %%
group_score
# Out:
#                              company_id   score_06 rating rating_lv2_06  \
# 0      037104ABF695434480112BA7ADDB22B6  35.850922      C             C
# 1      03883E352FEA3F8058BB65C6F19D37AE  34.499720      D             D
# 2      0482BE5FB05461753899653945CE003F  44.038051      C             C
# 3      08F9D27B865E3D6A4725018CBCD8376B  34.671243      D             D
# 4      0AA53DCAED205B42246ABF8E3531A829  28.791496      E             D
# ...                                 ...        ...    ...           ...
# 63895  F85B5F5935180917138DA0795AB8329B  44.609053      C             C
# 63896  FA082873F94B6E95FE30FC60ADDEF964  36.544666      C             C
# 63897  FB1F56D988B58933A5F3CA2C65C9B634  16.624731      E             E
# 63898  FCC722151BFC9C4737D54D33B4D0602E  29.152004      D             D
# 63899  FF60EAE87A689E9A18473B0932A4A23C  42.211039      C             C
#
#                                             score_detail  \
# ...

# %%
group_score.query('rating_lv2_05=="A" and rating_lv2_06=="B"')
# Out:
#                              company_id   score_06 rating rating_lv2_06  \
# 154    E382322AAAAFF08A8410A1150F12784C  30.891581      B             B
# 254    8CC9AFB31DE6ED7BF874A115BDB4AF6E  32.880632      B             B
# 351    1CA47A17E5A45B8F39C2C212EAE32181  44.304201      A             B
# 461    BDB143DB38C8513BE7AA24C47026FA69  32.953227      A             B
# 495    E77C142FF9FE6396D251CA0BEB89D9E1  31.331641      B             B
# ...                                 ...        ...    ...           ...
# 62662  F9F7997A5684ECFEBBDE0E53BB61E3E7  38.905919      A             B
# 63089  B7B63E27A3D72DE494CCF4D49FD1977F  31.863636      B             B
# 63286  E360E7EABD9CA246FC7B04605192D0A1  34.269649      B             B
# 63562  B8659636779C17C6404DE42657735D87  43.144853      A             B
# 63886  EB7285AE7252741ED3675E3191C43353  29.940508      B             B
#
#                                             score_detail  \
# ...

# %%
group_score.query('company_id=="3A2989A4DBD7BAD2594518A8FF4F9A9F"')
# Out:
#                              company_id   score_06 rating rating_lv2_06  \
# 60058  3A2989A4DBD7BAD2594518A8FF4F9A9F  78.876263      A             A
#
#                                             score_detail  \
# 60058  [{'dimension_name': 'fundamental', 'indicators...
#
#                                          score_dimension  \
# 60058  {'fundamental': 14.748408761, 'fundamental_rat...
#
#                                          original_detail     created_at  \
# 60058  {'active_inventor_ratio': 0.02818, 'actual_cap...  1655812532000
#
#           updated_at company_name   score_05 rating_lv2_05
# 60058  1655812532000  华润微电子控股有限公司  78.805646             A

# %%
group_score.sort_values('score_05',ascending=False).head(100)
# Out:
#                              company_id   score_06 rating rating_lv2_06  \
# 48868  A70A3E493E6B6E9C3D1CDA03B6279CAA  97.142937      A             A
# 44909  0F24DCBEFC027FFCCF68EF8F93B7FEA2  97.058267      A             A
# 14502  06B274EB9A5BF6B5CEAF83C5AED88E59  96.933639      A             A
# 17792  28919DF19AE0EA76015C5C49BBA76C16  96.566793      A             A
# 18618  31DD96D9B3973E7A3E028E41A8F4BE6D  96.992368      A             A
# 29109  BB651A916A5FC907E4E90EBDA727BDC3  96.900934      A             A
# 37959  D20A042931B04856A43ED66626D6377E  96.855278      A             A
# 12752  C6175C21C2AD25AC1428B1AEE08303A7  97.057903      A             A
# 18980  66328D3F25518BB03F4BE6FE3360E076  96.830604      A             A
# 49113  32D8297B4419FB163A033388256F206C  96.729558      A             A
# 8942   C7C5CFD1FCCEE0F3734EF2CF98704F2A  96.689436      A             A
# 9071   837BAAE7E810FE33FF8D4F6FD6D4D5B3  96.587590      A             A
# ...

# %%
group_score[group_score['company_name'].str.contains('字节跳动')]
# Out:
#                              company_id  score_06 rating rating_lv2_06  \
# 12129  CBAA8D99FF09DF020556894D4C7076A5  84.09745      A             A
#
#                                             score_detail  \
# 12129  [{'dimension_name': 'fundamental', 'indicators...
#
#                                          score_dimension  \
# 12129  {'fundamental': 17.543432651, 'fundamental_rat...
#
#                                          original_detail     created_at  \
# 12129  {'active_inventor_ratio': 0.0, 'actual_capital...  1655812532000
#
#           updated_at  company_name   score_05 rating_lv2_05
# 12129  1655812532000  北京字节跳动科技有限公司  84.257371             A

# %%
group_score[group_score['rating_lv2_05']!=group_score['rating_lv2_06']]
# Out:
#                              company_id   score_06 rating rating_lv2_06  \
# 29     31EA7CD84C244E952CFB76C94CB8977D  24.105699      B             B
# 35     36CBA919AD30D602E5AFDE03B7D63B44  40.951494      A             A
# 36     36F9C6D208AF903D9DDF8FB739008E23  31.462543      A             A
# 38     3A5129E1336943EEB9B50F4034CA0BD4  23.149992      B             B
# 41     3C997ECEE6323E01C5A4B100EEDF4A73  19.808628      C             C
# ...                                 ...        ...    ...           ...
# 63853  B4A5F20A35B76D8F4E35CD8FA9FDA294  35.690889      B             A
# 63866  C9D0231140B3E8115AC66F1B94CC8D9B  19.895029      B             B
# 63879  E015A0286FC6E30AA65E66F9BAF9DA8B  17.341142      C             C
# 63886  EB7285AE7252741ED3675E3191C43353  29.940508      B             B
# 63890  F2067B080E94199D18EC8394477A35B0  12.966615      D             D
#
#                                             score_detail  \
# ...
