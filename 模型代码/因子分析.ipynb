# %%
import pandas as pd
from sqlalchemy import create_engine
engine_retrain=create_engine('mysql+pymysql://company:company@192.168.16.244/company_retrain',echo=False)

# %% [markdown]
# # 原始值

# %%
test_quanguo_original=pd.read_sql('select * from v230_original',con=engine_retrain)

# %%
test_quanguo_original
# Out:
#                                company_id  joint_application_cnt  \
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F                      0
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E                      2
# 2        0027683A8AB4217205D5BE751D3A6D4E                      0
# 3        0034953AE8F88E6DD07C2809226C2A17                      0
# 4        003D83E767259BB08EC3F13BA588C53D                      0
# ...                                   ...                    ...
# 1077642  FF7923665B15F13461D87DDA4D3E282E                      0
# 1077643  FF985ECAFEB9221E6A1938ED023E7A4E                      0
# 1077644  FF99E88C41B48D6536FE40EBDDD72CEC                      0
# 1077645  FFBED44A7463AA6EE49D5DC46C5A8F17                      0
# 1077646  FFF18DDED6DDE300664F9F5916AF3353                      0
#
#          granted_invention_cnt_pb_original_2y  \
# 0                                           0
# 1                                           0
# ...

# %%
test_quanguo_original[['company_id','value_sum']]
# Out:
#                                company_id  value_sum
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F     7200.0
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E    98100.0
# 2        0027683A8AB4217205D5BE751D3A6D4E    69200.0
# 3        0034953AE8F88E6DD07C2809226C2A17        NaN
# 4        003D83E767259BB08EC3F13BA588C53D    46900.0
# ...                                   ...        ...
# 1077642  FF7923665B15F13461D87DDA4D3E282E        NaN
# 1077643  FF985ECAFEB9221E6A1938ED023E7A4E        NaN
# 1077644  FF99E88C41B48D6536FE40EBDDD72CEC        NaN
# 1077645  FFBED44A7463AA6EE49D5DC46C5A8F17     6600.0
# 1077646  FFF18DDED6DDE300664F9F5916AF3353     6900.0
#
# [1077647 rows x 2 columns]

# %%
test_quanguo_original[['value_sum']].min()
# Out:
# value_sum    3100.0
# dtype: float64

# %%
test_quanguo_original[['value_sum']].boxplot()
# Out:
# <AxesSubplot:>

# %%
alpha=1.5
seg_25=test_quanguo_original[['avg_remaining_life_span']].quantile(0.25)
seg_75=test_quanguo_original[['avg_remaining_life_span']].quantile(0.75)
up_limit=seg_75+(seg_75-seg_25)*alpha
low_limit=seg_25-(seg_75-seg_25)*alpha

# %%
seg_25
# Out:
# avg_remaining_life_span    7.387671
# Name: 0.25, dtype: float64

# %%
seg_75
# Out:
# avg_remaining_life_span    9.408524
# Name: 0.75, dtype: float64

# %%
low_limit
# Out:
# avg_remaining_life_span    4.356393
# dtype: float64

# %%
up_limit
# Out:
# avg_remaining_life_span    12.439802
# dtype: float64
