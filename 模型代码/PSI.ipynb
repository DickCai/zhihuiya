# %%
import pandas as pd
import numpy as np
import os
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/测试样本/科创模型/测试集')
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company_retrain',echo=False)

# %% [markdown]
# # 分数

# %% [markdown]
# ## test_quanguo_202204_score

# %%
test_quanguo_202204_score=pd.read_sql('select * from test_quanguo_202204_score',con=engine)
test_quanguo_202204_score
# Out:
#                                company_id      company_name   seic_lv1  \
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F  山东普时达创电子商务集团有限公司         其它
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E      广东科建生物技术有限公司       生物产业
# 2        0027683A8AB4217205D5BE751D3A6D4E        杭州乙对纺织有限公司         其它
# 3        0034953AE8F88E6DD07C2809226C2A17       什邡艾美墅家居有限公司         其它
# 4        003D83E767259BB08EC3F13BA588C53D      佛山五合精密科技有限公司   高端装备制造产业
# ...                                   ...               ...        ...
# 1052035  FED7E3FAC46D1723AFFBE0FDFE415EF9    西安新济铁路机车配件有限公司   高端装备制造产业
# 1052036  FF41E884CA1DCE7CF71AE2905EAB3457      江苏迅杰环境工程有限公司     节能环保产业
# 1052037  FF828D60E29A82AAEC71B2E221B21C4D   深圳市盛俊智能家居科技有限公司  新一代信息技术产业
# 1052038  FFB8D187EF1495AE8D841BB8EFD7A970    宁波司普瑞茵通信技术有限公司  新一代信息技术产业
# 1052039  FFF08C781D50E5DDF36A0F6232CFBBAE    福建石全石美新型材料有限公司      新材料产业
#
#           seic_lv2 province city  apno_cnt  status     patent  nonpatent  \
# ...

# %% [markdown]
# ## test_quanguo_202205_score

# %%
test_quanguo_score=pd.read_sql('select * from test_quanguo_score',con=engine)
test_quanguo_score
# Out:
#                                company_id       company_name   seic_lv1  \
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F   山东普时达创电子商务集团有限公司         其它
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E       广东科建生物技术有限公司       生物产业
# 2        0027683A8AB4217205D5BE751D3A6D4E         杭州乙对纺织有限公司         其它
# 3        0034953AE8F88E6DD07C2809226C2A17        什邡艾美墅家居有限公司         其它
# 4        003D83E767259BB08EC3F13BA588C53D       佛山五合精密科技有限公司   高端装备制造产业
# ...                                   ...                ...        ...
# 1077642  FF7923665B15F13461D87DDA4D3E282E       安徽路坦建设集团有限公司         其它
# 1077643  FF985ECAFEB9221E6A1938ED023E7A4E        南海海欣长毛绒有限公司         其它
# 1077644  FF99E88C41B48D6536FE40EBDDD72CEC     青岛赛微瑞云信息科技有限公司  新一代信息技术产业
# 1077645  FFBED44A7463AA6EE49D5DC46C5A8F17           锦明电气有限公司      新能源产业
# 1077646  FFF18DDED6DDE300664F9F5916AF3353  徐州宣鼎智能安防科技研究院有限公司  新一代信息技术产业
#
#               seic_lv2 province city  apno_cnt  status     patent  nonpatent  \
# ...

# %% [markdown]
# # 测试集

# %%
test=pd.read_excel('科创模型测试集.xlsx')
test
# Out:
#        company_name  label   source         source_list  level     clean_name  \
# 0     京东方科技集团股份有限公司      1  Polaris  ['Polaris', '启信宝']      2  京东方科技集团股份有限公司
# 1      浙江中控技术股份有限公司      1  Polaris  ['Polaris', '科创板']      2   浙江中控技术股份有限公司
# 2          华为技术有限公司      1  Polaris  ['Polaris', '启信宝']      2       华为技术有限公司
# 3        科大讯飞股份有限公司      1  Polaris         ['Polaris']      1     科大讯飞股份有限公司
# 4      珠海格力电器股份有限公司      1  Polaris  ['Polaris', '启信宝']      2   珠海格力电器股份有限公司
# ...             ...    ...      ...                 ...    ...            ...
# 2114   大连金砣水产食品有限公司      0   科技含金量低          ['科技含金量低']      1   大连金砣水产食品有限公司
# 2115     辽阳艺蒙织毯有限公司      0   科技含金量低          ['科技含金量低']      1     辽阳艺蒙织毯有限公司
# 2116   丹东优耐特纺织品有限公司      0   科技含金量低          ['科技含金量低']      1   丹东优耐特纺织品有限公司
# 2117   浙江玉帛纺织股份有限公司      0   科技含金量低          ['科技含金量低']      1   浙江玉帛纺织股份有限公司
# 2118     江苏宇顺纺织有限公司      0   科技含金量低          ['科技含金量低']      1     江苏宇顺纺织有限公司
#
# ...

# %%
test=pd.merge(test,test_quanguo_202204_score[['company_id','rating_seic_lv2']],on='company_id')
test
# Out:
#        company_name  label   source         source_list  level     clean_name  \
# 0     京东方科技集团股份有限公司      1  Polaris  ['Polaris', '启信宝']      2  京东方科技集团股份有限公司
# 1      浙江中控技术股份有限公司      1  Polaris  ['Polaris', '科创板']      2   浙江中控技术股份有限公司
# 2          华为技术有限公司      1  Polaris  ['Polaris', '启信宝']      2       华为技术有限公司
# 3        科大讯飞股份有限公司      1  Polaris         ['Polaris']      1     科大讯飞股份有限公司
# 4      珠海格力电器股份有限公司      1  Polaris  ['Polaris', '启信宝']      2   珠海格力电器股份有限公司
# ...             ...    ...      ...                 ...    ...            ...
# 2113   大连金砣水产食品有限公司      0   科技含金量低          ['科技含金量低']      1   大连金砣水产食品有限公司
# 2114     辽阳艺蒙织毯有限公司      0   科技含金量低          ['科技含金量低']      1     辽阳艺蒙织毯有限公司
# 2115   丹东优耐特纺织品有限公司      0   科技含金量低          ['科技含金量低']      1   丹东优耐特纺织品有限公司
# 2116   浙江玉帛纺织股份有限公司      0   科技含金量低          ['科技含金量低']      1   浙江玉帛纺织股份有限公司
# 2117     江苏宇顺纺织有限公司      0   科技含金量低          ['科技含金量低']      1     江苏宇顺纺织有限公司
#
# ...

# %%
test=pd.merge(test,test_quanguo_score[['company_id','rating_seic_lv2']],on='company_id',suffixes=['_actual','_expect'])
test
# Out:
#        company_name  label   source         source_list  level     clean_name  \
# 0     京东方科技集团股份有限公司      1  Polaris  ['Polaris', '启信宝']      2  京东方科技集团股份有限公司
# 1      浙江中控技术股份有限公司      1  Polaris  ['Polaris', '科创板']      2   浙江中控技术股份有限公司
# 2          华为技术有限公司      1  Polaris  ['Polaris', '启信宝']      2       华为技术有限公司
# 3        科大讯飞股份有限公司      1  Polaris         ['Polaris']      1     科大讯飞股份有限公司
# 4      珠海格力电器股份有限公司      1  Polaris  ['Polaris', '启信宝']      2   珠海格力电器股份有限公司
# ...             ...    ...      ...                 ...    ...            ...
# 2113   大连金砣水产食品有限公司      0   科技含金量低          ['科技含金量低']      1   大连金砣水产食品有限公司
# 2114     辽阳艺蒙织毯有限公司      0   科技含金量低          ['科技含金量低']      1     辽阳艺蒙织毯有限公司
# 2115   丹东优耐特纺织品有限公司      0   科技含金量低          ['科技含金量低']      1   丹东优耐特纺织品有限公司
# 2116   浙江玉帛纺织股份有限公司      0   科技含金量低          ['科技含金量低']      1   浙江玉帛纺织股份有限公司
# 2117     江苏宇顺纺织有限公司      0   科技含金量低          ['科技含金量低']      1     江苏宇顺纺织有限公司
#
# ...

# %%
actual=pd.DataFrame(test['rating_seic_lv2_actual'].value_counts()).reset_index()
expect=pd.DataFrame(test['rating_seic_lv2_expect'].value_counts()).reset_index()
actual.rename(columns={'index':'Score_bands','rating_seic_lv2_actual':'actual'},inplace=True)
expect.rename(columns={'index':'Score_bands','rating_seic_lv2_expect':'expect'},inplace=True)
psi_df=pd.merge(actual,expect,on='Score_bands')
psi_df['actual_rate'] = (psi_df['actual'] + 1) / psi_df['actual'].sum()#计算占比，分子加1，防止计算PSI时分子分母为0
psi_df['expect_rate'] = (psi_df['expect'] + 1) / psi_df['expect'].sum()
psi_df['psi'] = (psi_df['actual_rate'] - psi_df['expect_rate']) * np.log(
psi_df['actual_rate'] / psi_df['expect_rate'])
psi = psi_df['psi'].sum()
