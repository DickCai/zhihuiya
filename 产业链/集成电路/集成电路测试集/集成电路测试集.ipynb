# %%
import pandas as pd
import os
pd.set_option('max_columns',100)
pd.set_option('max_rows',100)
os.chdir(r'/Users/caicaiqijun/智慧牙/数据/全国数据/产业链/集成电路产业链/集成电路测试集')
from sqlalchemy import create_engine
from data_nlp_nameclean.clean.cleaning import cleanup_entity
engine_chain=create_engine('mysql+pymysql://company:company@192.168.16.244/company_v23',echo=False)

# %% [markdown]
# # 集成电路测试集

# %%
ic_test=pd.read_excel("集成电路产业链.xlsx")
ic_test.drop('company_id',axis=1,inplace=True)
ic_test
# Out:
#      node_name       company_name  是否本节点 node_name_check  是否集成电路相关  \
# 0       集成电路制造         北大方正集团有限公司      0              其它         1
# 1       集成电路制造    上海华虹宏力半导体制造有限公司      1          集成电路制造         1
# 2       集成电路制造        无锡迪思微电子有限公司      1          集成电路制造         1
# 3       集成电路制造      上海新安纳电子科技有限公司      1          集成电路制造         1
# 4       集成电路制造     郑州光力瑞弘电子科技有限公司      1          集成电路制造         1
# ...        ...                ...    ...             ...       ...
# 1657       光刻胶     北京中科飞鸿科技股份有限公司      1             光刻胶         1
# 1658       光刻胶       湖南启泰传感科技有限公司      1             光刻胶         1
# 1659       光刻胶      北京欣奕华材料科技有限公司      1             光刻胶         0
# 1660       光刻胶  盛美半导体设备（上海）股份有限公司      1             光刻胶         1
# 1661       光刻胶         上海稷以科技有限公司      1             光刻胶         1
#
#            node_id
# 0     ND0000000002
# 1     ND0000000002
# 2     ND0000000002
# 3     ND0000000002
# 4     ND0000000002
# ...            ...
# ...

# %%
ic_test['company_name']=ic_test['company_name'].apply(lambda x:cleanup_entity(x))
ic_test
# Out:
#      node_name     company_name  是否本节点 node_name_check  是否集成电路相关       node_id
# 0       集成电路制造       北大方正集团有限公司      0              其它         1  ND0000000002
# 1       集成电路制造  上海华虹宏力半导体制造有限公司      1          集成电路制造         1  ND0000000002
# 2       集成电路制造      无锡迪思微电子有限公司      1          集成电路制造         1  ND0000000002
# 3       集成电路制造    上海新安纳电子科技有限公司      1          集成电路制造         1  ND0000000002
# 4       集成电路制造   郑州光力瑞弘电子科技有限公司      1          集成电路制造         1  ND0000000002
# ...        ...              ...    ...             ...       ...           ...
# 1657       光刻胶   北京中科飞鸿科技股份有限公司      1             光刻胶         1  ND0000000412
# 1658       光刻胶     湖南启泰传感科技有限公司      1             光刻胶         1  ND0000000413
# 1659       光刻胶    北京欣奕华材料科技有限公司      1             光刻胶         0  ND0000000414
# 1660       光刻胶  盛美半导体设备上海股份有限公司      1             光刻胶         1  ND0000000415
# 1661       光刻胶       上海稷以科技有限公司      1             光刻胶         1  ND0000000416
#
# [1662 rows x 6 columns]

# %% [markdown]
# # 全国数据

# %%
test_quanguo_ficoscore=pd.read_sql('select * from test_quanguo_ficoscore',con=engine_chain)
test_quanguo_ficoscore
# Out:
#                                company_id      company_name       tffi  \
# 0        0139C87DB0780832486E85D0EA8C4F96        广东维锐电器有限公司   7.090851
# 1        017DBD040AA44BF1A7BC8D8DF6EAA4A4  北京益泰牡丹电子工程有限责任公司  28.888453
# 2        03C86219FFB74036706201F2A90ADBEC      安宇（长泰）工贸有限公司  14.353274
# 3        0541622B8798C48785C76E303EEC7C9C      深圳市邦仕达科技有限公司   3.499896
# 4        05BCC1C6896C17FD3AA9F03D434A9DCA        湖北臻猪科技有限公司  20.634069
# ...                                   ...               ...        ...
# 1099403  F7934CD5EAE2DD4EFDE56F12FF679C9F      厦门国际银行股份有限公司  45.289259
# 1099404  F7D039CF0BF31E7C16B44F65923A4D1B     广州壹夹壹信息科技有限公司   4.963876
# 1099405  FB8D3616B0D31E0D390AC08FAEA33782      浙江卓凡印刷科技有限公司  29.866931
# 1099406  FC6B054A9CA8052E9D1794690D31A9B3      上海致菱金属制品有限公司  11.246454
# 1099407  FCDDC9EF84792690A5BBF95AAB5972CA      中旅国际会议展览有限公司   1.344736
#
#                fico 调整等距分箱
# 0        338.999681     CC
# 1        458.886492      B
# 2        378.943006    CCC
# ...

# %%
test_quanguo_ficoscore['company_name']=test_quanguo_ficoscore['company_name'].apply(lambda x:cleanup_entity(x))
test_quanguo_ficoscore
# Out:
#                                company_id      company_name       tffi  \
# 0        0139C87DB0780832486E85D0EA8C4F96        广东维锐电器有限公司   7.090851
# 1        017DBD040AA44BF1A7BC8D8DF6EAA4A4  北京益泰牡丹电子工程有限责任公司  28.888453
# 2        03C86219FFB74036706201F2A90ADBEC        安宇长泰工贸有限公司  14.353274
# 3        0541622B8798C48785C76E303EEC7C9C      深圳市邦仕达科技有限公司   3.499896
# 4        05BCC1C6896C17FD3AA9F03D434A9DCA        湖北臻猪科技有限公司  20.634069
# ...                                   ...               ...        ...
# 1099403  F7934CD5EAE2DD4EFDE56F12FF679C9F      厦门国际银行股份有限公司  45.289259
# 1099404  F7D039CF0BF31E7C16B44F65923A4D1B     广州壹夹壹信息科技有限公司   4.963876
# 1099405  FB8D3616B0D31E0D390AC08FAEA33782      浙江卓凡印刷科技有限公司  29.866931
# 1099406  FC6B054A9CA8052E9D1794690D31A9B3      上海致菱金属制品有限公司  11.246454
# 1099407  FCDDC9EF84792690A5BBF95AAB5972CA      中旅国际会议展览有限公司   1.344736
#
#                fico 调整等距分箱
# 0        338.999681     CC
# 1        458.886492      B
# 2        378.943006    CCC
# ...

# %% [markdown]
# # 合并

# %%
result=pd.merge(ic_test,test_quanguo_ficoscore[['company_id','company_name']],how='left',on='company_name')
result
# Out:
#      node_name     company_name  是否本节点 node_name_check  是否集成电路相关  \
# 0       集成电路制造       北大方正集团有限公司      0              其它         1
# 1       集成电路制造  上海华虹宏力半导体制造有限公司      1          集成电路制造         1
# 2       集成电路制造      无锡迪思微电子有限公司      1          集成电路制造         1
# 3       集成电路制造    上海新安纳电子科技有限公司      1          集成电路制造         1
# 4       集成电路制造   郑州光力瑞弘电子科技有限公司      1          集成电路制造         1
# ...        ...              ...    ...             ...       ...
# 1657       光刻胶   北京中科飞鸿科技股份有限公司      1             光刻胶         1
# 1658       光刻胶     湖南启泰传感科技有限公司      1             光刻胶         1
# 1659       光刻胶    北京欣奕华材料科技有限公司      1             光刻胶         0
# 1660       光刻胶  盛美半导体设备上海股份有限公司      1             光刻胶         1
# 1661       光刻胶       上海稷以科技有限公司      1             光刻胶         1
#
#            node_id                        company_id
# 0     ND0000000002  9901DDF37543E7D453249E71B4D18D9B
# 1     ND0000000002  DDE01F033C69D7C5348E3F40F62A98CE
# ...

# %%
result=result[result['company_id'].notnull()]

# %%
result.to_excel("集成电路产业链.xlsx",encoding='utf-8',index=False)

# %%
result
# Out:
#      node_name     company_name  是否本节点 node_name_check  是否集成电路相关  \
# 0       集成电路制造       北大方正集团有限公司      0              其它         1
# 1       集成电路制造  上海华虹宏力半导体制造有限公司      1          集成电路制造         1
# 2       集成电路制造      无锡迪思微电子有限公司      1          集成电路制造         1
# 3       集成电路制造    上海新安纳电子科技有限公司      1          集成电路制造         1
# 4       集成电路制造   郑州光力瑞弘电子科技有限公司      1          集成电路制造         1
# ...        ...              ...    ...             ...       ...
# 1657       光刻胶   北京中科飞鸿科技股份有限公司      1             光刻胶         1
# 1658       光刻胶     湖南启泰传感科技有限公司      1             光刻胶         1
# 1659       光刻胶    北京欣奕华材料科技有限公司      1             光刻胶         0
# 1660       光刻胶  盛美半导体设备上海股份有限公司      1             光刻胶         1
# 1661       光刻胶       上海稷以科技有限公司      1             光刻胶         1
#
#            node_id                        company_id
# 0     ND0000000002  9901DDF37543E7D453249E71B4D18D9B
# 1     ND0000000002  DDE01F033C69D7C5348E3F40F62A98CE
# ...

# %%
result.drop_duplicates(subset=['company_id','node_id'],inplace=True)
# Out:
# /Users/caicaiqijun/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
