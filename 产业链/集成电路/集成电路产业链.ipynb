# %%
import pandas as pd
import os
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/industry_chain',echo=False)
pd.set_option('max_rows',200)
pd.set_option('max_columns',200)
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
from data_nlp_nameclean.clean.cleaning import cleanup_entity
from sklearn.metrics import classification_report

# %% [markdown]
# # 专利

# %% [markdown]
# ## INDUSTRY_all_patent_info

# %%
INDUSTRY_all_patent_info=pd.read_sql('select * from INDUSTRY_all_patent_info_2steps',con=engine)

# %%
INDUSTRY_all_patent_info
# Out:
#                                     patent_id  valid_indicator  \
# 0        fd975de9-23bd-497e-8044-161f0fb042bd                1
# 1        c3920a60-135d-4ec5-9d83-88d8cf8b5954                0
# 2        df42792c-84a8-428e-8a08-d27902bf93da                1
# 3        b953b6df-b63e-41dc-8c9a-db2877252840                1
# 4        2d5ee6b3-e6e2-4c78-8bd0-e98d217f15e1                1
# ...                                       ...              ...
# 3909188  6d002a55-897c-4020-83a3-967de9294a4f                1
# 3909189  aaacd858-8fa1-4847-b15d-991935505353                0
# 3909190  728a2e6d-f41f-42b3-ad4b-b66789f80d61                0
# 3909191  1ab7a14c-f9ff-40a7-9c9c-c984fa59e9b1                1
# 3909192  e0e8056d-f236-4013-819e-7cc4ce78d5d5                1
#
#                                           tech_topic_array  \
# 0                  [工程学, 有源设备, 负功率, 静电放电, 威化, 电气电子工程, 接地层]
# 1                          [工程学, 平面阵列, 图像传感器, 电气电子工程, 对角线]
# ...

# %%
INDUSTRY_all_patent_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681638 entries, 0 to 5681637
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   node_id          object
#  1   node_name        object
#  2   patent_id        object
#  3   valid_indicator  int64
#  4   ans_id           object
#  5   apno             object
#  6   tech_topic       object
#  7   app_domain       object
#  8   patent_seic2     object
# dtypes: int64(1), object(8)
# memory usage: 390.1+ MB

# %% [markdown]
# ### valid_indicator_1

# %%
valid_indicator_1=INDUSTRY_all_patent_info[INDUSTRY_all_patent_info['valid_indicator']==1]

# %%
valid_indicator_1
# Out:
#                                     patent_id  valid_indicator  \
# 0        fd975de9-23bd-497e-8044-161f0fb042bd                1
# 2        df42792c-84a8-428e-8a08-d27902bf93da                1
# 3        b953b6df-b63e-41dc-8c9a-db2877252840                1
# 4        2d5ee6b3-e6e2-4c78-8bd0-e98d217f15e1                1
# 5        b80707eb-b4a8-4013-b4bd-af16b9794c0a                1
# ...                                       ...              ...
# 3909186  c6871f9a-8d3e-486a-b173-998f016c8998                1
# 3909187  35a6091b-42a4-41bd-ba9a-38b986a6c529                1
# 3909188  6d002a55-897c-4020-83a3-967de9294a4f                1
# 3909191  1ab7a14c-f9ff-40a7-9c9c-c984fa59e9b1                1
# 3909192  e0e8056d-f236-4013-819e-7cc4ce78d5d5                1
#
#                                           tech_topic_array  \
# 0                  [工程学, 有源设备, 负功率, 静电放电, 威化, 电气电子工程, 接地层]
# 2                                     [标准单元, 工程学, 导体, 半导体]
# ...

# %%
import re

# %%
#pattern = r'[A-Z]+.+[0-9A-Z]+'
valid_indicator_1['apno']=valid_indicator_1['apno_array'].str.extract(r'([A-Z]+.+[0-9A-Z]+)',expand=True)

# %%
valid_indicator_1
# Out:
#                                     patent_id  valid_indicator  \
# 0        fd975de9-23bd-497e-8044-161f0fb042bd                1
# 2        df42792c-84a8-428e-8a08-d27902bf93da                1
# 3        b953b6df-b63e-41dc-8c9a-db2877252840                1
# 4        2d5ee6b3-e6e2-4c78-8bd0-e98d217f15e1                1
# 5        b80707eb-b4a8-4013-b4bd-af16b9794c0a                1
# ...                                       ...              ...
# 3909186  c6871f9a-8d3e-486a-b173-998f016c8998                1
# 3909187  35a6091b-42a4-41bd-ba9a-38b986a6c529                1
# 3909188  6d002a55-897c-4020-83a3-967de9294a4f                1
# 3909191  1ab7a14c-f9ff-40a7-9c9c-c984fa59e9b1                1
# 3909192  e0e8056d-f236-4013-819e-7cc4ce78d5d5                1
#
#                                           tech_topic_array  \
# 0                  [工程学, 有源设备, 负功率, 静电放电, 威化, 电气电子工程, 接地层]
# 2                                     [标准单元, 工程学, 导体, 半导体]
# ...

# %% [markdown]
# ### 测试数据

# %%
patent_test=pd.read_excel('/Users/caicaiqijun/智慧牙/数据/全国数据/产业链/2月结果/专利/专利精准测试数据.xlsx',sheet_name='Sheet2')

# %%
patent_test
# Out:
#      结果  人工标注       node_id node_name                  apno   备注
# 0    TP     1  ND0000000001    集成电路设计  ['CN201910308673.6']  NaN
# 1    TP     1  ND0000000001    集成电路设计  ['CN202010567174.1']  NaN
# 2    TP     1  ND0000000001    集成电路设计  ['CN202110141281.2']  NaN
# 3    TP     1  ND0000000001    集成电路设计  ['CN201980095557.9']  NaN
# 4    TP     1  ND0000000001    集成电路设计  ['CN202010523041.4']  NaN
# ..   ..   ...           ...       ...                   ...  ...
# 304  TP     1  ND0000000018     光刻掩膜版  ['CN201811466801.1']  NaN
# 305  TP     1  ND0000000061    化学气相沉积  ['CN201810064973.X']  NaN
# 306  TP     1  ND0000000062      外延工艺  ['CN202110055878.5']  NaN
# 307  TP     1  ND0000000002    集成电路制造  ['CN201911291628.0']  NaN
# 308  TP     1  ND0000000055       遮光膜  ['CN200710169221.1']  NaN
#
# [309 rows x 6 columns]

# %%
patent_test['apno']=patent_test['apno'].str.extract(r'([A-Z]+.+[0-9A-Z]+)',expand=True)

# %%
patent_test
# Out:
#      结果  人工标注       node_id node_name              apno   备注
# 0    TP     1  ND0000000001    集成电路设计  CN201910308673.6  NaN
# 1    TP     1  ND0000000001    集成电路设计  CN202010567174.1  NaN
# 2    TP     1  ND0000000001    集成电路设计  CN202110141281.2  NaN
# 3    TP     1  ND0000000001    集成电路设计  CN201980095557.9  NaN
# 4    TP     1  ND0000000001    集成电路设计  CN202010523041.4  NaN
# ..   ..   ...           ...       ...               ...  ...
# 304  TP     1  ND0000000018     光刻掩膜版  CN201811466801.1  NaN
# 305  TP     1  ND0000000061    化学气相沉积  CN201810064973.X  NaN
# 306  TP     1  ND0000000062      外延工艺  CN202110055878.5  NaN
# 307  TP     1  ND0000000002    集成电路制造  CN201911291628.0  NaN
# 308  TP     1  ND0000000055       遮光膜  CN200710169221.1  NaN
#
# [309 rows x 6 columns]

# %%
patent.to_excel('/Users/caicaiqijun/智慧牙/数据/全国数据/产业链/2月结果/专利/patent_test.xlsx')

# %%
patent_test.drop_duplicates(subset=['apno'],inplace=True)

# %%
patent=pd.merge(patent_test,valid_indicator_1[['apno','patent_id']],how='left',on='apno')

# %%
patent
# Out:
#      结果  人工标注       node_id node_name              apno   备注  \
# 0    TP     1  ND0000000001    集成电路设计  CN201910308673.6  NaN
# 1    TP     1  ND0000000001    集成电路设计  CN201910308673.6  NaN
# 2    TP     1  ND0000000001    集成电路设计  CN202010567174.1  NaN
# 3    TP     1  ND0000000001    集成电路设计  CN202110141281.2  NaN
# 4    TP     1  ND0000000001    集成电路设计  CN201980095557.9  NaN
# ..   ..   ...           ...       ...               ...  ...
# 321  TP     1  ND0000000062      外延工艺  CN202110055878.5  NaN
# 322  TP     1  ND0000000002    集成电路制造  CN201911291628.0  NaN
# 323  TP     1  ND0000000002    集成电路制造  CN201911291628.0  NaN
# 324  TP     1  ND0000000055       遮光膜  CN200710169221.1  NaN
# 325  TP     1  ND0000000055       遮光膜  CN200710169221.1  NaN
#
#                                 patent_id
# 0    921878a7-a3e4-4a07-ba60-37b96b426f45
# 1    7849bfec-330f-45b7-b537-4b313146152f
# 2    9f0ddd76-70a8-4527-9ff1-d2c763737e32
# 3    e11fcf16-2c2c-4897-b48a-e5d2a81b143a
# ...

# %%
patent.drop_duplicates(subset=['apno'],inplace=True)

# %%
patent
# Out:
#      结果  人工标注       node_id node_name              apno   备注  \
# 0    TP     1  ND0000000001    集成电路设计  CN201910308673.6  NaN
# 2    TP     1  ND0000000001    集成电路设计  CN202010567174.1  NaN
# 3    TP     1  ND0000000001    集成电路设计  CN202110141281.2  NaN
# 4    TP     1  ND0000000001    集成电路设计  CN201980095557.9  NaN
# 5    TP     1  ND0000000001    集成电路设计  CN202010523041.4  NaN
# ..   ..   ...           ...       ...               ...  ...
# 319  TP     1  ND0000000018     光刻掩膜版  CN201811466801.1  NaN
# 320  TP     1  ND0000000061    化学气相沉积  CN201810064973.X  NaN
# 321  TP     1  ND0000000062      外延工艺  CN202110055878.5  NaN
# 322  TP     1  ND0000000002    集成电路制造  CN201911291628.0  NaN
# 324  TP     1  ND0000000055       遮光膜  CN200710169221.1  NaN
#
#                                 patent_id
# 0    921878a7-a3e4-4a07-ba60-37b96b426f45
# 2    9f0ddd76-70a8-4527-9ff1-d2c763737e32
# 3    e11fcf16-2c2c-4897-b48a-e5d2a81b143a
# 4    ab91b196-88c1-42bc-9bde-4f5b02540d2c
# ...

# %%
patent.to_excel('/Users/caicaiqijun/智慧牙/数据/全国数据/产业链/2月结果/专利/专利精准测试数据_step2.xlsx')

# %%
precesion=172/245
precesion
# Out:
# 0.7020408163265306

# %% [markdown]
# ### valid_indicator_0

# %%
valid_indicator_0=INDUSTRY_all_patent_info[INDUSTRY_all_patent_info['valid_indicator']==0]

# %%
valid_indicator_0
# Out:
#               node_id node_name                             patent_id  \
# 0        ND0000000001    集成电路设计  b4db690a-8510-490e-aef0-6f448230d3fe
# 1        ND0000000001    集成电路设计  4bf5c094-57a3-44a1-9764-a212d3cae9aa
# 6        ND0000000001    集成电路设计  c6ff10c9-1cc9-4f2c-b3a9-83cc98ddb58f
# 8        ND0000000001    集成电路设计  ae3e8338-bc31-4ba5-86b3-60f35034b0f8
# 10       ND0000000001    集成电路设计  39f8fd2d-e844-4add-8937-84f21f414a39
# ...               ...       ...                                   ...
# 7084350  ND0000000066  化学气相沉积设备  97126f43-5c66-41d0-8e84-377d26547288
# 7084358  ND0000000066  化学气相沉积设备  814081e0-7d8e-4d6a-9b1a-1aaa199baaf2
# 7084359  ND0000000066  化学气相沉积设备  0d9b4a92-1dc4-4252-8d6e-19bcfe320f8e
# 7084361  ND0000000066  化学气相沉积设备  a0abcfb3-223d-4c2a-b46e-84e77012957e
# 7084362  ND0000000066  化学气相沉积设备  2643fe0a-9480-42c8-bb08-2f1fa67e69c2
#
#          valid_indicator                                             ans_id  \
# ...

# %% [markdown]
# # 企业

# %% [markdown]
# ## INDUSTRY_all_company_info

# %%
INDUSTRY_all_company_info=pd.read_sql('select * from INDUSTRY_all_company_info',con=engine)

# %%
INDUSTRY_all_company_info
# Out:
#             node_id node_name                                ans_id  \
# 0      ND0000000001    集成电路设计  85edbea1-b9fc-4568-beba-27141216fe73
# 1      ND0000000002    集成电路制造  85edbea1-b9fc-4568-beba-27141216fe73
# 2      ND0000000003    集成电路封测  85edbea1-b9fc-4568-beba-27141216fe73
# 3      ND0000000012     EDA软件  85edbea1-b9fc-4568-beba-27141216fe73
# 4      ND0000000013       IP核  85edbea1-b9fc-4568-beba-27141216fe73
# ...             ...       ...                                   ...
# 78756  ND0000000063      紫外光刻  bd54191f-8755-4590-880d-9d50d8d1c453
# 78757  ND0000000063      紫外光刻  115d6c55-2ce6-4aba-9c81-1c59e7b25e0d
# 78758  ND0000000063      紫外光刻  47cdbecf-22f4-489c-99c8-42c6d378e341
# 78759  ND0000000063      紫外光刻  85ab2739-3d3d-4460-93ad-cef023317adb
# 78760  ND0000000063      紫外光刻  fd1afa7c-b25a-44ed-a05c-b6cdeff7bff2
#
#                              company_id        company_name province city  \
# 0      D0E66B822C3766EF90489D60BB5549E8  中芯国际集成电路制造（上海）有限公司      上海市  上海市
# ...

# %%
INDUSTRY_all_company_info[INDUSTRY_all_company_info['company_id']=='0D90E776BA2B80CD6A047A67195A706B']
# Out:
#             node_id node_name                                ans_id  \
# 60400  ND0000000035      成膜工艺  7727d6d5-b893-488a-ab14-525a0ddc6c35
# 60401  ND0000000037      刻蚀工艺  7727d6d5-b893-488a-ab14-525a0ddc6c35
#
#                              company_id    company_name province city  \
# 60400  0D90E776BA2B80CD6A047A67195A706B  苏州华亚智能科技股份有限公司      江苏省  苏州市
# 60401  0D90E776BA2B80CD6A047A67195A706B  苏州华亚智能科技股份有限公司      江苏省  苏州市
#
#       district seic_lv2                                        description  \
# 60400      相城区   电子核心产业  苏州华亚智能科技股份有限公司是由苏州华亚电讯设备有限公司股份制改造后更名而来，是华东地区的精...
# 60401      相城区   电子核心产业  苏州华亚智能科技股份有限公司是由苏州华亚电讯设备有限公司股份制改造后更名而来，是华东地区的精...
#
#                                           business_scope
# 60400  研发、生产、销售：精密金属结构件，精密组装件，半导体设备及仪器，轨道交通设备及配套装置，数字...
# 60401  研发、生产、销售：精密金属结构件，精密组装件，半导体设备及仪器，轨道交通设备及配套装置，数字...

# %%
0D90E776BA2B80CD6A047A67195A706B

# %%
INDUSTRY_all_company_info[INDUSTRY_all_company_info['node_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [node_id, node_name, ans_id, company_id, company_name, province, city, district, seic_lv2, description, business_scope]
# Index: []

# %% [markdown]
# ## INDUSTRY_all_company_info_step2

# %%
INDUSTRY_all_company_info_2steps=pd.read_sql('select * from INDUSTRY_all_company_info_2steps2',con=engine)

# %%
INDUSTRY_all_company_info_2steps.drop_duplicates(subset=['company_id'],inplace=True)

# %%
INDUSTRY_all_company_info_2steps
# Out:
#             node_id node_name                                ans_id  \
# 0      ND0000000001    集成电路设计                                  None
# 1      ND0000000001    集成电路设计  4fdc4e16-138d-11eb-ae5d-127dc0bbd678
# 2      ND0000000001    集成电路设计  85edbea1-b9fc-4568-beba-27141216fe73
# 3      ND0000000001    集成电路设计  fc207de8-0c5f-11ec-b499-da0c6317cd53
# 4      ND0000000001    集成电路设计  62a31e43-8beb-4324-bf32-fd6036b9868e
# ...             ...       ...                                   ...
# 55168  ND0000000063      紫外光刻  115d6c55-2ce6-4aba-9c81-1c59e7b25e0d
# 55205  ND0000000063      紫外光刻  47cdbecf-22f4-489c-99c8-42c6d378e341
# 55239  ND0000000063      紫外光刻  85ab2739-3d3d-4460-93ad-cef023317adb
# 55264  ND0000000063      紫外光刻  fd1afa7c-b25a-44ed-a05c-b6cdeff7bff2
# 55308  ND0000000064    纳米压印工艺  7e5c3c9c-8564-4a5a-ab49-7a5d6a6a8a60
#
#                              company_id        company_name province  city  \
# ...

# %%
INDUSTRY_all_company_info_2steps[INDUSTRY_all_company_info_2steps['company_id']=='0D90E776BA2B80CD6A047A67195A706B']
# Out:
# Empty DataFrame
# Columns: [node_id, node_name, ans_id, company_id, company_name, province, city, district, seic_lv2, description, business_scope]
# Index: []

# %% [markdown]
# ##  INDUSTRY_all_company_info_3steps

# %%
INDUSTRY_all_company_info_3steps=pd.read_sql('select * from INDUSTRY_all_company_info_3steps',con=engine)

# %%
INDUSTRY_all_company_info_3steps
# Out:
#           node_id node_name                                ans_id  \
# 0    ND0000000001    集成电路设计  77eaf636-9bdd-49b9-931b-2be9f5c705c5
# 1    ND0000000001    集成电路设计  73fa97fa-718c-4952-a882-68626752361f
# 2    ND0000000012     EDA软件  42d1f543-02a5-4a47-a90e-2be999ec8b88
# 3    ND0000000012     EDA软件  5472ad4d-81b5-4980-a574-dfecfbbed580
# 4    ND0000000012     EDA软件  d4b0cde0-1ce2-4069-bf99-0e3e7d0463fd
# ..            ...       ...                                   ...
# 636  ND0000000062      外延工艺  e33ccf34-b6c5-4be0-8680-13a7bc98d3ed
# 637  ND0000000062      外延工艺  62d11c16-4905-4a31-8f68-b854363d56fb
# 638  ND0000000062      外延工艺  230f4760-6a95-47dd-9f20-2c7f01ba3d48
# 639  ND0000000062      外延工艺  e950922b-2d86-4cbc-8533-bdda1af6aa59
# 640  ND0000000062      外延工艺  d8ec3de2-4c4e-4d13-8836-52059bceee7c
#
#                            company_id       company_name province city  \
# 0    300F0F79939130A2DC29B514D2132440     北京四方继保工程技术有限公司      北京市  北京市
# ...

# %% [markdown]
# ## 测试数据

# %%
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/产业链/集成电路产业链/2月结果/企业')

# %%
hs=pd.read_excel('集成电路测试数据_外部.xlsx')
hs.drop_duplicates(subset=['company_id'],inplace=True)
hs
# Out:
#                      企业名称     节点名称            clean_name  \
# 0           上海韦尔半导体股份有限公司     集成电路         上海韦尔半导体股份有限公司
# 1          上海艾为电子技术股份有限公司     集成电路        上海艾为电子技术股份有限公司
# 2           无锡芯朋微电子股份有限公司     集成电路         无锡芯朋微电子股份有限公司
# 3             瑞芯微电子股份有限公司     集成电路           瑞芯微电子股份有限公司
# 4              上海贝岭股份有限公司     集成电路            上海贝岭股份有限公司
# ..                    ...      ...                   ...
# 333     新阳硅密(上海)半导体技术有限公司  其他半导体设备       新阳硅密上海半导体技术有限公司
# 335  北京集智未来人工智能产业创新基地有限公司   其他集成电路  北京集智未来人工智能产业创新基地有限公司
# 336       江阴江化微电子材料股份有限公司   湿电子化学品       江阴江化微电子材料股份有限公司
# 337            浙江巨化股份有限公司   湿电子化学品            浙江巨化股份有限公司
# 338        山东阳谷华泰化工股份有限公司   湿电子化学品        山东阳谷华泰化工股份有限公司
#
#                            company_id  标注
# 0    2EBC8F1BF646152D9CCBD1499E2A89EC  测试
# 1    95BD9E3B6D17FD2B2736EEF3E830B0FE  测试
# 2    4F87A82BE34ABDC88833AE8F4178AE83  测试
# 3    48FF70877F21DDFA4635F2991357077F  测试
# 4    99B0CB7DDD2FCD670101AC8EAB20B1C2  测试
# ...

# %%
step2_company=pd.merge(hs,INDUSTRY_all_company_info_3steps,how='left',on='company_id')
step2_company
# Out:
#                      企业名称     节点名称            clean_name  \
# 0           上海韦尔半导体股份有限公司     集成电路         上海韦尔半导体股份有限公司
# 1          上海艾为电子技术股份有限公司     集成电路        上海艾为电子技术股份有限公司
# 2           无锡芯朋微电子股份有限公司     集成电路         无锡芯朋微电子股份有限公司
# 3             瑞芯微电子股份有限公司     集成电路           瑞芯微电子股份有限公司
# 4              上海贝岭股份有限公司     集成电路            上海贝岭股份有限公司
# ..                    ...      ...                   ...
# 258     新阳硅密(上海)半导体技术有限公司  其他半导体设备       新阳硅密上海半导体技术有限公司
# 259  北京集智未来人工智能产业创新基地有限公司   其他集成电路  北京集智未来人工智能产业创新基地有限公司
# 260       江阴江化微电子材料股份有限公司   湿电子化学品       江阴江化微电子材料股份有限公司
# 261            浙江巨化股份有限公司   湿电子化学品            浙江巨化股份有限公司
# 262        山东阳谷华泰化工股份有限公司   湿电子化学品        山东阳谷华泰化工股份有限公司
#
#                            company_id  标注 node_id node_name ans_id  \
# 0    2EBC8F1BF646152D9CCBD1499E2A89EC  测试     NaN       NaN    NaN
# 1    95BD9E3B6D17FD2B2736EEF3E830B0FE  测试     NaN       NaN    NaN
# 2    4F87A82BE34ABDC88833AE8F4178AE83  测试     NaN       NaN    NaN
# ...

# %%
step2_company.drop_duplicates(subset=['company_id'],inplace=True)

# %%
step2_company[step2_company['node_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [企业名称, 节点名称, clean_name, company_id, 标注, node_id, node_name, ans_id, company_name, province, city, district, seic_lv2, description, business_scope]
# Index: []

# %%
step2_company.to_excel('集成电路召回测试数据_step3.xlsx',encoding='utf-8',index=False)

# %%
a=159/263
a
# Out:
# 0.6045627376425855

# %% [markdown]
# ## result

# %%
result=pd.read_excel('result1.xlsx')

# %%
result
# Out:
#                      企业名称     节点名称            clean_name  \
# 0           上海韦尔半导体股份有限公司     集成电路         上海韦尔半导体股份有限公司
# 1          上海艾为电子技术股份有限公司     集成电路        上海艾为电子技术股份有限公司
# 2           无锡芯朋微电子股份有限公司     集成电路         无锡芯朋微电子股份有限公司
# 3             瑞芯微电子股份有限公司     集成电路           瑞芯微电子股份有限公司
# 4              上海贝岭股份有限公司     集成电路            上海贝岭股份有限公司
# ..                    ...      ...                   ...
# 258     新阳硅密(上海)半导体技术有限公司  其他半导体设备       新阳硅密上海半导体技术有限公司
# 259  北京集智未来人工智能产业创新基地有限公司   其他集成电路  北京集智未来人工智能产业创新基地有限公司
# 260       江阴江化微电子材料股份有限公司   湿电子化学品       江阴江化微电子材料股份有限公司
# 261            浙江巨化股份有限公司   湿电子化学品            浙江巨化股份有限公司
# 262        山东阳谷华泰化工股份有限公司   湿电子化学品        山东阳谷华泰化工股份有限公司
#
#                            company_id  标注  y_true  y_pre       node_id  \
# 0    2EBC8F1BF646152D9CCBD1499E2A89EC  测试       1      1  ND0000000001
# 1    95BD9E3B6D17FD2B2736EEF3E830B0FE  测试       1      1  ND0000000001
# ...

# %%
perform = pd.DataFrame(classification_report(result['y_true'].tolist(), result['y_pre'].tolist(), target_names=['正','负'], output_dict = 'dict')).transpose()

# %%
perform
# Out:
#               precision    recall  f1-score     support
# 正              0.000000  0.000000  0.000000    0.000000
# 负              1.000000  0.612167  0.759434  263.000000
# accuracy       0.612167  0.612167  0.612167    0.612167
# macro avg      0.500000  0.306084  0.379717  263.000000
# weighted avg   1.000000  0.612167  0.759434  263.000000

# %% [markdown]
# ## precision

# %%
precision=pd.read_excel('集成电路精准测试数据.xlsx')
precision
# Out:
#      结果  标注                                ans_id  \
# 0    TP   1  da3d4f65-9114-428e-9887-0d3a9a4022e7
# 1    TP   1  0aea3eee-8ba0-4966-8be2-e698fc61e45c
# 2    TP   0  1f856ea0-ae98-49a6-bf8e-284115c97ecc
# 3    TP   1  a3c21984-be4d-4a06-908a-ddd32469043d
# 4    TP   0  de4d35ad-0972-45ea-93fa-f0fa39d8cdf4
# 5    TP   0  156b802e-713a-4f94-9115-4280b323b8f4
# 6    TP   0  8ba70cad-1c33-4b47-b884-43acf7415bfc
# 7    TP   0  c7ea4aa5-75df-47ae-a8fe-11592d7538b1
# 8    FN   0  e028a7cd-d3fe-41d2-bd76-cebec5b17365
# 9    TP   1  b9542bfb-0726-4450-b20b-9a58fcd9fb7a
# 10   FN   0  df05d7f0-bcca-4bee-ace6-5976e4663d14
# 11   FN   1  e5363980-c54d-4393-8408-64060cd08c06
# 12   TP   0  aac4f1fd-b4f7-4958-be7f-b8554eedb5f3
# 13   FN   1  70411e59-4348-4351-9861-f5d420271e5b
# 14   FN   0  53642cae-1120-46ff-82c8-54ba18f07f80
# 15   FN   0  5f3077ac-f12c-4481-ab5d-842a08197c96
# 16   TP   1  41fb0d5e-b030-407f-ab1f-ee7c76195452
# 17   FN   0  5b117a72-5f32-4172-b732-d2c84d9b473c
# ...

# %%
result=pd.merge(precision,INDUSTRY_all_company_info_3steps[['company_id','node_id']],how='left',on='company_id')
result
# Out:
#      结果  标注                                ans_id  \
# 0    TP   1  da3d4f65-9114-428e-9887-0d3a9a4022e7
# 1    TP   1  0aea3eee-8ba0-4966-8be2-e698fc61e45c
# 2    TP   0  1f856ea0-ae98-49a6-bf8e-284115c97ecc
# 3    TP   1  a3c21984-be4d-4a06-908a-ddd32469043d
# 4    TP   0  de4d35ad-0972-45ea-93fa-f0fa39d8cdf4
# 5    TP   0  156b802e-713a-4f94-9115-4280b323b8f4
# 6    TP   0  8ba70cad-1c33-4b47-b884-43acf7415bfc
# 7    TP   0  c7ea4aa5-75df-47ae-a8fe-11592d7538b1
# 8    FN   0  e028a7cd-d3fe-41d2-bd76-cebec5b17365
# 9    TP   1  b9542bfb-0726-4450-b20b-9a58fcd9fb7a
# 10   FN   0  df05d7f0-bcca-4bee-ace6-5976e4663d14
# 11   FN   1  e5363980-c54d-4393-8408-64060cd08c06
# 12   TP   0  aac4f1fd-b4f7-4958-be7f-b8554eedb5f3
# 13   FN   1  70411e59-4348-4351-9861-f5d420271e5b
# 14   FN   0  53642cae-1120-46ff-82c8-54ba18f07f80
# 15   FN   0  5f3077ac-f12c-4481-ab5d-842a08197c96
# 16   TP   1  41fb0d5e-b030-407f-ab1f-ee7c76195452
# 17   FN   0  5b117a72-5f32-4172-b732-d2c84d9b473c
# ...

# %%
result[result['node_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [结果, 标注, ans_id, company_id, company_name, seic_lv2, description, business_scope, node_id]
# Index: []

# %%
result.to_excel('集成电路精准测试数据_step2.xlsx',encoding='utf-8',index=False)

# %%
pre=106/137
pre
# Out:
# 0.7737226277372263

# %%
reacll=0.6045627376425855
pre=0.7737226277372263
f1=(2*reacll*pre)/(reacll+pre)
f1
# Out:
# 0.6787620064034152
