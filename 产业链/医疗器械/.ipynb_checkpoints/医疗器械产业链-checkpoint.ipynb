# %%
import pandas as pd
import os
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/产业链/医疗器械产业链')
from sqlalchemy import create_engine
engine_chain=create_engine('mysql+pymysql://company:company@192.168.16.244/industry_chain')
engine_retrain=create_engine('mysql+pymysql://company:company@192.168.16.244/company_retrain')
from data_nlp_nameclean.clean.cleaning import cleanup_entity
pd.set_option('max_rows',100)
pd.set_option('max_columns',100)

# %% [markdown]
# # Company_v110

# %%
Company_v110=pd.read_sql('select * from INDUSTRY_med_equip_company_info_v110',con=engine_chain)

# %%
Company_v110
# Out:
#              node_id node_name                                ans_id  \
# 0       ND0000000176    有源手术器械  8d3da856-0c9b-11ec-9dcb-be62958b97c4
# 1       ND0000000176    有源手术器械  8ab16ffc-e50c-48a4-b00e-003eab99bbfc
# 2       ND0000000176    有源手术器械  a0218594-7ea0-44f6-9129-cde29513f772
# 3       ND0000000176    有源手术器械  1d5d12a1-5f7d-420d-8583-0a4f6342ae7d
# 4       ND0000000176    有源手术器械  f81c2f1e-06b3-4413-ad05-ddcd22912e0d
# ...              ...       ...                                   ...
# 129482  ND0000001007     洁净工作台  bae9b003-8412-4393-af8e-2b9c9fcdfb2f
# 129483  ND0000001007     洁净工作台  35bf20d6-8bcf-48e4-9626-c0e13b00d463
# 129484  ND0000001007     洁净工作台  d579f205-5f44-4ea2-8584-7e37a4c02f17
# 129485  ND0000001007     洁净工作台  27f59dfe-3ad4-415a-aab9-5724d68687f1
# 129486  ND0000001007     洁净工作台  c8e78c5d-c08b-4578-b50d-e56268363fb7
#
#                               company_id        company_name province  city  \
# ...

# %%
Company_v110.drop_duplicates(subset=['company_id'],inplace=True)

# %%
Company_v110
# Out:
#             node_id        node_name                                ans_id  \
# 0      ND0000000176           有源手术器械  8d3da856-0c9b-11ec-9dcb-be62958b97c4
# 1      ND0000000176           有源手术器械  8ab16ffc-e50c-48a4-b00e-003eab99bbfc
# 2      ND0000000176           有源手术器械  a0218594-7ea0-44f6-9129-cde29513f772
# 3      ND0000000176           有源手术器械  1d5d12a1-5f7d-420d-8583-0a4f6342ae7d
# 4      ND0000000176           有源手术器械  f81c2f1e-06b3-4413-ad05-ddcd22912e0d
# ...             ...              ...                                   ...
# 37317  ND0000000195           临床检验器械  ad99a39a-80fb-48d1-bb09-93ef5a96818e
# 37325  ND0000000195           临床检验器械  2c23a003-bce4-42d0-beb2-abe0f98a75a4
# 56190  ND0000000306            医用内窥镜  a335c914-aa66-4788-91ef-3eb6fca0751c
# 56337  ND0000000306            医用内窥镜  7c29d1c5-ce15-44ae-83c4-8a1720b2f79e
# 56912  ND0000000310  图像显示、处理、传输及打印设备  d765cafa-0988-11ec-95a4-127dc0bbd678
#
# ...

# %%
Company_v110['node_name'].value_counts()
# Out:
# 注输、护理和防护器械    5832
# 骨科手术器械        5256
# 医用成像器械        4509
# 骨科用有源器械       4003
# 临床检验器械        3424
#               ...
# 血管内皮功能测试设备       1
# 人工肝设备            1
# 放射治疗患者摆位系统       1
# 鼻阻力测量设备          1
# 直流电治疗设备          1
# Name: node_name, Length: 721, dtype: int64

# %% [markdown]
# # Patent_v110

# %%
Patent_v110=pd.read_sql('select * from INDUSTRY_med_equip_patent_info_v110',con=engine_chain)

# %%
Patent_v110['ans']=Patent_v110['ans_id'].str.extract(r'\[(.*)\]',expand=True)

# %%
Patent_v110
# Out:
#                node_id   node_name                             patent_id  \
# 0         ND0000000179      骨科手术器械  0eab32ab-0b3a-4310-b590-803e77a9bcc0
# 1         ND0000000263    基础通用辅助器械  0eab32ab-0b3a-4310-b590-803e77a9bcc0
# 2         ND0000000179      骨科手术器械  4559c165-707c-4ce9-be28-d7ad1fdb7745
# 3         ND0000000263    基础通用辅助器械  4559c165-707c-4ce9-be28-d7ad1fdb7745
# 4         ND0000000179      骨科手术器械  054dda25-5ce0-474d-8483-d2d8130c0d2a
# ...                ...         ...                                   ...
# 12988533  ND0000000633        包扎敷料  66eece70-694a-4225-be48-da596b257c65
# 12988534  ND0000000714          胶带  66eece70-694a-4225-be48-da596b257c65
# 12988535  ND0000000189  注输、护理和防护器械  6df7e290-aeff-47e6-bbf1-99d71c19daeb
# 12988536  ND0000000633        包扎敷料  6df7e290-aeff-47e6-bbf1-99d71c19daeb
# 12988537  ND0000000714          胶带  6df7e290-aeff-47e6-bbf1-99d71c19daeb
#
#           valid_indicator                                  ans_id  \
# ...

# %%
Patent_v110['node_name'].value_counts().head(100)
# Out:
# 口腔科器械                 1023003
# 骨科手术器械                1007376
# 骨科用有源器械                813623
# 注输、护理和防护器械             711567
# 临床检验器械                 679715
# 医用成像器械                 658150
# 呼吸、麻醉和急救器械             380000
# 包扎敷料                   374863
# 其他医用分析设备               280832
# 胶带                     266082
# 口腔充填修复材料               240000
# 无源植入器械                 235337
# 培养与孵育设备                235078
# 医用培养恒温箱                231887
# 色谱柱                    204524
# 无源手术器械                 164277
# 麻醉蒸发器                  157591
# 注射、穿刺器械                154092
# 雾化设备                   142275
# 复合体                    140000
# 呼吸、麻醉、急救设备辅助装置         140000
# 口腔治疗辅助材料               137717
# 整形及普通外科植入物             135055
# 修补固定器                  130606
# 基础通用辅助器械               127163
# 预处理剂                   122103
# 绷带                     117594
# 口腔植入及组织重建材料            112687
# 注射针                    104961
# 粘接剂                     98011
# 骨填充及修复材料                94945
# ...

# %%
Patent_v110.query('patent_id=="81de938f-1abd-4df8-b9a4-5c8d50a28d93"')
# Out:
#               node_id  node_name                             patent_id  \
# 5997061  ND0000000176     有源手术器械  81de938f-1abd-4df8-b9a4-5c8d50a28d93
# 5997062  ND0000000190     患者承载器械  81de938f-1abd-4df8-b9a4-5c8d50a28d93
# 5997063  ND0000000202  手术导航、控制系统  81de938f-1abd-4df8-b9a4-5c8d50a28d93
# 5997064  ND0000000218     手术导航系统  81de938f-1abd-4df8-b9a4-5c8d50a28d93
# 5997065  ND0000000733        手术台  81de938f-1abd-4df8-b9a4-5c8d50a28d93
#
#          valid_indicator                                             ans_id  \
# 5997061                1  [e9f9daa1-9c63-454a-94e1-7ca1a6860a65, a5039aa...
# 5997062                1  [e9f9daa1-9c63-454a-94e1-7ca1a6860a65, a5039aa...
# 5997063                1  [e9f9daa1-9c63-454a-94e1-7ca1a6860a65, a5039aa...
# 5997064                1  [e9f9daa1-9c63-454a-94e1-7ca1a6860a65, a5039aa...
# 5997065                1  [e9f9daa1-9c63-454a-94e1-7ca1a6860a65, a5039aa...
#
#                        apno                            tech_topic  \
# ...

# %% [markdown]
# # test_quanguo_score

# %%
test_quanguo_score=pd.read_sql('select * from test_quanguo_score',con=engine_retrain)
test_quanguo_score
# Out:
#                                company_id      company_name   seic_lv1  \
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F  山东普时达创电子商务集团有限公司         其它
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E      广东科建生物技术有限公司       生物产业
# 2        0027683A8AB4217205D5BE751D3A6D4E        杭州乙对纺织有限公司         其它
# 3        0034953AE8F88E6DD07C2809226C2A17       什邡艾美墅家居有限公司         其它
# 4        003D83E767259BB08EC3F13BA588C53D      佛山五合精密科技有限公司   高端装备制造产业
# ...                                   ...               ...        ...
# 1014980  FF39C458789446EBB2EEF14863AE8B8A      杭州萧山绿洲化纤有限公司      新材料产业
# 1014981  FF670701DAFF91C99EAAD7CA4DFEA623        广西昭平县凝香翠茶厂       生物产业
# 1014982  FF74A8877EC61C7D1835409AD37980AC    凯来幕墙科技（北京）有限公司     数字创意产业
# 1014983  FF856A2A8F89209A1C432CCC10780A4E      北京弘毅知行科技有限公司  新一代信息技术产业
# 1014984  FFBE9230E615F6950C13EB98EE84AF3C    北京康曦国际医学科技有限公司       生物产业
#
#               seic_lv2  apno_cnt     patent  nonpatent      total  rank_total  \
# ...

# %% [markdown]
# # 测试数据

# %%
import openpyxl
wb = openpyxl.load_workbook('附件1：产品产业链-医疗器械 (1).xlsx')
wb.sheetnames
# Out:
# ['01-产品层级', '02-产品上下游', '03-上市发债企业主营产品', '04-一般工商企业(非上市发债)信息']

# %% [markdown]
# ## 上市

# %%
Instruments=pd.read_excel('附件1：产品产业链-医疗器械 (1).xlsx',sheet_name='03-上市发债企业主营产品')
Instruments.drop_duplicates(subset=['企业名称'],inplace=True)
Instruments
# Out:
#      上市板块          企业编码     企业编号            企业名称       截止日期     主营产品披露名称  \
# 0      A股  ETP000001KZO     1065  北京万东医疗科技股份有限公司 2020-12-31       医疗器械制造
# 3      A股  ETP000001UNO   633033    奥精医疗科技股份有限公司 2020-12-31           骼金
# 11     A股  ETP000002S3M   168752   北京利德曼生化股份有限公司 2020-12-31       体外诊断试剂
# 16     A股  ETP000006K30   170636  北京九强生物技术股份有限公司 2020-12-31       体外检测试剂
# 21     A股  ETP000006QON    79075  天津九安医疗电子股份有限公司 2020-12-31  iHealth系列产品
# ...   ...           ...      ...             ...        ...          ...
# 1088   发债  ETP000001KTK  1010522      中国同辐股份有限公司 2020-12-31     1.主营业务小计
# 1097   发债  ETP00002FZCQ   200376        威高集团有限公司 2020-12-31         医疗健康
# 1100   发债  ETP0000B01TS   229060      淄博蓝帆投资有限公司 2020-12-31       健康防护产品
# 1104   发债  ETP00001RCF2   235048  郑州安图实业集团股份有限公司 2020-12-31          试剂类
# 1107   发债  ETP0000WONYO   223819  苏州德品医疗科技股份有限公司 2020-12-31     主营业务：治疗柜
#
#           主营标准产品代码   主营标准产品名称  \
# 0     PRD000008918     医用成像器械
# ...

# %% [markdown]
# ## 工商企业

# %%
Commercial=pd.read_excel('附件1：产品产业链-医疗器械 (1).xlsx',sheet_name='04-一般工商企业(非上市发债)信息')
Commercial.drop_duplicates(subset=['企业名称'],inplace=True)
Commercial
# Out:
#                   企业名称            披露产品名称         对应标准产品            统一社会信用代码  \
# 0         东软医疗系统股份有限公司       彩色多普勒超声诊断系统       超声影像诊断设备  91210112702087542R
# 9      兰州生物制品研究所有限责任公司  轮状病毒检测试剂盒（酶联免疫法）         免疫诊断试剂  916200002243483486
# 14         金红叶纸业集团有限公司         一次性使用医用口罩         医用防护口罩  91320594608243799B
# 15        柳州五菱汽车工业有限公司       医用外科口罩(非无菌)      手术室感染控制用品  91450200794328218E
# 16          深圳迈瑞科技有限公司               输液泵            输液泵  91440300763451547B
# ...                ...               ...            ...                 ...
# 43340  中国核动力研究设计院设备制造厂           放射治疗模拟机  放射治疗模拟及图像引导系统  915111269075114823
# 43343       中山市科艺义齿加工厂           定制式活动义齿       口腔义齿制作材料  91442000796269311Q
# 43345      中山市小榄镇森蓝电子厂            耳内式助听器            助听器  91442000L024028666
# 43347        重庆态美齿科研究所           定制式固定义齿       口腔义齿制作材料  915001077428968623
# 43349       遵化市立洪义齿加工部           定制式固定义齿       口腔义齿制作材料  91130281667707282M
#
#            国民经济行业(三级)     注册资本(万元)    注册地省市    企业资质
# ...

# %% [markdown]
# ## Test

# %%
Test=pd.concat([Instruments[['企业名称']],Commercial[['企业名称']]])
Test['clean_name']=Test['企业名称'].apply(lambda x:cleanup_entity(x))
Test=pd.merge(Test,test_quanguo_score[['company_id','company_name']],left_on='clean_name',right_on='company_name')
Test=Test[['company_id','company_name']]
Test
# Out:
#                             company_id     company_name
# 0     3C58AFE6DB17B1AA44A8B64B0BB8BEB7   北京万东医疗科技股份有限公司
# 1     85EF25CCD15E8D08F9637F1764A33317     奥精医疗科技股份有限公司
# 2     5022EE14F63226C7266BC5619EC17288    北京利德曼生化股份有限公司
# 3     B31F4F1F633106965893BA3640839742   北京九强生物技术股份有限公司
# 4     9691F7BE61761A4EC33730A5357FA58F   天津九安医疗电子股份有限公司
# ...                                ...              ...
# 5866  D9132B9173ABF2D1525A7904FD886A44        武汉美观义齿加工厂
# 5867  5962F0B8923477D261DCD9CA88C65631       永康市双锦保健器材厂
# 5868  A87D0BFAD79478FA4F18FD39C479E500       余姚市吉康医疗器械厂
# 5869  2E9389F7C0D0D0C6C789F38D1F333998  中国核动力研究设计院设备制造厂
# 5870  F601C1C51741BE12EE4078CA6D25702A      中山市小榄镇森蓝电子厂
#
# [5871 rows x 2 columns]

# %% [markdown]
# # 公司测试

# %% [markdown]
# ## 召回率

# %%
Recall=pd.merge(Test,Company_v110,how='left',on='company_id')
Recall

# %%
Recall=pd.merge(Recall,test_quanguo_score[['company_id','seic_lv2']],how='left',on='company_id')

# %%
Recall

# %%
Recall.to_excel('医疗器械召回率.xlsx',encoding='utf-8',index=False)

# %%
a=3358/5871
a
# Out:
# 0.571963890308295

# %% [markdown]
# ## 精确率

# %%
Precesion=Company_v110.sample(n=150,random_state=None)
Precesion

# %%
Precesion.to_excel('医疗器械精准测试数据.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# # 科创战新企业专利

# %%
Seic_patent=pd.merge(Company_v110,Patent_v110,how='left',left_on='ans_id',right_on='ans')
Seic_patent.drop(columns=['node_id_x','node_name_x','ans_id_x'],inplace=True)
Seic_patent
# Out:
#                               company_id      company_name province city  \
# 0       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 1       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 2       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 3       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 4       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# ...                                  ...               ...      ...  ...
# 546999  D0645123B5CDFB68009E0D75EA23E016      广州发元生物科技有限公司      广东省  广州市
# 547000  F6E74D4FE74EBE5E68A1C4D7CB038C52       厦门罗雅光科技有限公司      福建省  厦门市
# 547001  AE534F720A77893435022D1DE510B331      杭州小安医疗科技有限公司      浙江省  杭州市
# 547002  AE534F720A77893435022D1DE510B331      杭州小安医疗科技有限公司      浙江省  杭州市
# 547003  F94F88B8D1258CBDC0C3256C85636DE5      重庆中迪医疗设备有限公司      重庆市  重庆市
#
#        district  seic_lv2                                        description  \
# ...

# %%
Seic_patent.rename(columns={'node_id_y':'node_id','node_name_y':'node_name','ans_id_y':'ans_id'},inplace=True)

# %%
Seic_patent
# Out:
#                               company_id      company_name province city  \
# 0       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 1       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 2       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 3       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# 4       E4976C16AF85C1689FD26EB9AD55B239  深圳开立生物医疗科技股份有限公司      广东省  深圳市
# ...                                  ...               ...      ...  ...
# 546999  D0645123B5CDFB68009E0D75EA23E016      广州发元生物科技有限公司      广东省  广州市
# 547000  F6E74D4FE74EBE5E68A1C4D7CB038C52       厦门罗雅光科技有限公司      福建省  厦门市
# 547001  AE534F720A77893435022D1DE510B331      杭州小安医疗科技有限公司      浙江省  杭州市
# 547002  AE534F720A77893435022D1DE510B331      杭州小安医疗科技有限公司      浙江省  杭州市
# 547003  F94F88B8D1258CBDC0C3256C85636DE5      重庆中迪医疗设备有限公司      重庆市  重庆市
#
#        district  seic_lv2                                        description  \
# ...

# %%
Seic_patent.to_sql('INDUSTRY_med_company_patent_info_v110',con=engine_chain,index=False)

# %%
Seic_patent['valid_indicator'].value_counts()
# Out:
# 1.0    453807
# 0.0     92904
# Name: valid_indicator, dtype: int64

# %%
node_name=pd.DataFrame(Seic_patent['node_name'].value_counts().reset_index().rename(columns={'index':'node_name','node_name':'num'}))

# %%
node_name
# Out:
#       node_name    num
# 0    注输、护理和防护器械  33901
# 1        临床检验器械  26149
# 2        医用成像器械  23981
# 3        骨科手术器械  23680
# 4        无源手术器械  19566
# ..          ...    ...
# 716     负压引流封闭膜      1
# 717    认知障碍康复设备      1
# 718      振动训练设备      1
# 719      结扎手术器械      1
# 720     末梢血采集容器      1
#
# [721 rows x 2 columns]

# %%
node_name.to_excel('node_name.xlsx',encoding='utf-8')

# %% [markdown]
# ## 注输、护理和防护器械

# %%
Infusion=Seic_patent[(Seic_patent['node_name']=='注输、护理和防护器械')&(Seic_patent['valid_indicator']==1)].sample(n=50,random_state=None)

# %%
Infusion=Infusion[['ans_id','node_id','node_name','patent_id','apno','valid_indicator']]
Infusion
# Out:
#                                         ans_id       node_id   node_name  \
# 434439  [1db61524-6487-11ec-8c34-6a0b3c9cb180]  ND0000000189  注输、护理和防护器械
# 212705  [0214e8d1-9d02-498e-a189-05cb401a044d]  ND0000000189  注输、护理和防护器械
# 330911  [12341f27-6d9f-4e12-b0d3-b038a92f13a0]  ND0000000189  注输、护理和防护器械
# 256915  [7958c0df-d8fa-4ca3-b1cf-85aba5792439]  ND0000000189  注输、护理和防护器械
# 196189  [c1b60944-daba-4a86-bca5-0ecc4a15772b]  ND0000000189  注输、护理和防护器械
# 191903  [3fb631bf-a409-43f4-8b6c-c08d9ae6f17e]  ND0000000189  注输、护理和防护器械
# 187506  [96e0e999-edf1-452d-b55a-0d71c4fe2090]  ND0000000189  注输、护理和防护器械
# 333599  [8eba779f-52db-47b4-84a4-9b7d97afc446]  ND0000000189  注输、护理和防护器械
# 232605  [1a8e2913-84d8-4eba-8080-cc324afc4276]  ND0000000189  注输、护理和防护器械
# 202969  [d8887122-0675-489e-a5cb-bd365f72c479]  ND0000000189  注输、护理和防护器械
# 276519  [c1685c0a-b741-4f8f-93de-865de179d9e1]  ND0000000189  注输、护理和防护器械
# 370583  [b714d6b6-f7be-4911-aa14-c221fad58e78]  ND0000000189  注输、护理和防护器械
# ...

# %%
Infusion.to_excel('注输、护理和防护器械专利测试数据.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# ## 骨科用有源器械

# %%
orthopedics=Seic_patent[(Seic_patent['node_name']=='骨科用有源器械')&(Seic_patent['valid_indicator']==1)].sample(n=20,random_state=None)
orthopedics=orthopedics[['ans_id','node_id','node_name','patent_id','apno','valid_indicator']]
orthopedics
# Out:
#                                         ans_id       node_id node_name  \
# 77826   [8a0241b2-0406-11ec-b622-127dc0bbd678]  ND0000000261   骨科用有源器械
# 376005  [de46dd59-f64d-4c06-97dd-e0d7f00c1f15]  ND0000000261   骨科用有源器械
# 271604  [0ab100fb-af77-49a2-8441-3a73697b60e6]  ND0000000261   骨科用有源器械
# 213246  [d47fd96c-156a-437d-b39e-b0f77f06fb30]  ND0000000261   骨科用有源器械
# 11820   [822d7cf6-f033-4032-9a57-e14cda2d0bce]  ND0000000261   骨科用有源器械
# 256511  [e70c909f-bbc4-49ad-be83-c208b8a29154]  ND0000000261   骨科用有源器械
# 400785  [600cdf2b-b9e9-402f-a5ce-c53b6d58ab68]  ND0000000261   骨科用有源器械
# 398605  [550dd144-08db-4ead-9e60-bc69c9cde39b]  ND0000000261   骨科用有源器械
# 66429   [dc73994f-7719-4734-9bdd-aab1bfaa9643]  ND0000000261   骨科用有源器械
# 372373  [ce5502ed-4ead-40ce-be07-8e47fdad1896]  ND0000000261   骨科用有源器械
# 140608  [74f52c3e-fe6a-4dcd-a45f-979934408b44]  ND0000000261   骨科用有源器械
# 388813  [1007bead-1652-45a8-be6b-083a46ef26d6]  ND0000000261   骨科用有源器械
# ...

# %%
orthopedics.to_excel('骨科用有源器械专利测试数据1.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# ## 医用培养恒温箱

# %%
Medical=Seic_patent[(Seic_patent['node_name']=='医用培养恒温箱')&(Seic_patent['valid_indicator']==1)].sample(n=35,random_state=None)
Medical=Medical[['ans_id','node_id','node_name','patent_id','apno','valid_indicator']]
Medical
# Out:
#                                         ans_id       node_id node_name  \
# 212257  [6b04dcc2-a8a3-4a8e-991e-234b88ec1c13]  ND0000000997   医用培养恒温箱
# 535293  [344a69f6-1239-419f-b7c3-6c2071c0070d]  ND0000000997   医用培养恒温箱
# 457211  [caf79381-aa2f-4c03-81a7-e94fc1c103be]  ND0000000997   医用培养恒温箱
# 413400  [f82f2fca-2381-4e63-95b2-4b2b7ef723a5]  ND0000000997   医用培养恒温箱
# 513042  [0d939008-7d0e-42b8-97bf-a524281fccec]  ND0000000997   医用培养恒温箱
# 88998   [f7624b71-c29e-4090-8b15-1abc7d581f5a]  ND0000000997   医用培养恒温箱
# 540791  [4e3b160c-135d-4947-9c5f-df6d02f6a3ef]  ND0000000997   医用培养恒温箱
# 210839  [ea0f99a9-7b26-45ed-8db7-9614feed805f]  ND0000000997   医用培养恒温箱
# 359319  [e0b8a9f3-5650-4e50-84b6-3876c1b42f33]  ND0000000997   医用培养恒温箱
# 397309  [28e08eae-a4cf-46bd-8e5b-f9a1d7b5a4f9]  ND0000000997   医用培养恒温箱
# 218457  [892f7ffb-075b-414e-a65d-24cccb7908c0]  ND0000000997   医用培养恒温箱
# 443130  [b3187f76-a670-4827-9251-863569337849]  ND0000000997   医用培养恒温箱
# ...

# %%
Medical.to_excel('医用培养恒温箱专利测试数据.xlsx',encoding='utf-8',index=False)
