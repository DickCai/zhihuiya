# %%
import pandas as pd
import os
import openpyxl
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns',100)
pd.set_option('max_rows',100)
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company_test',echo=False)
from data_nlp_nameclean.clean.cleaning import cleanup_entity
os.chdir('D:\数据\全国数据\产业链\恒生聚源')

# %% [markdown]
# # 集成电路

# %%
Integrated_circuit=openpyxl.load_workbook('集成电路产业链.xlsx')

# %%
Integrated_circuit.sheetnames
# Out:
# ['01-产品层级',
#  '02-产品上下游',
#  '03-上市发债企业主营产品',
#  '04-主题产业链关系表',
#  '5.主题产业链关联企业表',
#  '06-一般工商企业(非上市发债)信息']

# %% [markdown]
# ## 产品层级

# %%
Product_hierarchy=pd.read_excel('集成电路产业链.xlsx',sheet_name='01-产品层级')

# %%
Product_hierarchy
# Out:
#             节点代码       节点名称         父节点代码      父节点名称  节点层级深度  序号
# 0   PRD000000964       集成电路  PRD000000963        半导体       3   1
# 1   PRD000000965       通讯芯片  PRD000000964       集成电路       4   1
# 2   PRD000000966       射频芯片  PRD000000965       通讯芯片       5   1
# 3   PRD000000968       基带芯片  PRD000000965       通讯芯片       5   2
# 4   PRD000025O40     无线通讯芯片  PRD000000965       通讯芯片       5   3
# 5   PRD000026Q3V       信道芯片  PRD000000965       通讯芯片       5   4
# 6   PRD000026Q3W     网络通信芯片  PRD000000965       通讯芯片       5   5
# 7   PRD000026Q3Y  电力线载波通信芯片  PRD000000965       通讯芯片       5   6
# 8   PRD000026Q3Z  数字信号编解码芯片  PRD000000965       通讯芯片       5   7
# 9   PRD000026Q40      电话机芯片  PRD000000965       通讯芯片       5   8
# 10  PRD000000969        光芯片  PRD000000965       通讯芯片       5   9
# 11  PRD000026XMH        电芯片  PRD000000965       通讯芯片       5  10
# 12  PRD000020579       通讯模块  PRD000000965       通讯芯片       5  11
# ...

# %% [markdown]
# ## 产品上下游

# %%
Product_stream=pd.read_excel('集成电路产业链.xlsx',sheet_name='02-产品上下游')

# %%
Product_stream
# Out:
#              产品代码     产品名称  关联关系方向 关联关系名称        关联产品代码    关联产品名称  关联强度序号
# 0    PRD000000964     集成电路       1     服务  PRD000026Q8G  集成电路晶圆代工       1
# 1    PRD000000964     集成电路       1     服务  PRD000001201  集成电路封测服务       2
# 2    PRD000000964     集成电路       1     服务  PRD000026OFZ    芯片技术服务       3
# 3    PRD000000964     集成电路       1     设备  PRD000025YX8    真空镀膜设备       4
# 4    PRD000000964     集成电路       1     设备  PRD000001139     半导体设备       5
# ..            ...      ...     ...    ...           ...       ...     ...
# 398  PRD000026QE1  图像传感器芯片       1     服务  PRD000026OFZ    芯片技术服务       4
# 399  PRD000026QE1  图像传感器芯片      -1     主体  PRD000026EYA      相机模组       1
# 400  PRD000026QE1  图像传感器芯片      -1     渠道  PRD000026O8W   半导体芯片经销       2
# 401  PRD000026QGS     红外芯片       1    原材料  PRD000026Q8G  集成电路晶圆代工       1
# 402  PRD000026QGS     红外芯片      -1     主体  PRD0000267F1     红外探测器       1
#
# [403 rows x 7 columns]

# %% [markdown]
# ## 上市发债企业主营产品

# %%
Main_products=pd.read_excel('集成电路产业链.xlsx',sheet_name='03-上市发债企业主营产品')

# %%
Main_products
# Out:
#      上市板块          企业编码      企业编号           企业名称  证券简称     信息发布日期       截止日期  \
# 0      A股  ETP000002MIL    171501   北京赛微电子股份有限公司  赛微电子 2021-03-17 2020-12-31
# 1      A股  ETP000002MIL    171501   北京赛微电子股份有限公司  赛微电子 2021-03-17 2020-12-31
# 2      A股  ETP000002MIL    171501   北京赛微电子股份有限公司  赛微电子 2021-03-17 2020-12-31
# 3      A股  ETP000002MIL    171501   北京赛微电子股份有限公司  赛微电子 2021-03-17 2020-12-31
# 4      A股  ETP000002MIL    171501   北京赛微电子股份有限公司  赛微电子 2021-03-17 2020-12-31
# ...   ...           ...       ...            ...   ...        ...        ...
# 1354   三板  ETP00010LSQY  10023610  深圳市华创生活股份有限公司  华创生活 2021-03-31 2020-12-31
# 1355   发债  ETP00001NM73      6596   上海华虹(集团)有限公司   NaN 2021-04-01 2020-12-31
# 1356   发债  ETP00001NM73      6596   上海华虹(集团)有限公司   NaN 2021-04-01 2020-12-31
# 1357   发债  ETP00001NM73      6596   上海华虹(集团)有限公司   NaN 2021-04-01 2020-12-31
# 1358   发债  ETP00001NM73      6596   上海华虹(集团)有限公司   NaN 2021-04-01 2020-12-31
#
# ...

# %% [markdown]
# ## 主题产业链关系表

# %%
Industry_chain=pd.read_excel('集成电路产业链.xlsx',sheet_name='04-主题产业链关系表')

# %%
Industry_chain
# Out:
#     主题名称  产业链类型       节点名称  上游节点    父节点  节点层级深度  节点序号  是否叶节点    节点展示名称  \
# 0   集成电路  上中下游型  半导体IP授权服务   NaN    NaN       1     1      1        IP
# 1   集成电路  上中下游型      半导体硅片   NaN  半导体材料       1     1      1        硅片
# 2   集成电路  上中下游型      晶体生长炉   NaN  半导体设备       1     1      1    晶体生长设备
# 3   集成电路  上中下游型      激光切割机   NaN  半导体设备       1     2      1     晶圆切割机
# 4   集成电路  上中下游型      光刻掩膜版   NaN  半导体材料       1     2      1       掩膜版
# 5   集成电路  上中下游型      EDA软件   NaN    NaN       1     2      1     EDA软件
# 6   集成电路  上中下游型     集成电路设计   NaN    NaN       1     3      1  集成电路设计服务
# 7   集成电路  上中下游型        光刻胶   NaN  半导体材料       1     3      1       光刻胶
# 8   集成电路  上中下游型        光刻机   NaN  半导体设备       1     3      1       光刻机
# 9   集成电路  上中下游型       刻蚀设备   NaN  半导体设备       1     4      1       刻蚀机
# 10  集成电路  上中下游型       溅射靶材   NaN  半导体材料       1     4      1      溅镀靶材
# 11  集成电路  上中下游型      半导体材料   NaN    NaN       1     4      0     半导体材料
# ...

# %% [markdown]
# ## 主题产业链关联企业表

# %%
Subject_industry_chain=pd.read_excel('集成电路产业链.xlsx',sheet_name='5.主题产业链关联企业表')

# %%
Subject_industry_chain.head(100)
# Out:
#     主题名称       节点名称                     企业名称          企业代码  \
# 0   集成电路    CMP抛光材料                       杜邦  ETP00010LR7J
# 1   集成电路    CMP抛光材料                   卡伯特微电子  ETP00010LN5Y
# 2   集成电路    CMP抛光材料             湖北鼎龙控股股份有限公司  ETP0000WNZRB
# 3   集成电路    CMP抛光材料        安集微电子科技(上海)股份有限公司  ETP00007PFDO
# 4   集成电路    CMP抛光材料  Hitachi Chemical Co.Ltd  ETP00010MOD8
# 5   集成电路    CMP抛光材料                   富士胶片公司  ETP00010LDR7
# 6   集成电路    CMP抛光材料        中国电子科技集团公司第四十五研究所  ETP00010L3QW
# 7   集成电路      EDA软件                   新思科技公司  ETP00010LSJD
# 8   集成电路      EDA软件               铿腾电子科技有限公司  ETP00010LN61
# 9   集成电路      EDA软件          Mentor Graphics  ETP00010LOPI
# 10  集成电路      EDA软件           北京华大九天科技股份有限公司  ETP000000XR2
# 11  集成电路      EDA软件          北京芯愿景软件技术股份有限公司  ETP000007DA0
# 12  集成电路      EDA软件            杭州广立微电子股份有限公司  ETP00004CNDF
# 13  集成电路      EDA软件             深圳市海思半导体有限公司  ETP00008Z1II
# 14  集成电路      EDA软件                      IBM  ETP00010LJNH
# ...

# %% [markdown]
# ## 一般工商企业(非上市发债)信息

# %%
Unlisted_bond_issuance=pd.read_excel('集成电路产业链.xlsx',sheet_name='06-一般工商企业(非上市发债)信息')

# %%
Unlisted_bond_issuance
# Out:
#                 企业名称            统一社会信用代码     国民经济行业(三级)    注册资本(万元) 注册地省市  \
# 0        安徽超元半导体有限公司  91341700399898763G  电子元件及电子专用材料制造   2000.0000   安徽省
# 1    安徽晶谷周界微电子股份有限公司  91340300MA2RCC8Y2X   其他未列明专业技术服务业   3636.3636   安徽省
# 2      安徽芯瑞达科技股份有限公司  91340100595739962H        其他计算机制造  18418.4000   安徽省
# 3     安徽中创电子信息材料有限公司  913403003959366383    其他非金属矿物制品制造   5594.0600   安徽省
# 4    安捷利电子科技(苏州)有限公司  913205057768970116       其他电子设备制造   7500.0000   江苏省
# ..               ...                 ...            ...         ...   ...
# 370    重庆中科芯亿达电子有限公司  91500106699253465D         电子电路制造    800.0000   重庆市
# 371       珠海博雅科技有限公司  914404003247554698     软件和信息技术服务业    645.4910   广东省
# 372    珠海市杰理科技股份有限公司  91440400560866566C        研究和试验发展  38317.5000   广东省
# 373    珠海一微半导体股份有限公司  914404000956241144        研究和试验发展   2121.1829   广东省
# 374     珠海智融科技股份有限公司  91440400315124358L           软件开发   4500.0000   广东省
#
#                            企业资质
# 0                 高新技术企业、专精特新企业
# ...

# %% [markdown]
# ## 上市名单产业链名单提取

# %%
Main_products_list=pd.merge(Product_hierarchy['节点代码'],Main_products,how='left',left_on='节点代码',right_on='主营标准产品代码')

# %%
Main_products_list
# Out:
#              节点代码   上市板块          企业编码      企业编号            企业名称  证券简称  \
# 0    PRD000000964  A股、发债  ETP0000033T8  207413.0   上海韦尔半导体股份有限公司  韦尔股份
# 1    PRD000000964  A股、发债  ETP000006JPG    1517.0    江苏长电科技股份有限公司  长电科技
# 2    PRD000000964     A股  ETP00001T5PJ  208579.0  上海艾为电子技术股份有限公司  艾为电子
# 3    PRD000000964     A股  ETP00001T5PJ  208579.0  上海艾为电子技术股份有限公司  艾为电子
# 4    PRD000000964     A股  ETP00001T5PJ  208579.0  上海艾为电子技术股份有限公司  艾为电子
# ..            ...    ...           ...       ...             ...   ...
# 132  PRD000026D5O     A股  ETP00010LHNC  536026.0  恒玄科技(上海)股份有限公司  恒玄科技
# 133  PRD000026D5O     A股  ETP00010LHNC  536026.0  恒玄科技(上海)股份有限公司  恒玄科技
# 134  PRD000026D5O     A股  ETP00010LHNC  536026.0  恒玄科技(上海)股份有限公司  恒玄科技
# 135  PRD000026D5O     A股  ETP00010LHNC  536026.0  恒玄科技(上海)股份有限公司  恒玄科技
# 136  PRD000026D5O     A股  ETP00010LHNC  536026.0  恒玄科技(上海)股份有限公司  恒玄科技
#
#         信息发布日期       截止日期  主营产品披露名称      主营标准产品代码  主营标准产品名称  \
# ...

# %% [markdown]
# ##  集成电路测试名单

# %%
Main_products_list=Main_products_list[['企业名称','主营标准产品名称']]
Main_products_list.rename(columns={'主营标准产品名称':'节点名称'},inplace=True)
Main_products_list
# Out:
#                企业名称      节点名称
# 0     上海韦尔半导体股份有限公司      集成电路
# 1      江苏长电科技股份有限公司      集成电路
# 2    上海艾为电子技术股份有限公司      集成电路
# 3    上海艾为电子技术股份有限公司      集成电路
# 4    上海艾为电子技术股份有限公司      集成电路
# ..              ...       ...
# 132  恒玄科技(上海)股份有限公司  智能蓝牙音频芯片
# 133  恒玄科技(上海)股份有限公司  智能蓝牙音频芯片
# 134  恒玄科技(上海)股份有限公司  智能蓝牙音频芯片
# 135  恒玄科技(上海)股份有限公司  智能蓝牙音频芯片
# 136  恒玄科技(上海)股份有限公司  智能蓝牙音频芯片
#
# [137 rows x 2 columns]

# %%
Subject_industry_chain=Subject_industry_chain[['节点名称','企业名称']]
Subject_industry_chain
# Out:
#         节点名称                     企业名称
# 0    CMP抛光材料                       杜邦
# 1    CMP抛光材料                   卡伯特微电子
# 2    CMP抛光材料             湖北鼎龙控股股份有限公司
# 3    CMP抛光材料        安集微电子科技(上海)股份有限公司
# 4    CMP抛光材料  Hitachi Chemical Co.Ltd
# ..       ...                      ...
# 640   湿电子化学品          江阴江化微电子材料股份有限公司
# 641   湿电子化学品             晶瑞电子材料股份有限公司
# 642   湿电子化学品               浙江巨化股份有限公司
# 643   湿电子化学品          杭州格林达电子材料股份有限公司
# 644   湿电子化学品           山东阳谷华泰化工股份有限公司
#
# [645 rows x 2 columns]

# %%
Integrated_list=pd.concat([Main_products_list,Subject_industry_chain])

# %%
Integrated_list
# Out:
#                 企业名称    节点名称
# 0      上海韦尔半导体股份有限公司    集成电路
# 1       江苏长电科技股份有限公司    集成电路
# 2     上海艾为电子技术股份有限公司    集成电路
# 3     上海艾为电子技术股份有限公司    集成电路
# 4     上海艾为电子技术股份有限公司    集成电路
# ..               ...     ...
# 640  江阴江化微电子材料股份有限公司  湿电子化学品
# 641     晶瑞电子材料股份有限公司  湿电子化学品
# 642       浙江巨化股份有限公司  湿电子化学品
# 643  杭州格林达电子材料股份有限公司  湿电子化学品
# 644   山东阳谷华泰化工股份有限公司  湿电子化学品
#
# [782 rows x 2 columns]

# %%
Integrated_list.drop_duplicates(subset=['企业名称','节点名称'],inplace=True)

# %%
Integrated_list.to_excel('集成电路企业测试名单.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# # 匹配集成电路测试企业company_id

# %% [markdown]
# ## 集成电路测试数据

# %%
Integrated=pd.read_excel('集成电路企业测试名单.xlsx')
Integrated
# Out:
#                 企业名称    节点名称
# 0      上海韦尔半导体股份有限公司    集成电路
# 1       江苏长电科技股份有限公司    集成电路
# 2     上海艾为电子技术股份有限公司    集成电路
# 3         国民技术股份有限公司    集成电路
# 4      无锡芯朋微电子股份有限公司    集成电路
# ..               ...     ...
# 672  江阴江化微电子材料股份有限公司  湿电子化学品
# 673     晶瑞电子材料股份有限公司  湿电子化学品
# 674       浙江巨化股份有限公司  湿电子化学品
# 675  杭州格林达电子材料股份有限公司  湿电子化学品
# 676   山东阳谷华泰化工股份有限公司  湿电子化学品
#
# [677 rows x 2 columns]

# %%
Integrated['clean_name']=Integrated['企业名称'].apply(lambda x:cleanup_entity(x))

# %%
Integrated
# Out:
#                 企业名称    节点名称       clean_name
# 0      上海韦尔半导体股份有限公司    集成电路    上海韦尔半导体股份有限公司
# 1       江苏长电科技股份有限公司    集成电路     江苏长电科技股份有限公司
# 2     上海艾为电子技术股份有限公司    集成电路   上海艾为电子技术股份有限公司
# 3         国民技术股份有限公司    集成电路       国民技术股份有限公司
# 4      无锡芯朋微电子股份有限公司    集成电路    无锡芯朋微电子股份有限公司
# ..               ...     ...              ...
# 672  江阴江化微电子材料股份有限公司  湿电子化学品  江阴江化微电子材料股份有限公司
# 673     晶瑞电子材料股份有限公司  湿电子化学品     晶瑞电子材料股份有限公司
# 674       浙江巨化股份有限公司  湿电子化学品       浙江巨化股份有限公司
# 675  杭州格林达电子材料股份有限公司  湿电子化学品  杭州格林达电子材料股份有限公司
# 676   山东阳谷华泰化工股份有限公司  湿电子化学品   山东阳谷华泰化工股份有限公司
#
# [677 rows x 3 columns]

# %% [markdown]
# ## 全国12月数据

# %%
test_quanguo_score=pd.read_sql('select * from test_quanguo_score',con=engine)

# %%
test_quanguo_score
# Out:
#                               company_id     company_name   seic_lv1  \
# 0       00001FF532C2D92470F99149D48C7820   中科点击（辽宁）科技有限公司  新一代信息技术产业
# 1       00002B5B4529376232011C86E1A588FF     江门市葵峰混凝土有限公司      新材料产业
# 2       00003DFB06D095BD2D6DE4A828C6CB5C       合肥德良机械有限公司   高端装备制造产业
# 3       00003E68CDE39A6DA970E85788FDB98D       杭州弥奥科技有限公司     节能环保产业
# 4       00003FCBDCE7E5340E6603C08DD6291A      广东格瑞克科技有限公司   高端装备制造产业
# ...                                  ...              ...        ...
# 960108  FFFF9B34AD5B60CECBF0DA6C52F3B0F1   声佗医疗科技（上海）有限公司       生物产业
# 960109  FFFFCFE0644923912519B1A1034E5E8D       武汉已为科技有限公司     数字创意产业
# 960110  FFFFE42F6484FEC563A1C55993BE494C  广东泰索斯营销策划服务有限公司         其它
# 960111  FFFFF51AB69F00656AE94BC3C57CC8D2    广西草本源中药饮片有限公司       生物产业
# 960112  FFFFFBA85B6D854ABC614B7219A0F258     江苏浦贝智能科技有限公司   高端装备制造产业
#
#              seic_lv2  apno_cnt     patent  nonpatent      total  rank_total  \
# ...

# %%
test_quanguo_score['clean_name']=test_quanguo_score['company_name'].apply(lambda x:cleanup_entity(x))

# %%
Integrated_list=pd.merge(Integrated,test_quanguo_score[['company_id','clean_name']],how='left',on='clean_name')

# %%
Integrated_list
# Out:
#                 企业名称    节点名称       clean_name  \
# 0      上海韦尔半导体股份有限公司    集成电路    上海韦尔半导体股份有限公司
# 1       江苏长电科技股份有限公司    集成电路     江苏长电科技股份有限公司
# 2     上海艾为电子技术股份有限公司    集成电路   上海艾为电子技术股份有限公司
# 3         国民技术股份有限公司    集成电路       国民技术股份有限公司
# 4      无锡芯朋微电子股份有限公司    集成电路    无锡芯朋微电子股份有限公司
# ..               ...     ...              ...
# 672  江阴江化微电子材料股份有限公司  湿电子化学品  江阴江化微电子材料股份有限公司
# 673     晶瑞电子材料股份有限公司  湿电子化学品     晶瑞电子材料股份有限公司
# 674       浙江巨化股份有限公司  湿电子化学品       浙江巨化股份有限公司
# 675  杭州格林达电子材料股份有限公司  湿电子化学品  杭州格林达电子材料股份有限公司
# 676   山东阳谷华泰化工股份有限公司  湿电子化学品   山东阳谷华泰化工股份有限公司
#
#                            company_id
# 0    2EBC8F1BF646152D9CCBD1499E2A89EC
# 1    CE663A97CF28E4934DCD44C56CA03088
# 2    95BD9E3B6D17FD2B2736EEF3E830B0FE
# 3    5330482F6331144A854FE975DCFDF70D
# 4    4F87A82BE34ABDC88833AE8F4178AE83
# ..                                ...
# 672  B1634E49EAC97D54BEAF4D5E883EB9BD
# 673  35F987A950FC58673B5DC12AA06880C6
# 674  3F26F9FCD728328ADE590D9B23EB6988
# ...

# %%
Integrated_list.to_excel('集成电路测试名单1.xlsx',encoding='utf-8',index=False)
