# %%
import pandas as pd
from sqlalchemy import create_engine
engine_chain=create_engine('mysql+pymysql://company:company@192.168.16.244/industry_chain',echo=False)
engine_retrain=create_engine('mysql+pymysql://company:company@192.168.16.244/company_retrain')
import os
os.chdir('/Users/caicaiqijun/智慧牙/数据/全国数据/产业链/绿色产业链')
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_rows',100)
pd.set_option('max_columns',100)

# %% [markdown]
# # INDUSTRY_green_company_info_v121

# %%
INDUSTRY_green_company_info_v121=pd.read_sql('select * from INDUSTRY_green_company_info_v121',con=engine_chain)

# %%
INDUSTRY_green_company_info_v121
# Out:
#              node_id node_name                                ans_id  \
# 0       ND0000001040      生态农业  e8a3a9f4-9990-4979-a1e4-dd532d54de50
# 1       ND0000001040      生态农业  b7676860-6f4a-46af-b94f-5e9c874dbb8c
# 2       ND0000001040      生态农业  45d17bf6-dea5-4c2c-b890-90920d527045
# 3       ND0000001075      生物质能  45d17bf6-dea5-4c2c-b890-90920d527045
# 4       ND0000001040      生态农业  185a7ba8-c5e7-4ff0-92ea-71db1cf4e7a1
# ...              ...       ...                                   ...
# 383682  ND0000001090      共享交通  822bed91-a211-471d-b15d-418a8d6183ce
# 383683  ND0000001090      共享交通  632fa5d6-88cb-483c-b187-00f3b9dc544d
# 383684  ND0000001090      共享交通  499fc765-46a2-49c5-a545-a4a8de690b3e
# 383685  ND0000001090      共享交通  150a9fda-bb80-4e35-ab70-43c1bf271177
# 383686  ND0000001090      共享交通  b3687a59-eefc-4cd7-9ac3-583cb65a5fbf
#
#                               company_id      company_name      score  \
# ...

# %%
INDUSTRY_green_company_info_v121.drop_duplicates(subset=['company_id'],inplace=True)

# %%
pd.DataFrame(INDUSTRY_green_company_info_v121['node_name'].value_counts().reset_index())
# Out:
#                  index  node_name
# 0                  太阳能      40766
# 1                   风能      26006
# 2              高效发电机制造      25172
# 3             节能风机风扇制造      21802
# 4                 水力发电      13809
# 5                新能源汽车       9979
# 6             海洋石油和天然气       9974
# 7        充电、换电、加氢和加气设施       9036
# 8          节能型气体压缩设备制造       8930
# 9             绿色高效照明产品       6985
# 10         雨水的收集、处理、利用       5748
# 11                  核能       4915
# 12            高效节能家用电器       4759
# 13            固体废物处理处置       4554
# 14                生物质能       4446
# 15                智能电网       3324
# 16               绿色畜牧业       3271
# 17                市政园林       3042
# 18                减振降噪       2876
# 19                园林绿化       2862
# 20                  氢能       2716
# 21                海绵城市       2066
# 22          海水、苦咸水淡化处理       2005
# 23                 地热能       1962
# 24              绿色建筑材料       1660
# 25                 海洋能       1249
# ...

# %% [markdown]
# # test_quanguo_score

# %%
test_quanguo_score=pd.read_sql('select * from test_quanguo_score',con=engine_retrain)
test_quanguo_score
# Out:
#                                company_id      company_name   seic_lv1  \
# 0        001EE90C50C0F16CA15D3BCCBFF14A0F  山东普时达创电子商务集团有限公司         其它
# 1        0024C93C237B20C2AB8FD2A5E20A4D3E      广东科建生物技术有限公司       生物产业
# 2        0027683A8AB4217205D5BE751D3A6D4E        杭州乙对纺织有限公司         其它
# 3        0034953AE8F88E6DD07C2809226C2A17       什邡艾美墅家居有限公司         其它
# 4        003D83E767259BB08EC3F13BA588C53D      佛山五合精密科技有限公司   高端装备制造产业
# ...                                   ...               ...        ...
# 1052035  FED7E3FAC46D1723AFFBE0FDFE415EF9    西安新济铁路机车配件有限公司   高端装备制造产业
# 1052036  FF41E884CA1DCE7CF71AE2905EAB3457      江苏迅杰环境工程有限公司     节能环保产业
# 1052037  FF828D60E29A82AAEC71B2E221B21C4D   深圳市盛俊智能家居科技有限公司  新一代信息技术产业
# 1052038  FFB8D187EF1495AE8D841BB8EFD7A970    宁波司普瑞茵通信技术有限公司  新一代信息技术产业
# 1052039  FFF08C781D50E5DDF36A0F6232CFBBAE    福建石全石美新型材料有限公司      新材料产业
#
#           seic_lv2 province city  apno_cnt  status     patent  nonpatent  \
# ...

# %% [markdown]
# ## 召回率

# %%
recall=pd.read_excel('对应公司id.xlsx')
recall
# Out:
#         company_name                        company_id
# 0         湘潭电机股份有限公司  69A9D0E155B10D4748BB44A5706DA59A
# 1     深圳市农产品集团股份有限公司  95E89A6C6F87BFB87686EADB0087FAD7
# 2         山东仙坛股份有限公司  E22F3A305CE24552C0716D8D94D899A3
# 3         中车永济电机有限公司  10AF2015F88959DAFDC44C94A2044329
# 4       浙江金盾风机股份有限公司  F832FEF7D8887D361E5E0D5965537FF0
# ...              ...                               ...
# 1197   河北思凯淋环保科技有限公司  F3531F33A600CC0A4BD74190BEF59092
# 1198  江苏吉鑫风能科技股份有限公司  860148A3B21B0E0F2DD055C3872483CB
# 1199    大唐国际发电股份有限公司  CFB5F0AB346AC4953F5DC5BCDEBA585D
# 1200      中国建筑股份有限公司  A9C0DE2FA43E988D38D280415DD5D22F
# 1201    晶科电力科技股份有限公司  156C4831A3D2BF488E7C8CDF1543C0E0
#
# [1202 rows x 2 columns]

# %%
recall=pd.merge(recall,INDUSTRY_green_company_info_v121,on='company_id',how='left')
recall
# Out:
#       company_name_x                        company_id       node_id  \
# 0         湘潭电机股份有限公司  69A9D0E155B10D4748BB44A5706DA59A  ND0000001070
# 1     深圳市农产品集团股份有限公司  95E89A6C6F87BFB87686EADB0087FAD7           NaN
# 2         山东仙坛股份有限公司  E22F3A305CE24552C0716D8D94D899A3           NaN
# 3         中车永济电机有限公司  10AF2015F88959DAFDC44C94A2044329  ND0000001087
# 4       浙江金盾风机股份有限公司  F832FEF7D8887D361E5E0D5965537FF0           NaN
# ...              ...                               ...           ...
# 1197   河北思凯淋环保科技有限公司  F3531F33A600CC0A4BD74190BEF59092           NaN
# 1198  江苏吉鑫风能科技股份有限公司  860148A3B21B0E0F2DD055C3872483CB  ND0000001070
# 1199    大唐国际发电股份有限公司  CFB5F0AB346AC4953F5DC5BCDEBA585D           NaN
# 1200      中国建筑股份有限公司  A9C0DE2FA43E988D38D280415DD5D22F           NaN
# 1201    晶科电力科技股份有限公司  156C4831A3D2BF488E7C8CDF1543C0E0  ND0000001072
#
#      node_name                                ans_id  company_name_y  \
# ...

# %%
recall['node_id'].notnull().sum()
# Out:
# 512

# %%
recall=pd.merge(recall,test_quanguo_score[['company_id','total']],on='company_id')
recall
# Out:
#       company_name_x                        company_id       node_id  \
# 0         湘潭电机股份有限公司  69A9D0E155B10D4748BB44A5706DA59A  ND0000001070
# 1     深圳市农产品集团股份有限公司  95E89A6C6F87BFB87686EADB0087FAD7           NaN
# 2         山东仙坛股份有限公司  E22F3A305CE24552C0716D8D94D899A3           NaN
# 3         中车永济电机有限公司  10AF2015F88959DAFDC44C94A2044329  ND0000001087
# 4       浙江金盾风机股份有限公司  F832FEF7D8887D361E5E0D5965537FF0           NaN
# ...              ...                               ...           ...
# 1196   河北思凯淋环保科技有限公司  F3531F33A600CC0A4BD74190BEF59092           NaN
# 1197  江苏吉鑫风能科技股份有限公司  860148A3B21B0E0F2DD055C3872483CB  ND0000001070
# 1198    大唐国际发电股份有限公司  CFB5F0AB346AC4953F5DC5BCDEBA585D           NaN
# 1199      中国建筑股份有限公司  A9C0DE2FA43E988D38D280415DD5D22F           NaN
# 1200    晶科电力科技股份有限公司  156C4831A3D2BF488E7C8CDF1543C0E0  ND0000001072
#
#      node_name                                ans_id  company_name_y  \
# ...

# %%
recall.to_excel('绿色产业链召回率.xlsx',encoding='utf-8',index=False)

# %%
a=512/1202
a
# Out:
# 0.4259567387687188

# %%
f1=(2*0.87*0.43)/(0.87+0.43)
f1
# Out:
# 0.5755384615384616

# %% [markdown]
# ## 太阳能

# %%
solar=INDUSTRY_green_company_info_v121[INDUSTRY_green_company_info_v121['node_name']=="太阳能"]
solar
# Out:
#              node_id node_name                                ans_id  \
# 50      ND0000001072       太阳能  39a6e912-7611-45b5-b933-0c4f93376bae
# 68      ND0000001072       太阳能  76caeb79-6813-448e-8b8f-9c8dd7bd880b
# 175     ND0000001072       太阳能  85afd289-e768-45ca-916e-0b7574e812df
# 255     ND0000001072       太阳能  5a897ccf-2cbb-4612-a2b9-605badc7dad6
# 275     ND0000001072       太阳能  c800c321-861c-4ed9-8a7f-e72b3323a1c2
# ...              ...       ...                                   ...
# 286356  ND0000001072       太阳能  a64d2067-c3fe-4429-9ea9-6de11394a19d
# 286357  ND0000001072       太阳能  bf63706a-dcc5-4c43-bad7-219cecb24502
# 286358  ND0000001072       太阳能  f89eac93-d83d-48da-8534-98486a13b2b1
# 286359  ND0000001072       太阳能  c80bee33-0142-4551-847b-e6dfc7ed80b8
# 286360  ND0000001072       太阳能  84a80366-383d-47d6-b34d-e949ca0a1280
#
#                               company_id      company_name      score  \
# ...

# %%
solar.drop_duplicates(subset=['company_id'],inplace=True)
solar
# Out:
#              node_id node_name                                ans_id  \
# 50      ND0000001072       太阳能  39a6e912-7611-45b5-b933-0c4f93376bae
# 68      ND0000001072       太阳能  76caeb79-6813-448e-8b8f-9c8dd7bd880b
# 175     ND0000001072       太阳能  85afd289-e768-45ca-916e-0b7574e812df
# 255     ND0000001072       太阳能  5a897ccf-2cbb-4612-a2b9-605badc7dad6
# 275     ND0000001072       太阳能  c800c321-861c-4ed9-8a7f-e72b3323a1c2
# ...              ...       ...                                   ...
# 286321  ND0000001072       太阳能  c732067b-1afa-4654-b6f6-a2f381218f51
# 286325  ND0000001072       太阳能  3e87bc77-31df-497a-98b2-4ab95650daca
# 286326  ND0000001072       太阳能  7a5d3e6f-9c23-400a-b218-e7a00130c43b
# 286350  ND0000001072       太阳能  c6e5657d-fb0d-47ca-9818-e2a68150f36d
# 286353  ND0000001072       太阳能  be0553bc-7c20-4188-b962-c7e5c5f6f313
#
#                               company_id      company_name      score  \
# ...

# %%
solar=solar.sample(n=28,random_state=None)
solar
# Out:
#              node_id node_name                                ans_id  \
# 93633   ND0000001072       太阳能  8604bd57-e52d-4b34-952a-ce1f153e72b4
# 184800  ND0000001072       太阳能  7109f60a-1530-4378-8ed2-d71ec26dccdf
# 38980   ND0000001072       太阳能  2e08fd61-8f74-4aca-b2f0-03d78c549168
# 206969  ND0000001072       太阳能  c36955c0-d882-4f50-8467-ad625ccfc97b
# 227986  ND0000001072       太阳能  803d4cc1-1ec2-4a81-b697-39e5b25dc404
# 152366  ND0000001072       太阳能  20b27d18-6f85-4417-821b-ccb078779c21
# 205848  ND0000001072       太阳能  8c90769e-9175-439c-a9cf-8be444ec12a5
# 277095  ND0000001072       太阳能  643c3dbf-253f-4dc0-8528-f178a0c18cd0
# 229626  ND0000001072       太阳能  311bd6e4-1ae7-4501-8e53-d1a4606e423e
# 17097   ND0000001072       太阳能  16582d28-d709-4668-b987-9efe1949b621
# 221219  ND0000001072       太阳能  185a18bb-9cd5-4791-8f2c-bd3e44d80673
# 198770  ND0000001072       太阳能  806b6462-ce4f-4d9d-82ec-d6df1341a129
# 197774  ND0000001072       太阳能  ec2d700e-4a43-46c2-81e7-de1416bc6c71
# ...

# %%
solar.to_excel('太阳能.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# ## 新能源汽车

# %%
New_car=INDUSTRY_green_company_info_v121[INDUSTRY_green_company_info_v121['node_name']=="新能源汽车"]
New_car.drop_duplicates(subset=['company_id'],inplace=True)
New_car=New_car.sample(n=26,random_state=None)
New_car
# Out:
#              node_id node_name                                ans_id  \
# 359509  ND0000001087     新能源汽车  83338a19-158e-4666-9234-a142fa9d0426
# 357477  ND0000001087     新能源汽车  fd5b87a0-fbbe-4b2b-970c-0b55040c1037
# 347150  ND0000001087     新能源汽车  38d557bb-deb4-467e-82f9-3aee32b1fa19
# 239588  ND0000001087     新能源汽车  2bf7e39a-f0b6-45a9-a2de-9dc60b6771b1
# 358979  ND0000001087     新能源汽车  71b577e1-6590-4859-834e-9ad1d168fca7
# 349211  ND0000001087     新能源汽车  0d460a9b-b3ff-4f00-a847-82fd24277d01
# 24721   ND0000001087     新能源汽车  84827bcf-d781-47d8-acb3-17b4b9c0f290
# 365533  ND0000001087     新能源汽车  fdf8fe7c-df86-450a-ae71-671c114ef6c9
# 313932  ND0000001087     新能源汽车  0d007964-37c0-408e-b780-73748e26a8c8
# 167125  ND0000001087     新能源汽车  2a3c3b69-d8c4-4621-8db0-d8f03ae18b4e
# 33426   ND0000001087     新能源汽车  4ab3ef18-4d79-49b9-884d-49a10a3c217a
# 171756  ND0000001087     新能源汽车  6d969ef8-8091-4a1c-bca7-f195f2ff5fb8
# 24027   ND0000001087     新能源汽车  fbb9e786-3c48-43f5-9a0f-069957fdc4b2
# ...

# %%
New_car.to_excel('新能源汽车.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# # INDUSTRY_green_patent_info_v121

# %%
INDUSTRY_green_patent_info_v121=pd.read_sql('select * from INDUSTRY_green_patent_info_v121',con=engine_chain)

# %%
INDUSTRY_green_patent_info_v121_1=INDUSTRY_green_patent_info_v121[INDUSTRY_green_patent_info_v121['valid_indicator']==1]
INDUSTRY_green_patent_info_v121_1
# Out:
#               node_id node_name                             patent_id  \
# 0        ND0000001087     新能源汽车  ee3b9361-cd2a-43e5-a653-90d948a08a41
# 1        ND0000001087     新能源汽车  6319ac0f-9318-4b25-891b-958f845cb1b3
# 2        ND0000001087     新能源汽车  2fb79e03-66dd-443e-bbc0-360abfcc3576
# 3        ND0000001087     新能源汽车  8070744f-d5b2-4ed6-96d0-dbd916843257
# 4        ND0000001087     新能源汽车  056e6892-4fc4-4f7e-bc10-3f745f3754c5
# ...               ...       ...                                   ...
# 2781258  ND0000001072       太阳能  8ef54497-414c-40bd-872d-2c16f5999176
# 2781260  ND0000001072       太阳能  b5a75b2d-c96b-47a2-9ad3-63354fe2f556
# 2781261  ND0000001072       太阳能  21455093-8e0e-477d-aff3-2537b90eff75
# 2781262  ND0000001072       太阳能  4cf80b06-1720-4b5d-a188-7edc91f5ce95
# 2781263  ND0000001072       太阳能  ceb3ca70-998b-4b51-bba2-0c811c9e0aa7
#
#              score  valid_indicator                                  ans_id  \
# ...

# %%
INDUSTRY_green_patent_info_v121_1.query('apno=="[CN201610817154.9]"')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j4/dk74yxrs5dx24vbjm9496s3r0000gn/T/ipykernel_90538/586827054.py in <module>
# ----> 1 INDUSTRY_green_patent_info_v121_1.query('apno=="[CN201610817154.9]"')
#
# NameError: name 'INDUSTRY_green_patent_info_v121_1' is not defined

# %%
pd.DataFrame(INDUSTRY_green_patent_info_v121['node_name'].value_counts().reset_index()).to_excel('node.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# ## 太阳能

# %%
solar=INDUSTRY_green_patent_info_v121_1[INDUSTRY_green_patent_info_v121_1['node_name']=="太阳能"]
solar=solar.sample(n=30,random_state=None)
solar
# Out:
#               node_id node_name                             patent_id  \
# 416198   ND0000001072       太阳能  f5e05ae8-2fe8-4356-8330-a69f5657bc19
# 424694   ND0000001072       太阳能  b1f35b73-bc7c-4ee7-ac9f-5e82a8318914
# 2231475  ND0000001072       太阳能  ae0f24a7-4ecd-4f34-9477-1b077738d7ef
# 1529137  ND0000001072       太阳能  9f563136-307a-4301-8bfe-37772577e095
# 387761   ND0000001072       太阳能  91b95054-dab5-46c7-a592-8e3b2158c43e
# 999441   ND0000001072       太阳能  480b4438-d275-48f6-ac15-8b0938f702de
# 1751316  ND0000001072       太阳能  a25d1ec3-3376-49dc-8f93-7f7989800b8f
# 2050602  ND0000001072       太阳能  f6556edb-88f3-4a37-b50c-01ec1af04ff2
# 1794021  ND0000001072       太阳能  dfdfe883-81fa-4938-82a0-45350da495be
# 2726657  ND0000001072       太阳能  0bd04f6a-ddb9-4958-8da6-f178d587c8e6
# 1835564  ND0000001072       太阳能  9a1eb18e-78c2-4fad-8c97-b3808d6d2a4c
# 451189   ND0000001072       太阳能  8b2437a7-f4fa-4225-888d-1d9cf2621317
# ...

# %%
solar.to_excel('太阳能专利.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# ## 新能源汽车

# %%
New_car=INDUSTRY_green_patent_info_v121_1[INDUSTRY_green_patent_info_v121_1['node_name']=="新能源汽车"]
New_car=New_car.sample(n=25,random_state=None)
New_car
# Out:
#               node_id node_name                             patent_id  \
# 1951272  ND0000001087     新能源汽车  c0d170bd-5e41-479b-8154-2cc6bcc92c1c
# 438282   ND0000001087     新能源汽车  92053bab-785d-4700-bb6f-fc5b587a9355
# 2347196  ND0000001087     新能源汽车  a458c2b6-43d2-4563-a656-72f2c050bbf2
# 413625   ND0000001087     新能源汽车  84e7ea28-9e7d-471f-be21-5faf9425f8a6
# 2256767  ND0000001087     新能源汽车  6cb659d6-0940-426e-92d1-c4fb4ea38d4a
# 1065304  ND0000001087     新能源汽车  9bf4421f-b999-4f32-b2a8-8ba5ae64678e
# 2328445  ND0000001087     新能源汽车  3477e705-04c9-4f11-90f6-75784d2b9133
# 2350426  ND0000001087     新能源汽车  03bda502-cb4a-45d0-9871-77450dda84b1
# 2456405  ND0000001087     新能源汽车  06deb010-ad8d-49fd-bcbb-85a6524f3fb7
# 2356465  ND0000001087     新能源汽车  3bd7e4c4-adf7-4e0e-b326-af6dfda73400
# 994167   ND0000001087     新能源汽车  052874f5-3ee9-41f3-88bc-10725b9bd5e2
# 2711673  ND0000001087     新能源汽车  755de263-4e58-4129-bfae-63c7eb4d1322
# ...

# %%
New_car.to_excel('新能源汽车专利.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# # 按专利数量排序

# %%
company=INDUSTRY_green_company_info_v121
company
# Out:
#              node_id node_name                                ans_id  \
# 0       ND0000001040      生态农业  e8a3a9f4-9990-4979-a1e4-dd532d54de50
# 1       ND0000001040      生态农业  b7676860-6f4a-46af-b94f-5e9c874dbb8c
# 2       ND0000001040      生态农业  45d17bf6-dea5-4c2c-b890-90920d527045
# 3       ND0000001075      生物质能  45d17bf6-dea5-4c2c-b890-90920d527045
# 4       ND0000001040      生态农业  185a7ba8-c5e7-4ff0-92ea-71db1cf4e7a1
# ...              ...       ...                                   ...
# 383682  ND0000001090      共享交通  822bed91-a211-471d-b15d-418a8d6183ce
# 383683  ND0000001090      共享交通  632fa5d6-88cb-483c-b187-00f3b9dc544d
# 383684  ND0000001090      共享交通  499fc765-46a2-49c5-a545-a4a8de690b3e
# 383685  ND0000001090      共享交通  150a9fda-bb80-4e35-ab70-43c1bf271177
# 383686  ND0000001090      共享交通  b3687a59-eefc-4cd7-9ac3-583cb65a5fbf
#
#                               company_id      company_name      score  \
# ...

# %%
company_node=company.groupby(['node_name','company_name','seic_lv2']).agg({'score':'count'}).reset_index().rename(columns={'score':'apno'})
company_node
# Out:
#           node_name       company_name       seic_lv2  apno
# 0      不停车收费系统（ETC）       上海依图网络科技有限公司           人工智能     1
# 1      不停车收费系统（ETC）       上海北汇信息科技有限公司  新兴软件和新型信息技术服务     1
# 2      不停车收费系统（ETC）   上海博泰悦臻网络技术服务有限公司  互联网与云计算、大数据服务     2
# 3      不停车收费系统（ETC）       上海搜林信息技术有限公司  互联网与云计算、大数据服务    10
# 4      不停车收费系统（ETC）       上海擎感智能科技有限公司      下一代信息网络产业     2
# ...             ...                ...            ...   ...
# 97980      高效节能家用电器       鼎信阳光环境技术有限公司         高效节能产业     2
# 97981      高效节能家用电器     龙创信恒（北京）科技有限公司         高效节能产业     3
# 97982      高效节能家用电器        龙岩市锥形电机有限公司       智能制造装备产业     1
# 97983      高效节能家用电器     龙钜清洁科技（西安）有限公司         先进环保产业     1
# 97984      高效节能家用电器  ＴＣＬ瑞智（惠州）制冷设备有限公司       智能制造装备产业     3
#
# [97985 rows x 4 columns]

# %%
company_node[company_node['node_name']=="太阳能"].sort_values('apno',ascending=False).head(100)
# Out:
#       node_name           company_name  seic_lv2  apno
# 17148       太阳能               国家电网有限公司    智能电网产业  3117
# 30032       太阳能        阿特斯阳光电力集团股份有限公司     太阳能产业   902
# 28879       太阳能        苏州阿特斯阳光电力科技有限公司     太阳能产业   893
# 13486       太阳能              东君新能源有限公司     太阳能产业   761
# 13839       太阳能          中国电力科学研究院有限公司    智能电网产业   714
# 13810       太阳能    中国华能集团清洁能源技术研究院有限公司     太阳能产业   634
# 25136       太阳能             浙江晶科能源有限公司     太阳能产业   607
# 25248       太阳能          浙江爱旭太阳能科技有限公司     太阳能产业   574
# 27583       太阳能           珠海格力电器股份有限公司    高效节能产业   566
# 19577       太阳能        常熟阿特斯阳光电力科技有限公司    智能电网产业   555
# 21859       太阳能             晶科能源股份有限公司     太阳能产业   555
# 19881       太阳能             广东爱旭科技有限公司     太阳能产业   546
# 17386       太阳能             天合光能股份有限公司     太阳能产业   505
# 24690       太阳能         泰州隆基乐叶光伏科技有限公司     太阳能产业   473
# 30020       太阳能             阳光电源股份有限公司     太阳能产业   449
# 13279       太阳能             上海祖强能源有限公司     太阳能产业   443
# ...

# %%
company_node.to_sql('INDUSTRY_green_Inter_company_info_v120',con=engine_chain,index=False,if_exists='replace')
